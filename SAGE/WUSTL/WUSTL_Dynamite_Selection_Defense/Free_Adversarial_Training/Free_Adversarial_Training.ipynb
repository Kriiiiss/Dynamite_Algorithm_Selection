# %%
import numpy as np
import pandas as pd

from sklearn.metrics import accuracy_score, precision_recall_fscore_support, roc_auc_score, confusion_matrix
from sklearn.preprocessing import label_binarize

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset


import time

# %%
head = {
            "model" : '',
            "attack_model": '',
            'epsilon': '',
            'Accuracy': '',
            'Macro Precision': '',
            'Weighted Precision': '',
            'Macro Recall': '',
            'Weighted Recall': '',
            'Macro F1': '',
            'Weighted F1': '',

        }
head = pd.DataFrame([head])
head.to_csv("./Free_Adversarial_Training.csv", mode='a', index=False)

# %%
def calculate_performance_metrics(X_test, y_test, model, model_name, attack_name, eps):
    model.eval()
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.to(device)
    
    all_preds = []
    all_labels = []
    probabilities = []

    num_classes = len(np.unique(y_test))
    
    X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
    y_test_tensor = torch.tensor(y_test, dtype=torch.long)
    test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
    test_loader = DataLoader(dataset=test_dataset)

    with torch.no_grad():
        
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            preds = torch.argmax(outputs, dim=1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            probabilities.extend(torch.nn.functional.softmax(outputs, dim=1).cpu().numpy())
        
        all_preds = np.array(all_preds)
        all_labels = np.array(all_labels)
        probabilities = np.array(probabilities)
        
        accuracy = accuracy_score(all_labels, all_preds)

        precision_macro, recall_macro, f1_macro, _ = precision_recall_fscore_support(all_labels, all_preds, average='macro')
        precision_weighted, recall_weighted, f1_weighted, _ = precision_recall_fscore_support(all_labels, all_preds, average='weighted')
    

        print(f"Accuracy: {accuracy}")
        
        print("\nmacro")
        print(f"Precision: {precision_macro}\nRecall: {recall_macro}\nF1 Score: {f1_macro}")
    
        print("\nweighted")
        print(f"Precision: {precision_weighted}\nRecall: {recall_weighted}\nF1 Score: {f1_weighted}")
        print()
        

        new_row = {
            "model" : model_name,
            "attack_model" : attack_name,
            'epsilon': eps,
            'Accuracy': accuracy,
            'Macro Precision': precision_macro,
            'Weighted Precision': precision_weighted,
            'Macro Recall': recall_macro,
            'Weighted Recall': recall_weighted,
            'Macro F1': f1_macro,
            'Weighted F1': f1_weighted,

        }
        new_row_df = pd.DataFrame([new_row])
        new_row_df.to_csv("./Free_Adversarial_Training.csv", mode='a', index=False, header=False)

# %%
# def calculate_performance_metrics(X_test, y_test, model, model_name, attack_name, eps):
#     model.eval()
#     device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#     model.to(device)
    
#     all_preds = []
#     all_labels = []
#     probabilities = []

#     num_classes = len(np.unique(y_test))
    
#     X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
#     y_test_tensor = torch.tensor(y_test, dtype=torch.long)
#     test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
#     test_loader = DataLoader(dataset=test_dataset)

#     with torch.no_grad():
        
#         for inputs, labels in test_loader:
#             inputs, labels = inputs.to(device), labels.to(device)
#             outputs = model(inputs)
#             preds = torch.argmax(outputs, dim=1)
#             all_preds.extend(preds.cpu().numpy())
#             all_labels.extend(labels.cpu().numpy())
#             probabilities.extend(torch.nn.functional.softmax(outputs, dim=1).cpu().numpy())
        
#         all_preds = np.array(all_preds)
#         all_labels = np.array(all_labels)
#         probabilities = np.array(probabilities)

#         np.save(f"/home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Defense_Label/WUSTL_Def4/y_pred_{attack_name}{eps}_Def4.npy", all_preds)

# %%
x_test = np.load('/home/jovyan/Sample_Based_Extension/WUSTL/x_test.npy')
x_train = np.load('/home/jovyan/Sample_Based_Extension/WUSTL/x_train.npy')
x_val = np.load('/home/jovyan/Sample_Based_Extension/WUSTL/x_val.npy')
y_test = np.load('/home/jovyan/Sample_Based_Extension/WUSTL/y_test.npy')
y_train = np.load('/home/jovyan/Sample_Based_Extension/WUSTL/y_train.npy')
y_val = np.load('/home/jovyan/Sample_Based_Extension/WUSTL/y_val.npy')

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
input_shape = x_train.shape[1]
output_shape = len(np.unique(y_train))

# %%
x_train_tensor = torch.tensor(x_train, dtype=torch.float32).to(device)
y_train_tensor = torch.tensor(y_train, dtype=torch.long).to(device)

x_val_tensor = torch.tensor(x_val, dtype=torch.float32).to(device)
y_val_tensor = torch.tensor(y_val, dtype=torch.long).to(device)

train_dataset = TensorDataset(x_train_tensor, y_train_tensor)
train_loader = DataLoader(train_dataset, batch_size=100, shuffle=True)

val_dataset = TensorDataset(x_val_tensor, y_val_tensor)
val_loader = DataLoader(val_dataset, batch_size=100, shuffle=True)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

class DNNModel(nn.Module):
    def __init__(self, input_size, output_size):
        super(DNNModel, self).__init__()
        self.fc1 = nn.Linear(input_size, 50)
        self.fc2 = nn.Linear(50, 30)
        self.fc3 = nn.Linear(30, 20)
        self.fc4 = nn.Linear(20, output_size)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = self.fc4(x)
        return x

# %%
def fgsm(grad, epsilon):
    sign_grad = grad.sign()
    return epsilon * sign_grad

# %%
# Initialize model, optimizer, and loss function
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = DNNModel(input_size=input_shape, output_size=output_shape).to(device)
optimizer = optim.Adam(model.parameters(), lr=0.001)
loss_function = nn.CrossEntropyLoss()

# Early stopping variables
min_delta = 0.001
patience = 5
patience_counter = 0
best_loss = float('inf')

# Adversarial training parameters
epsilon = 0.03  # Step size for FGSM
clip_eps = 0.1  # Maximum perturbation
n_repeats = 4   # Number of iterations to update noise

global_noise_data = torch.zeros(train_loader.batch_size, input_shape).to(device)

# %%
# from torch.autograd import Variable


# for epoch in range(10):
#     model.train()
#     train_loss = 0.0
#     for inputs, labels in train_loader:
#         inputs, labels = inputs.to(device), labels.to(device)
#         for j in range(n_repeats):
#             noise_batch = Variable(global_noise_data[0:inputs.size(0)], requires_grad=True).to(device)
#             inputs_adv = inputs + noise_batch
#             inputs_adv.clamp_(0, 1.0)
#             optimizer.zero_grad()
#             outputs = model(inputs_adv)
#             loss = loss_function(outputs, labels)
#             loss.backward()
#             pert = fgsm(noise_batch.grad, epsilon)
#             global_noise_data[0:inputs.size(0)] += pert.data
#             global_noise_data.clamp_(-clip_eps, clip_eps)
#             optimizer.step()
#             train_loss += loss.item()

#     avg_train_loss = train_loss / len(train_loader)

#     model.eval()
#     val_train_loss = 0.0
#     correct_predictions = 0
#     with torch.no_grad():
#         for inputs, labels in val_loader:
#             inputs, labels = inputs.to(device), labels.to(device)
#             outputs = model(inputs)
#             loss = loss_function(outputs, labels)
#             val_train_loss += loss.item()
#             _, predicted = torch.max(outputs.data, 1)
#             correct_predictions += (predicted == labels).sum().item()

#     avg_val_loss = val_train_loss / len(val_loader)
#     val_accuracy = correct_predictions / len(val_dataset)

#     print(f"Epoch {epoch+1}, Training Loss: {avg_train_loss:.4f}, Validation Loss: {avg_val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}")

#     # Early stopping check using min_delta
#     if best_loss - avg_val_loss > min_delta:
#         best_loss = avg_val_loss
#         patience_counter = 0
#     else:
#         patience_counter += 1

#     if patience_counter >= patience:
#         print("Early stopping triggered")
#         break

# %%
model.load_state_dict(torch.load("/home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Defense/Free_Adversarial_Training/Free_Adversarial_Training.pt"))
# Out:
# /tmp/ipykernel_17071/1171431382.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("/home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Defense/Free_Adversarial_Training/Free_Adversarial_Training.pt"))
# <All keys matched successfully>

# %%
# calculate_performance_metrics(x_test, y_test, model, 'DNN', 'baseline', '0')

# %%
def print_empty_file():
    new_row = {
        "model" : "0",
        "attack_model" : "0",
        'epsilon': "0",
        'Accuracy': "0",
        'Macro Precision': "0",
        'Weighted Precision': "0",
        'Macro Recall': "0",
        'Weighted Recall': "0",
        'Macro F1': "0",
        'Weighted F1': "0",
    }
    new_row_df = pd.DataFrame([new_row])
    new_row_df.to_csv("./Free_Adversarial_Training.csv", mode='a', index=False, header=False)

# %%
epsilon = 0
Def = "Def4"
attack_names = [
    "baseline", "BIM", "FGSM", "PGD", "DF",
    "AutoPGD", "ZOO", "CaFA", "SINIFGSM", "VNIFGSM"
]

percentage = ["100", "50", "20", "10", "1"]
model_name = ["XGB", "RF" ]

base_path = "/home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data"

for m_name in model_name:
    for p in percentage:
        for attack in attack_names:
            print(f"start {m_name} {p} {attack}")
            
            x_path = f"{base_path}/{m_name}/WUSTL_Input{p}/x_test_adv_{attack}_{Def}.npy"
            y_path = f"{base_path}/{m_name}/WUSTL_Input{p}/y_test_adv_{attack}_{Def}.npy"

            try:
                x_test_adv = np.load(x_path)
                y_test_adv = np.load(y_path)
                print(x_test_adv.shape, y_test_adv.shape)

                m_per_name = f"{m_name}{p}"
                calculate_performance_metrics(x_test_adv, y_test_adv, model, m_per_name, attack, epsilon)
            except FileNotFoundError:
                print(x_path, "not found")
                print_empty_file()
# Out:
# start XGB 100 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input100/x_test_adv_baseline_Def4.npy not found
# start XGB 100 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input100/x_test_adv_BIM_Def4.npy not found
# start XGB 100 FGSM
# (6, 42) (6,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 100 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input100/x_test_adv_PGD_Def4.npy not found
# start XGB 100 DF
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (6, 42) (6,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 AutoPGD
# (51, 42) (51,)
# Accuracy: 0.8627450980392157
#
# macro
# Precision: 0.3333333333333333
# Recall: 0.28758169934640526
# F1 Score: 0.3087719298245614
#
# weighted
# Precision: 1.0
# Recall: 0.8627450980392157
# F1 Score: 0.9263157894736842
#
# start XGB 100 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input100/x_test_adv_ZOO_Def4.npy not found
# start XGB 100 CaFA
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (42357, 42) (42357,)
# Accuracy: 0.8724886087305522
#
# macro
# Precision: 0.7622442595048153
# Recall: 0.703443735141938
# F1 Score: 0.6218680982902219
#
# weighted
# Precision: 0.9651269327925835
# Recall: 0.8724886087305522
# F1 Score: 0.9128295010600288
#
# start XGB 100 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input100/x_test_adv_SINIFGSM_Def4.npy not found
# start XGB 100 VNIFGSM
# (1, 42) (1,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input50/x_test_adv_baseline_Def4.npy not found
# start XGB 50 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input50/x_test_adv_BIM_Def4.npy not found
# start XGB 50 FGSM
# (23, 42) (23,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 50 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input50/x_test_adv_PGD_Def4.npy not found
# start XGB 50 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input50/x_test_adv_DF_Def4.npy not found
# start XGB 50 AutoPGD
# (2, 42) (2,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 50 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input50/x_test_adv_ZOO_Def4.npy not found
# start XGB 50 CaFA
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (43137, 42) (43137,)
# Accuracy: 0.8550664163015509
#
# macro
# Precision: 0.7519971458094024
# Recall: 0.7114464194131076
# F1 Score: 0.6246609595218551
#
# weighted
# Precision: 0.962070544299361
# Recall: 0.8550664163015509
# F1 Score: 0.9015646042903148
#
# start XGB 50 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input50/x_test_adv_SINIFGSM_Def4.npy not found
# start XGB 50 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input50/x_test_adv_VNIFGSM_Def4.npy not found
# start XGB 20 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input20/x_test_adv_baseline_Def4.npy not found
# start XGB 20 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input20/x_test_adv_BIM_Def4.npy not found
# start XGB 20 FGSM
# (5, 42) (5,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 20 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input20/x_test_adv_PGD_Def4.npy not found
# start XGB 20 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input20/x_test_adv_DF_Def4.npy not found
# start XGB 20 AutoPGD
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (1, 42) (1,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 20 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input20/x_test_adv_ZOO_Def4.npy not found
# start XGB 20 CaFA
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (39872, 42) (39872,)
# Accuracy: 0.8745234751203852
#
# macro
# Precision: 0.7421238041249181
# Recall: 0.6872567003406148
# F1 Score: 0.6133866608552856
#
# weighted
# Precision: 0.9628747455032903
# Recall: 0.8745234751203852
# F1 Score: 0.9133512346150625
#
# start XGB 20 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input20/x_test_adv_SINIFGSM_Def4.npy not found
# start XGB 20 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input20/x_test_adv_VNIFGSM_Def4.npy not found
# start XGB 10 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input10/x_test_adv_baseline_Def4.npy not found
# start XGB 10 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input10/x_test_adv_BIM_Def4.npy not found
# start XGB 10 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input10/x_test_adv_FGSM_Def4.npy not found
# start XGB 10 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input10/x_test_adv_PGD_Def4.npy not found
# start XGB 10 DF
# (34, 42) (34,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 10 AutoPGD
# (4, 42) (4,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 10 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input10/x_test_adv_ZOO_Def4.npy not found
# start XGB 10 CaFA
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (34849, 42) (34849,)
# Accuracy: 0.8881460013199804
#
# macro
# Precision: 0.70633622569034
# Recall: 0.6410721883703921
# F1 Score: 0.5729550367394318
#
# weighted
# Precision: 0.9515365078917221
# Recall: 0.8881460013199804
# F1 Score: 0.9152511016492524
#
# start XGB 10 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input10/x_test_adv_SINIFGSM_Def4.npy not found
# start XGB 10 VNIFGSM
# (1, 42) (1,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 1 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input1/x_test_adv_baseline_Def4.npy not found
# start XGB 1 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input1/x_test_adv_BIM_Def4.npy not found
# start XGB 1 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input1/x_test_adv_FGSM_Def4.npy not found
# start XGB 1 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input1/x_test_adv_PGD_Def4.npy not found
# start XGB 1 DF
# (10, 42) (10,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 1 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input1/x_test_adv_AutoPGD_Def4.npy not found
# start XGB 1 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input1/x_test_adv_ZOO_Def4.npy not found
# start XGB 1 CaFA
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (32129, 42) (32129,)
# Accuracy: 0.8890410532540696
#
# macro
# Precision: 0.6848724168692655
# Recall: 0.6699079388338026
# F1 Score: 0.582313644370812
#
# weighted
# Precision: 0.9347573049685581
# Recall: 0.8890410532540696
# F1 Score: 0.9073868373802567
#
# start XGB 1 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input1/x_test_adv_SINIFGSM_Def4.npy not found
# start XGB 1 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input1/x_test_adv_VNIFGSM_Def4.npy not found
# start RF 100 baseline
# (1, 42) (1,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input100/x_test_adv_BIM_Def4.npy not found
# start RF 100 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input100/x_test_adv_FGSM_Def4.npy not found
# start RF 100 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input100/x_test_adv_PGD_Def4.npy not found
# start RF 100 DF
# (34, 42) (34,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input100/x_test_adv_AutoPGD_Def4.npy not found
# start RF 100 ZOO
# (3, 42) (3,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 CaFA
# (15757, 42) (15757,)
# Accuracy: 0.9536079202893952
#
# macro
# Precision: 0.7840339812333236
# Recall: 0.7190446604380064
# F1 Score: 0.672674293070315
#
# weighted
# Precision: 0.9676116732790065
# Recall: 0.9536079202893952
# F1 Score: 0.9542049366591338
#
# start RF 100 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input100/x_test_adv_SINIFGSM_Def4.npy not found
# start RF 100 VNIFGSM
# (15, 42) (15,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input50/x_test_adv_baseline_Def4.npy not found
# start RF 50 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input50/x_test_adv_BIM_Def4.npy not found
# start RF 50 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input50/x_test_adv_FGSM_Def4.npy not found
# start RF 50 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input50/x_test_adv_PGD_Def4.npy not found
# start RF 50 DF
# (34, 42) (34,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input50/x_test_adv_AutoPGD_Def4.npy not found
# start RF 50 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input50/x_test_adv_ZOO_Def4.npy not found
# start RF 50 CaFA
# (15417, 42) (15417,)
# Accuracy: 0.9488875916196406
#
# macro
# Precision: 0.7591793079189715
# Recall: 0.6736421265617375
# F1 Score: 0.6057817680453862
#
# weighted
# Precision: 0.9686502886893189
# Recall: 0.9488875916196406
# F1 Score: 0.9488806989681547
#
# start RF 50 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input50/x_test_adv_SINIFGSM_Def4.npy not found
# start RF 50 VNIFGSM
# (6, 42) (6,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input20/x_test_adv_baseline_Def4.npy not found
# start RF 20 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input20/x_test_adv_BIM_Def4.npy not found
# start RF 20 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input20/x_test_adv_FGSM_Def4.npy not found
# start RF 20 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input20/x_test_adv_PGD_Def4.npy not found
# start RF 20 DF
# (37, 42) (37,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input20/x_test_adv_AutoPGD_Def4.npy not found
# start RF 20 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input20/x_test_adv_ZOO_Def4.npy not found
# start RF 20 CaFA
# (15801, 42) (15801,)
# Accuracy: 0.9446237579900006
#
# macro
# Precision: 0.7543808109282069
# Recall: 0.6535309098081531
# F1 Score: 0.5916764606061438
#
# weighted
# Precision: 0.9602619504549927
# Recall: 0.9446237579900006
# F1 Score: 0.9409452972153011
#
# start RF 20 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input20/x_test_adv_SINIFGSM_Def4.npy not found
# start RF 20 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input20/x_test_adv_VNIFGSM_Def4.npy not found
# start RF 10 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input10/x_test_adv_baseline_Def4.npy not found
# start RF 10 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input10/x_test_adv_BIM_Def4.npy not found
# start RF 10 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input10/x_test_adv_FGSM_Def4.npy not found
# start RF 10 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input10/x_test_adv_PGD_Def4.npy not found
# start RF 10 DF
# (37, 42) (37,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 10 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input10/x_test_adv_AutoPGD_Def4.npy not found
# start RF 10 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input10/x_test_adv_ZOO_Def4.npy not found
# start RF 10 CaFA
# (15465, 42) (15465,)
# Accuracy: 0.9361784675072745
#
# macro
# Precision: 0.7291482590935277
# Recall: 0.6585459412643105
# F1 Score: 0.5673510572277759
#
# weighted
# Precision: 0.9603162640786429
# Recall: 0.9361784675072745
# F1 Score: 0.9315433418009481
#
# start RF 10 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input10/x_test_adv_SINIFGSM_Def4.npy not found
# start RF 10 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input10/x_test_adv_VNIFGSM_Def4.npy not found
# start RF 1 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input1/x_test_adv_baseline_Def4.npy not found
# start RF 1 BIM
# (1, 42) (1,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 1 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input1/x_test_adv_FGSM_Def4.npy not found
# start RF 1 PGD
# (1, 42) (1,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 1 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input1/x_test_adv_DF_Def4.npy not found
# start RF 1 AutoPGD
# (266, 42) (266,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 1 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input1/x_test_adv_ZOO_Def4.npy not found
# start RF 1 CaFA
# (14808, 42) (14808,)
# Accuracy: 0.9376012965964343
#
# macro
# Precision: 0.7147846616111031
# Recall: 0.6047604685433371
# F1 Score: 0.536556201756754
#
# weighted
# Precision: 0.9552893466958458
# Recall: 0.9376012965964343
# F1 Score: 0.9314640926662191
#
# start RF 1 SINIFGSM
# (72, 42) (72,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 1 VNIFGSM
# (5, 42) (5,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0

# %%
epsilon = 0
Def = "Def4"
attack_names = [
    "baseline", "BIM", "FGSM", "PGD", "DF",
    "AutoPGD", "ZOO", "CaFA", "SINIFGSM", "VNIFGSM"
]

percentage = ["100", "50", "20", "10", "1"]
model_name = ["XGB", "RF" ]

base_path = "/home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data"

for m_name in model_name:
    for p in percentage:
        for attack in attack_names:
            print(f"start {m_name} {p} {attack}")
            
            x_path = f"{base_path}/{m_name}_ExcludeCaFA/WUSTL_Input{p}/x_test_adv_{attack}_{Def}.npy"
            y_path = f"{base_path}/{m_name}_ExcludeCaFA/WUSTL_Input{p}/y_test_adv_{attack}_{Def}.npy"

            try:
                x_test_adv = np.load(x_path)
                y_test_adv = np.load(y_path)
                print(x_test_adv.shape, y_test_adv.shape)

                m_per_name = f"{m_name}{p}_ExcludeCaFA"
                calculate_performance_metrics(x_test_adv, y_test_adv, model, m_per_name, attack, epsilon)
            except FileNotFoundError:
                print(x_path, "not found")
                print_empty_file()
# Out:
# start XGB 100 baseline
# (1, 42) (1,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input100/x_test_adv_BIM_Def4.npy not found
# start XGB 100 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input100/x_test_adv_FGSM_Def4.npy not found
# start XGB 100 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input100/x_test_adv_PGD_Def4.npy not found
# start XGB 100 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input100/x_test_adv_DF_Def4.npy not found
# start XGB 100 AutoPGD
# (3, 42) (3,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 ZOO
# (4, 42) (4,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 CaFA
# (62, 42) (62,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.16129032258064516
#
# macro
# Precision: 0.2590909090909091
# Recall: 0.3207070707070707
# F1 Score: 0.1469298245614035
#
# weighted
# Precision: 0.4533724340175953
# Recall: 0.16129032258064516
# F1 Score: 0.1989247311827957
#
# start XGB 100 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input100/x_test_adv_SINIFGSM_Def4.npy not found
# start XGB 100 VNIFGSM
# (1, 42) (1,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 50 baseline
# (1, 42) (1,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input50/x_test_adv_BIM_Def4.npy not found
# start XGB 50 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input50/x_test_adv_FGSM_Def4.npy not found
# start XGB 50 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input50/x_test_adv_PGD_Def4.npy not found
# start XGB 50 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input50/x_test_adv_DF_Def4.npy not found
# start XGB 50 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input50/x_test_adv_AutoPGD_Def4.npy not found
# start XGB 50 ZOO
# (3, 42) (3,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 CaFA
# (6, 42) (6,)
# Accuracy: 0.16666666666666666
#
# macro
# Precision: 0.08333333333333333
# Recall: 0.5
# F1 Score: 0.14285714285714285
#
# weighted
# Precision: 0.027777777777777776
# Recall: 0.16666666666666666
# F1 Score: 0.047619047619047616
#
# start XGB 50 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input50/x_test_adv_SINIFGSM_Def4.npy not found
# start XGB 50 VNIFGSM
# (2, 42) (2,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 20 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input20/x_test_adv_baseline_Def4.npy not found
# start XGB 20 BIM
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (74, 42) (74,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 20 FGSM
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (91, 42) (91,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.7582417582417582
#
# macro
# Precision: 0.4852941176470588
# Recall: 0.44485294117647056
# F1 Score: 0.46143250688705234
#
# weighted
# Precision: 0.9127343244990305
# Recall: 0.7582417582417582
# F1 Score: 0.8251142796597342
#
# start XGB 20 PGD
# (74, 42) (74,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 20 DF
# (38, 42) (38,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 AutoPGD
# (226, 42) (226,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.2168141592920354
#
# macro
# Precision: 0.14411764705882352
# Recall: 0.06012269938650307
# F1 Score: 0.08484848484848485
#
# weighted
# Precision: 0.5197162935970848
# Recall: 0.2168141592920354
# F1 Score: 0.30598015553767766
#
# start XGB 20 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input20/x_test_adv_ZOO_Def4.npy not found
# start XGB 20 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input20/x_test_adv_CaFA_Def4.npy not found
# start XGB 20 SINIFGSM
# (2, 42) (2,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 20 VNIFGSM
# (9, 42) (9,)
# Accuracy: 0.3333333333333333
#
# macro
# Precision: 0.25
# Recall: 0.09375
# F1 Score: 0.13636363636363635
#
# weighted
# Precision: 0.8888888888888888
# Recall: 0.3333333333333333
# F1 Score: 0.4848484848484848
#
# start XGB 10 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input10/x_test_adv_baseline_Def4.npy not found
# start XGB 10 BIM
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (1181, 42) (1181,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 10 FGSM
# (6, 42) (6,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 10 PGD
# (1181, 42) (1181,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 10 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input10/x_test_adv_DF_Def4.npy not found
# start XGB 10 AutoPGD
# (50038, 42) (50038,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.0006395139693832687
#
# macro
# Precision: 0.1641025641025641
# Recall: 0.00012813069330717332
# F1 Score: 0.0002560614547491398
#
# weighted
# Precision: 0.8190534168390996
# Recall: 0.0006395139693832687
# F1 Score: 0.0012780300574827914
#
# start XGB 10 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input10/x_test_adv_ZOO_Def4.npy not found
# start XGB 10 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input10/x_test_adv_CaFA_Def4.npy not found
# start XGB 10 SINIFGSM
# (4, 42) (4,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 10 VNIFGSM
# (36, 42) (36,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 1 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input1/x_test_adv_baseline_Def4.npy not found
# start XGB 1 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input1/x_test_adv_BIM_Def4.npy not found
# start XGB 1 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input1/x_test_adv_FGSM_Def4.npy not found
# start XGB 1 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input1/x_test_adv_PGD_Def4.npy not found
# start XGB 1 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input1/x_test_adv_DF_Def4.npy not found
# start XGB 1 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input1/x_test_adv_AutoPGD_Def4.npy not found
# start XGB 1 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input1/x_test_adv_ZOO_Def4.npy not found
# start XGB 1 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input1/x_test_adv_CaFA_Def4.npy not found
# start XGB 1 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input1/x_test_adv_SINIFGSM_Def4.npy not found
# start XGB 1 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input1/x_test_adv_VNIFGSM_Def4.npy not found
# start RF 100 baseline
# (1, 42) (1,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input100/x_test_adv_BIM_Def4.npy not found
# start RF 100 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input100/x_test_adv_FGSM_Def4.npy not found
# start RF 100 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input100/x_test_adv_PGD_Def4.npy not found
# start RF 100 DF
# (34, 42) (34,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input100/x_test_adv_AutoPGD_Def4.npy not found
# start RF 100 ZOO
# (3, 42) (3,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input100/x_test_adv_CaFA_Def4.npy not found
# start RF 100 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input100/x_test_adv_SINIFGSM_Def4.npy not found
# start RF 100 VNIFGSM
# (4, 42) (4,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 baseline
# (1, 42) (1,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input50/x_test_adv_BIM_Def4.npy not found
# start RF 50 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input50/x_test_adv_FGSM_Def4.npy not found
# start RF 50 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input50/x_test_adv_PGD_Def4.npy not found
# start RF 50 DF
# (34, 42) (34,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input50/x_test_adv_AutoPGD_Def4.npy not found
# start RF 50 ZOO
# (3, 42) (3,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input50/x_test_adv_CaFA_Def4.npy not found
# start RF 50 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input50/x_test_adv_SINIFGSM_Def4.npy not found
# start RF 50 VNIFGSM
# (12, 42) (12,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input20/x_test_adv_baseline_Def4.npy not found
# start RF 20 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input20/x_test_adv_BIM_Def4.npy not found
# start RF 20 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input20/x_test_adv_FGSM_Def4.npy not found
# start RF 20 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input20/x_test_adv_PGD_Def4.npy not found
# start RF 20 DF
# (36, 42) (36,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input20/x_test_adv_AutoPGD_Def4.npy not found
# start RF 20 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input20/x_test_adv_ZOO_Def4.npy not found
# start RF 20 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input20/x_test_adv_CaFA_Def4.npy not found
# start RF 20 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input20/x_test_adv_SINIFGSM_Def4.npy not found
# start RF 20 VNIFGSM
# (13, 42) (13,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 10 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input10/x_test_adv_baseline_Def4.npy not found
# start RF 10 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input10/x_test_adv_BIM_Def4.npy not found
# start RF 10 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input10/x_test_adv_FGSM_Def4.npy not found
# start RF 10 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input10/x_test_adv_PGD_Def4.npy not found
# start RF 10 DF
# (36, 42) (36,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 10 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input10/x_test_adv_AutoPGD_Def4.npy not found
# start RF 10 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input10/x_test_adv_ZOO_Def4.npy not found
# start RF 10 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input10/x_test_adv_CaFA_Def4.npy not found
# start RF 10 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input10/x_test_adv_SINIFGSM_Def4.npy not found
# start RF 10 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input10/x_test_adv_VNIFGSM_Def4.npy not found
# start RF 1 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input1/x_test_adv_baseline_Def4.npy not found
# start RF 1 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input1/x_test_adv_BIM_Def4.npy not found
# start RF 1 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input1/x_test_adv_FGSM_Def4.npy not found
# start RF 1 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input1/x_test_adv_PGD_Def4.npy not found
# start RF 1 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input1/x_test_adv_DF_Def4.npy not found
# start RF 1 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input1/x_test_adv_AutoPGD_Def4.npy not found
# start RF 1 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input1/x_test_adv_ZOO_Def4.npy not found
# start RF 1 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input1/x_test_adv_CaFA_Def4.npy not found
# start RF 1 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input1/x_test_adv_SINIFGSM_Def4.npy not found
# start RF 1 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input1/x_test_adv_VNIFGSM_Def4.npy not found

# %%
epsilon = 0
Def = "Def4"
attack_names = [
    "baseline", "BIM", "FGSM", "PGD", "DF",
    "AutoPGD", "ZOO", "CaFA", "SINIFGSM", "VNIFGSM"
]

percentage = ["100", "50", "20", "10", "1"]
model_name = ["XGB", "RF" ]

base_path = "/home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data"

total_num_attack = ["2", "3"]
for num_attack in total_num_attack:
    for m_name in model_name:
        for p in percentage:
            for attack in attack_names:
                print(f"start {m_name} {p} {attack}")
                
                x_path = f"{base_path}/{m_name}_Exclude{num_attack}Attack/WUSTL_Input{p}/x_test_adv_{attack}_{Def}.npy"
                y_path = f"{base_path}/{m_name}_Exclude{num_attack}Attack/WUSTL_Input{p}/y_test_adv_{attack}_{Def}.npy"
    
                try:
                    x_test_adv = np.load(x_path)
                    y_test_adv = np.load(y_path)
                    print(x_test_adv.shape, y_test_adv.shape)
    
                    m_per_name = f"{m_name}{p}_Exclude{num_attack}Attack"
                    calculate_performance_metrics(x_test_adv, y_test_adv, model, m_per_name, attack, epsilon)
                except FileNotFoundError:
                    print(x_path, "not found")
                    print_empty_file()
# Out:
# start XGB 100 baseline
# (2, 42) (2,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input100/x_test_adv_BIM_Def4.npy not found
# start XGB 100 FGSM
# (1, 42) (1,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 100 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input100/x_test_adv_PGD_Def4.npy not found
# start XGB 100 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input100/x_test_adv_DF_Def4.npy not found
# start XGB 100 AutoPGD
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (2, 42) (2,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 ZOO
# (6, 42) (6,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 CaFA
# (49, 42) (49,)
# Accuracy: 0.16326530612244897
#
# macro
# Precision: 0.22800000000000004
# Recall: 0.16484848484848486
# F1 Score: 0.13475355054302424
#
# weighted
# Precision: 0.5085714285714286
# Recall: 0.16326530612244897
# F1 Score: 0.20141339743917616
#
# start XGB 100 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input100/x_test_adv_SINIFGSM_Def4.npy not found
# start XGB 100 VNIFGSM
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (81, 42) (81,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.04938271604938271
#
# macro
# Precision: 0.3333333333333333
# Recall: 0.3333333333333333
# F1 Score: 0.3333333333333333
#
# weighted
# Precision: 0.04938271604938271
# Recall: 0.04938271604938271
# F1 Score: 0.04938271604938271
#
# start XGB 50 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input50/x_test_adv_baseline_Def4.npy not found
# start XGB 50 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input50/x_test_adv_BIM_Def4.npy not found
# start XGB 50 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input50/x_test_adv_FGSM_Def4.npy not found
# start XGB 50 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input50/x_test_adv_PGD_Def4.npy not found
# start XGB 50 DF
# (2, 42) (2,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 AutoPGD
# (15, 42) (15,)
# Accuracy: 0.8666666666666667
#
# macro
# Precision: 0.25
# Recall: 0.23214285714285715
# F1 Score: 0.24074074074074073
#
# weighted
# Precision: 0.9333333333333333
# Recall: 0.8666666666666667
# F1 Score: 0.8987654320987654
#
# start XGB 50 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input50/x_test_adv_ZOO_Def4.npy not found
# start XGB 50 CaFA
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (3, 42) (3,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 50 SINIFGSM
# (2, 42) (2,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 50 VNIFGSM
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (3, 42) (3,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 20 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input20/x_test_adv_baseline_Def4.npy not found
# start XGB 20 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input20/x_test_adv_BIM_Def4.npy not found
# start XGB 20 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input20/x_test_adv_FGSM_Def4.npy not found
# start XGB 20 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input20/x_test_adv_PGD_Def4.npy not found
# start XGB 20 DF
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (21, 42) (21,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 AutoPGD
# (19, 42) (19,)
# Accuracy: 0.6842105263157895
#
# macro
# Precision: 0.4
# Recall: 0.38461538461538464
# F1 Score: 0.392
#
# weighted
# Precision: 0.7368421052631579
# Recall: 0.6842105263157895
# F1 Score: 0.7094736842105264
#
# start XGB 20 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input20/x_test_adv_ZOO_Def4.npy not found
# start XGB 20 CaFA
# (5, 42) (5,)
# Accuracy: 0.2
#
# macro
# Precision: 0.1111111111111111
# Recall: 0.3333333333333333
# F1 Score: 0.16666666666666666
#
# weighted
# Precision: 0.06666666666666667
# Recall: 0.2
# F1 Score: 0.1
#
# start XGB 20 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input20/x_test_adv_SINIFGSM_Def4.npy not found
# start XGB 20 VNIFGSM
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (37, 42) (37,)
# Accuracy: 0.05405405405405406
#
# macro
# Precision: 0.3333333333333333
# Recall: 0.3333333333333333
# F1 Score: 0.3333333333333333
#
# weighted
# Precision: 0.05405405405405406
# Recall: 0.05405405405405406
# F1 Score: 0.05405405405405406
#
# start XGB 10 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input10/x_test_adv_baseline_Def4.npy not found
# start XGB 10 BIM
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (52, 42) (52,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 10 FGSM
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (27, 42) (27,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 10 PGD
# (52, 42) (52,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 10 DF
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (34, 42) (34,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 10 AutoPGD
# (7982, 42) (7982,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.017539463793535454
#
# macro
# Precision: 0.19858156028368795
# Recall: 0.0036091776230987365
# F1 Score: 0.007089505000632991
#
# weighted
# Precision: 0.9650436887251636
# Recall: 0.017539463793535454
# F1 Score: 0.03445275607298343
#
# start XGB 10 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input10/x_test_adv_ZOO_Def4.npy not found
# start XGB 10 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input10/x_test_adv_CaFA_Def4.npy not found
# start XGB 10 SINIFGSM
# (24, 42) (24,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 10 VNIFGSM
# (206, 42) (206,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.05825242718446602
#
# macro
# Precision: 0.21666666666666665
# Recall: 0.11285714285714285
# F1 Score: 0.12065217391304348
#
# weighted
# Precision: 0.17152103559870552
# Recall: 0.05825242718446602
# F1 Score: 0.08368509919797383
#
# start XGB 1 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input1/x_test_adv_baseline_Def4.npy not found
# start XGB 1 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input1/x_test_adv_BIM_Def4.npy not found
# start XGB 1 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input1/x_test_adv_FGSM_Def4.npy not found
# start XGB 1 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input1/x_test_adv_PGD_Def4.npy not found
# start XGB 1 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input1/x_test_adv_DF_Def4.npy not found
# start XGB 1 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input1/x_test_adv_AutoPGD_Def4.npy not found
# start XGB 1 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input1/x_test_adv_ZOO_Def4.npy not found
# start XGB 1 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input1/x_test_adv_CaFA_Def4.npy not found
# start XGB 1 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input1/x_test_adv_SINIFGSM_Def4.npy not found
# start XGB 1 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input1/x_test_adv_VNIFGSM_Def4.npy not found
# start RF 100 baseline
# (1, 42) (1,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input100/x_test_adv_BIM_Def4.npy not found
# start RF 100 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input100/x_test_adv_FGSM_Def4.npy not found
# start RF 100 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input100/x_test_adv_PGD_Def4.npy not found
# start RF 100 DF
# (34, 42) (34,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input100/x_test_adv_AutoPGD_Def4.npy not found
# start RF 100 ZOO
# (3, 42) (3,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input100/x_test_adv_CaFA_Def4.npy not found
# start RF 100 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input100/x_test_adv_SINIFGSM_Def4.npy not found
# start RF 100 VNIFGSM
# (5, 42) (5,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input50/x_test_adv_baseline_Def4.npy not found
# start RF 50 BIM
# (4, 42) (4,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 FGSM
# (73, 42) (73,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 PGD
# (4, 42) (4,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 DF
# (34, 42) (34,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 AutoPGD
# (8, 42) (8,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input50/x_test_adv_ZOO_Def4.npy not found
# start RF 50 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input50/x_test_adv_CaFA_Def4.npy not found
# start RF 50 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input50/x_test_adv_SINIFGSM_Def4.npy not found
# start RF 50 VNIFGSM
# (16, 42) (16,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input20/x_test_adv_baseline_Def4.npy not found
# start RF 20 BIM
# (646, 42) (646,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.9984520123839009
#
# macro
# Precision: 0.6666666666666666
# Recall: 0.6655480984340044
# F1 Score: 0.6661064425770308
#
# weighted
# Precision: 1.0
# Recall: 0.9984520123839009
# F1 Score: 0.9992247053620211
#
# start RF 20 FGSM
# (1466, 42) (1466,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.9986357435197817
#
# macro
# Precision: 0.5
# Recall: 0.5
# F1 Score: 0.5
#
# weighted
# Precision: 0.9986357435197817
# Recall: 0.9986357435197817
# F1 Score: 0.9986357435197817
#
# start RF 20 PGD
# (646, 42) (646,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.9984520123839009
#
# macro
# Precision: 0.6666666666666666
# Recall: 0.6655480984340044
# F1 Score: 0.6661064425770308
#
# weighted
# Precision: 1.0
# Recall: 0.9984520123839009
# F1 Score: 0.9992247053620211
#
# start RF 20 DF
# (34, 42) (34,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 AutoPGD
# (568, 42) (568,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.9982394366197183
#
# macro
# Precision: 0.75
# Recall: 0.7439024390243902
# F1 Score: 0.7469135802469136
#
# weighted
# Precision: 1.0
# Recall: 0.9982394366197183
# F1 Score: 0.9991088506346721
#
# start RF 20 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input20/x_test_adv_ZOO_Def4.npy not found
# start RF 20 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input20/x_test_adv_CaFA_Def4.npy not found
# start RF 20 SINIFGSM
# (8, 42) (8,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 VNIFGSM
# (1134, 42) (1134,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.9973544973544973
#
# macro
# Precision: 0.74951171875
# Recall: 0.7487745098039216
# F1 Score: 0.7491413701091121
#
# weighted
# Precision: 0.9991198881172839
# Recall: 0.9973544973544973
# F1 Score: 0.99823351257043
#
# start RF 10 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input10/x_test_adv_baseline_Def4.npy not found
# start RF 10 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input10/x_test_adv_BIM_Def4.npy not found
# start RF 10 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input10/x_test_adv_FGSM_Def4.npy not found
# start RF 10 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input10/x_test_adv_PGD_Def4.npy not found
# start RF 10 DF
# (35, 42) (35,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 10 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input10/x_test_adv_AutoPGD_Def4.npy not found
# start RF 10 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input10/x_test_adv_ZOO_Def4.npy not found
# start RF 10 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input10/x_test_adv_CaFA_Def4.npy not found
# start RF 10 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input10/x_test_adv_SINIFGSM_Def4.npy not found
# start RF 10 VNIFGSM
# (7, 42) (7,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 1 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input1/x_test_adv_baseline_Def4.npy not found
# start RF 1 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input1/x_test_adv_BIM_Def4.npy not found
# start RF 1 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input1/x_test_adv_FGSM_Def4.npy not found
# start RF 1 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input1/x_test_adv_PGD_Def4.npy not found
# start RF 1 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input1/x_test_adv_DF_Def4.npy not found
# start RF 1 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input1/x_test_adv_AutoPGD_Def4.npy not found
# start RF 1 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input1/x_test_adv_ZOO_Def4.npy not found
# start RF 1 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input1/x_test_adv_CaFA_Def4.npy not found
# start RF 1 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input1/x_test_adv_SINIFGSM_Def4.npy not found
# start RF 1 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input1/x_test_adv_VNIFGSM_Def4.npy not found
# start XGB 100 baseline
# (2, 42) (2,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 BIM
# (55, 42) (55,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 FGSM
# (254, 42) (254,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.9960629921259843
#
# macro
# Precision: 0.5833333333333334
# Recall: 0.6666666666666666
# F1 Score: 0.6190476190476191
#
# weighted
# Precision: 0.9931102362204725
# Recall: 0.9960629921259843
# F1 Score: 0.9943757030371204
#
# start XGB 100 PGD
# (55, 42) (55,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 DF
# (8, 42) (8,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 100 AutoPGD
# (4, 42) (4,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 ZOO
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (7, 42) (7,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 CaFA
# (40, 42) (40,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.125
#
# macro
# Precision: 0.2333333333333333
# Recall: 0.06285714285714286
# F1 Score: 0.09616724738675958
#
# weighted
# Precision: 0.6458333333333333
# Recall: 0.125
# F1 Score: 0.20644599303135885
#
# start XGB 100 SINIFGSM
# (79, 42) (79,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 VNIFGSM
# (194, 42) (194,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input50/x_test_adv_baseline_Def4.npy not found
# start XGB 50 BIM
# (225, 42) (225,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 FGSM
# (673, 42) (673,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 PGD
# (225, 42) (225,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input50/x_test_adv_DF_Def4.npy not found
# start XGB 50 AutoPGD
# (17, 42) (17,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input50/x_test_adv_ZOO_Def4.npy not found
# start XGB 50 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input50/x_test_adv_CaFA_Def4.npy not found
# start XGB 50 SINIFGSM
# (9, 42) (9,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 VNIFGSM
# (665, 42) (665,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input20/x_test_adv_baseline_Def4.npy not found
# start XGB 20 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input20/x_test_adv_BIM_Def4.npy not found
# start XGB 20 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input20/x_test_adv_FGSM_Def4.npy not found
# start XGB 20 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input20/x_test_adv_PGD_Def4.npy not found
# start XGB 20 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input20/x_test_adv_DF_Def4.npy not found
# start XGB 20 AutoPGD
# (5, 42) (5,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input20/x_test_adv_ZOO_Def4.npy not found
# start XGB 20 CaFA
# (16, 42) (16,)
# Accuracy: 0.25
#
# macro
# Precision: 0.375
# Recall: 0.23333333333333334
# F1 Score: 0.2875
#
# weighted
# Precision: 0.40625
# Recall: 0.25
# F1 Score: 0.309375
#
# start XGB 20 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input20/x_test_adv_SINIFGSM_Def4.npy not found
# start XGB 20 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input20/x_test_adv_VNIFGSM_Def4.npy not found
# start XGB 10 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input10/x_test_adv_baseline_Def4.npy not found
# start XGB 10 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input10/x_test_adv_BIM_Def4.npy not found
# start XGB 10 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input10/x_test_adv_FGSM_Def4.npy not found
# start XGB 10 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input10/x_test_adv_PGD_Def4.npy not found
# start XGB 10 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input10/x_test_adv_DF_Def4.npy not found
# start XGB 10 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input10/x_test_adv_AutoPGD_Def4.npy not found
# start XGB 10 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input10/x_test_adv_ZOO_Def4.npy not found
# start XGB 10 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input10/x_test_adv_CaFA_Def4.npy not found
# start XGB 10 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input10/x_test_adv_SINIFGSM_Def4.npy not found
# start XGB 10 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input10/x_test_adv_VNIFGSM_Def4.npy not found
# start XGB 1 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input1/x_test_adv_baseline_Def4.npy not found
# start XGB 1 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input1/x_test_adv_BIM_Def4.npy not found
# start XGB 1 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input1/x_test_adv_FGSM_Def4.npy not found
# start XGB 1 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input1/x_test_adv_PGD_Def4.npy not found
# start XGB 1 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input1/x_test_adv_DF_Def4.npy not found
# start XGB 1 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input1/x_test_adv_AutoPGD_Def4.npy not found
# start XGB 1 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input1/x_test_adv_ZOO_Def4.npy not found
# start XGB 1 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input1/x_test_adv_CaFA_Def4.npy not found
# start XGB 1 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input1/x_test_adv_SINIFGSM_Def4.npy not found
# start XGB 1 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input1/x_test_adv_VNIFGSM_Def4.npy not found
# start RF 100 baseline
# (1, 42) (1,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# start RF 100 BIM
# (2, 42) (2,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 FGSM
# (5, 42) (5,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 PGD
# (2, 42) (2,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input100/x_test_adv_DF_Def4.npy not found
# start RF 100 AutoPGD
# (1, 42) (1,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 ZOO
# (3, 42) (3,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input100/x_test_adv_CaFA_Def4.npy not found
# start RF 100 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input100/x_test_adv_SINIFGSM_Def4.npy not found
# start RF 100 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input100/x_test_adv_VNIFGSM_Def4.npy not found
# start RF 50 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input50/x_test_adv_baseline_Def4.npy not found
# start RF 50 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input50/x_test_adv_BIM_Def4.npy not found
# start RF 50 FGSM
# (2, 42) (2,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input50/x_test_adv_PGD_Def4.npy not found
# start RF 50 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input50/x_test_adv_DF_Def4.npy not found
# start RF 50 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input50/x_test_adv_AutoPGD_Def4.npy not found
# start RF 50 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input50/x_test_adv_ZOO_Def4.npy not found
# start RF 50 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input50/x_test_adv_CaFA_Def4.npy not found
# start RF 50 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input50/x_test_adv_SINIFGSM_Def4.npy not found
# start RF 50 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input50/x_test_adv_VNIFGSM_Def4.npy not found
# start RF 20 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input20/x_test_adv_baseline_Def4.npy not found
# start RF 20 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input20/x_test_adv_BIM_Def4.npy not found
# start RF 20 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input20/x_test_adv_FGSM_Def4.npy not found
# start RF 20 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input20/x_test_adv_PGD_Def4.npy not found
# start RF 20 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input20/x_test_adv_DF_Def4.npy not found
# start RF 20 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input20/x_test_adv_AutoPGD_Def4.npy not found
# start RF 20 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input20/x_test_adv_ZOO_Def4.npy not found
# start RF 20 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input20/x_test_adv_CaFA_Def4.npy not found
# start RF 20 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input20/x_test_adv_SINIFGSM_Def4.npy not found
# start RF 20 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input20/x_test_adv_VNIFGSM_Def4.npy not found
# start RF 10 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input10/x_test_adv_baseline_Def4.npy not found
# start RF 10 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input10/x_test_adv_BIM_Def4.npy not found
# start RF 10 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input10/x_test_adv_FGSM_Def4.npy not found
# start RF 10 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input10/x_test_adv_PGD_Def4.npy not found
# start RF 10 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input10/x_test_adv_DF_Def4.npy not found
# start RF 10 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input10/x_test_adv_AutoPGD_Def4.npy not found
# start RF 10 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input10/x_test_adv_ZOO_Def4.npy not found
# start RF 10 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input10/x_test_adv_CaFA_Def4.npy not found
# start RF 10 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input10/x_test_adv_SINIFGSM_Def4.npy not found
# start RF 10 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input10/x_test_adv_VNIFGSM_Def4.npy not found
# start RF 1 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input1/x_test_adv_baseline_Def4.npy not found
# start RF 1 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input1/x_test_adv_BIM_Def4.npy not found
# start RF 1 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input1/x_test_adv_FGSM_Def4.npy not found
# start RF 1 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input1/x_test_adv_PGD_Def4.npy not found
# start RF 1 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input1/x_test_adv_DF_Def4.npy not found
# start RF 1 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input1/x_test_adv_AutoPGD_Def4.npy not found
# start RF 1 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input1/x_test_adv_ZOO_Def4.npy not found
# start RF 1 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input1/x_test_adv_CaFA_Def4.npy not found
# start RF 1 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input1/x_test_adv_SINIFGSM_Def4.npy not found
# start RF 1 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input1/x_test_adv_VNIFGSM_Def4.npy not found

# %%
epsilon = 0

Def = "Def4"
attack_names = [
    "baseline", "BIM", "FGSM", "PGD", "DF",
    "AutoPGD", "ZOO", "CaFA", "SINIFGSM", "VNIFGSM"
]

base_path = "/home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data"

rec_list = ["Euclidean", "cosine", "manhattan"]
for rec in rec_list:
    for attack in attack_names:
        print(f"start {attack}")
        
        x_path = f"{base_path}/Recommendation_{rec}/x_test_adv_{attack}_{Def}.npy"
        y_path = f"{base_path}/Recommendation_{rec}/y_test_adv_{attack}_{Def}.npy"
    
        try:
            x_test_adv = np.load(x_path)
            y_test_adv = np.load(y_path)
            m_per_name = f"Recommendation_{rec}"
            calculate_performance_metrics(x_test_adv, y_test_adv, model, m_per_name, attack, epsilon)
        except FileNotFoundError:
            print(x_path, "not found")
            print_empty_file()
# Out:
# start baseline
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start BIM
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.014598540145985401
#
# macro
# Precision: 0.0072992700729927005
# Recall: 0.5
# F1 Score: 0.014388489208633094
#
# weighted
# Precision: 0.00021311737439394746
# Recall: 0.014598540145985401
# F1 Score: 0.0004201018747046159
#
# start FGSM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start PGD
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.014598540145985401
#
# macro
# Precision: 0.0072992700729927005
# Recall: 0.5
# F1 Score: 0.014388489208633094
#
# weighted
# Precision: 0.00021311737439394746
# Recall: 0.014598540145985401
# F1 Score: 0.0004201018747046159
#
# start DF
# Accuracy: 0.9444444444444444
#
# macro
# Precision: 0.3333333333333333
# Recall: 0.3333333333333333
# F1 Score: 0.3333333333333333
#
# weighted
# Precision: 0.9444444444444444
# Recall: 0.9444444444444444
# F1 Score: 0.9444444444444444
#
# start AutoPGD
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.014218009478672985
#
# macro
# Precision: 0.33460559796437656
# Recall: 0.33703116745905964
# F1 Score: 0.009849378801784728
#
# weighted
# Precision: 0.9968525017184617
# Recall: 0.014218009478672985
# F1 Score: 0.02189826873586304
#
# start ZOO
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start CaFA
# Accuracy: 0.8427495930548019
#
# macro
# Precision: 0.6654431472734736
# Recall: 0.7484955104296073
# F1 Score: 0.6247841460228518
#
# weighted
# Precision: 0.9369743657542817
# Recall: 0.8427495930548019
# F1 Score: 0.8817110885819912
#
# start SINIFGSM
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.8333333333333334
#
# macro
# Precision: 0.5333333333333333
# Recall: 0.6666666666666666
# F1 Score: 0.5833333333333334
#
# weighted
# Precision: 0.7333333333333334
# Recall: 0.8333333333333334
# F1 Score: 0.7708333333333334
#
# start VNIFGSM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start baseline
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start BIM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start FGSM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start PGD
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start DF
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start AutoPGD
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start ZOO
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start CaFA
# Accuracy: 0.8762013667674045
#
# macro
# Precision: 0.6714700904449702
# Recall: 0.7684326035133537
# F1 Score: 0.6385611141112341
#
# weighted
# Precision: 0.9482788881112276
# Recall: 0.8762013667674045
# F1 Score: 0.9075584688637258
#
# start SINIFGSM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/Recommendation_cosine/x_test_adv_VNIFGSM_Def4.npy not found
# start baseline
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start BIM
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.019230769230769232
#
# macro
# Precision: 0.004901960784313725
# Recall: 0.25
# F1 Score: 0.009615384615384616
#
# weighted
# Precision: 0.0003770739064856712
# Recall: 0.019230769230769232
# F1 Score: 0.0007396449704142013
#
# start FGSM
# Accuracy: 0.5
#
# macro
# Precision: 0.3333333333333333
# Recall: 0.3333333333333333
# F1 Score: 0.3333333333333333
#
# weighted
# Precision: 0.5
# Recall: 0.5
# F1 Score: 0.5
#
# start PGD
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.019230769230769232
#
# macro
# Precision: 0.004901960784313725
# Recall: 0.25
# F1 Score: 0.009615384615384616
#
# weighted
# Precision: 0.0003770739064856712
# Recall: 0.019230769230769232
# F1 Score: 0.0007396449704142013
#
# start DF
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start AutoPGD
# Accuracy: 0.11914893617021277
#
# macro
# Precision: 0.45784578457845787
# Recall: 0.6986899563318777
# F1 Score: 0.24274666041715495
#
# weighted
# Precision: 0.9807419039776317
# Recall: 0.11914893617021277
# F1 Score: 0.18006798006139815
#
# start ZOO
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start CaFA
# Accuracy: 0.8305457902773339
#
# macro
# Precision: 0.6530956640364358
# Recall: 0.7324008849819178
# F1 Score: 0.6120837491847311
#
# weighted
# Precision: 0.9345080226982245
# Recall: 0.8305457902773339
# F1 Score: 0.8725658253696691
#
# start SINIFGSM
# Accuracy: 0.85
#
# macro
# Precision: 0.5
# Recall: 0.6666666666666666
# F1 Score: 0.5555555555555555
#
# weighted
# Precision: 0.775
# Recall: 0.85
# F1 Score: 0.8
#
# start VNIFGSM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
epsilon = 0
Def = "Def4"
attack_names = [
    "baseline", "BIM", "FGSM", "PGD", "DF",
    "AutoPGD", "ZOO", "CaFA", "SINIFGSM", "VNIFGSM"
]

percentage = ["100", "50", "20", "10", "1"]
model_name = ["XGB", "RF" ]

base_path = "/home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data"

for m_name in model_name:
    for p in percentage:
        for attack in attack_names:
            print(f"start {m_name} {p} {attack}")
            
            x_path = f"{base_path}/{m_name}_Cluster/WUSTL_Input{p}/x_test_adv_{attack}_{Def}.npy"
            y_path = f"{base_path}/{m_name}_Cluster/WUSTL_Input{p}/y_test_adv_{attack}_{Def}.npy"

            try:
                x_test_adv = np.load(x_path)
                y_test_adv = np.load(y_path)
                print(x_test_adv.shape, y_test_adv.shape)

                m_per_name = f"{m_name}{p}_Cluster"
                calculate_performance_metrics(x_test_adv, y_test_adv, model, m_per_name, attack, epsilon)
            except FileNotFoundError:
                print(x_path, "not found")
                print_empty_file()
# Out:
# start XGB 100 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input100/x_test_adv_baseline_Def4.npy not found
# start XGB 100 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input100/x_test_adv_BIM_Def4.npy not found
# start XGB 100 FGSM
# (6, 42) (6,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 100 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input100/x_test_adv_PGD_Def4.npy not found
# start XGB 100 DF
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (6, 42) (6,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 AutoPGD
# (51, 42) (51,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.8627450980392157
#
# macro
# Precision: 0.3333333333333333
# Recall: 0.28758169934640526
# F1 Score: 0.3087719298245614
#
# weighted
# Precision: 1.0
# Recall: 0.8627450980392157
# F1 Score: 0.9263157894736842
#
# start XGB 100 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input100/x_test_adv_ZOO_Def4.npy not found
# start XGB 100 CaFA
# (42357, 42) (42357,)
# Accuracy: 0.8724886087305522
#
# macro
# Precision: 0.7622442595048153
# Recall: 0.703443735141938
# F1 Score: 0.6218680982902219
#
# weighted
# Precision: 0.9651269327925835
# Recall: 0.8724886087305522
# F1 Score: 0.9128295010600288
#
# start XGB 100 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input100/x_test_adv_SINIFGSM_Def4.npy not found
# start XGB 100 VNIFGSM
# (1, 42) (1,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input50/x_test_adv_baseline_Def4.npy not found
# start XGB 50 BIM
# (65, 42) (65,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 FGSM
# (25, 42) (25,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 PGD
# (65, 42) (65,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input50/x_test_adv_DF_Def4.npy not found
# start XGB 50 AutoPGD
# (19, 42) (19,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input50/x_test_adv_ZOO_Def4.npy not found
# start XGB 50 CaFA
# (36816, 42) (36816,)
# Accuracy: 0.8975173837461973
#
# macro
# Precision: 0.7412597453610952
# Recall: 0.6923415077298374
# F1 Score: 0.6015868586535864
#
# weighted
# Precision: 0.9544574770746287
# Recall: 0.8975173837461973
# F1 Score: 0.921188969314066
#
# start XGB 50 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input50/x_test_adv_SINIFGSM_Def4.npy not found
# start XGB 50 VNIFGSM
# (4, 42) (4,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 baseline
# (1134, 42) (1134,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input20/x_test_adv_BIM_Def4.npy not found
# start XGB 20 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input20/x_test_adv_FGSM_Def4.npy not found
# start XGB 20 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input20/x_test_adv_PGD_Def4.npy not found
# start XGB 20 DF
# (18, 42) (18,)
# Accuracy: 0.3333333333333333
#
# macro
# Precision: 0.21428571428571427
# Recall: 0.25
# F1 Score: 0.23076923076923078
#
# weighted
# Precision: 0.2857142857142857
# Recall: 0.3333333333333333
# F1 Score: 0.3076923076923077
#
# start XGB 20 AutoPGD
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (202, 42) (202,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 ZOO
# (3402, 42) (3402,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 CaFA
# (6968, 42) (6968,)
# Accuracy: 0.9585246842709529
#
# macro
# Precision: 0.5950395135111687
# Recall: 0.6560747764017888
# F1 Score: 0.5979055780825503
#
# weighted
# Precision: 0.9776440822854122
# Recall: 0.9585246842709529
# F1 Score: 0.9672465771453569
#
# start XGB 20 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input20/x_test_adv_SINIFGSM_Def4.npy not found
# start XGB 20 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input20/x_test_adv_VNIFGSM_Def4.npy not found
# start XGB 10 baseline
# (3161, 42) (3161,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 10 BIM
# (3, 42) (3,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 10 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input10/x_test_adv_FGSM_Def4.npy not found
# start XGB 10 PGD
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (3, 42) (3,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 10 DF
# (34, 42) (34,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 10 AutoPGD
# (451, 42) (451,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 10 ZOO
# (9483, 42) (9483,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 10 CaFA
# (10326, 42) (10326,)
# Accuracy: 0.6859384079023824
#
# macro
# Precision: 0.4916408930525638
# Recall: 0.5977697632177262
# F1 Score: 0.4485058964025098
#
# weighted
# Precision: 0.6479036318229465
# Recall: 0.6859384079023824
# F1 Score: 0.6525274044368402
#
# start XGB 10 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input10/x_test_adv_SINIFGSM_Def4.npy not found
# start XGB 10 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input10/x_test_adv_VNIFGSM_Def4.npy not found
# start XGB 1 baseline
# (155, 42) (155,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 1 BIM
# (1, 42) (1,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 1 FGSM
# (1, 42) (1,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 1 PGD
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (1, 42) (1,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 1 DF
# (110, 42) (110,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.9636363636363636
#
# macro
# Precision: 0.19813084112149532
# Recall: 0.1962962962962963
# F1 Score: 0.1972093023255814
#
# weighted
# Precision: 0.9726423109600679
# Recall: 0.9636363636363636
# F1 Score: 0.9681183932346723
#
# start XGB 1 AutoPGD
# (33, 42) (33,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 1 ZOO
# (465, 42) (465,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 1 CaFA
# (6771, 42) (6771,)
# Accuracy: 0.9443213705508787
#
# macro
# Precision: 0.5986730999344602
# Recall: 0.6258079711230278
# F1 Score: 0.602985472221547
#
# weighted
# Precision: 0.9386715414846448
# Recall: 0.9443213705508787
# F1 Score: 0.9412820093378592
#
# start XGB 1 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input1/x_test_adv_SINIFGSM_Def4.npy not found
# start XGB 1 VNIFGSM
# (22, 42) (22,)
# Accuracy: 0.9545454545454546
#
# macro
# Precision: 0.975
# Recall: 0.8333333333333333
# F1 Score: 0.8871794871794871
#
# weighted
# Precision: 0.9568181818181819
# Recall: 0.9545454545454546
# F1 Score: 0.9505827505827504
#
# start RF 100 baseline
# (1, 42) (1,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input100/x_test_adv_BIM_Def4.npy not found
# start RF 100 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input100/x_test_adv_FGSM_Def4.npy not found
# start RF 100 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input100/x_test_adv_PGD_Def4.npy not found
# start RF 100 DF
# (34, 42) (34,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input100/x_test_adv_AutoPGD_Def4.npy not found
# start RF 100 ZOO
# (3, 42) (3,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 CaFA
# (15320, 42) (15320,)
# Accuracy: 0.9539817232375979
#
# macro
# Precision: 0.791211429857276
# Recall: 0.7102383233330698
# F1 Score: 0.6574000755142506
#
# weighted
# Precision: 0.9729907924153359
# Recall: 0.9539817232375979
# F1 Score: 0.9559681024090592
#
# start RF 100 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input100/x_test_adv_SINIFGSM_Def4.npy not found
# start RF 100 VNIFGSM
# (6, 42) (6,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input50/x_test_adv_baseline_Def4.npy not found
# start RF 50 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input50/x_test_adv_BIM_Def4.npy not found
# start RF 50 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input50/x_test_adv_FGSM_Def4.npy not found
# start RF 50 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input50/x_test_adv_PGD_Def4.npy not found
# start RF 50 DF
# (34, 42) (34,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input50/x_test_adv_AutoPGD_Def4.npy not found
# start RF 50 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input50/x_test_adv_ZOO_Def4.npy not found
# start RF 50 CaFA
# (15356, 42) (15356,)
# Accuracy: 0.9447772857514978
#
# macro
# Precision: 0.7611330914791862
# Recall: 0.6810794680951444
# F1 Score: 0.6052136551826409
#
# weighted
# Precision: 0.9687700114584067
# Recall: 0.9447772857514978
# F1 Score: 0.9452591884354221
#
# start RF 50 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input50/x_test_adv_SINIFGSM_Def4.npy not found
# start RF 50 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input50/x_test_adv_VNIFGSM_Def4.npy not found
# start RF 20 baseline
# (35, 42) (35,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input20/x_test_adv_BIM_Def4.npy not found
# start RF 20 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input20/x_test_adv_FGSM_Def4.npy not found
# start RF 20 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input20/x_test_adv_PGD_Def4.npy not found
# start RF 20 DF
# (34, 42) (34,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 AutoPGD
# (3, 42) (3,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 ZOO
# (105, 42) (105,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 CaFA
# (6839, 42) (6839,)
# Accuracy: 0.968855095774236
#
# macro
# Precision: 0.599246817745852
# Recall: 0.7461208494022261
# F1 Score: 0.6025769011199962
#
# weighted
# Precision: 0.9930990330236865
# Recall: 0.968855095774236
# F1 Score: 0.9797358131063221
#
# start RF 20 SINIFGSM
# (5, 42) (5,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input20/x_test_adv_VNIFGSM_Def4.npy not found
# start RF 10 baseline
# (57, 42) (57,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 10 BIM
# (19, 42) (19,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 10 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input10/x_test_adv_FGSM_Def4.npy not found
# start RF 10 PGD
# (19, 42) (19,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 10 DF
# (35, 42) (35,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 10 AutoPGD
# (34, 42) (34,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 10 ZOO
# (171, 42) (171,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 10 CaFA
# (7345, 42) (7345,)
# Accuracy: 0.917358747447243
#
# macro
# Precision: 0.6383132274196098
# Recall: 0.6361635684871206
# F1 Score: 0.6279440525899903
#
# weighted
# Precision: 0.880008385996935
# Recall: 0.917358747447243
# F1 Score: 0.897776499993258
#
# start RF 10 SINIFGSM
# (34, 42) (34,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 10 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input10/x_test_adv_VNIFGSM_Def4.npy not found
# start RF 1 baseline
# (5589, 42) (5589,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.9996421542315262
#
# macro
# Precision: 0.4998210771157631
# Recall: 0.5
# F1 Score: 0.4999105225483178
#
# weighted
# Precision: 0.9992844365166464
# Recall: 0.9996421542315262
# F1 Score: 0.9994632633664168
#
# start RF 1 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input1/x_test_adv_BIM_Def4.npy not found
# start RF 1 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input1/x_test_adv_FGSM_Def4.npy not found
# start RF 1 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input1/x_test_adv_PGD_Def4.npy not found
# start RF 1 DF
# (102, 42) (102,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 1 AutoPGD
# (425, 42) (425,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.9858823529411764
#
# macro
# Precision: 0.4929411764705882
# Recall: 0.5
# F1 Score: 0.49644549763033174
#
# weighted
# Precision: 0.9719640138408304
# Recall: 0.9858823529411764
# F1 Score: 0.9788737106216894
#
# start RF 1 ZOO
# (16767, 42) (16767,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.9996421542315262
#
# macro
# Precision: 0.4998210771157631
# Recall: 0.5
# F1 Score: 0.4999105225483178
#
# weighted
# Precision: 0.9992844365166464
# Recall: 0.9996421542315262
# F1 Score: 0.9994632633664168
#
# start RF 1 CaFA
# (8437, 42) (8437,)
# Accuracy: 0.8085812492592154
#
# macro
# Precision: 0.5060215407518222
# Recall: 0.5354204264193344
# F1 Score: 0.5130481454741644
#
# weighted
# Precision: 0.6819041759352572
# Recall: 0.8085812492592154
# F1 Score: 0.7385461145590769
#
# start RF 1 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input1/x_test_adv_SINIFGSM_Def4.npy not found
# start RF 1 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input1/x_test_adv_VNIFGSM_Def4.npy not found

# %%
epsilon = 0
Def = "Def4"
attack_names = [
    "baseline", "BIM", "FGSM", "PGD", "DF",
    "AutoPGD", "ZOO", "CaFA", "SINIFGSM", "VNIFGSM"
]

percentage = ["100", "50", "20", "10", "1"]
model_name = ["XGB", "RF" ]

base_path = "/home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data"

for m_name in model_name:
    for p in percentage:
        for attack in attack_names:
            print(f"start {m_name} {p} {attack}")
            
            x_path = f"{base_path}/{m_name}_ActiveLearning/WUSTL_Input{p}/x_test_adv_{attack}_{Def}.npy"
            y_path = f"{base_path}/{m_name}_ActiveLearning/WUSTL_Input{p}/y_test_adv_{attack}_{Def}.npy"

            try:
                x_test_adv = np.load(x_path)
                y_test_adv = np.load(y_path)
                print(x_test_adv.shape, y_test_adv.shape)

                m_per_name = f"{m_name}{p}_ActiveLearning"
                calculate_performance_metrics(x_test_adv, y_test_adv, model, m_per_name, attack, epsilon)
            except FileNotFoundError:
                print(x_path, "not found")
                print_empty_file()
# Out:
# start XGB 100 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input100/x_test_adv_baseline_Def4.npy not found
# start XGB 100 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input100/x_test_adv_BIM_Def4.npy not found
# start XGB 100 FGSM
# (6, 42) (6,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 100 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input100/x_test_adv_PGD_Def4.npy not found
# start XGB 100 DF
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (6, 42) (6,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 AutoPGD
# (51, 42) (51,)
# Accuracy: 0.8627450980392157
#
# macro
# Precision: 0.3333333333333333
# Recall: 0.28758169934640526
# F1 Score: 0.3087719298245614
#
# weighted
# Precision: 1.0
# Recall: 0.8627450980392157
# F1 Score: 0.9263157894736842
#
# start XGB 100 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input100/x_test_adv_ZOO_Def4.npy not found
# start XGB 100 CaFA
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (42357, 42) (42357,)
# Accuracy: 0.8724886087305522
#
# macro
# Precision: 0.7622442595048153
# Recall: 0.703443735141938
# F1 Score: 0.6218680982902219
#
# weighted
# Precision: 0.9651269327925835
# Recall: 0.8724886087305522
# F1 Score: 0.9128295010600288
#
# start XGB 100 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input100/x_test_adv_SINIFGSM_Def4.npy not found
# start XGB 100 VNIFGSM
# (1, 42) (1,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input50/x_test_adv_baseline_Def4.npy not found
# start XGB 50 BIM
# (7, 42) (7,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 50 FGSM
# (1, 42) (1,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 50 PGD
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (7, 42) (7,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 50 DF
# (30, 42) (30,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 AutoPGD
# (39, 42) (39,)
# Accuracy: 0.7948717948717948
#
# macro
# Precision: 0.5652173913043478
# Recall: 0.5768833849329206
# F1 Score: 0.5607843137254902
#
# weighted
# Precision: 0.79041248606466
# Recall: 0.7948717948717948
# F1 Score: 0.7785822021116139
#
# start XGB 50 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input50/x_test_adv_ZOO_Def4.npy not found
# start XGB 50 CaFA
# (42120, 42) (42120,)
# Accuracy: 0.89002849002849
#
# macro
# Precision: 0.7473120573479012
# Recall: 0.7630500970698115
# F1 Score: 0.6575743549784135
#
# weighted
# Precision: 0.9578855438271913
# Recall: 0.89002849002849
# F1 Score: 0.9200983105700233
#
# start XGB 50 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input50/x_test_adv_SINIFGSM_Def4.npy not found
# start XGB 50 VNIFGSM
# (6, 42) (6,)
# Accuracy: 0.3333333333333333
#
# macro
# Precision: 0.3333333333333333
# Recall: 0.3333333333333333
# F1 Score: 0.3333333333333333
#
# weighted
# Precision: 0.3333333333333333
# Recall: 0.3333333333333333
# F1 Score: 0.3333333333333333
#
# start XGB 20 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input20/x_test_adv_baseline_Def4.npy not found
# start XGB 20 BIM
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (37, 42) (37,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 FGSM
# (82, 42) (82,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 PGD
# (37, 42) (37,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input20/x_test_adv_DF_Def4.npy not found
# start XGB 20 AutoPGD
# (30, 42) (30,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input20/x_test_adv_ZOO_Def4.npy not found
# start XGB 20 CaFA
# (16833, 42) (16833,)
# Accuracy: 0.9176023287589853
#
# macro
# Precision: 0.6707397798369014
# Recall: 0.7079464981025851
# F1 Score: 0.6231624186304465
#
# weighted
# Precision: 0.9366618571774251
# Recall: 0.9176023287589853
# F1 Score: 0.9257999203189499
#
# start XGB 20 SINIFGSM
# (101, 42) (101,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 VNIFGSM
# (175, 42) (175,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 10 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input10/x_test_adv_baseline_Def4.npy not found
# start XGB 10 BIM
# (37, 42) (37,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 10 FGSM
# (82, 42) (82,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 10 PGD
# (37, 42) (37,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 10 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input10/x_test_adv_DF_Def4.npy not found
# start XGB 10 AutoPGD
# (30, 42) (30,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 10 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input10/x_test_adv_ZOO_Def4.npy not found
# start XGB 10 CaFA
# (16833, 42) (16833,)
# Accuracy: 0.9176023287589853
#
# macro
# Precision: 0.6707397798369014
# Recall: 0.7079464981025851
# F1 Score: 0.6231624186304465
#
# weighted
# Precision: 0.9366618571774251
# Recall: 0.9176023287589853
# F1 Score: 0.9257999203189499
#
# start XGB 10 SINIFGSM
# (101, 42) (101,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 10 VNIFGSM
# (175, 42) (175,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 1 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input1/x_test_adv_baseline_Def4.npy not found
# start XGB 1 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input1/x_test_adv_BIM_Def4.npy not found
# start XGB 1 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input1/x_test_adv_FGSM_Def4.npy not found
# start XGB 1 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input1/x_test_adv_PGD_Def4.npy not found
# start XGB 1 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input1/x_test_adv_DF_Def4.npy not found
# start XGB 1 AutoPGD
# (3, 42) (3,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 1 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input1/x_test_adv_ZOO_Def4.npy not found
# start XGB 1 CaFA
# (234, 42) (234,)
# Accuracy: 0.7051282051282052
#
# macro
# Precision: 0.5975237222444967
# Recall: 0.7084750179141424
# F1 Score: 0.6106639656639656
#
# weighted
# Precision: 0.6795067613843031
# Recall: 0.7051282051282052
# F1 Score: 0.6647861793160939
#
# start XGB 1 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input1/x_test_adv_SINIFGSM_Def4.npy not found
# start XGB 1 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input1/x_test_adv_VNIFGSM_Def4.npy not found
# start RF 100 baseline
# (1, 42) (1,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input100/x_test_adv_BIM_Def4.npy not found
# start RF 100 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input100/x_test_adv_FGSM_Def4.npy not found
# start RF 100 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input100/x_test_adv_PGD_Def4.npy not found
# start RF 100 DF
# (34, 42) (34,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input100/x_test_adv_AutoPGD_Def4.npy not found
# start RF 100 ZOO
# (3, 42) (3,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 CaFA
# (15508, 42) (15508,)
# Accuracy: 0.9528630384317771
#
# macro
# Precision: 0.7786461290991714
# Recall: 0.7144858612657583
# F1 Score: 0.6601416549337731
#
# weighted
# Precision: 0.9697192287846292
# Recall: 0.9528630384317771
# F1 Score: 0.9541147190539697
#
# start RF 100 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input100/x_test_adv_SINIFGSM_Def4.npy not found
# start RF 100 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input100/x_test_adv_VNIFGSM_Def4.npy not found
# start RF 50 baseline
# (1, 42) (1,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input50/x_test_adv_BIM_Def4.npy not found
# start RF 50 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input50/x_test_adv_FGSM_Def4.npy not found
# start RF 50 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input50/x_test_adv_PGD_Def4.npy not found
# start RF 50 DF
# (34, 42) (34,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input50/x_test_adv_AutoPGD_Def4.npy not found
# start RF 50 ZOO
# (3, 42) (3,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 CaFA
# (15143, 42) (15143,)
# Accuracy: 0.9532457240969425
#
# macro
# Precision: 0.7511376966084417
# Recall: 0.7186147849050444
# F1 Score: 0.6304596887324445
#
# weighted
# Precision: 0.9770685692750332
# Recall: 0.9532457240969425
# F1 Score: 0.9574712562593651
#
# start RF 50 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input50/x_test_adv_SINIFGSM_Def4.npy not found
# start RF 50 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input50/x_test_adv_VNIFGSM_Def4.npy not found
# start RF 20 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input20/x_test_adv_baseline_Def4.npy not found
# start RF 20 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input20/x_test_adv_BIM_Def4.npy not found
# start RF 20 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input20/x_test_adv_FGSM_Def4.npy not found
# start RF 20 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input20/x_test_adv_PGD_Def4.npy not found
# start RF 20 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input20/x_test_adv_DF_Def4.npy not found
# start RF 20 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input20/x_test_adv_AutoPGD_Def4.npy not found
# start RF 20 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input20/x_test_adv_ZOO_Def4.npy not found
# start RF 20 CaFA
# (14808, 42) (14808,)
# Accuracy: 0.9553619665045922
#
# macro
# Precision: 0.7213187458359457
# Recall: 0.7648834590587972
# F1 Score: 0.5892341217456731
#
# weighted
# Precision: 0.9923279295901993
# Recall: 0.9553619665045922
# F1 Score: 0.9702296147546015
#
# start RF 20 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input20/x_test_adv_SINIFGSM_Def4.npy not found
# start RF 20 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input20/x_test_adv_VNIFGSM_Def4.npy not found
# start RF 10 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input10/x_test_adv_baseline_Def4.npy not found
# start RF 10 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input10/x_test_adv_BIM_Def4.npy not found
# start RF 10 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input10/x_test_adv_FGSM_Def4.npy not found
# start RF 10 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input10/x_test_adv_PGD_Def4.npy not found
# start RF 10 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input10/x_test_adv_DF_Def4.npy not found
# start RF 10 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input10/x_test_adv_AutoPGD_Def4.npy not found
# start RF 10 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input10/x_test_adv_ZOO_Def4.npy not found
# start RF 10 CaFA
# (14722, 42) (14722,)
# Accuracy: 0.9574106778970248
#
# macro
# Precision: 0.7229156169731821
# Recall: 0.6372970594961208
# F1 Score: 0.5598241938915981
#
# weighted
# Precision: 0.9927267356574898
# Recall: 0.9574106778970248
# F1 Score: 0.9715329345540566
#
# start RF 10 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input10/x_test_adv_SINIFGSM_Def4.npy not found
# start RF 10 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input10/x_test_adv_VNIFGSM_Def4.npy not found
# start RF 1 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input1/x_test_adv_baseline_Def4.npy not found
# start RF 1 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input1/x_test_adv_BIM_Def4.npy not found
# start RF 1 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input1/x_test_adv_FGSM_Def4.npy not found
# start RF 1 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input1/x_test_adv_PGD_Def4.npy not found
# start RF 1 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input1/x_test_adv_DF_Def4.npy not found
# start RF 1 AutoPGD
# (10, 42) (10,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 1 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input1/x_test_adv_ZOO_Def4.npy not found
# start RF 1 CaFA
# (105, 42) (105,)
# Accuracy: 0.8571428571428571
#
# macro
# Precision: 0.7029411764705882
# Recall: 0.7036846874056176
# F1 Score: 0.6899641577060931
#
# weighted
# Precision: 0.8872549019607843
# Recall: 0.8571428571428571
# F1 Score: 0.859861507326945
#
# start RF 1 SINIFGSM
# (34, 42) (34,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 1 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input1/x_test_adv_VNIFGSM_Def4.npy not found

# %%
epsilon = 0

Def = "Def4"
attack_names = [
    "baseline", "BIM", "FGSM", "PGD", "DF",
    "AutoPGD", "ZOO", "CaFA", "SINIFGSM", "VNIFGSM"
]

percentage = ["100", "50", "20", "10", "1"]
model_name = ["XGB", "RF" ]
active_learning_name = ["DensityWeighted", "BatchMode"]

base_path = "/home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data"

for ac_name in active_learning_name:
    for m_name in model_name:
        for p in percentage:
            for attack in attack_names:
                print(f"start {m_name} {p} {attack}")
                
                x_path = f"{base_path}/{m_name}_ActiveLearning_{ac_name}/WUSTL_Input{p}/x_test_adv_{attack}_{Def}.npy"
                y_path = f"{base_path}/{m_name}_ActiveLearning_{ac_name}/WUSTL_Input{p}/y_test_adv_{attack}_{Def}.npy"
    
                try:
                    x_test_adv = np.load(x_path)
                    y_test_adv = np.load(y_path)
                    m_per_name = f"{m_name}{p}_ActiveLearning_{ac_name}"
                    calculate_performance_metrics(x_test_adv, y_test_adv, model, m_per_name, attack, epsilon)
                except FileNotFoundError:
                    print(x_path, "not found")
                    print_empty_file()
# Out:
# start XGB 100 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input100/x_test_adv_baseline_Def4.npy not found
# start XGB 100 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input100/x_test_adv_BIM_Def4.npy not found
# start XGB 100 FGSM
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 100 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input100/x_test_adv_PGD_Def4.npy not found
# start XGB 100 DF
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 AutoPGD
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.8627450980392157
#
# macro
# Precision: 0.3333333333333333
# Recall: 0.28758169934640526
# F1 Score: 0.3087719298245614
#
# weighted
# Precision: 1.0
# Recall: 0.8627450980392157
# F1 Score: 0.9263157894736842
#
# start XGB 100 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input100/x_test_adv_ZOO_Def4.npy not found
# start XGB 100 CaFA
# Accuracy: 0.8724886087305522
#
# macro
# Precision: 0.7622442595048153
# Recall: 0.703443735141938
# F1 Score: 0.6218680982902219
#
# weighted
# Precision: 0.9651269327925835
# Recall: 0.8724886087305522
# F1 Score: 0.9128295010600288
#
# start XGB 100 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input100/x_test_adv_SINIFGSM_Def4.npy not found
# start XGB 100 VNIFGSM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input50/x_test_adv_baseline_Def4.npy not found
# start XGB 50 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input50/x_test_adv_BIM_Def4.npy not found
# start XGB 50 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input50/x_test_adv_FGSM_Def4.npy not found
# start XGB 50 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input50/x_test_adv_PGD_Def4.npy not found
# start XGB 50 DF
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 AutoPGD
# Accuracy: 0.9310344827586207
#
# macro
# Precision: 0.962962962962963
# Recall: 0.75
# F1 Score: 0.8141025641025641
#
# weighted
# Precision: 0.9361430395913155
# Recall: 0.9310344827586207
# F1 Score: 0.9208664898320071
#
# start XGB 50 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input50/x_test_adv_ZOO_Def4.npy not found
# start XGB 50 CaFA
# Accuracy: 0.8995962182391176
#
# macro
# Precision: 0.7590540075387444
# Recall: 0.7239521651191552
# F1 Score: 0.641121838442999
#
# weighted
# Precision: 0.9587560635070314
# Recall: 0.8995962182391176
# F1 Score: 0.9252545762581473
#
# start XGB 50 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input50/x_test_adv_SINIFGSM_Def4.npy not found
# start XGB 50 VNIFGSM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input20/x_test_adv_baseline_Def4.npy not found
# start XGB 20 BIM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 FGSM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 PGD
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 DF
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 AutoPGD
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.9490909090909091
#
# macro
# Precision: 0.6
# Recall: 0.5599999999999999
# F1 Score: 0.5777777777777777
#
# weighted
# Precision: 1.0
# Recall: 0.9490909090909091
# F1 Score: 0.9717171717171718
#
# start XGB 20 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input20/x_test_adv_ZOO_Def4.npy not found
# start XGB 20 CaFA
# Accuracy: 0.9147960179582276
#
# macro
# Precision: 0.7729829788286279
# Recall: 0.6573404894909103
# F1 Score: 0.623066604655172
#
# weighted
# Precision: 0.9597424282717796
# Recall: 0.9147960179582276
# F1 Score: 0.9288875829386766
#
# start XGB 20 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input20/x_test_adv_SINIFGSM_Def4.npy not found
# start XGB 20 VNIFGSM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 10 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input10/x_test_adv_baseline_Def4.npy not found
# start XGB 10 BIM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 10 FGSM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 10 PGD
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 10 DF
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 10 AutoPGD
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 10 ZOO
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 10 CaFA
# Accuracy: 0.8361471154195258
#
# macro
# Precision: 0.7198528984943791
# Recall: 0.6749061401361185
# F1 Score: 0.5923170094734258
#
# weighted
# Precision: 0.9167168011402882
# Recall: 0.8361471154195258
# F1 Score: 0.8636875220945858
#
# start XGB 10 SINIFGSM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 10 VNIFGSM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 1 baseline
# Accuracy: 0.9995968438633877
#
# macro
# Precision: 0.9992109607363421
# Recall: 0.932468694096601
# F1 Score: 0.9633394731549901
#
# weighted
# Precision: 0.9995977306753957
# Recall: 0.9995968438633877
# F1 Score: 0.9995833784975675
#
# start XGB 1 BIM
# Accuracy: 0.9991557619248628
#
# macro
# Precision: 0.9997448979591836
# Recall: 0.95
# F1 Score: 0.9720946060915433
#
# weighted
# Precision: 0.9991566233922864
# Recall: 0.9991557619248628
# F1 Score: 0.9991090752863705
#
# start XGB 1 FGSM
# Accuracy: 0.9953379953379954
#
# macro
# Precision: 0.9986127625842252
# Recall: 0.8987785862785863
# F1 Score: 0.937220915024067
#
# weighted
# Precision: 0.995363864567194
# Recall: 0.9953379953379954
# F1 Score: 0.9951309231359134
#
# start XGB 1 PGD
# Accuracy: 0.9991557619248628
#
# macro
# Precision: 0.9997448979591836
# Recall: 0.95
# F1 Score: 0.9720946060915433
#
# weighted
# Precision: 0.9991566233922864
# Recall: 0.9991557619248628
# F1 Score: 0.9991090752863705
#
# start XGB 1 DF
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.1724137931034483
#
# macro
# Precision: 0.24989429175475686
# Recall: 0.1869281045751634
# F1 Score: 0.2103023516237402
#
# weighted
# Precision: 0.21907122548662242
# Recall: 0.1724137931034483
# F1 Score: 0.19094875854346063
#
# start XGB 1 AutoPGD
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.9978980937885047
#
# macro
# Precision: 0.7975610985925008
# Recall: 0.6744241126970097
# F1 Score: 0.7242055865811089
#
# weighted
# Precision: 0.9980527051254103
# Recall: 0.9978980937885047
# F1 Score: 0.9978123929369778
#
# start XGB 1 ZOO
# Accuracy: 0.9995776378436492
#
# macro
# Precision: 0.9918577137158404
# Recall: 0.9307692307692308
# F1 Score: 0.9592387065047958
#
# weighted
# Precision: 0.999575701748537
# Recall: 0.9995776378436492
# F1 Score: 0.9995631864140114
#
# start XGB 1 CaFA
# Accuracy: 0.23156254491761294
#
# macro
# Precision: 0.27875763373548323
# Recall: 0.39956936136178334
# F1 Score: 0.17851119226623133
#
# weighted
# Precision: 0.8240323845937565
# Recall: 0.23156254491761294
# F1 Score: 0.32511540882376766
#
# start XGB 1 SINIFGSM
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 1 VNIFGSM
# Accuracy: 0.9948275862068966
#
# macro
# Precision: 0.9843344247487862
# Recall: 0.953125
# F1 Score: 0.966081404227956
#
# weighted
# Precision: 0.9949422432286171
# Recall: 0.9948275862068966
# F1 Score: 0.9945894865142783
#
# start RF 100 baseline
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input100/x_test_adv_BIM_Def4.npy not found
# start RF 100 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input100/x_test_adv_FGSM_Def4.npy not found
# start RF 100 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input100/x_test_adv_PGD_Def4.npy not found
# start RF 100 DF
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input100/x_test_adv_AutoPGD_Def4.npy not found
# start RF 100 ZOO
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 CaFA
# Accuracy: 0.9539909149902661
#
# macro
# Precision: 0.7785041157481114
# Recall: 0.7159494527337354
# F1 Score: 0.655280925390196
#
# weighted
# Precision: 0.9719347122244639
# Recall: 0.9539909149902661
# F1 Score: 0.9555718963663065
#
# start RF 100 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input100/x_test_adv_SINIFGSM_Def4.npy not found
# start RF 100 VNIFGSM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 baseline
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input50/x_test_adv_BIM_Def4.npy not found
# start RF 50 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input50/x_test_adv_FGSM_Def4.npy not found
# start RF 50 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input50/x_test_adv_PGD_Def4.npy not found
# start RF 50 DF
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input50/x_test_adv_AutoPGD_Def4.npy not found
# start RF 50 ZOO
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 CaFA
# Accuracy: 0.9567553400602804
#
# macro
# Precision: 0.7669199349722062
# Recall: 0.7365389752707229
# F1 Score: 0.6660609655046694
#
# weighted
# Precision: 0.9753301347093731
# Recall: 0.9567553400602804
# F1 Score: 0.9601861392880892
#
# start RF 50 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input50/x_test_adv_SINIFGSM_Def4.npy not found
# start RF 50 VNIFGSM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 baseline
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input20/x_test_adv_BIM_Def4.npy not found
# start RF 20 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input20/x_test_adv_FGSM_Def4.npy not found
# start RF 20 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input20/x_test_adv_PGD_Def4.npy not found
# start RF 20 DF
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input20/x_test_adv_AutoPGD_Def4.npy not found
# start RF 20 ZOO
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 CaFA
# Accuracy: 0.9161719153329891
#
# macro
# Precision: 0.7112433022708542
# Recall: 0.6821206265518677
# F1 Score: 0.5463359425534386
#
# weighted
# Precision: 0.9488413173488918
# Recall: 0.9161719153329891
# F1 Score: 0.9041557242500778
#
# start RF 20 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input20/x_test_adv_SINIFGSM_Def4.npy not found
# start RF 20 VNIFGSM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 10 baseline
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 10 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input10/x_test_adv_BIM_Def4.npy not found
# start RF 10 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input10/x_test_adv_FGSM_Def4.npy not found
# start RF 10 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input10/x_test_adv_PGD_Def4.npy not found
# start RF 10 DF
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 10 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input10/x_test_adv_AutoPGD_Def4.npy not found
# start RF 10 ZOO
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 10 CaFA
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.6658978583196046
#
# macro
# Precision: 0.6615033257946188
# Recall: 0.5929193591350651
# F1 Score: 0.5292406096628995
#
# weighted
# Precision: 0.8126105193225832
# Recall: 0.6658978583196046
# F1 Score: 0.5817506878220695
#
# start RF 10 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input10/x_test_adv_SINIFGSM_Def4.npy not found
# start RF 10 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input10/x_test_adv_VNIFGSM_Def4.npy not found
# start RF 1 baseline
# Accuracy: 0.9987995198079231
#
# macro
# Precision: 0.9964285714285716
# Recall: 0.980952380952381
# F1 Score: 0.9881981981981983
#
# weighted
# Precision: 0.9988209569542102
# Recall: 0.9987995198079231
# F1 Score: 0.9987749153715542
#
# start RF 1 BIM
# Accuracy: 0.999923774677948
#
# macro
# Precision: 0.9568028105993219
# Recall: 0.935654717450834
# F1 Score: 0.9405383870928539
#
# weighted
# Precision: 0.999931023653684
# Recall: 0.999923774677948
# F1 Score: 0.9999215411789681
#
# start RF 1 FGSM
# Accuracy: 0.9998136958924179
#
# macro
# Precision: 0.9118100846071029
# Recall: 0.912066140776699
# F1 Score: 0.9013855302024307
#
# weighted
# Precision: 0.9998507387825608
# Recall: 0.9998136958924179
# F1 Score: 0.9998141050187531
#
# start RF 1 PGD
# Accuracy: 0.999923774677948
#
# macro
# Precision: 0.9568028105993219
# Recall: 0.935654717450834
# F1 Score: 0.9405383870928539
#
# weighted
# Precision: 0.999931023653684
# Recall: 0.999923774677948
# F1 Score: 0.9999215411789681
#
# start RF 1 DF
# Accuracy: 0.22388059701492538
#
# macro
# Precision: 0.19642857142857142
# Recall: 0.13537549407114624
# F1 Score: 0.16025641025641027
#
# weighted
# Precision: 0.3238272921108742
# Recall: 0.22388059701492538
# F1 Score: 0.26470213037377216
#
# start RF 1 AutoPGD
# Accuracy: 0.9997037241869698
#
# macro
# Precision: 0.954356039958417
# Recall: 0.9420867084149593
# F1 Score: 0.9432526342461742
#
# weighted
# Precision: 0.9997242297823964
# Recall: 0.9997037241869698
# F1 Score: 0.999702242697634
#
# start RF 1 ZOO
# Accuracy: 0.9985007496251874
#
# macro
# Precision: 0.9901944444444444
# Recall: 0.9767441860465116
# F1 Score: 0.982685995839957
#
# weighted
# Precision: 0.9985314426120273
# Recall: 0.9985007496251874
# F1 Score: 0.9984622347046515
#
# start RF 1 CaFA
# Accuracy: 0.23282702970266206
#
# macro
# Precision: 0.2739649338047115
# Recall: 0.40569957839720516
# F1 Score: 0.1776470110775445
#
# weighted
# Precision: 0.8184777620884834
# Recall: 0.23282702970266206
# F1 Score: 0.32430852863851534
#
# start RF 1 SINIFGSM
# Accuracy: 0.9999272257158635
#
# macro
# Precision: 0.9626216748536987
# Recall: 0.9365086774067356
# F1 Score: 0.9443302743191012
#
# weighted
# Precision: 0.9999327839390971
# Recall: 0.9999272257158635
# F1 Score: 0.9999243916628627
#
# start RF 1 VNIFGSM
# Accuracy: 0.9999087556187329
#
# macro
# Precision: 0.95704794269401
# Recall: 0.9491571261604663
# F1 Score: 0.9491764627342976
#
# weighted
# Precision: 0.9999179303917063
# Recall: 0.9999087556187329
# F1 Score: 0.999907867571521
#
# start XGB 100 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input100/x_test_adv_baseline_Def4.npy not found
# start XGB 100 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input100/x_test_adv_BIM_Def4.npy not found
# start XGB 100 FGSM
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 100 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input100/x_test_adv_PGD_Def4.npy not found
# start XGB 100 DF
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 AutoPGD
# Accuracy: 0.8627450980392157
#
# macro
# Precision: 0.3333333333333333
# Recall: 0.28758169934640526
# F1 Score: 0.3087719298245614
#
# weighted
# Precision: 1.0
# Recall: 0.8627450980392157
# F1 Score: 0.9263157894736842
#
# start XGB 100 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input100/x_test_adv_ZOO_Def4.npy not found
# start XGB 100 CaFA
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.8724886087305522
#
# macro
# Precision: 0.7622442595048153
# Recall: 0.703443735141938
# F1 Score: 0.6218680982902219
#
# weighted
# Precision: 0.9651269327925835
# Recall: 0.8724886087305522
# F1 Score: 0.9128295010600288
#
# start XGB 100 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input100/x_test_adv_SINIFGSM_Def4.npy not found
# start XGB 100 VNIFGSM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input50/x_test_adv_baseline_Def4.npy not found
# start XGB 50 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input50/x_test_adv_BIM_Def4.npy not found
# start XGB 50 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input50/x_test_adv_FGSM_Def4.npy not found
# start XGB 50 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input50/x_test_adv_PGD_Def4.npy not found
# start XGB 50 DF
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 AutoPGD
# Accuracy: 0.8679245283018868
#
# macro
# Precision: 0.3129251700680272
# Recall: 0.3066666666666667
# F1 Score: 0.30976430976430974
#
# weighted
# Precision: 0.8856372737774355
# Recall: 0.8679245283018868
# F1 Score: 0.8766914427291785
#
# start XGB 50 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input50/x_test_adv_ZOO_Def4.npy not found
# start XGB 50 CaFA
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.9056652404763132
#
# macro
# Precision: 0.7704358277220065
# Recall: 0.7405051898934165
# F1 Score: 0.6466817115447278
#
# weighted
# Precision: 0.9679038026833391
# Recall: 0.9056652404763132
# F1 Score: 0.9328998281216478
#
# start XGB 50 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input50/x_test_adv_SINIFGSM_Def4.npy not found
# start XGB 50 VNIFGSM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input20/x_test_adv_baseline_Def4.npy not found
# start XGB 20 BIM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 FGSM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 PGD
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 DF
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 AutoPGD
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.9945945945945946
#
# macro
# Precision: 0.3333333333333333
# Recall: 0.33153153153153153
# F1 Score: 0.3324299909665763
#
# weighted
# Precision: 1.0
# Recall: 0.9945945945945946
# F1 Score: 0.9972899728997291
#
# start XGB 20 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input20/x_test_adv_ZOO_Def4.npy not found
# start XGB 20 CaFA
# Accuracy: 0.9090100051239179
#
# macro
# Precision: 0.7709988584306673
# Recall: 0.7336599810522373
# F1 Score: 0.6424131690142656
#
# weighted
# Precision: 0.9670122323610905
# Recall: 0.9090100051239179
# F1 Score: 0.9339836992193628
#
# start XGB 20 SINIFGSM
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.9995386389850057
#
# macro
# Precision: 0.3333333333333333
# Recall: 0.3333333333333333
# F1 Score: 0.3333333333333333
#
# weighted
# Precision: 0.9995386389850057
# Recall: 0.9995386389850057
# F1 Score: 0.9995386389850057
#
# start XGB 20 VNIFGSM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 10 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input10/x_test_adv_baseline_Def4.npy not found
# start XGB 10 BIM
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 10 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input10/x_test_adv_FGSM_Def4.npy not found
# start XGB 10 PGD
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 10 DF
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 10 AutoPGD
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.9259855189058729
#
# macro
# Precision: 0.4807692307692308
# Recall: 0.4813160032493907
# F1 Score: 0.480295358649789
#
# weighted
# Precision: 0.9992573797883533
# Recall: 0.9259855189058729
# F1 Score: 0.9611700289553992
#
# start XGB 10 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input10/x_test_adv_ZOO_Def4.npy not found
# start XGB 10 CaFA
# Accuracy: 0.9079680310002421
#
# macro
# Precision: 0.7764766479095345
# Recall: 0.7659432112996865
# F1 Score: 0.674263848397322
#
# weighted
# Precision: 0.9705642214977516
# Recall: 0.9079680310002421
# F1 Score: 0.9361056120268193
#
# start XGB 10 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input10/x_test_adv_SINIFGSM_Def4.npy not found
# start XGB 10 VNIFGSM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 1 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input1/x_test_adv_baseline_Def4.npy not found
# start XGB 1 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input1/x_test_adv_BIM_Def4.npy not found
# start XGB 1 FGSM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 1 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input1/x_test_adv_PGD_Def4.npy not found
# start XGB 1 DF
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 1 AutoPGD
# Accuracy: 0.971830985915493
#
# macro
# Precision: 0.6613756613756614
# Recall: 0.6197089947089948
# F1 Score: 0.6391534391534391
#
# weighted
# Precision: 0.9859154929577465
# Recall: 0.971830985915493
# F1 Score: 0.9784037558685447
#
# start XGB 1 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input1/x_test_adv_ZOO_Def4.npy not found
# start XGB 1 CaFA
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.9541103081959114
#
# macro
# Precision: 0.7943089787446806
# Recall: 0.7353858730253766
# F1 Score: 0.6855740392797803
#
# weighted
# Precision: 0.9660069561285419
# Recall: 0.9541103081959114
# F1 Score: 0.9541284204597412
#
# start RF 20 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input20/x_test_adv_SINIFGSM_Def4.npy not found
# start RF 20 VNIFGSM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 10 baseline
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 10 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input10/x_test_adv_BIM_Def4.npy not found
# start RF 10 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input10/x_test_adv_FGSM_Def4.npy not found
# start RF 10 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input10/x_test_adv_PGD_Def4.npy not found
# start RF 10 DF
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 10 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input10/x_test_adv_AutoPGD_Def4.npy not found
# start RF 10 ZOO
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 10 CaFA
# Accuracy: 0.9534711964549483
#
# macro
# Precision: 0.7932194959199961
# Recall: 0.7261519848554431
# F1 Score: 0.6800275265423241
#
# weighted
# Precision: 0.9654972894332726
# Recall: 0.9534711964549483
# F1 Score: 0.9535480679129802
#
# start RF 10 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input10/x_test_adv_SINIFGSM_Def4.npy not found
# start RF 10 VNIFGSM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 1 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input1/x_test_adv_baseline_Def4.npy not found
# start RF 1 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input1/x_test_adv_BIM_Def4.npy not found
# start RF 1 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input1/x_test_adv_FGSM_Def4.npy not found
# start RF 1 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input1/x_test_adv_PGD_Def4.npy not found
# start RF 1 DF
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 1 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input1/x_test_adv_AutoPGD_Def4.npy not found
# start RF 1 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input1/x_test_adv_ZOO_Def4.npy not found
# start RF 1 CaFA
# Accuracy: 0.9531548757170172
#
# macro
# Precision: 0.7898884366753449
# Recall: 0.7261980697963799
# F1 Score: 0.6710441715280577
#
# weighted
# Precision: 0.9682414722097521
# Recall: 0.9531548757170172
# F1 Score: 0.9538492060406195
#
# start RF 1 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input1/x_test_adv_SINIFGSM_Def4.npy not found
# start RF 1 VNIFGSM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0

# %%
epsilon = 0

Def = "Def4"
attack_names = [
    "baseline", "BIM", "FGSM", "PGD", "DF",
    "AutoPGD", "ZOO", "CaFA", "SINIFGSM", "VNIFGSM"
]

percentage = ["100", "50", "20", "10", "1"]
model_name = ["XGB", "RF"]

base_path = "/home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data"
total_num_attack = ["EOAL", "EOAL_ExcludeCaFA", "EOAL_Exclude2Attack", "EOAL_Exclude3Attack"]
for num_attack in total_num_attack:
    for m_name in model_name:
        for p in percentage:
            for attack in attack_names:
                print(f"start {m_name} {p} {attack}")
                
                x_path = f"{base_path}/{m_name}_ActiveLearning_{num_attack}/WUSTL_Input{p}/x_test_adv_{attack}_{Def}.npy"
                y_path = f"{base_path}/{m_name}_ActiveLearning_{num_attack}/WUSTL_Input{p}/y_test_adv_{attack}_{Def}.npy"
    
                try:
                    x_test_adv = np.load(x_path)
                    y_test_adv = np.load(y_path)
                    m_per_name = f"{m_name}{p}_ActiveLearning_{num_attack}"
                    calculate_performance_metrics(x_test_adv, y_test_adv, model, m_per_name, attack, epsilon)
                except FileNotFoundError:
                    print(x_path, "not found")
                    print_empty_file()

# %%
# torch.save(model.state_dict(), "./Free_Adversarial_Training.pt")

# %%
# import time

# epsilon_values = [0.01, 0.1, 0.2, 0.3]

# start_time = time.time()

# for epsilon in epsilon_values:
#     filename = f'/home/jovyan/Sample_Based_Extension/WUSTL/transfer_attack/x_test_adv_BIM_eps_{epsilon}.npy'
#     x_test_adv = np.load(filename)

#     calculate_performance_metrics(x_test_adv, y_test, model, 'DNN', 'BIM', epsilon)

# end_time = time.time()
# result = end_time - start_time
# print(f"Execution Time: {result:.6f} seconds")
