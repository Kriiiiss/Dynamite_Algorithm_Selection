# %%
import numpy as np
import pandas as pd

from sklearn.metrics import accuracy_score, precision_recall_fscore_support, roc_auc_score, confusion_matrix
from sklearn.preprocessing import label_binarize

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

# %%
from art.defences.preprocessor.feature_squeezing import FeatureSqueezing

feature_squeezer = FeatureSqueezing(clip_values=(0, 1), bit_depth=1)

def preprocess(inputs, feature_squeezer):
    inputs_squeezed, _ = feature_squeezer(inputs)
    return torch.tensor(inputs_squeezed, dtype=torch.float32)

# %%
head = {
            "model" : '',
            "attack_model": '',
            'epsilon': '',
            'Accuracy': '',
            'Macro Precision': '',
            'Weighted Precision': '',
            'Macro Recall': '',
            'Weighted Recall': '',
            'Macro F1': '',
            'Weighted F1': '',

        }
head = pd.DataFrame([head])
head.to_csv("./FeatureSqueezing.csv", mode='a', index=False)

# %%
def calculate_performance_metrics(X_test, y_test, model, model_name, attack_name, eps):
    model.eval()
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.to(device)
    
    all_preds = []
    all_labels = []
    probabilities = []

    num_classes = len(np.unique(y_test))
    
    # X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
    X_test_tensor = preprocess(X_test, feature_squeezer).to(device)
    y_test_tensor = torch.tensor(y_test, dtype=torch.long).to(device)
    test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
    test_loader = DataLoader(dataset=test_dataset)

    with torch.no_grad():
        
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            preds = torch.argmax(outputs, dim=1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            probabilities.extend(torch.nn.functional.softmax(outputs, dim=1).cpu().numpy())
        
        all_preds = np.array(all_preds)
        all_labels = np.array(all_labels)
        probabilities = np.array(probabilities)
        
        accuracy = accuracy_score(all_labels, all_preds)

        precision_macro, recall_macro, f1_macro, _ = precision_recall_fscore_support(all_labels, all_preds, average='macro')
        precision_weighted, recall_weighted, f1_weighted, _ = precision_recall_fscore_support(all_labels, all_preds, average='weighted')
    
    

        print(f"Accuracy: {accuracy}")
        
        print("\nmacro")
        print(f"Precision: {precision_macro}\nRecall: {recall_macro}\nF1 Score: {f1_macro}")
    
        print("\nweighted")
        print(f"Precision: {precision_weighted}\nRecall: {recall_weighted}\nF1 Score: {f1_weighted}")
        print()
        

        new_row = {
            "model" : model_name,
            "attack_model" : attack_name,
            'epsilon': eps,
            'Accuracy': accuracy,
            'Macro Precision': precision_macro,
            'Weighted Precision': precision_weighted,
            'Macro Recall': recall_macro,
            'Weighted Recall': recall_weighted,
            'Macro F1': f1_macro,
            'Weighted F1': f1_weighted,

        }
        new_row_df = pd.DataFrame([new_row])
        new_row_df.to_csv("./FeatureSqueezing.csv", mode='a', index=False, header=False)

# %%
# def calculate_performance_metrics(X_test, y_test, model, model_name, attack_name, eps):
#     model.eval()
#     device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#     model.to(device)
    
#     all_preds = []
#     all_labels = []
#     probabilities = []

#     num_classes = len(np.unique(y_test))
    
#     # X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
#     X_test_tensor = preprocess(X_test, feature_squeezer).to(device)
#     y_test_tensor = torch.tensor(y_test, dtype=torch.long).to(device)
#     test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
#     test_loader = DataLoader(dataset=test_dataset)

#     with torch.no_grad():
        
#         for inputs, labels in test_loader:
#             inputs, labels = inputs.to(device), labels.to(device)
#             outputs = model(inputs)
#             preds = torch.argmax(outputs, dim=1)
#             all_preds.extend(preds.cpu().numpy())
#             all_labels.extend(labels.cpu().numpy())
#             probabilities.extend(torch.nn.functional.softmax(outputs, dim=1).cpu().numpy())
        
#         all_preds = np.array(all_preds)
#         all_labels = np.array(all_labels)
#         probabilities = np.array(probabilities)

#         np.save(f"/home/jovyan/Sample_Based_Extension/UNSW/UNSW_Defense_Label/UNSW_Def5/y_pred_{attack_name}{eps}_Def5.npy", all_preds)

# %%
x_test = np.load('/home/jovyan/Sample_Based_Extension/UNSW/x_test.npy')
x_train = np.load('/home/jovyan/Sample_Based_Extension/UNSW/x_train.npy')
x_val = np.load('/home/jovyan/Sample_Based_Extension/UNSW/x_val.npy')
y_test = np.load('/home/jovyan/Sample_Based_Extension/UNSW/y_test.npy')
y_train = np.load('/home/jovyan/Sample_Based_Extension/UNSW/y_train.npy')
y_val = np.load('/home/jovyan/Sample_Based_Extension/UNSW/y_val.npy')

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
input_shape = x_train.shape[1]
output_shape = len(np.unique(y_train))

# %%
# x_train_tensor = torch.tensor(x_train, dtype=torch.float32).to(device)
x_train_tensor = preprocess(x_train, feature_squeezer).to(device)
y_train_tensor = torch.tensor(y_train, dtype=torch.long).to(device)

# x_val_tensor = torch.tensor(x_val, dtype=torch.float32).to(device)
x_val_tensor = preprocess(x_val, feature_squeezer).to(device)
y_val_tensor = torch.tensor(y_val, dtype=torch.long).to(device)

train_dataset = TensorDataset(x_train_tensor, y_train_tensor)
train_loader = DataLoader(train_dataset, batch_size=100, shuffle=True)

val_dataset = TensorDataset(x_val_tensor, y_val_tensor)
val_loader = DataLoader(val_dataset, batch_size=100, shuffle=True)

# %%
class DNNModel(nn.Module):
    def __init__(self, input_size, output_size):
        super(DNNModel, self).__init__()
        self.fc1 = nn.Linear(input_size, 50)
        self.fc2 = nn.Linear(50, 30)
        self.fc3 = nn.Linear(30, 20)
        self.fc4 = nn.Linear(20, output_size)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = self.fc4(x)
        return x

model = DNNModel(input_size=input_shape, output_size=output_shape).to(device)

# Compile model
optimizer = optim.Adam(model.parameters(), lr=0.001)
loss_function = nn.CrossEntropyLoss()

# Early stopping variables
min_delta = 0.001
patience = 5
patience_counter = 0
best_loss = float('inf')

# %%
for epoch in range(50):
    model.train()
    train_loss = 0.0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = loss_function(outputs, labels)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

    avg_train_loss = train_loss / len(train_loader)

    model.eval()
    val_train_loss = 0.0
    correct_predictions = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = loss_function(outputs, labels)
            val_train_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            correct_predictions += (predicted == labels).sum().item()

    avg_val_loss = val_train_loss / len(val_loader)
    val_accuracy = correct_predictions / len(val_dataset)

    print(f"Epoch {epoch+1}, Training Loss: {avg_train_loss:.4f}, Validation Loss: {avg_val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}")

    # Early stopping check using min_delta
    if best_loss - avg_val_loss > min_delta:
        best_loss = avg_val_loss
        patience_counter = 0
    else:
        patience_counter += 1

    if patience_counter >= patience:
        print("Early stopping triggered")
        break
# Out:
# Epoch 1, Training Loss: 0.1938, Validation Loss: 0.1379, Validation Accuracy: 0.9422
# Epoch 2, Training Loss: 0.1328, Validation Loss: 0.1236, Validation Accuracy: 0.9454
# Epoch 3, Training Loss: 0.1252, Validation Loss: 0.1183, Validation Accuracy: 0.9484
# Epoch 4, Training Loss: 0.1218, Validation Loss: 0.1308, Validation Accuracy: 0.9413
# Epoch 5, Training Loss: 0.1187, Validation Loss: 0.1152, Validation Accuracy: 0.9497
# Epoch 6, Training Loss: 0.1153, Validation Loss: 0.1125, Validation Accuracy: 0.9505
# Epoch 7, Training Loss: 0.1150, Validation Loss: 0.1124, Validation Accuracy: 0.9508
# Epoch 8, Training Loss: 0.1128, Validation Loss: 0.1092, Validation Accuracy: 0.9521
# Epoch 9, Training Loss: 0.1120, Validation Loss: 0.1115, Validation Accuracy: 0.9515
# Epoch 10, Training Loss: 0.1111, Validation Loss: 0.1068, Validation Accuracy: 0.9535
# Epoch 11, Training Loss: 0.1104, Validation Loss: 0.1125, Validation Accuracy: 0.9506
# Epoch 12, Training Loss: 0.1087, Validation Loss: 0.1083, Validation Accuracy: 0.9524
# Epoch 13, Training Loss: 0.1085, Validation Loss: 0.1065, Validation Accuracy: 0.9530
# Epoch 14, Training Loss: 0.1075, Validation Loss: 0.1102, Validation Accuracy: 0.9526
# Epoch 15, Training Loss: 0.1072, Validation Loss: 0.1056, Validation Accuracy: 0.9535
# Epoch 16, Training Loss: 0.1066, Validation Loss: 0.1042, Validation Accuracy: 0.9552
# Epoch 17, Training Loss: 0.1055, Validation Loss: 0.1021, Validation Accuracy: 0.9552
# Epoch 18, Training Loss: 0.1054, Validation Loss: 0.1035, Validation Accuracy: 0.9549
# Epoch 19, Training Loss: 0.1050, Validation Loss: 0.1011, Validation Accuracy: 0.9560
# Epoch 20, Training Loss: 0.1045, Validation Loss: 0.1060, Validation Accuracy: 0.9534
# Epoch 21, Training Loss: 0.1040, Validation Loss: 0.1022, Validation Accuracy: 0.9555
# Epoch 22, Training Loss: 0.1032, Validation Loss: 0.1021, Validation Accuracy: 0.9559
# Epoch 23, Training Loss: 0.1026, Validation Loss: 0.1041, Validation Accuracy: 0.9543
# Epoch 24, Training Loss: 0.1024, Validation Loss: 0.1006, Validation Accuracy: 0.9564
# Early stopping triggered

# %%
model.load_state_dict(torch.load("/home/jovyan/Sample_Based_Extension/UNSW/UNSW_Defense/preprocessor/dnn_pytorch_FeatureSqueezing.pt"))
# Out:
# /tmp/ipykernel_2291/2979463627.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("/home/jovyan/Sample_Based_Extension/UNSW/UNSW_Defense/preprocessor/dnn_pytorch_FeatureSqueezing.pt"))
# <All keys matched successfully>

# %%
# calculate_performance_metrics(x_test, y_test, model, 'DNN', 'Baseline', '0')

# %%
epsilon = 0
Def = "Def5"
attack_names = [
    "baseline", "BIM", "FGSM", "PGD", "DF",
    "AutoPGD", "ZOO", "CaFA", "SINIFGSM", "VNIFGSM"
]

percentage = ["100", "50", "20", "1"]
model_name = ["XGB", "RF", "DT" ]

base_path = "/home/jovyan/Sample_Based_Extension/UNSW/UNSW_Dynamite_Selection_Data"

for m_name in model_name:
    for p in percentage:
        for attack in attack_names:
            print(f"start {m_name} {p} {attack}")
            
            x_path = f"{base_path}/{m_name}/UNSW_Input{p}/x_test_adv_{attack}_{Def}.npy"
            y_path = f"{base_path}/{m_name}/UNSW_Input{p}/y_test_adv_{attack}_{Def}.npy"

            try:
                x_test_adv = np.load(x_path)
                y_test_adv = np.load(y_path)
                print(x_test_adv.shape, y_test_adv.shape)

                m_per_name = f"{m_name}{p}"
                calculate_performance_metrics(x_test_adv, y_test_adv, model, m_per_name, attack, epsilon)
            except FileNotFoundError:
                print(x_path, "not found")
                new_row = {
                    "model" : "0",
                    "attack_model" : "0",
                    'epsilon': "0",
                    'Accuracy': "0",
                    'Macro Precision': "0",
                    'Weighted Precision': "0",
                    'Macro Recall': "0",
                    'Weighted Recall': "0",
                    'Macro F1': "0",
                    'Weighted F1': "0",
                }
                new_row_df = pd.DataFrame([new_row])
                new_row_df.to_csv("./FeatureSqueezing.csv", mode='a', index=False, header=False)
# Out:
# start XGB 100 baseline
# (66, 56) (66,)
# Accuracy: 0.9090909090909091
#
# macro
# Precision: 0.90625
# Recall: 0.925
# F1 Score: 0.907735321528425
#
# weighted
# Precision: 0.9261363636363636
# Recall: 0.9090909090909091
# F1 Score: 0.9101075997627722
#
# start XGB 100 BIM
# (451, 56) (451,)
# Accuracy: 0.6452328159645233
#
# macro
# Precision: 0.5771048894299047
# Recall: 0.7122235872235871
# F1 Score: 0.5331262939958592
#
# weighted
# Precision: 0.8901483999623928
# Recall: 0.6452328159645233
# F1 Score: 0.7172650608493661
#
# start XGB 100 FGSM
# (114, 56) (114,)
# Accuracy: 0.32456140350877194
#
# macro
# Precision: 0.5470588235294118
# Recall: 0.6367924528301887
# F1 Score: 0.3008363201911589
#
# weighted
# Precision: 0.9364293085655314
# Recall: 0.32456140350877194
# F1 Score: 0.41155337567335304
#
# start XGB 100 PGD
# (451, 56) (451,)
# Accuracy: 0.6452328159645233
#
# macro
# Precision: 0.5771048894299047
# Recall: 0.7122235872235871
# F1 Score: 0.5331262939958592
#
# weighted
# Precision: 0.8901483999623928
# Recall: 0.6452328159645233
# F1 Score: 0.7172650608493661
#
# start XGB 100 DF
# (199, 56) (199,)
# Accuracy: 0.8391959798994975
#
# macro
# Precision: 0.8469130895601484
# Recall: 0.791917502787068
# F1 Score: 0.8091127098321342
#
# weighted
# Precision: 0.8420600618354092
# Recall: 0.8391959798994975
# F1 Score: 0.8323415639347819
#
# start XGB 100 AutoPGD
# (479, 56) (479,)
# Accuracy: 0.8100208768267223
#
# macro
# Precision: 0.7443820224719101
# Recall: 0.8839285714285714
# F1 Score: 0.7626453211358872
#
# weighted
# Precision: 0.9071450353029485
# Recall: 0.8100208768267223
# F1 Score: 0.8301665570503953
#
# start XGB 100 ZOO
# (196, 56) (196,)
# Accuracy: 0.923469387755102
#
# macro
# Precision: 0.9193548387096775
# Recall: 0.9364406779661016
# F1 Score: 0.9222036992934826
#
# weighted
# Precision: 0.935813034891376
# Recall: 0.923469387755102
# F1 Score: 0.9242288008320737
#
# start XGB 100 CaFA
# (170, 56) (170,)
# Accuracy: 0.7647058823529411
#
# macro
# Precision: 0.7359683794466403
# Recall: 0.7317186772240335
# F1 Score: 0.7337092731829574
#
# weighted
# Precision: 0.7627900488258545
# Recall: 0.7647058823529411
# F1 Score: 0.7636370337608728
#
# start XGB 100 SINIFGSM
# (269, 56) (269,)
# Accuracy: 0.38661710037174724
#
# macro
# Precision: 0.4754704301075269
# Recall: 0.4658878504672897
# F1 Score: 0.37412750116333177
#
# weighted
# Precision: 0.6456834352640205
# Recall: 0.38661710037174724
# F1 Score: 0.42638661364064895
#
# start XGB 100 VNIFGSM
# (326, 56) (326,)
# Accuracy: 0.30368098159509205
#
# macro
# Precision: 0.5176226507200391
# Recall: 0.5589869281045752
# F1 Score: 0.2748527696935846
#
# weighted
# Precision: 0.9098490441157753
# Recall: 0.30368098159509205
# F1 Score: 0.4016969020602174
#
# start XGB 50 baseline
# (53, 56) (53,)
# Accuracy: 0.9811320754716981
#
# macro
# Precision: 0.9791666666666667
# Recall: 0.9833333333333334
# F1 Score: 0.9808871258564731
#
# weighted
# Precision: 0.9819182389937108
# Recall: 0.9811320754716981
# F1 Score: 0.981172900407569
#
# start XGB 50 BIM
# (187, 56) (187,)
# Accuracy: 0.6631016042780749
#
# macro
# Precision: 0.5434782608695652
# Recall: 0.8259668508287292
# F1 Score: 0.47464882943143816
#
# weighted
# Precision: 0.9707044873285282
# Recall: 0.6631016042780749
# F1 Score: 0.7691062901293081
#
# start XGB 50 FGSM
# (83, 56) (83,)
# Accuracy: 0.6265060240963856
#
# macro
# Precision: 0.7327586206896551
# Recall: 0.7232142857142857
# F1 Score: 0.6262890341321714
#
# weighted
# Precision: 0.8261321146655588
# Recall: 0.6265060240963856
# F1 Score: 0.6231426796510662
#
# start XGB 50 PGD
# (187, 56) (187,)
# Accuracy: 0.6631016042780749
#
# macro
# Precision: 0.5434782608695652
# Recall: 0.8259668508287292
# F1 Score: 0.47464882943143816
#
# weighted
# Precision: 0.9707044873285282
# Recall: 0.6631016042780749
# F1 Score: 0.7691062901293081
#
# start XGB 50 DF
# (176, 56) (176,)
# Accuracy: 0.7727272727272727
#
# macro
# Precision: 0.7898184540520307
# Recall: 0.7146223146223146
# F1 Score: 0.7270471464019852
#
# weighted
# Precision: 0.7817960628179605
# Recall: 0.7727272727272727
# F1 Score: 0.7562316715542522
#
# start XGB 50 AutoPGD
# (270, 56) (270,)
# Accuracy: 0.8333333333333334
#
# macro
# Precision: 0.8021250211374782
# Recall: 0.8828571428571429
# F1 Score: 0.8140239702438352
#
# weighted
# Precision: 0.8943313980797776
# Recall: 0.8333333333333334
# F1 Score: 0.8428770415269933
#
# start XGB 50 ZOO
# (159, 56) (159,)
# Accuracy: 0.9811320754716981
#
# macro
# Precision: 0.9791666666666667
# Recall: 0.9833333333333334
# F1 Score: 0.9808871258564731
#
# weighted
# Precision: 0.9819182389937107
# Recall: 0.9811320754716981
# F1 Score: 0.981172900407569
#
# start XGB 50 CaFA
# (187, 56) (187,)
# Accuracy: 0.7754010695187166
#
# macro
# Precision: 0.753399708596406
# Recall: 0.7631778058007566
# F1 Score: 0.7573529411764706
#
# weighted
# Precision: 0.7812680990979993
# Recall: 0.7754010695187166
# F1 Score: 0.7775243787354513
#
# start XGB 50 SINIFGSM
# (142, 56) (142,)
# Accuracy: 0.4225352112676056
#
# macro
# Precision: 0.5403846153846154
# Recall: 0.6431818181818182
# F1 Score: 0.36717391304347824
#
# weighted
# Precision: 0.9187432286023834
# Recall: 0.4225352112676056
# F1 Score: 0.5279853031230863
#
# start XGB 50 VNIFGSM
# (156, 56) (156,)
# Accuracy: 0.5128205128205128
#
# macro
# Precision: 0.6
# Recall: 0.7226277372262774
# F1 Score: 0.4747474747474747
#
# weighted
# Precision: 0.9025641025641027
# Recall: 0.5128205128205128
# F1 Score: 0.5817145817145817
#
# start XGB 20 baseline
# (41, 56) (41,)
# Accuracy: 0.975609756097561
#
# macro
# Precision: 0.9666666666666667
# Recall: 0.9814814814814814
# F1 Score: 0.9733246584255042
#
# weighted
# Precision: 0.9772357723577235
# Recall: 0.975609756097561
# F1 Score: 0.9758001809035657
#
# start XGB 20 BIM
# (211, 56) (211,)
# Accuracy: 0.6729857819905213
#
# macro
# Precision: 0.625
# Recall: 0.8164893617021276
# F1 Score: 0.5876221498371336
#
# weighted
# Precision: 0.9182464454976303
# Recall: 0.6729857819905213
# F1 Score: 0.7343408926007687
#
# start XGB 20 FGSM
# (89, 56) (89,)
# Accuracy: 0.3146067415730337
#
# macro
# Precision: 0.5314542483660131
# Recall: 0.5346846846846847
# F1 Score: 0.3142604521914867
#
# weighted
# Precision: 0.7640724829257546
# Recall: 0.3146067415730337
# F1 Score: 0.32447598894712415
#
# start XGB 20 PGD
# (211, 56) (211,)
# Accuracy: 0.6729857819905213
#
# macro
# Precision: 0.625
# Recall: 0.8164893617021276
# F1 Score: 0.5876221498371336
#
# weighted
# Precision: 0.9182464454976303
# Recall: 0.6729857819905213
# F1 Score: 0.7343408926007687
#
# start XGB 20 DF
# (333, 56) (333,)
# Accuracy: 0.5345345345345346
#
# macro
# Precision: 0.6727055647840532
# Recall: 0.5602455454150369
# F1 Score: 0.459602357794227
#
# weighted
# Precision: 0.6834921507886624
# Recall: 0.5345345345345346
# F1 Score: 0.44691223108820716
#
# start XGB 20 AutoPGD
# (259, 56) (259,)
# Accuracy: 0.8532818532818532
#
# macro
# Precision: 0.7764705882352941
# Recall: 0.9103773584905661
# F1 Score: 0.8068378081331449
#
# weighted
# Precision: 0.9188734953440836
# Recall: 0.8532818532818532
# F1 Score: 0.8671784967121755
#
# start XGB 20 ZOO
# (115, 56) (115,)
# Accuracy: 0.9652173913043478
#
# macro
# Precision: 0.9534883720930232
# Recall: 0.9736842105263157
# F1 Score: 0.9620962425840475
#
# weighted
# Precision: 0.9684529828109202
# Recall: 0.9652173913043478
# F1 Score: 0.965595712361354
#
# start XGB 20 CaFA
# (75, 56) (75,)
# Accuracy: 0.7066666666666667
#
# macro
# Precision: 0.7035714285714285
# Recall: 0.7056277056277056
# F1 Score: 0.7040889526542324
#
# weighted
# Precision: 0.7091428571428571
# Recall: 0.7066666666666667
# F1 Score: 0.707403156384505
#
# start XGB 20 SINIFGSM
# (141, 56) (141,)
# Accuracy: 0.5319148936170213
#
# macro
# Precision: 0.5882716049382716
# Recall: 0.6850733390854185
# F1 Score: 0.4886813186813187
#
# weighted
# Precision: 0.8646878557044042
# Recall: 0.5319148936170213
# F1 Score: 0.5972924947393032
#
# start XGB 20 VNIFGSM
# (293, 56) (293,)
# Accuracy: 0.4334470989761092
#
# macro
# Precision: 0.6612244897959183
# Recall: 0.6121495327102804
# F1 Score: 0.42703326736405617
#
# weighted
# Precision: 0.8173155951800516
# Recall: 0.4334470989761092
# F1 Score: 0.3991020651825348
#
# start XGB 1 baseline
# (10, 56) (10,)
# Accuracy: 0.7
#
# macro
# Precision: 0.8125
# Recall: 0.7
# F1 Score: 0.6703296703296704
#
# weighted
# Precision: 0.8125
# Recall: 0.7
# F1 Score: 0.6703296703296703
#
# start XGB 1 BIM
# (243, 56) (243,)
# Accuracy: 0.35802469135802467
#
# macro
# Precision: 0.41470588235294115
# Recall: 0.3964285714285714
# F1 Score: 0.35
#
# weighted
# Precision: 0.5199709513435004
# Recall: 0.35802469135802467
# F1 Score: 0.38477366255144035
#
# start XGB 1 FGSM
# (25, 56) (25,)
# Accuracy: 0.36
#
# macro
# Precision: 0.36038961038961037
# Recall: 0.3621794871794872
# F1 Score: 0.358974358974359
#
# weighted
# Precision: 0.3605194805194805
# Recall: 0.36
# F1 Score: 0.35794871794871796
#
# start XGB 1 PGD
# (243, 56) (243,)
# Accuracy: 0.35802469135802467
#
# macro
# Precision: 0.41470588235294115
# Recall: 0.3964285714285714
# F1 Score: 0.35
#
# weighted
# Precision: 0.5199709513435004
# Recall: 0.35802469135802467
# F1 Score: 0.38477366255144035
#
# start XGB 1 DF
# (158, 56) (158,)
# Accuracy: 0.5759493670886076
#
# macro
# Precision: 0.6871442125237192
# Recall: 0.6305210918114144
# F1 Score: 0.5589717951922676
#
# weighted
# Precision: 0.721738164436865
# Recall: 0.5759493670886076
# F1 Score: 0.5436372141246057
#
# start XGB 1 AutoPGD
# (201, 56) (201,)
# Accuracy: 0.373134328358209
#
# macro
# Precision: 0.502680200729927
# Recall: 0.5047113071371292
# F1 Score: 0.3535327751684705
#
# weighted
# Precision: 0.756448142499183
# Recall: 0.373134328358209
# F1 Score: 0.4336191210579733
#
# start XGB 1 ZOO
# (30, 56) (30,)
# Accuracy: 0.7333333333333333
#
# macro
# Precision: 0.8333333333333333
# Recall: 0.7142857142857143
# F1 Score: 0.7
#
# weighted
# Precision: 0.8222222222222222
# Recall: 0.7333333333333333
# F1 Score: 0.7066666666666668
#
# start XGB 1 CaFA
# (86, 56) (86,)
# Accuracy: 0.6627906976744186
#
# macro
# Precision: 0.5891938250428816
# Recall: 0.6547619047619048
# F1 Score: 0.5754893617021277
#
# weighted
# Precision: 0.8026247556743388
# Recall: 0.6627906976744186
# F1 Score: 0.7053221177634834
#
# start XGB 1 SINIFGSM
# (122, 56) (122,)
# Accuracy: 0.2540983606557377
#
# macro
# Precision: 0.26716417910447765
# Recall: 0.24464285714285716
# F1 Score: 0.24553177030241252
#
# weighted
# Precision: 0.30853927085882066
# Recall: 0.2540983606557377
# F1 Score: 0.27057257287367076
#
# start XGB 1 VNIFGSM
# (90, 56) (90,)
# Accuracy: 0.35555555555555557
#
# macro
# Precision: 0.41203703703703703
# Recall: 0.3680555555555556
# F1 Score: 0.3287037037037037
#
# weighted
# Precision: 0.5814814814814815
# Recall: 0.35555555555555557
# F1 Score: 0.40925925925925927
#
# start RF 100 baseline
# (138, 56) (138,)
# Accuracy: 0.9855072463768116
#
# macro
# Precision: 0.9898989898989898
# Recall: 0.975609756097561
# F1 Score: 0.9823979591836735
#
# weighted
# Precision: 0.9858000292782901
# Recall: 0.9855072463768116
# F1 Score: 0.9854000295770482
#
# start RF 100 BIM
# (7, 56) (7,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 FGSM
# (6, 56) (6,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 PGD
# (7, 56) (7,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 DF
# (277, 56) (277,)
# Accuracy: 0.8086642599277978
#
# macro
# Precision: 0.8231539670070699
# Recall: 0.7713853765805387
# F1 Score: 0.7837626854020296
#
# weighted
# Precision: 0.8158511546391167
# Recall: 0.8086642599277978
# F1 Score: 0.8004520385416403
#
# start RF 100 AutoPGD
# (409, 56) (409,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 ZOO
# (407, 56) (407,)
# Accuracy: 0.9926289926289926
#
# macro
# Precision: 0.9948275862068965
# Recall: 0.9875
# F1 Score: 0.9910712326964
#
# weighted
# Precision: 0.9927052444293823
# Recall: 0.9926289926289926
# F1 Score: 0.9926015027478293
#
# start RF 100 CaFA
# (89, 56) (89,)
# Accuracy: 0.9101123595505618
#
# macro
# Precision: 0.8687423687423688
# Recall: 0.9097693351424694
# F1 Score: 0.8858974358974359
#
# weighted
# Precision: 0.9190572224280089
# Recall: 0.9101123595505618
# F1 Score: 0.9124747911264767
#
# start RF 100 SINIFGSM
# (12, 56) (12,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 VNIFGSM
# (7, 56) (7,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 baseline
# (119, 56) (119,)
# Accuracy: 0.9159663865546218
#
# macro
# Precision: 0.9425287356321839
# Recall: 0.8809523809523809
# F1 Score: 0.9019446275543836
#
# weighted
# Precision: 0.9256254225828262
# Recall: 0.9159663865546218
# F1 Score: 0.9128504401101244
#
# start RF 50 BIM
# (6, 56) (6,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 FGSM
# (8, 56) (8,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 PGD
# (6, 56) (6,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 DF
# (245, 56) (245,)
# Accuracy: 0.7387755102040816
#
# macro
# Precision: 0.7490079365079365
# Recall: 0.6856770466394251
# F1 Score: 0.6925490196078432
#
# weighted
# Precision: 0.7446226109491416
# Recall: 0.7387755102040816
# F1 Score: 0.7202849139655862
#
# start RF 50 AutoPGD
# (330, 56) (330,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 ZOO
# (342, 56) (342,)
# Accuracy: 0.9502923976608187
#
# macro
# Precision: 0.9654471544715447
# Recall: 0.9247787610619469
# F1 Score: 0.9414354066985646
#
# weighted
# Precision: 0.95372747587125
# Recall: 0.9502923976608187
# F1 Score: 0.9491603010716585
#
# start RF 50 CaFA
# (67, 56) (67,)
# Accuracy: 0.8955223880597015
#
# macro
# Precision: 0.8982974910394266
# Recall: 0.8961675579322639
# F1 Score: 0.8954292084726867
#
# weighted
# Precision: 0.8988525116353715
# Recall: 0.8955223880597015
# F1 Score: 0.8953826186791793
#
# start RF 50 SINIFGSM
# (6, 56) (6,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 VNIFGSM
# (6, 56) (6,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 baseline
# (59, 56) (59,)
# Accuracy: 0.8983050847457628
#
# macro
# Precision: 0.9117647058823529
# Recall: 0.9032258064516129
# F1 Score: 0.8980414746543779
#
# weighted
# Precision: 0.9162512462612165
# Recall: 0.8983050847457628
# F1 Score: 0.897777864562993
#
# start RF 20 BIM
# (4, 56) (4,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 FGSM
# (1, 56) (1,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 PGD
# (4, 56) (4,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 DF
# (177, 56) (177,)
# Accuracy: 0.6497175141242938
#
# macro
# Precision: 0.7325925925925926
# Recall: 0.621141975308642
# F1 Score: 0.5869467028003613
#
# weighted
# Precision: 0.7224858757062147
# Recall: 0.6497175141242938
# F1 Score: 0.6005925313490422
#
# start RF 20 AutoPGD
# (162, 56) (162,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 ZOO
# (170, 56) (170,)
# Accuracy: 0.9294117647058824
#
# macro
# Precision: 0.9368421052631579
# Recall: 0.9310344827586207
# F1 Score: 0.9292550977944236
#
# weighted
# Precision: 0.9383281733746129
# Recall: 0.9294117647058824
# F1 Score: 0.9291767643386942
#
# start RF 20 CaFA
# (11, 56) (11,)
# Accuracy: 0.6363636363636364
#
# macro
# Precision: 0.6666666666666666
# Recall: 0.7777777777777778
# F1 Score: 0.6071428571428572
#
# weighted
# Precision: 0.8787878787878788
# Recall: 0.6363636363636364
# F1 Score: 0.6753246753246753
#
# start RF 20 SINIFGSM
# (20, 56) (20,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 VNIFGSM
# (16, 56) (16,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 1 baseline
# (3, 56) (3,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 1 BIM
# /home/jovyan/Sample_Based_Extension/UNSW/UNSW_Dynamite_Selection_Data/RF/UNSW_Input1/x_test_adv_BIM_Def5.npy not found
# start RF 1 FGSM
# /home/jovyan/Sample_Based_Extension/UNSW/UNSW_Dynamite_Selection_Data/RF/UNSW_Input1/x_test_adv_FGSM_Def5.npy not found
# start RF 1 PGD
# /home/jovyan/Sample_Based_Extension/UNSW/UNSW_Dynamite_Selection_Data/RF/UNSW_Input1/x_test_adv_PGD_Def5.npy not found
# start RF 1 DF
# (65, 56) (65,)
# Accuracy: 0.4461538461538462
#
# macro
# Precision: 0.6896551724137931
# Recall: 0.5813953488372093
# F1 Score: 0.41500000000000004
#
# weighted
# Precision: 0.789920424403183
# Recall: 0.4461538461538462
# F1 Score: 0.37138461538461537
#
# start RF 1 AutoPGD
# (9, 56) (9,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 1 ZOO
# (9, 56) (9,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 1 CaFA
# (40, 56) (40,)
# Accuracy: 0.925
#
# macro
# Precision: 0.625
# Recall: 0.9615384615384616
# F1 Score: 0.6799999999999999
#
# weighted
# Precision: 0.98125
# Recall: 0.925
# F1 Score: 0.946
#
# start RF 1 SINIFGSM
# /home/jovyan/Sample_Based_Extension/UNSW/UNSW_Dynamite_Selection_Data/RF/UNSW_Input1/x_test_adv_SINIFGSM_Def5.npy not found
# start RF 1 VNIFGSM
# /home/jovyan/Sample_Based_Extension/UNSW/UNSW_Dynamite_Selection_Data/RF/UNSW_Input1/x_test_adv_VNIFGSM_Def5.npy not found
# start DT 100 baseline
# (198, 56) (198,)
# Accuracy: 0.9242424242424242
#
# macro
# Precision: 0.9222709217915355
# Recall: 0.8877012072434608
# F1 Score: 0.9027982326951398
#
# weighted
# Precision: 0.9239664138992998
# Recall: 0.9242424242424242
# F1 Score: 0.9226283453087577
#
# start DT 100 BIM
# (3513, 56) (3513,)
# Accuracy: 0.23797324224309707
#
# macro
# Precision: 0.31165524304473774
# Recall: 0.3056939897250028
# F1 Score: 0.23785368182933253
#
# weighted
# Precision: 0.38929332442633224
# Recall: 0.23797324224309707
# F1 Score: 0.24254642806959167
#
# start DT 100 FGSM
# (541, 56) (541,)
# Accuracy: 0.3364140480591497
#
# macro
# Precision: 0.35512157925951027
# Recall: 0.34956011730205283
# F1 Score: 0.33531487318487185
#
# weighted
# Precision: 0.3823150009012715
# Recall: 0.3364140480591497
# F1 Score: 0.3423595848791073
#
# start DT 100 PGD
# (3513, 56) (3513,)
# Accuracy: 0.23797324224309707
#
# macro
# Precision: 0.31165524304473774
# Recall: 0.3056939897250028
# F1 Score: 0.23785368182933253
#
# weighted
# Precision: 0.38929332442633224
# Recall: 0.23797324224309707
# F1 Score: 0.24254642806959167
#
# start DT 100 DF
# (586, 56) (586,)
# Accuracy: 0.4948805460750853
#
# macro
# Precision: 0.5697189994854686
# Recall: 0.5509244104988786
# F1 Score: 0.4790985969632904
#
# weighted
# Precision: 0.5968479388467325
# Recall: 0.4948805460750853
# F1 Score: 0.461150497973406
#
# start DT 100 AutoPGD
# (2973, 56) (2973,)
# Accuracy: 0.35486041035990584
#
# macro
# Precision: 0.46623826083474057
# Recall: 0.47189045270700586
# F1 Score: 0.3518384726604771
#
# weighted
# Precision: 0.55081148339447
# Recall: 0.35486041035990584
# F1 Score: 0.33276900372959894
#
# start DT 100 ZOO
# (567, 56) (567,)
# Accuracy: 0.9541446208112875
#
# macro
# Precision: 0.9565507545558087
# Recall: 0.9211731678486997
# F1 Score: 0.9371246758564215
#
# weighted
# Precision: 0.9543921972737464
# Recall: 0.9541446208112875
# F1 Score: 0.9532215051527184
#
# start DT 100 CaFA
# (877, 56) (877,)
# Accuracy: 0.4811858608893957
#
# macro
# Precision: 0.4691130306654139
# Recall: 0.4693076923076923
# F1 Score: 0.4691601093514078
#
# weighted
# Precision: 0.47964464852037675
# Recall: 0.4811858608893957
# F1 Score: 0.4803659232845328
#
# start DT 100 SINIFGSM
# (2744, 56) (2744,)
# Accuracy: 0.2164723032069971
#
# macro
# Precision: 0.2449736944974202
# Recall: 0.22420737677167876
# F1 Score: 0.21373178599473405
#
# weighted
# Precision: 0.2874244072049084
# Recall: 0.2164723032069971
# F1 Score: 0.23041172408912514
#
# start DT 100 VNIFGSM
# (2078, 56) (2078,)
# Accuracy: 0.2964388835418672
#
# macro
# Precision: 0.326366143553077
# Recall: 0.32115250268278706
# F1 Score: 0.2960632840413552
#
# weighted
# Precision: 0.36142379099477995
# Recall: 0.2964388835418672
# F1 Score: 0.30119647721501874
#
# start DT 50 baseline
# (164, 56) (164,)
# Accuracy: 0.823170731707317
#
# macro
# Precision: 0.8559649122807017
# Recall: 0.8054342917356616
# F1 Score: 0.8113821138211382
#
# weighted
# Precision: 0.8467415489944372
# Recall: 0.823170731707317
# F1 Score: 0.8165576046004362
#
# start DT 50 BIM
# (1250, 56) (1250,)
# Accuracy: 0.7656
#
# macro
# Precision: 0.7592592592592593
# Recall: 0.7683333333333333
# F1 Score: 0.7609139126886986
#
# weighted
# Precision: 0.7751111111111111
# Recall: 0.7656
# F1 Score: 0.7676083231334149
#
# start DT 50 FGSM
# (844, 56) (844,)
# Accuracy: 0.3080568720379147
#
# macro
# Precision: 0.3287785626447794
# Recall: 0.30796174053617137
# F1 Score: 0.29973631569376247
#
# weighted
# Precision: 0.38294578896798703
# Recall: 0.3080568720379147
# F1 Score: 0.3266876829824294
#
# start DT 50 PGD
# (1250, 56) (1250,)
# Accuracy: 0.7656
#
# macro
# Precision: 0.7592592592592593
# Recall: 0.7683333333333333
# F1 Score: 0.7609139126886986
#
# weighted
# Precision: 0.7751111111111111
# Recall: 0.7656
# F1 Score: 0.7676083231334149
#
# start DT 50 DF
# (409, 56) (409,)
# Accuracy: 0.6161369193154034
#
# macro
# Precision: 0.6932962090383379
# Recall: 0.6297627606038821
# F1 Score: 0.5873651336293593
#
# weighted
# Precision: 0.699534619696788
# Recall: 0.6161369193154034
# F1 Score: 0.5823034305919996
#
# start DT 50 AutoPGD
# (898, 56) (898,)
# Accuracy: 0.9020044543429844
#
# macro
# Precision: 0.9049013477308199
# Recall: 0.8982205088974555
# F1 Score: 0.9005116428974297
#
# weighted
# Precision: 0.9032459800806282
# Recall: 0.9020044543429844
# F1 Score: 0.9015973239487423
#
# start DT 50 ZOO
# (515, 56) (515,)
# Accuracy: 0.7941747572815534
#
# macro
# Precision: 0.8230793363078639
# Recall: 0.7813496038612149
# F1 Score: 0.7833730158730159
#
# weighted
# Precision: 0.8168090308048017
# Recall: 0.7941747572815534
# F1 Score: 0.7872240715056249
#
# start DT 50 CaFA
# (2577, 56) (2577,)
# Accuracy: 0.38804811796662786
#
# macro
# Precision: 0.42562126318932125
# Recall: 0.42441617543346066
# F1 Score: 0.3879537433140986
#
# weighted
# Precision: 0.4664930110104404
# Recall: 0.38804811796662786
# F1 Score: 0.3902924651720889
#
# start DT 50 SINIFGSM
# (723, 56) (723,)
# Accuracy: 0.5477178423236515
#
# macro
# Precision: 0.5648964851551058
# Recall: 0.5601069733029164
# F1 Score: 0.5431875489087905
#
# weighted
# Precision: 0.5700081788756849
# Recall: 0.5477178423236515
# F1 Score: 0.5393493836545333
#
# start DT 50 VNIFGSM
# (835, 56) (835,)
# Accuracy: 0.5053892215568863
#
# macro
# Precision: 0.5070183650590017
# Recall: 0.5069772385187228
# F1 Score: 0.5051052990349083
#
# weighted
# Precision: 0.5077296812359816
# Recall: 0.5053892215568863
# F1 Score: 0.5046652191258426
#
# start DT 20 baseline
# (158, 56) (158,)
# Accuracy: 0.6329113924050633
#
# macro
# Precision: 0.6278128541363122
# Recall: 0.6285621234326657
# F1 Score: 0.6280844155844156
#
# weighted
# Precision: 0.634186026972251
# Recall: 0.6329113924050633
# F1 Score: 0.633447723162913
#
# start DT 20 BIM
# (3081, 56) (3081,)
# Accuracy: 0.2395326192794547
#
# macro
# Precision: 0.31174862282294735
# Recall: 0.2888396945525358
# F1 Score: 0.2376771973303221
#
# weighted
# Precision: 0.40140200927130243
# Recall: 0.2395326192794547
# F1 Score: 0.25675630592567916
#
# start DT 20 FGSM
# (976, 56) (976,)
# Accuracy: 0.24487704918032788
#
# macro
# Precision: 0.3258246527777778
# Recall: 0.31875970305134504
# F1 Score: 0.24469864577240955
#
# weighted
# Precision: 0.4120059376423042
# Recall: 0.24487704918032788
# F1 Score: 0.25057406467318644
#
# start DT 20 PGD
# (3081, 56) (3081,)
# Accuracy: 0.2395326192794547
#
# macro
# Precision: 0.31174862282294735
# Recall: 0.2888396945525358
# F1 Score: 0.2376771973303221
#
# weighted
# Precision: 0.40140200927130243
# Recall: 0.2395326192794547
# F1 Score: 0.25675630592567916
#
# start DT 20 DF
# (2276, 56) (2276,)
# Accuracy: 0.10764499121265378
#
# macro
# Precision: 0.2645408163265306
# Recall: 0.31868425575961573
# F1 Score: 0.10687102987487458
#
# weighted
# Precision: 0.4102773842401636
# Recall: 0.10764499121265378
# F1 Score: 0.08665562179855228
#
# start DT 20 AutoPGD
# (3346, 56) (3346,)
# Accuracy: 0.2686790197250448
#
# macro
# Precision: 0.3532361863107619
# Recall: 0.333171296479079
# F1 Score: 0.266673061598871
#
# weighted
# Precision: 0.4588125349312808
# Recall: 0.2686790197250448
# F1 Score: 0.2868243438035203
#
# start DT 20 ZOO
# (465, 56) (465,)
# Accuracy: 0.6516129032258065
#
# macro
# Precision: 0.6538611039129308
# Recall: 0.6590909090909091
# F1 Score: 0.6493930818780951
#
# weighted
# Precision: 0.6712335637679827
# Recall: 0.6516129032258065
# F1 Score: 0.6544926714606752
#
# start DT 20 CaFA
# (1899, 56) (1899,)
# Accuracy: 0.31648235913638756
#
# macro
# Precision: 0.3534581604167043
# Recall: 0.3610169512281741
# F1 Score: 0.31568061530670943
#
# weighted
# Precision: 0.38369223074829567
# Recall: 0.31648235913638756
# F1 Score: 0.30848958988051933
#
# start DT 20 SINIFGSM
# (3729, 56) (3729,)
# Accuracy: 0.1592920353982301
#
# macro
# Precision: 0.16532735833388595
# Recall: 0.16093198168737738
# F1 Score: 0.15896083191576382
#
# weighted
# Precision: 0.17307057380200278
# Recall: 0.1592920353982301
# F1 Score: 0.16196404187164043
#
# start DT 20 VNIFGSM
# (1385, 56) (1385,)
# Accuracy: 0.31624548736462094
#
# macro
# Precision: 0.342990252697411
# Recall: 0.35000470974513553
# F1 Score: 0.3154232350916348
#
# weighted
# Precision: 0.3641896671188667
# Recall: 0.31624548736462094
# F1 Score: 0.3091364312544281
#
# start DT 1 baseline
# (82, 56) (82,)
# Accuracy: 0.573170731707317
#
# macro
# Precision: 0.5668402777777778
# Recall: 0.5462462462462463
# F1 Score: 0.5212677231025855
#
# weighted
# Precision: 0.5679412262872628
# Recall: 0.573170731707317
# F1 Score: 0.5366463923188023
#
# start DT 1 BIM
# (1078, 56) (1078,)
# Accuracy: 0.4072356215213358
#
# macro
# Precision: 0.38506323656818814
# Recall: 0.4045450163871217
# F1 Score: 0.3792219659836542
#
# weighted
# Precision: 0.3857623658234676
# Recall: 0.4072356215213358
# F1 Score: 0.3809345912130321
#
# start DT 1 FGSM
# (1181, 56) (1181,)
# Accuracy: 0.30143945808636746
#
# macro
# Precision: 0.3228114914408531
# Recall: 0.3431548875308166
# F1 Score: 0.29679295872743217
#
# weighted
# Precision: 0.33575758967406305
# Recall: 0.30143945808636746
# F1 Score: 0.28251465340570386
#
# start DT 1 PGD
# (1078, 56) (1078,)
# Accuracy: 0.4072356215213358
#
# macro
# Precision: 0.38506323656818814
# Recall: 0.4045450163871217
# F1 Score: 0.3792219659836542
#
# weighted
# Precision: 0.3857623658234676
# Recall: 0.4072356215213358
# F1 Score: 0.3809345912130321
#
# start DT 1 DF
# (1015, 56) (1015,)
# Accuracy: 0.31724137931034485
#
# macro
# Precision: 0.29752340587044535
# Recall: 0.3482661357225817
# F1 Score: 0.2913532187038139
#
# weighted
# Precision: 0.29248983491553815
# Recall: 0.31724137931034485
# F1 Score: 0.27360514983438816
#
# start DT 1 AutoPGD
# (671, 56) (671,)
# Accuracy: 0.6631892697466468
#
# macro
# Precision: 0.6444555444555444
# Recall: 0.6549386323787258
# F1 Score: 0.645720026165779
#
# weighted
# Precision: 0.6821122245861442
# Recall: 0.6631892697466468
# F1 Score: 0.6690514320221058
#
# start DT 1 ZOO
# (389, 56) (389,)
# Accuracy: 0.532133676092545
#
# macro
# Precision: 0.46779018132478106
# Recall: 0.46932272086466165
# F1 Score: 0.46806816132716234
#
# weighted
# Precision: 0.5216286157222978
# Recall: 0.532133676092545
# F1 Score: 0.5264389636689555
#
# start DT 1 CaFA
# (1733, 56) (1733,)
# Accuracy: 0.447201384881708
#
# macro
# Precision: 0.45010281334704183
# Recall: 0.4494939870415271
# F1 Score: 0.4465156315842814
#
# weighted
# Precision: 0.4570729116143379
# Recall: 0.447201384881708
# F1 Score: 0.4488651797672675
#
# start DT 1 SINIFGSM
# (1481, 56) (1481,)
# Accuracy: 0.24848075624577987
#
# macro
# Precision: 0.2669521583620194
# Recall: 0.24743265005543372
# F1 Score: 0.24351422535786552
#
# weighted
# Precision: 0.30512638940224773
# Recall: 0.24848075624577987
# F1 Score: 0.2627595325485336
#
# start DT 1 VNIFGSM
# (1409, 56) (1409,)
# Accuracy: 0.4414478353442158
#
# macro
# Precision: 0.44855491563427086
# Recall: 0.44612019634273503
# F1 Score: 0.43802266492531605
#
# weighted
# Precision: 0.47247444392230564
# Recall: 0.4414478353442158
# F1 Score: 0.44776883166273074

# %%
# torch.save(model.state_dict(), "./dnn_pytorch_FeatureSqueezing.pt")

# %%
# import time

# epsilon_values = [0.01, 0.1, 0.2, 0.3]

# start_time = time.time()

# for epsilon in epsilon_values:
#     filename = f'/home/jovyan/Sample_Based_Extension/UNSW/transfer_attack/x_test_adv_BIM_eps_{epsilon}.npy'
#     x_test_adv = np.load(filename)

#     calculate_performance_metrics(x_test_adv, y_test, model, 'DNN', 'BIM', epsilon)

# end_time = time.time()
# result = end_time - start_time
# print(f"Execution Time: {result:.6f} seconds")
