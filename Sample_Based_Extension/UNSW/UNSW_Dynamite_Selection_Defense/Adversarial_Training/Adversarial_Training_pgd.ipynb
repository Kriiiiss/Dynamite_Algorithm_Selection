# %%
import numpy as np
import pandas as pd

from sklearn.metrics import accuracy_score, precision_recall_fscore_support, roc_auc_score, confusion_matrix
from sklearn.preprocessing import label_binarize

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset


import time

# %%
head = {
            "model" : '',
            "attack_model": '',
            'epsilon': '',
            'Accuracy': '',
            'Macro Precision': '',
            'Weighted Precision': '',
            'Macro Recall': '',
            'Weighted Recall': '',
            'Macro F1': '',
            'Weighted F1': '',
        }
head = pd.DataFrame([head])
head.to_csv("./Adversarial_Training_pgd.csv", mode='a', index=False)

# %%
def calculate_performance_metrics(X_test, y_test, model, model_name, attack_name, eps):
    model.eval()
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.to(device)
    
    all_preds = []
    all_labels = []
    probabilities = []

    num_classes = len(np.unique(y_test))
    
    X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
    y_test_tensor = torch.tensor(y_test, dtype=torch.long)
    test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
    test_loader = DataLoader(dataset=test_dataset)

    with torch.no_grad():
        
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            preds = torch.argmax(outputs, dim=1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            probabilities.extend(torch.nn.functional.softmax(outputs, dim=1).cpu().numpy())
        
        all_preds = np.array(all_preds)
        all_labels = np.array(all_labels)
        probabilities = np.array(probabilities)
        
        accuracy = accuracy_score(all_labels, all_preds)

        precision_macro, recall_macro, f1_macro, _ = precision_recall_fscore_support(all_labels, all_preds, average='macro')
        precision_weighted, recall_weighted, f1_weighted, _ = precision_recall_fscore_support(all_labels, all_preds, average='weighted')
    
        print(f"Accuracy: {accuracy}")
        
        print("\nmacro")
        print(f"Precision: {precision_macro}\nRecall: {recall_macro}\nF1 Score: {f1_macro}")
    
        print("\nweighted")
        print(f"Precision: {precision_weighted}\nRecall: {recall_weighted}\nF1 Score: {f1_weighted}")
        print()
        

        new_row = {
            "model" : model_name,
            "attack_model" : attack_name,
            'epsilon': eps,
            'Accuracy': accuracy,
            'Macro Precision': precision_macro,
            'Weighted Precision': precision_weighted,
            'Macro Recall': recall_macro,
            'Weighted Recall': recall_weighted,
            'Macro F1': f1_macro,
            'Weighted F1': f1_weighted,
        }
        new_row_df = pd.DataFrame([new_row])
        new_row_df.to_csv("./Adversarial_Training_pgd.csv", mode='a', index=False, header=False)

# %%
# def calculate_performance_metrics(X_test, y_test, model, model_name, attack_name, eps):
#     model.eval()
#     device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#     model.to(device)
    
#     all_preds = []
#     all_labels = []
#     probabilities = []

#     num_classes = len(np.unique(y_test))
    
#     X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
#     y_test_tensor = torch.tensor(y_test, dtype=torch.long)
#     test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
#     test_loader = DataLoader(dataset=test_dataset)

#     with torch.no_grad():
        
#         for inputs, labels in test_loader:
#             inputs, labels = inputs.to(device), labels.to(device)
#             outputs = model(inputs)
#             preds = torch.argmax(outputs, dim=1)
#             all_preds.extend(preds.cpu().numpy())
#             all_labels.extend(labels.cpu().numpy())
#             probabilities.extend(torch.nn.functional.softmax(outputs, dim=1).cpu().numpy())
        
#         all_preds = np.array(all_preds)
#         all_labels = np.array(all_labels)
#         probabilities = np.array(probabilities)

#         np.save(f"/home/jovyan/Sample_Based_Extension/UNSW/UNSW_Defense_Label/UNSW_Def1/y_pred_{attack_name}{eps}_Def1.npy", all_preds)

# %%
x_test = np.load('/home/jovyan/Sample_Based_Extension/UNSW/x_test.npy')
x_train = np.load('/home/jovyan/Sample_Based_Extension/UNSW/x_train.npy')
x_val = np.load('/home/jovyan/Sample_Based_Extension/UNSW/x_val.npy')
y_test = np.load('/home/jovyan/Sample_Based_Extension/UNSW/y_test.npy')
y_train = np.load('/home/jovyan/Sample_Based_Extension/UNSW/y_train.npy')
y_val = np.load('/home/jovyan/Sample_Based_Extension/UNSW/y_val.npy')

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
input_shape = x_train.shape[1]
output_shape = len(np.unique(y_train))

# %%
x_train_tensor = torch.tensor(x_train, dtype=torch.float32).to(device)
y_train_tensor = torch.tensor(y_train, dtype=torch.long).to(device)

x_val_tensor = torch.tensor(x_val, dtype=torch.float32).to(device)
y_val_tensor = torch.tensor(y_val, dtype=torch.long).to(device)

train_dataset = TensorDataset(x_train_tensor, y_train_tensor)
train_loader = DataLoader(train_dataset, batch_size=100, shuffle=True)

val_dataset = TensorDataset(x_val_tensor, y_val_tensor)
val_loader = DataLoader(val_dataset, batch_size=100, shuffle=True)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

class DNNModel(nn.Module):
    def __init__(self, input_size, output_size):
        super(DNNModel, self).__init__()
        self.fc1 = nn.Linear(input_size, 50)
        self.fc2 = nn.Linear(50, 30)
        self.fc3 = nn.Linear(30, 20)
        self.fc4 = nn.Linear(20, output_size)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = self.fc4(x)
        return x

# %%
# PGD attack function
def pgd_attack(model, images, labels, eps=0.3, alpha=2/255, iters=10):
    images = images.clone().detach().to(device)
    labels = labels.clone().detach().to(device)
    loss = nn.CrossEntropyLoss()

    ori_images = images.data

    for i in range(iters):
        images.requires_grad = True
        outputs = model(images)

        model.zero_grad()
        cost = loss(outputs, labels).to(device)
        cost.backward()

        adv_images = images + alpha*images.grad.sign()
        eta = torch.clamp(adv_images - ori_images, min=-eps, max=eps)
        images = torch.clamp(ori_images + eta, min=0, max=1).detach_()

    return images

# Initialize model, optimizer, and loss function
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = DNNModel(input_size=input_shape, output_size=output_shape).to(device)
optimizer = optim.Adam(model.parameters(), lr=0.001)
loss_function = nn.CrossEntropyLoss()

# Early stopping variables
min_delta = 0.001
patience = 5
patience_counter = 0
best_loss = float('inf')

# %%
# # Adversarial training loop
# for epoch in range(10):
#     model.train()
#     train_loss = 0.0
#     for inputs, labels in train_loader:
#         inputs, labels = inputs.to(device), labels.to(device)

#         # Generate adversarial examples
#         adv_inputs = pgd_attack(model, inputs, labels, eps=0.3, alpha=2/255, iters=10)

#         optimizer.zero_grad()
#         outputs = model(adv_inputs)
#         loss = loss_function(outputs, labels)
#         loss.backward()
#         optimizer.step()
#         train_loss += loss.item()

#     avg_train_loss = train_loss / len(train_loader)

#     model.eval()
#     val_train_loss = 0.0
#     correct_predictions = 0
#     with torch.no_grad():
#         for inputs, labels in val_loader:
#             inputs, labels = inputs.to(device), labels.to(device)
#             outputs = model(inputs)
#             loss = loss_function(outputs, labels)
#             val_train_loss += loss.item()
#             _, predicted = torch.max(outputs.data, 1)
#             correct_predictions += (predicted == labels).sum().item()

#     avg_val_loss = val_train_loss / len(val_loader)
#     val_accuracy = correct_predictions / len(val_dataset)

#     print(f"Epoch {epoch+1}, Training Loss: {avg_train_loss:.4f}, Validation Loss: {avg_val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}")

#     # Early stopping check using min_delta
#     if best_loss - avg_val_loss > min_delta:
#         best_loss = avg_val_loss
#         patience_counter = 0
#     else:
#         patience_counter += 1

#     if patience_counter >= patience:
#         print("Early stopping triggered")
#         break

# %%
model.load_state_dict(torch.load("/home/jovyan/Sample_Based_Extension/UNSW/UNSW_Defense/Adversarial_Training/Adversarial_Training_pgd.pt"))
# Out:
# /tmp/ipykernel_169/4205641916.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("/home/jovyan/Sample_Based_Extension/UNSW/UNSW_Defense/Adversarial_Training/Adversarial_Training_pgd.pt"))
# <All keys matched successfully>

# %%
# calculate_performance_metrics(x_test, y_test, model, 'DNN', 'baseline', '0')

# %%
def print_empty_file():
    new_row = {
        "model" : "0",
        "attack_model" : "0",
        'epsilon': "0",
        'Accuracy': "0",
        'Macro Precision': "0",
        'Weighted Precision': "0",
        'Macro Recall': "0",
        'Weighted Recall': "0",
        'Macro F1': "0",
        'Weighted F1': "0",
    }
    new_row_df = pd.DataFrame([new_row])
    new_row_df.to_csv("./Adversarial_Training_pgd.csv", mode='a', index=False, header=False)

# %%
epsilon = 0

Def = "Def1"
attack_names = [
    "baseline", "BIM", "FGSM", "PGD", "DF",
    "AutoPGD", "ZOO", "CaFA", "SINIFGSM", "VNIFGSM"
]

percentage = ["100", "50", "20", "1"]
model_name = ["XGB", "RF", "DT" ]

base_path = "/home/jovyan/Sample_Based_Extension/UNSW/UNSW_Dynamite_Selection_Data"

for m_name in model_name:
    for p in percentage:
        for attack in attack_names:
            print(f"start {m_name} {p} {attack}")
            
            x_path = f"{base_path}/{m_name}/UNSW_Input{p}/x_test_adv_{attack}_{Def}.npy"
            y_path = f"{base_path}/{m_name}/UNSW_Input{p}/y_test_adv_{attack}_{Def}.npy"

            try:
                x_test_adv = np.load(x_path)
                y_test_adv = np.load(y_path)
                m_per_name = f"{m_name}{p}"
                calculate_performance_metrics(x_test_adv, y_test_adv, model, m_per_name, attack, epsilon)
            except FileNotFoundError:
                print(x_path, "not found")
                print_empty_file()
# Out:
# start XGB 100 baseline
# Accuracy: 0.9645256651437786
#
# macro
# Precision: 0.9457923758969612
# Recall: 0.6449753693638322
# F1 Score: 0.7123586819982607
#
# weighted
# Precision: 0.9632413538972536
# Recall: 0.9645256651437786
# F1 Score: 0.955574847047052
#
# start XGB 100 BIM
# Accuracy: 0.9347027739873435
#
# macro
# Precision: 0.916209923008404
# Recall: 0.9210901873224838
# F1 Score: 0.9186041891508978
#
# weighted
# Precision: 0.935145181158532
# Recall: 0.9347027739873435
# F1 Score: 0.9348930622370937
#
# start XGB 100 FGSM
# Accuracy: 0.9406582043408988
#
# macro
# Precision: 0.9158856914091945
# Recall: 0.918628849157006
# F1 Score: 0.9172464813707737
#
# weighted
# Precision: 0.9408654685380206
# Recall: 0.9406582043408988
# F1 Score: 0.940755735770281
#
# start XGB 100 PGD
# Accuracy: 0.9347027739873435
#
# macro
# Precision: 0.916209923008404
# Recall: 0.9210901873224838
# F1 Score: 0.9186041891508978
#
# weighted
# Precision: 0.935145181158532
# Recall: 0.9347027739873435
# F1 Score: 0.9348930622370937
#
# start XGB 100 DF
# Accuracy: 0.9041594008948727
#
# macro
# Precision: 0.7999434354583473
# Recall: 0.7557405311436237
# F1 Score: 0.7751737940320308
#
# weighted
# Precision: 0.8981832465851664
# Recall: 0.9041594008948727
# F1 Score: 0.900351962532637
#
# start XGB 100 AutoPGD
# Accuracy: 0.9634560146460024
#
# macro
# Precision: 0.9483213192047497
# Recall: 0.9558405315242359
# F1 Score: 0.9519971693314805
#
# weighted
# Precision: 0.9638627840491277
# Recall: 0.9634560146460024
# F1 Score: 0.963607960248897
#
# start XGB 100 ZOO
# Accuracy: 0.970954356846473
#
# macro
# Precision: 0.9309062679813542
# Recall: 0.578496652918496
# F1 Score: 0.626541748401007
#
# weighted
# Precision: 0.9687058887482828
# Recall: 0.970954356846473
# F1 Score: 0.9610067197693596
#
# start XGB 100 CaFA
# Accuracy: 0.952662074554295
#
# macro
# Precision: 0.950808345856474
# Recall: 0.9489608434902119
# F1 Score: 0.949865749717645
#
# weighted
# Precision: 0.9525987414288012
# Recall: 0.952662074554295
# F1 Score: 0.9526134757748153
#
# start XGB 100 SINIFGSM
# Accuracy: 0.9581851154355863
#
# macro
# Precision: 0.9562131874313053
# Recall: 0.9551375266537976
# F1 Score: 0.9556691905542997
#
# weighted
# Precision: 0.9581468089188316
# Recall: 0.9581851154355863
# F1 Score: 0.9581604386727337
#
# start XGB 100 VNIFGSM
# Accuracy: 0.9512781357019581
#
# macro
# Precision: 0.9411498867970113
# Recall: 0.9301414154464547
# F1 Score: 0.9354611225241178
#
# weighted
# Precision: 0.9508915239413481
# Recall: 0.9512781357019581
# F1 Score: 0.950970381379809
#
# start XGB 50 baseline
# Accuracy: 0.9608904408555216
#
# macro
# Precision: 0.9410464564969441
# Recall: 0.6828427105759448
# F1 Score: 0.7525142863315726
#
# weighted
# Precision: 0.9594179575896321
# Recall: 0.9608904408555216
# F1 Score: 0.9528614861811615
#
# start XGB 50 BIM
# Accuracy: 0.765414128852649
#
# macro
# Precision: 0.7350256594428819
# Recall: 0.8099098976575358
# F1 Score: 0.738303447216299
#
# weighted
# Precision: 0.8466558171546607
# Recall: 0.765414128852649
# F1 Score: 0.7809227814272891
#
# start XGB 50 FGSM
# Accuracy: 0.9297557108171052
#
# macro
# Precision: 0.9086827382415125
# Recall: 0.9037209171303772
# F1 Score: 0.9061615172193129
#
# weighted
# Precision: 0.9293759953075856
# Recall: 0.9297557108171052
# F1 Score: 0.9295412054303236
#
# start XGB 50 PGD
# Accuracy: 0.765414128852649
#
# macro
# Precision: 0.7350256594428819
# Recall: 0.8099098976575358
# F1 Score: 0.738303447216299
#
# weighted
# Precision: 0.8466558171546607
# Recall: 0.765414128852649
# F1 Score: 0.7809227814272891
#
# start XGB 50 DF
# Accuracy: 0.8956767296443219
#
# macro
# Precision: 0.7803375634031418
# Recall: 0.7459690536252719
# F1 Score: 0.7614010364264105
#
# weighted
# Precision: 0.8899743964310903
# Recall: 0.8956767296443219
# F1 Score: 0.8922733232914059
#
# start XGB 50 AutoPGD
# Accuracy: 0.8227320639343151
#
# macro
# Precision: 0.7788683427056035
# Recall: 0.8633937190727342
# F1 Score: 0.7945145541182856
#
# weighted
# Precision: 0.8818815718824649
# Recall: 0.8227320639343151
# F1 Score: 0.8340956701130344
#
# start XGB 50 ZOO
# Accuracy: 0.966735410336739
#
# macro
# Precision: 0.8784017310473652
# Recall: 0.5613330184449605
# F1 Score: 0.5986070371047534
#
# weighted
# Precision: 0.9612236115844375
# Recall: 0.966735410336739
# F1 Score: 0.9548804083121226
#
# start XGB 50 CaFA
# Accuracy: 0.9501361936690091
#
# macro
# Precision: 0.9484468685540537
# Recall: 0.9458823407411103
# F1 Score: 0.9471286481558336
#
# weighted
# Precision: 0.9500577461810807
# Recall: 0.9501361936690091
# F1 Score: 0.950064702791392
#
# start XGB 50 SINIFGSM
# Accuracy: 0.9203749231714813
#
# macro
# Precision: 0.9123918254388244
# Recall: 0.9206329949546451
# F1 Score: 0.9160583676241117
#
# weighted
# Precision: 0.9219772568350894
# Recall: 0.9203749231714813
# F1 Score: 0.9207686136286407
#
# start XGB 50 VNIFGSM
# Accuracy: 0.9176636683841295
#
# macro
# Precision: 0.8724992501345303
# Recall: 0.903690144718863
# F1 Score: 0.8865227483696889
#
# weighted
# Precision: 0.922725814904682
# Recall: 0.9176636683841295
# F1 Score: 0.9193162344329066
#
# start XGB 20 baseline
# Accuracy: 0.9604526503871352
#
# macro
# Precision: 0.9354865637973828
# Recall: 0.698173363337766
# F1 Score: 0.7669347415864165
#
# weighted
# Precision: 0.958624815493028
# Recall: 0.9604526503871352
# F1 Score: 0.9530994926689677
#
# start XGB 20 BIM
# Accuracy: 0.9424780939253716
#
# macro
# Precision: 0.9306992908907925
# Recall: 0.9297004313163214
# F1 Score: 0.9301978132289623
#
# weighted
# Precision: 0.9424142160578751
# Recall: 0.9424780939253716
# F1 Score: 0.9424447046677615
#
# start XGB 20 FGSM
# Accuracy: 0.9396816990659155
#
# macro
# Precision: 0.9280256940420344
# Recall: 0.9213092410777135
# F1 Score: 0.9245831685933492
#
# weighted
# Precision: 0.9393192124601143
# Recall: 0.9396816990659155
# F1 Score: 0.9394432185119542
#
# start XGB 20 PGD
# Accuracy: 0.9424780939253716
#
# macro
# Precision: 0.9306992908907925
# Recall: 0.9297004313163214
# F1 Score: 0.9301978132289623
#
# weighted
# Precision: 0.9424142160578751
# Recall: 0.9424780939253716
# F1 Score: 0.9424447046677615
#
# start XGB 20 DF
# Accuracy: 0.8816390482260463
#
# macro
# Precision: 0.7529243545318903
# Recall: 0.7338449964953198
# F1 Score: 0.7427676913232748
#
# weighted
# Precision: 0.8774110931256764
# Recall: 0.8816390482260463
# F1 Score: 0.8793201756335539
#
# start XGB 20 AutoPGD
# Accuracy: 0.9630633846322812
#
# macro
# Precision: 0.9511543731374665
# Recall: 0.9513555700505021
# F1 Score: 0.9512549121984257
#
# weighted
# Precision: 0.9630716919312398
# Recall: 0.9630633846322812
# F1 Score: 0.9630675017795532
#
# start XGB 20 ZOO
# Accuracy: 0.9632744484827994
#
# macro
# Precision: 0.8880678409560226
# Recall: 0.5999047163645175
# F1 Score: 0.6522546738777695
#
# weighted
# Precision: 0.9582563430936117
# Recall: 0.9632744484827994
# F1 Score: 0.9525400433800951
#
# start XGB 20 CaFA
# Accuracy: 0.9503657427543395
#
# macro
# Precision: 0.9478374015969789
# Recall: 0.9461745815722135
# F1 Score: 0.9469923946987171
#
# weighted
# Precision: 0.9502974852836287
# Recall: 0.9503657427543395
# F1 Score: 0.9503195846556803
#
# start XGB 20 SINIFGSM
# Accuracy: 0.942628849959926
#
# macro
# Precision: 0.9365668813554027
# Recall: 0.941054315914926
# F1 Score: 0.9387093270052104
#
# weighted
# Precision: 0.9431001372650889
# Recall: 0.942628849959926
# F1 Score: 0.9427755104191158
#
# start XGB 20 VNIFGSM
# Accuracy: 0.9580920242601122
#
# macro
# Precision: 0.9539377628399924
# Recall: 0.9450915681131955
# F1 Score: 0.9493608599139638
#
# weighted
# Precision: 0.95790037140152
# Recall: 0.9580920242601122
# F1 Score: 0.957885866885464
#
# start XGB 1 baseline
# Accuracy: 0.9186266994795659
#
# macro
# Precision: 0.8312819843891224
# Recall: 0.7323374844341191
# F1 Score: 0.7698930527444434
#
# weighted
# Precision: 0.9106539478411202
# Recall: 0.9186266994795659
# F1 Score: 0.9115139352614521
#
# start XGB 1 BIM
# Accuracy: 0.856192939643192
#
# macro
# Precision: 0.8082765496164177
# Recall: 0.8635491924474132
# F1 Score: 0.8268401894422688
#
# weighted
# Precision: 0.8801351757450625
# Recall: 0.856192939643192
# F1 Score: 0.8620603608977032
#
# start XGB 1 FGSM
# Accuracy: 0.9118649935093033
#
# macro
# Precision: 0.8633987596697319
# Recall: 0.8082365377894256
# F1 Score: 0.8320067471284223
#
# weighted
# Precision: 0.9076697704629536
# Recall: 0.9118649935093033
# F1 Score: 0.9082523871936345
#
# start XGB 1 PGD
# Accuracy: 0.856192939643192
#
# macro
# Precision: 0.8082765496164177
# Recall: 0.8635491924474132
# F1 Score: 0.8268401894422688
#
# weighted
# Precision: 0.8801351757450625
# Recall: 0.856192939643192
# F1 Score: 0.8620603608977032
#
# start XGB 1 DF
# Accuracy: 0.817418402082499
#
# macro
# Precision: 0.6707314266847983
# Recall: 0.7050212322853118
# F1 Score: 0.684362181027967
#
# weighted
# Precision: 0.8369545498338621
# Recall: 0.817418402082499
# F1 Score: 0.8257255995997146
#
# start XGB 1 AutoPGD
# Accuracy: 0.8833315012275109
#
# macro
# Precision: 0.8498844812113391
# Recall: 0.8897281821157956
# F1 Score: 0.8648007313357704
#
# weighted
# Precision: 0.8969179425566172
# Recall: 0.8833315012275109
# F1 Score: 0.8864598028188816
#
# start XGB 1 ZOO
# Accuracy: 0.9141313505489655
#
# macro
# Precision: 0.7899294145419089
# Recall: 0.6925310858323643
# F1 Score: 0.727993145589602
#
# weighted
# Precision: 0.9031282775313609
# Recall: 0.9141313505489655
# F1 Score: 0.9055042007281099
#
# start XGB 1 CaFA
# Accuracy: 0.9214598702091076
#
# macro
# Precision: 0.9217952859996066
# Recall: 0.9139916576723968
# F1 Score: 0.9174641751195995
#
# weighted
# Precision: 0.9215162320114101
# Recall: 0.9214598702091076
# F1 Score: 0.9210933679261567
#
# start XGB 1 SINIFGSM
# Accuracy: 0.9283247135364315
#
# macro
# Precision: 0.9199282021440311
# Recall: 0.9238697912501024
# F1 Score: 0.9218342607328733
#
# weighted
# Precision: 0.9287692915326006
# Recall: 0.9283247135364315
# F1 Score: 0.9284921099472372
#
# start XGB 1 VNIFGSM
# Accuracy: 0.9282669221519924
#
# macro
# Precision: 0.9220297794389491
# Recall: 0.9107259203752498
# F1 Score: 0.9160533659885741
#
# weighted
# Precision: 0.9277888608607989
# Recall: 0.9282669221519924
# F1 Score: 0.9277801999664201
#
# start RF 100 baseline
# Accuracy: 0.972005684999354
#
# macro
# Precision: 0.9072971547167828
# Recall: 0.811948145932117
# F1 Score: 0.8524266511365584
#
# weighted
# Precision: 0.9700301312833066
# Recall: 0.972005684999354
# F1 Score: 0.9701520125926966
#
# start RF 100 BIM
# Accuracy: 0.8911597940116461
#
# macro
# Precision: 0.8747247058218419
# Recall: 0.8827889530391229
# F1 Score: 0.8784999684889414
#
# weighted
# Precision: 0.8927357334083085
# Recall: 0.8911597940116461
# F1 Score: 0.8917389919080267
#
# start RF 100 FGSM
# Accuracy: 0.9191869729765619
#
# macro
# Precision: 0.9155538207311535
# Recall: 0.8942167784592765
# F1 Score: 0.9037819969138023
#
# weighted
# Precision: 0.9187176379426091
# Recall: 0.9191869729765619
# F1 Score: 0.9181232496496672
#
# start RF 100 PGD
# Accuracy: 0.8911597940116461
#
# macro
# Precision: 0.8747247058218419
# Recall: 0.8827889530391229
# F1 Score: 0.8784999684889414
#
# weighted
# Precision: 0.8927357334083085
# Recall: 0.8911597940116461
# F1 Score: 0.8917389919080267
#
# start RF 100 DF
# Accuracy: 0.9346926240452919
#
# macro
# Precision: 0.8294508701614576
# Recall: 0.8295591340888316
# F1 Score: 0.8295049897573185
#
# weighted
# Precision: 0.9347033589832964
# Recall: 0.9346926240452919
# F1 Score: 0.9346979884805298
#
# start RF 100 AutoPGD
# Accuracy: 0.9428000948614181
#
# macro
# Precision: 0.9266906377177512
# Recall: 0.9431950024323923
# F1 Score: 0.9342257227909452
#
# weighted
# Precision: 0.9449754236064747
# Recall: 0.9428000948614181
# F1 Score: 0.9433423971885299
#
# start RF 100 ZOO
# Accuracy: 0.9792110128804711
#
# macro
# Precision: 0.8822186826310381
# Recall: 0.8017728843065532
# F1 Score: 0.8368427101531388
#
# weighted
# Precision: 0.9775602701851298
# Recall: 0.9792110128804711
# F1 Score: 0.9779891096485337
#
# start RF 100 CaFA
# Accuracy: 0.9516060112549785
#
# macro
# Precision: 0.9496236496202801
# Recall: 0.9480723945082942
# F1 Score: 0.9488343143531824
#
# weighted
# Precision: 0.951547089708984
# Recall: 0.9516060112549785
# F1 Score: 0.9515641984139672
#
# start RF 100 SINIFGSM
# Accuracy: 0.9323375788831952
#
# macro
# Precision: 0.9328980454143498
# Recall: 0.9237144233506882
# F1 Score: 0.9278547639373568
#
# weighted
# Precision: 0.9324214500672544
# Recall: 0.9323375788831952
# F1 Score: 0.9319750363914588
#
# start RF 100 VNIFGSM
# Accuracy: 0.9373995279953483
#
# macro
# Precision: 0.9433774602422007
# Recall: 0.9202145870458529
# F1 Score: 0.9300607433819996
#
# weighted
# Precision: 0.938625138648375
# Recall: 0.9373995279953483
# F1 Score: 0.93656129129229
#
# start RF 50 baseline
# Accuracy: 0.9600416233090531
#
# macro
# Precision: 0.872860555306118
# Recall: 0.7640398031160707
# F1 Score: 0.8076114592300454
#
# weighted
# Precision: 0.9562294703103427
# Recall: 0.9600416233090531
# F1 Score: 0.9566344866043645
#
# start RF 50 BIM
# Accuracy: 0.9015056213556131
#
# macro
# Precision: 0.8955369658599377
# Recall: 0.8800600859333693
# F1 Score: 0.8870431357360512
#
# weighted
# Precision: 0.9007465787224384
# Recall: 0.9015056213556131
# F1 Score: 0.9005235691436625
#
# start RF 50 FGSM
# Accuracy: 0.8987996807924246
#
# macro
# Precision: 0.893196709226632
# Recall: 0.8641490587288089
# F1 Score: 0.8766455588424324
#
# weighted
# Precision: 0.8978984762686588
# Recall: 0.8987996807924246
# F1 Score: 0.8968621842987005
#
# start RF 50 PGD
# Accuracy: 0.9015056213556131
#
# macro
# Precision: 0.8955369658599377
# Recall: 0.8800600859333693
# F1 Score: 0.8870431357360512
#
# weighted
# Precision: 0.9007465787224384
# Recall: 0.9015056213556131
# F1 Score: 0.9005235691436625
#
# start RF 50 DF
# Accuracy: 0.9081315292804168
#
# macro
# Precision: 0.7847103782395879
# Recall: 0.7816350620549832
# F1 Score: 0.7831601266421946
#
# weighted
# Precision: 0.9076398459138159
# Recall: 0.9081315292804168
# F1 Score: 0.9078821028316484
#
# start RF 50 AutoPGD
# Accuracy: 0.9479047611435696
#
# macro
# Precision: 0.9382812432776304
# Recall: 0.9399761953252912
# F1 Score: 0.9391218970369355
#
# weighted
# Precision: 0.9480155565493614
# Recall: 0.9479047611435696
# F1 Score: 0.9479550302561468
#
# start RF 50 ZOO
# Accuracy: 0.9671237378263727
#
# macro
# Precision: 0.8455367292421118
# Recall: 0.7394095405128999
# F1 Score: 0.7817068182217058
#
# weighted
# Precision: 0.9632797792508925
# Recall: 0.9671237378263727
# F1 Score: 0.9641456958606311
#
# start RF 50 CaFA
# Accuracy: 0.9466653876591765
#
# macro
# Precision: 0.9447766825576809
# Recall: 0.9424114854859025
# F1 Score: 0.9435621181701332
#
# weighted
# Precision: 0.9465807905900433
# Recall: 0.9466653876591765
# F1 Score: 0.9465942961920517
#
# start RF 50 SINIFGSM
# Accuracy: 0.9224454986407974
#
# macro
# Precision: 0.9291784997674111
# Recall: 0.9095858381809061
# F1 Score: 0.9172789212496589
#
# weighted
# Precision: 0.9244506920543142
# Recall: 0.9224454986407974
# F1 Score: 0.92154154961765
#
# start RF 50 VNIFGSM
# Accuracy: 0.9280820400095725
#
# macro
# Precision: 0.9391005803255079
# Recall: 0.905549282503392
# F1 Score: 0.918845163201424
#
# weighted
# Precision: 0.931025601256706
# Recall: 0.9280820400095725
# F1 Score: 0.9266580326241793
#
# start RF 20 baseline
# Accuracy: 0.950175301908843
#
# macro
# Precision: 0.8367212951513402
# Recall: 0.6894935129740518
# F1 Score: 0.739112291285117
#
# weighted
# Precision: 0.9429535985266772
# Recall: 0.950175301908843
# F1 Score: 0.9432370704972008
#
# start RF 20 BIM
# Accuracy: 0.880285201807072
#
# macro
# Precision: 0.8699642101376046
# Recall: 0.8636830710618122
# F1 Score: 0.8666572643605426
#
# weighted
# Precision: 0.8795372199566294
# Recall: 0.880285201807072
# F1 Score: 0.8797728136947625
#
# start RF 20 FGSM
# Accuracy: 0.9090063143901629
#
# macro
# Precision: 0.908286152232854
# Recall: 0.8795365411539788
# F1 Score: 0.8918177444529912
#
# weighted
# Precision: 0.9088796473379703
# Recall: 0.9090063143901629
# F1 Score: 0.9073489372739099
#
# start RF 20 PGD
# Accuracy: 0.880285201807072
#
# macro
# Precision: 0.8699642101376046
# Recall: 0.8636830710618122
# F1 Score: 0.8666572643605426
#
# weighted
# Precision: 0.8795372199566294
# Recall: 0.880285201807072
# F1 Score: 0.8797728136947625
#
# start RF 20 DF
# Accuracy: 0.8815059445178336
#
# macro
# Precision: 0.74333426500711
# Recall: 0.7455376956658107
# F1 Score: 0.7444277465993782
#
# weighted
# Precision: 0.8820453264807903
# Recall: 0.8815059445178336
# F1 Score: 0.8817729799683242
#
# start RF 20 AutoPGD
# Accuracy: 0.9299985494300788
#
# macro
# Precision: 0.9167777418665157
# Recall: 0.9238428454330556
# F1 Score: 0.9201649440768394
#
# weighted
# Precision: 0.9308138251515675
# Recall: 0.9299985494300788
# F1 Score: 0.930292680545169
#
# start RF 20 ZOO
# Accuracy: 0.9534986408356446
#
# macro
# Precision: 0.7933845841927114
# Recall: 0.6465772691392286
# F1 Score: 0.6920774845851179
#
# weighted
# Precision: 0.9443129332498631
# Recall: 0.9534986408356446
# F1 Score: 0.9457783485087852
#
# start RF 20 CaFA
# Accuracy: 0.9417887311814488
#
# macro
# Precision: 0.9391567254087323
# Recall: 0.9369877313144974
# F1 Score: 0.9380471833812598
#
# weighted
# Precision: 0.941689275173347
# Recall: 0.9417887311814488
# F1 Score: 0.9417166786290775
#
# start RF 20 SINIFGSM
# Accuracy: 0.9185806913560604
#
# macro
# Precision: 0.9217024306513057
# Recall: 0.9098963799785063
# F1 Score: 0.9147396387249596
#
# weighted
# Precision: 0.9193964999242075
# Recall: 0.9185806913560604
# F1 Score: 0.9180033600823726
#
# start RF 20 VNIFGSM
# Accuracy: 0.9235723946821496
#
# macro
# Precision: 0.9340659276913135
# Recall: 0.9031566409391729
# F1 Score: 0.9152020468938762
#
# weighted
# Precision: 0.9265915022330151
# Recall: 0.9235723946821496
# F1 Score: 0.9221659477417968
#
# start RF 1 baseline
# Accuracy: 0.914681179293795
#
# macro
# Precision: 0.693749541834587
# Recall: 0.5853200363700759
# F1 Score: 0.6120266133747845
#
# weighted
# Precision: 0.8919657301919968
# Recall: 0.914681179293795
# F1 Score: 0.898279008116679
#
# start RF 1 BIM
# Accuracy: 0.8719498676265373
#
# macro
# Precision: 0.8430859858032755
# Recall: 0.8498398219527595
# F1 Score: 0.8463295393860646
#
# weighted
# Precision: 0.8733908883749324
# Recall: 0.8719498676265373
# F1 Score: 0.872573835567619
#
# start RF 1 FGSM
# Accuracy: 0.8899797085097964
#
# macro
# Precision: 0.8707338613056084
# Recall: 0.8439426410068792
# F1 Score: 0.855867401496258
#
# weighted
# Precision: 0.8877877758555859
# Recall: 0.8899797085097964
# F1 Score: 0.8879198635951159
#
# start RF 1 PGD
# Accuracy: 0.8719498676265373
#
# macro
# Precision: 0.8430859858032755
# Recall: 0.8498398219527595
# F1 Score: 0.8463295393860646
#
# weighted
# Precision: 0.8733908883749324
# Recall: 0.8719498676265373
# F1 Score: 0.872573835567619
#
# start RF 1 DF
# Accuracy: 0.8179962025645694
#
# macro
# Precision: 0.665662731041195
# Recall: 0.7162167874808076
# F1 Score: 0.6835626764070402
#
# weighted
# Precision: 0.84779288852207
# Recall: 0.8179962025645694
# F1 Score: 0.8299726125945653
#
# start RF 1 AutoPGD
# Accuracy: 0.908692395957153
#
# macro
# Precision: 0.8937029250887398
# Recall: 0.901781393085329
# F1 Score: 0.8975121916152514
#
# weighted
# Precision: 0.9099890956312092
# Recall: 0.908692395957153
# F1 Score: 0.9091559313691231
#
# start RF 1 ZOO
# Accuracy: 0.9033733485346389
#
# macro
# Precision: 0.6776006301523028
# Recall: 0.5877141888666
# F1 Score: 0.6116711846714945
#
# weighted
# Precision: 0.8795942107543063
# Recall: 0.9033733485346389
# F1 Score: 0.8871578917261145
#
# start RF 1 CaFA
# Accuracy: 0.9141102114775002
#
# macro
# Precision: 0.9145404311241516
# Recall: 0.9065842800824455
# F1 Score: 0.9100699542021113
#
# weighted
# Precision: 0.9141905175950314
# Recall: 0.9141102114775002
# F1 Score: 0.913694311493125
#
# start RF 1 SINIFGSM
# Accuracy: 0.8950764199720961
#
# macro
# Precision: 0.889128083064787
# Recall: 0.8870613759308021
# F1 Score: 0.8880684126008551
#
# weighted
# Precision: 0.8948439308610622
# Recall: 0.8950764199720961
# F1 Score: 0.8949367372214141
#
# start RF 1 VNIFGSM
# Accuracy: 0.9001403232632212
#
# macro
# Precision: 0.8894472364341227
# Recall: 0.866602112996731
# F1 Score: 0.8768232168160945
#
# weighted
# Precision: 0.8988418439508865
# Recall: 0.9001403232632212
# F1 Score: 0.8986330930244588
#
# start DT 100 baseline
# Accuracy: 0.9684352764816417
#
# macro
# Precision: 0.9276616962782148
# Recall: 0.8816725989445288
# F1 Score: 0.9030089865748857
#
# weighted
# Precision: 0.9673330363148562
# Recall: 0.9684352764816417
# F1 Score: 0.9675388185762355
#
# start DT 100 BIM
# Accuracy: 0.8440510657415264
#
# macro
# Precision: 0.8343303559674065
# Recall: 0.8517745362087521
# F1 Score: 0.8388135967317835
#
# weighted
# Precision: 0.8558016471556937
# Recall: 0.8440510657415264
# F1 Score: 0.8460241134494095
#
# start DT 100 FGSM
# Accuracy: 0.8762441340550118
#
# macro
# Precision: 0.8625799466016827
# Recall: 0.8742532809317476
# F1 Score: 0.8675499751226077
#
# weighted
# Precision: 0.8797136379020789
# Recall: 0.8762441340550118
# F1 Score: 0.8772235657264005
#
# start DT 100 PGD
# Accuracy: 0.8440510657415264
#
# macro
# Precision: 0.8343303559674065
# Recall: 0.8517745362087521
# F1 Score: 0.8388135967317835
#
# weighted
# Precision: 0.8558016471556937
# Recall: 0.8440510657415264
# F1 Score: 0.8460241134494095
#
# start DT 100 DF
# Accuracy: 0.8928253243499081
#
# macro
# Precision: 0.7613627009509945
# Recall: 0.778928929433412
# F1 Score: 0.7696832683884498
#
# weighted
# Precision: 0.8965977918759931
# Recall: 0.8928253243499081
# F1 Score: 0.8945671818247184
#
# start DT 100 AutoPGD
# Accuracy: 0.8753748963052773
#
# macro
# Precision: 0.8586206183853264
# Recall: 0.8931180444260833
# F1 Score: 0.8677113335772306
#
# weighted
# Precision: 0.8950539138919612
# Recall: 0.8753748963052773
# F1 Score: 0.8782103591020535
#
# start DT 100 ZOO
# Accuracy: 0.972885191142855
#
# macro
# Precision: 0.8435798374010618
# Recall: 0.7857422105996195
# F1 Score: 0.8117149891720601
#
# weighted
# Precision: 0.9709019376303424
# Recall: 0.972885191142855
# F1 Score: 0.9716396448685778
#
# start DT 100 CaFA
# Accuracy: 0.970100593131671
#
# macro
# Precision: 0.9680278479675644
# Recall: 0.962113747151576
# F1 Score: 0.9649948840973468
#
# weighted
# Precision: 0.9700248303679412
# Recall: 0.970100593131671
# F1 Score: 0.9700055443547907
#
# start DT 100 SINIFGSM
# Accuracy: 0.8709640200394717
#
# macro
# Precision: 0.8638683194739847
# Recall: 0.8761653702861976
# F1 Score: 0.8676139265999987
#
# weighted
# Precision: 0.8776169106958256
# Recall: 0.8709640200394717
# F1 Score: 0.8720332722629957
#
# start DT 100 VNIFGSM
# Accuracy: 0.9036788363784055
#
# macro
# Precision: 0.9014077900183481
# Recall: 0.8995910104169405
# F1 Score: 0.9004626572921012
#
# weighted
# Precision: 0.9035296407217405
# Recall: 0.9036788363784055
# F1 Score: 0.9035696055123499
#
# start DT 50 baseline
# Accuracy: 0.9539808719413737
#
# macro
# Precision: 0.9202525172590739
# Recall: 0.8658186951843402
# F1 Score: 0.8903792365414415
#
# weighted
# Precision: 0.9523336233114873
# Recall: 0.9539808719413737
# F1 Score: 0.952388886448689
#
# start DT 50 BIM
# Accuracy: 0.7215243620001324
#
# macro
# Precision: 0.720438905679659
# Recall: 0.7710161262039559
# F1 Score: 0.7075579671716884
#
# weighted
# Precision: 0.8132786009676518
# Recall: 0.7215243620001324
# F1 Score: 0.7351679484799892
#
# start DT 50 FGSM
# Accuracy: 0.8554865009355788
#
# macro
# Precision: 0.8373003815347251
# Recall: 0.8588705009079134
# F1 Score: 0.8449729192664392
#
# weighted
# Precision: 0.8652863180939904
# Recall: 0.8554865009355788
# F1 Score: 0.8577179627125157
#
# start DT 50 PGD
# Accuracy: 0.7215243620001324
#
# macro
# Precision: 0.720438905679659
# Recall: 0.7710161262039559
# F1 Score: 0.7075579671716884
#
# weighted
# Precision: 0.8132786009676518
# Recall: 0.7215243620001324
# F1 Score: 0.7351679484799892
#
# start DT 50 DF
# Accuracy: 0.8614293584980293
#
# macro
# Precision: 0.7271383799525462
# Recall: 0.7372449301493879
# F1 Score: 0.7319889010676586
#
# weighted
# Precision: 0.8645946052311924
# Recall: 0.8614293584980293
# F1 Score: 0.862937050129277
#
# start DT 50 AutoPGD
# Accuracy: 0.755833278302406
#
# macro
# Precision: 0.7537949395919488
# Recall: 0.8109054535821815
# F1 Score: 0.7435151915669643
#
# weighted
# Precision: 0.8446316151452612
# Recall: 0.755833278302406
# F1 Score: 0.7676106720811754
#
# start DT 50 ZOO
# Accuracy: 0.9560645363918713
#
# macro
# Precision: 0.819400474257407
# Recall: 0.7407717680310664
# F1 Score: 0.7736510089395243
#
# weighted
# Precision: 0.9515263080457009
# Recall: 0.9560645363918713
# F1 Score: 0.9529846801414449
#
# start DT 50 CaFA
# Accuracy: 0.9627435697583788
#
# macro
# Precision: 0.9625887234233949
# Recall: 0.9573355864190003
# F1 Score: 0.959846537740153
#
# weighted
# Precision: 0.9627326021796597
# Recall: 0.9627435697583788
# F1 Score: 0.9626372063237623
#
# start DT 50 SINIFGSM
# Accuracy: 0.8456782843487167
#
# macro
# Precision: 0.8214155463154894
# Recall: 0.8592590756512268
# F1 Score: 0.8320611647178321
#
# weighted
# Precision: 0.8677175597498692
# Recall: 0.8456782843487167
# F1 Score: 0.8499312781377373
#
# start DT 50 VNIFGSM
# Accuracy: 0.9034468427183192
#
# macro
# Precision: 0.8873855896644178
# Recall: 0.9007862480978565
# F1 Score: 0.8933547504852071
#
# weighted
# Precision: 0.9062885852915061
# Recall: 0.9034468427183192
# F1 Score: 0.9042670842288126
#
# start DT 20 baseline
# Accuracy: 0.9452608142493639
#
# macro
# Precision: 0.9079682801358147
# Recall: 0.8419967630058292
# F1 Score: 0.8708434683989148
#
# weighted
# Precision: 0.9429266249490273
# Recall: 0.9452608142493639
# F1 Score: 0.9428566334971873
#
# start DT 20 BIM
# Accuracy: 0.7987308796077011
#
# macro
# Precision: 0.7574196409677911
# Recall: 0.8047533011807
# F1 Score: 0.7697373238139661
#
# weighted
# Precision: 0.8322710357679061
# Recall: 0.7987308796077011
# F1 Score: 0.8071023185133417
#
# start DT 20 FGSM
# Accuracy: 0.8516995291924201
#
# macro
# Precision: 0.8195617378888813
# Recall: 0.8497128504840514
# F1 Score: 0.8309549216586889
#
# weighted
# Precision: 0.863983505038937
# Recall: 0.8516995291924201
# F1 Score: 0.8550280000331222
#
# start DT 20 PGD
# Accuracy: 0.7987308796077011
#
# macro
# Precision: 0.7574196409677911
# Recall: 0.8047533011807
# F1 Score: 0.7697373238139661
#
# weighted
# Precision: 0.8322710357679061
# Recall: 0.7987308796077011
# F1 Score: 0.8071023185133417
#
# start DT 20 DF
# Accuracy: 0.8326996197718631
#
# macro
# Precision: 0.6998357830761874
# Recall: 0.70553924933768
# F1 Score: 0.7026026823054882
#
# weighted
# Precision: 0.8351253213504046
# Recall: 0.8326996197718631
# F1 Score: 0.8338764699480395
#
# start DT 20 AutoPGD
# Accuracy: 0.834410010184781
#
# macro
# Precision: 0.7895489998140142
# Recall: 0.8561854181208564
# F1 Score: 0.8067633049900333
#
# weighted
# Precision: 0.8736482024812111
# Recall: 0.834410010184781
# F1 Score: 0.8428219591823751
#
# start DT 20 ZOO
# Accuracy: 0.9445660533633082
#
# macro
# Precision: 0.7874362434164213
# Recall: 0.6941286718824137
# F1 Score: 0.7299772604666326
#
# weighted
# Precision: 0.9369113087273813
# Recall: 0.9445660533633082
# F1 Score: 0.9392085964410253
#
# start DT 20 CaFA
# Accuracy: 0.9531311425887533
#
# macro
# Precision: 0.9527676136780238
# Recall: 0.946984734713774
# F1 Score: 0.9497227403695729
#
# weighted
# Precision: 0.95310037772561
# Recall: 0.9531311425887533
# F1 Score: 0.952980546454528
#
# start DT 20 SINIFGSM
# Accuracy: 0.8303205070439458
#
# macro
# Precision: 0.7967575022556928
# Recall: 0.8423291920823686
# F1 Score: 0.8095835094625092
#
# weighted
# Precision: 0.857573642878048
# Recall: 0.8303205070439458
# F1 Score: 0.8363085694428962
#
# start DT 20 VNIFGSM
# Accuracy: 0.9174118390024656
#
# macro
# Precision: 0.9057996554639001
# Recall: 0.901532069974988
# F1 Score: 0.9036167947718361
#
# weighted
# Precision: 0.9170500937956457
# Recall: 0.9174118390024656
# F1 Score: 0.9171935660871102
#
# start DT 1 baseline
# Accuracy: 0.9073853692684635
#
# macro
# Precision: 0.7786667807386682
# Recall: 0.7072173922352161
# F1 Score: 0.7355518008563513
#
# weighted
# Precision: 0.8975997455790637
# Recall: 0.9073853692684635
# F1 Score: 0.9005955930090183
#
# start DT 1 BIM
# Accuracy: 0.7213981324080758
#
# macro
# Precision: 0.7202898006141478
# Recall: 0.7626344404220432
# F1 Score: 0.7093546945997137
#
# weighted
# Precision: 0.8004266040539432
# Recall: 0.7213981324080758
# F1 Score: 0.7331129813109533
#
# start DT 1 FGSM
# Accuracy: 0.8137959095551662
#
# macro
# Precision: 0.7367048387529287
# Recall: 0.7622585215043252
# F1 Score: 0.747454239498878
#
# weighted
# Precision: 0.8257117577622456
# Recall: 0.8137959095551662
# F1 Score: 0.8185552523448758
#
# start DT 1 PGD
# Accuracy: 0.7213981324080758
#
# macro
# Precision: 0.7202898006141478
# Recall: 0.7626344404220432
# F1 Score: 0.7093546945997137
#
# weighted
# Precision: 0.8004266040539432
# Recall: 0.7213981324080758
# F1 Score: 0.7331129813109533
#
# start DT 1 DF
# Accuracy: 0.7805357116875936
#
# macro
# Precision: 0.6612821815289767
# Recall: 0.6635014164874455
# F1 Score: 0.6623698581228243
#
# weighted
# Precision: 0.7820587377391702
# Recall: 0.7805357116875936
# F1 Score: 0.7812854913344225
#
# start DT 1 AutoPGD
# Accuracy: 0.7219539700954689
#
# macro
# Precision: 0.7410523367098026
# Recall: 0.7659982941494341
# F1 Score: 0.7185917328459692
#
# weighted
# Precision: 0.8007192470549428
# Recall: 0.7219539700954689
# F1 Score: 0.7284818738308747
#
# start DT 1 ZOO
# Accuracy: 0.9061495780834585
#
# macro
# Precision: 0.7631860068855737
# Recall: 0.6963145088862409
# F1 Score: 0.7229289304544815
#
# weighted
# Precision: 0.8959020659217768
# Recall: 0.9061495780834585
# F1 Score: 0.8993389341006048
#
# start DT 1 CaFA
# Accuracy: 0.9309014678610985
#
# macro
# Precision: 0.931206836240307
# Recall: 0.9249842971868466
# F1 Score: 0.927800074463907
#
# weighted
# Precision: 0.9309471982118271
# Recall: 0.9309014678610985
# F1 Score: 0.9306504480392496
#
# start DT 1 SINIFGSM
# Accuracy: 0.8376056839237725
#
# macro
# Precision: 0.8286723014721099
# Recall: 0.8476853151554692
# F1 Score: 0.8326044322318797
#
# weighted
# Precision: 0.8524319887045523
# Recall: 0.8376056839237725
# F1 Score: 0.8398737512109947
#
# start DT 1 VNIFGSM
# Accuracy: 0.8787900259212679
#
# macro
# Precision: 0.8491076699964826
# Recall: 0.8667825219709001
# F1 Score: 0.8570010118841789
#
# weighted
# Precision: 0.8831633443067557
# Recall: 0.8787900259212679
# F1 Score: 0.8802850563660216

# %%
epsilon = 0

Def = "Def1"
attack_names = [
    "baseline", "BIM", "FGSM", "PGD", "DF",
    "AutoPGD", "ZOO", "CaFA", "SINIFGSM", "VNIFGSM"
]

percentage = ["100", "50", "20", "1"]
model_name = ["XGB", "RF", "DT" ]

base_path = "/home/jovyan/Sample_Based_Extension/UNSW/UNSW_Dynamite_Selection_Data"

for m_name in model_name:
    for p in percentage:
        for attack in attack_names:
            print(f"start {m_name} {p} {attack}")
            
            x_path = f"{base_path}/{m_name}_ExcludeCaFA/UNSW_Input{p}/x_test_adv_{attack}_{Def}.npy"
            y_path = f"{base_path}/{m_name}_ExcludeCaFA/UNSW_Input{p}/y_test_adv_{attack}_{Def}.npy"

            try:
                x_test_adv = np.load(x_path)
                y_test_adv = np.load(y_path)
                m_per_name = f"{m_name}{p}_ExcludeCaFA"
                calculate_performance_metrics(x_test_adv, y_test_adv, model, m_per_name, attack, epsilon)
            except FileNotFoundError:
                print(x_path, "not found")
                nprint_empty_file()
# Out:
# start XGB 100 baseline
# Accuracy: 0.7254069355980184
#
# macro
# Precision: 0.7850527444471243
# Recall: 0.6037443119969272
# F1 Score: 0.5919908015524241
#
# weighted
# Precision: 0.7616057713133378
# Recall: 0.7254069355980184
# F1 Score: 0.6672850554197397
#
# start XGB 100 BIM
# Accuracy: 0.9372716245639677
#
# macro
# Precision: 0.9292619771727252
# Recall: 0.9374774844375552
# F1 Score: 0.9330215869293141
#
# weighted
# Precision: 0.938476020846614
# Recall: 0.9372716245639677
# F1 Score: 0.9375688157704823
#
# start XGB 100 FGSM
# Accuracy: 0.9299066988857565
#
# macro
# Precision: 0.9131358910303559
# Recall: 0.9016031752918385
# F1 Score: 0.9071479813321681
#
# weighted
# Precision: 0.9291912719998663
# Recall: 0.9299066988857565
# F1 Score: 0.9294106864332276
#
# start XGB 100 PGD
# Accuracy: 0.9372716245639677
#
# macro
# Precision: 0.9292619771727252
# Recall: 0.9374774844375552
# F1 Score: 0.9330215869293141
#
# weighted
# Precision: 0.938476020846614
# Recall: 0.9372716245639677
# F1 Score: 0.9375688157704823
#
# start XGB 100 DF
# Accuracy: 0.9051909628832706
#
# macro
# Precision: 0.8052829732234369
# Recall: 0.7557024163512944
# F1 Score: 0.777179283288429
#
# weighted
# Precision: 0.8988673247500354
# Recall: 0.9051909628832706
# F1 Score: 0.9010073371458287
#
# start XGB 100 AutoPGD
# Accuracy: 0.954833603271504
#
# macro
# Precision: 0.9448449678527506
# Recall: 0.9585377828194335
# F1 Score: 0.9509524156423607
#
# weighted
# Precision: 0.9567644940244335
# Recall: 0.954833603271504
# F1 Score: 0.9551756743883599
#
# start XGB 100 ZOO
# Accuracy: 0.7304425569959767
#
# macro
# Precision: 0.7812873513183091
# Recall: 0.619544004776954
# F1 Score: 0.6143568646862998
#
# weighted
# Precision: 0.761071021064886
# Recall: 0.7304425569959767
# F1 Score: 0.680407794992865
#
# start XGB 100 CaFA
# Accuracy: 0.6637818169452332
#
# macro
# Precision: 0.6027506210795048
# Recall: 0.5756385295587967
# F1 Score: 0.5748472495248659
#
# weighted
# Precision: 0.6369858193871248
# Recall: 0.6637818169452332
# F1 Score: 0.638766800137824
#
# start XGB 100 SINIFGSM
# Accuracy: 0.9591573580123198
#
# macro
# Precision: 0.9590322369267636
# Recall: 0.9592980222129406
# F1 Score: 0.9591323235740102
#
# weighted
# Precision: 0.9592346931805554
# Recall: 0.9591573580123198
# F1 Score: 0.9591632681967734
#
# start XGB 100 VNIFGSM
# Accuracy: 0.9513757707523969
#
# macro
# Precision: 0.9459779333195473
# Recall: 0.9338278715721305
# F1 Score: 0.9396335263832258
#
# weighted
# Precision: 0.9510757259705191
# Recall: 0.9513757707523969
# F1 Score: 0.9510400882709865
#
# start XGB 50 baseline
# Accuracy: 0.7352849579570228
#
# macro
# Precision: 0.785853069488517
# Recall: 0.6104144839225829
# F1 Score: 0.6043911158421548
#
# weighted
# Precision: 0.7647134635546217
# Recall: 0.7352849579570228
# F1 Score: 0.6815667487945594
#
# start XGB 50 BIM
# Accuracy: 0.916250914038709
#
# macro
# Precision: 0.8494874216488024
# Recall: 0.8986539051826357
# F1 Score: 0.8707288925765179
#
# weighted
# Precision: 0.9248242317209013
# Recall: 0.916250914038709
# F1 Score: 0.9189973877954085
#
# start XGB 50 FGSM
# Accuracy: 0.9109330636692466
#
# macro
# Precision: 0.8404378011959476
# Recall: 0.8072325225080426
# F1 Score: 0.8224403727515761
#
# weighted
# Precision: 0.9073891802343141
# Recall: 0.9109330636692466
# F1 Score: 0.9086513943755729
#
# start XGB 50 PGD
# Accuracy: 0.916250914038709
#
# macro
# Precision: 0.8494874216488024
# Recall: 0.8986539051826357
# F1 Score: 0.8707288925765179
#
# weighted
# Precision: 0.9248242317209013
# Recall: 0.916250914038709
# F1 Score: 0.9189973877954085
#
# start XGB 50 DF
# Accuracy: 0.8974214343271555
#
# macro
# Precision: 0.7819149522653535
# Recall: 0.7472256235560781
# F1 Score: 0.7628091544060842
#
# weighted
# Precision: 0.8917961838701853
# Recall: 0.8974214343271555
# F1 Score: 0.8940617667710978
#
# start XGB 50 AutoPGD
# Accuracy: 0.9496588709941942
#
# macro
# Precision: 0.9209003254404127
# Recall: 0.9500919943855837
# F1 Score: 0.9341559119874869
#
# weighted
# Precision: 0.9529656206205618
# Recall: 0.9496588709941942
# F1 Score: 0.9505017050422326
#
# start XGB 50 ZOO
# Accuracy: 0.7085893954551951
#
# macro
# Precision: 0.7649286203768622
# Recall: 0.6171543717857093
# F1 Score: 0.6046231508387382
#
# weighted
# Precision: 0.7458827477714208
# Recall: 0.7085893954551951
# F1 Score: 0.6571568190354039
#
# start XGB 50 CaFA
# Accuracy: 0.8031724220336958
#
# macro
# Precision: 0.7677112806533095
# Recall: 0.7074184312208736
# F1 Score: 0.7263257447817985
#
# weighted
# Precision: 0.7933442362278268
# Recall: 0.8031724220336958
# F1 Score: 0.7908101241974123
#
# start XGB 50 SINIFGSM
# Accuracy: 0.9447647079313107
#
# macro
# Precision: 0.931678904233691
# Recall: 0.9436534443489575
# F1 Score: 0.9372615701063095
#
# weighted
# Precision: 0.9461519127672625
# Recall: 0.9447647079313107
# F1 Score: 0.9451423870920939
#
# start XGB 50 VNIFGSM
# Accuracy: 0.9472270594138308
#
# macro
# Precision: 0.9299406938480332
# Recall: 0.9052101239020262
# F1 Score: 0.9168600856541912
#
# weighted
# Precision: 0.946360121116319
# Recall: 0.9472270594138308
# F1 Score: 0.9464459980496503
#
# start XGB 20 baseline
# Accuracy: 0.682791435368755
#
# macro
# Precision: 0.703916688498821
# Recall: 0.6224051707869409
# F1 Score: 0.612522200849317
#
# weighted
# Precision: 0.6974067140263402
# Recall: 0.682791435368755
# F1 Score: 0.6456285627365009
#
# start XGB 20 BIM
# Accuracy: 0.9502072631349293
#
# macro
# Precision: 0.9448873311835575
# Recall: 0.9396873501063383
# F1 Score: 0.9422213057545803
#
# weighted
# Precision: 0.950015792407216
# Recall: 0.9502072631349293
# F1 Score: 0.9500609174676589
#
# start XGB 20 FGSM
# Accuracy: 0.9483097583352658
#
# macro
# Precision: 0.9388149455250554
# Recall: 0.9253980221502371
# F1 Score: 0.9318262924381504
#
# weighted
# Precision: 0.947858574652417
# Recall: 0.9483097583352658
# F1 Score: 0.9479085881142398
#
# start XGB 20 PGD
# Accuracy: 0.9502072631349293
#
# macro
# Precision: 0.9448873311835575
# Recall: 0.9396873501063383
# F1 Score: 0.9422213057545803
#
# weighted
# Precision: 0.950015792407216
# Recall: 0.9502072631349293
# F1 Score: 0.9500609174676589
#
# start XGB 20 DF
# Accuracy: 0.8872141163230033
#
# macro
# Precision: 0.7613485965212266
# Recall: 0.7335709440381846
# F1 Score: 0.7462104934432037
#
# weighted
# Precision: 0.8816910007409067
# Recall: 0.8872141163230033
# F1 Score: 0.8840510202944952
#
# start XGB 20 AutoPGD
# Accuracy: 0.9662127659574468
#
# macro
# Precision: 0.9572454680346688
# Recall: 0.9649018655668917
# F1 Score: 0.9609358571642602
#
# weighted
# Precision: 0.9667024429016889
# Recall: 0.9662127659574468
# F1 Score: 0.9663530146718669
#
# start XGB 20 ZOO
# Accuracy: 0.6864642909517524
#
# macro
# Precision: 0.6855939698492461
# Recall: 0.6140091032001507
# F1 Score: 0.6082440546375515
#
# weighted
# Precision: 0.6859206103352466
# Recall: 0.6864642909517524
# F1 Score: 0.6509353093111702
#
# start XGB 20 CaFA
# Accuracy: 0.7796888253939908
#
# macro
# Precision: 0.7868373700851954
# Recall: 0.7656059350930524
# F1 Score: 0.7696354745220497
#
# weighted
# Precision: 0.7839015530801928
# Recall: 0.7796888253939908
# F1 Score: 0.7754890524353059
#
# start XGB 20 SINIFGSM
# Accuracy: 0.9650366240621571
#
# macro
# Precision: 0.9651830283104601
# Recall: 0.9639624991716389
# F1 Score: 0.9645425197968024
#
# weighted
# Precision: 0.9650496278803228
# Recall: 0.9650366240621571
# F1 Score: 0.9650136607505451
#
# start XGB 20 VNIFGSM
# Accuracy: 0.9555161212704524
#
# macro
# Precision: 0.9543392812074184
# Recall: 0.9390082598522923
# F1 Score: 0.9462093467592114
#
# weighted
# Precision: 0.9554234236577076
# Recall: 0.9555161212704524
# F1 Score: 0.9551345545071267
#
# start XGB 1 baseline
# Accuracy: 0.65
#
# macro
# Precision: 0.6689085996240601
# Recall: 0.6288436334307894
# F1 Score: 0.6174573055028463
#
# weighted
# Precision: 0.6654590578007519
# Recall: 0.65
# F1 Score: 0.6274990512333966
#
# start XGB 1 BIM
# Accuracy: 0.8857738347750705
#
# macro
# Precision: 0.8635088224401101
# Recall: 0.8788135829561792
# F1 Score: 0.8703203294736885
#
# weighted
# Precision: 0.8894436795009185
# Recall: 0.8857738347750705
# F1 Score: 0.8869504347459228
#
# start XGB 1 FGSM
# Accuracy: 0.8761763064906082
#
# macro
# Precision: 0.8402385225138649
# Recall: 0.7884605093140372
# F1 Score: 0.8096692205494489
#
# weighted
# Precision: 0.8710731285613216
# Recall: 0.8761763064906082
# F1 Score: 0.8710934048153337
#
# start XGB 1 PGD
# Accuracy: 0.8857738347750705
#
# macro
# Precision: 0.8635088224401101
# Recall: 0.8788135829561792
# F1 Score: 0.8703203294736885
#
# weighted
# Precision: 0.8894436795009185
# Recall: 0.8857738347750705
# F1 Score: 0.8869504347459228
#
# start XGB 1 DF
# Accuracy: 0.8231431564424232
#
# macro
# Precision: 0.6745943196985069
# Recall: 0.6930982881239101
# F1 Score: 0.6828361830278457
#
# weighted
# Precision: 0.832866867341279
# Recall: 0.8231431564424232
# F1 Score: 0.8275897319290176
#
# start XGB 1 AutoPGD
# Accuracy: 0.9180805381219783
#
# macro
# Precision: 0.9099117467459068
# Recall: 0.9245071421000313
# F1 Score: 0.915137507864491
#
# weighted
# Precision: 0.9233228317143325
# Recall: 0.9180805381219783
# F1 Score: 0.918795474037951
#
# start XGB 1 ZOO
# Accuracy: 0.6952598175327251
#
# macro
# Precision: 0.6888227319762914
# Recall: 0.6375263854364499
# F1 Score: 0.6385928942286804
#
# weighted
# Precision: 0.6915197198480167
# Recall: 0.6952598175327251
# F1 Score: 0.6720566070137887
#
# start XGB 1 CaFA
# Accuracy: 0.7326669134888313
#
# macro
# Precision: 0.7002655698253504
# Recall: 0.676013651851572
# F1 Score: 0.6835185819480394
#
# weighted
# Precision: 0.7230479536066544
# Recall: 0.7326669134888313
# F1 Score: 0.7240999708182799
#
# start XGB 1 SINIFGSM
# Accuracy: 0.9100085405552598
#
# macro
# Precision: 0.9102114154601035
# Recall: 0.9056979808420706
# F1 Score: 0.9076745588307733
#
# weighted
# Precision: 0.9100476312597527
# Recall: 0.9100085405552598
# F1 Score: 0.9097597072695424
#
# start XGB 1 VNIFGSM
# Accuracy: 0.9035905213745385
#
# macro
# Precision: 0.8989076259799548
# Recall: 0.884639181443725
# F1 Score: 0.891074813161993
#
# weighted
# Precision: 0.9029770529348867
# Recall: 0.9035905213745385
# F1 Score: 0.9027132694085259
#
# start RF 100 baseline
# Accuracy: 0.8728923476005188
#
# macro
# Precision: 0.8547091979721007
# Recall: 0.8260353756782838
# F1 Score: 0.8384002346124548
#
# weighted
# Precision: 0.8702771577633935
# Recall: 0.8728923476005188
# F1 Score: 0.8702197414285071
#
# start RF 100 BIM
# Accuracy: 0.9010188062666197
#
# macro
# Precision: 0.8903606230225809
# Recall: 0.8825983696685127
# F1 Score: 0.8862903793057102
#
# weighted
# Precision: 0.9003230988049206
# Recall: 0.9010188062666197
# F1 Score: 0.9005218931212791
#
# start RF 100 FGSM
# Accuracy: 0.9095713398895677
#
# macro
# Precision: 0.9012428801597505
# Recall: 0.8777400640515098
# F1 Score: 0.8882792071118911
#
# weighted
# Precision: 0.908569312009716
# Recall: 0.9095713398895677
# F1 Score: 0.908208487227446
#
# start RF 100 PGD
# Accuracy: 0.9010188062666197
#
# macro
# Precision: 0.8903606230225809
# Recall: 0.8825983696685127
# F1 Score: 0.8862903793057102
#
# weighted
# Precision: 0.9003230988049206
# Recall: 0.9010188062666197
# F1 Score: 0.9005218931212791
#
# start RF 100 DF
# Accuracy: 0.9338102088661552
#
# macro
# Precision: 0.8271907163306162
# Recall: 0.8307724467926061
# F1 Score: 0.8289679555390408
#
# weighted
# Precision: 0.9341772607696962
# Recall: 0.9338102088661552
# F1 Score: 0.9339903655190301
#
# start RF 100 AutoPGD
# Accuracy: 0.9465320561230574
#
# macro
# Precision: 0.9304027068223971
# Recall: 0.9433873544010485
# F1 Score: 0.9365224620394006
#
# weighted
# Precision: 0.9478648767986284
# Recall: 0.9465320561230574
# F1 Score: 0.9469292097569494
#
# start RF 100 ZOO
# Accuracy: 0.868859649122807
#
# macro
# Precision: 0.8334278271529267
# Recall: 0.8316933747451458
# F1 Score: 0.8325532270554803
#
# weighted
# Precision: 0.8685274757918394
# Recall: 0.868859649122807
# F1 Score: 0.8686886612637772
#
# start RF 100 CaFA
# Accuracy: 0.8649088889363611
#
# macro
# Precision: 0.8697155015540935
# Recall: 0.8623992422331118
# F1 Score: 0.8636720437848141
#
# weighted
# Precision: 0.868297008076607
# Recall: 0.8649088889363611
# F1 Score: 0.8642357150711486
#
# start RF 100 SINIFGSM
# Accuracy: 0.9177520132114341
#
# macro
# Precision: 0.9187183768255714
# Recall: 0.9026787030583078
# F1 Score: 0.909661250327134
#
# weighted
# Precision: 0.917926369795404
# Recall: 0.9177520132114341
# F1 Score: 0.9169497490342047
#
# start RF 100 VNIFGSM
# Accuracy: 0.9354079662310836
#
# macro
# Precision: 0.9436889109034244
# Recall: 0.9131469020432127
# F1 Score: 0.925883372058858
#
# weighted
# Precision: 0.9371904548918025
# Recall: 0.9354079662310836
# F1 Score: 0.9342592402798098
#
# start RF 50 baseline
# Accuracy: 0.8108305002428363
#
# macro
# Precision: 0.8111420108393372
# Recall: 0.7533016899713972
# F1 Score: 0.7700034966341043
#
# weighted
# Precision: 0.8109488800866981
# Recall: 0.8108305002428363
# F1 Score: 0.8012532146700675
#
# start RF 50 BIM
# Accuracy: 0.8951828250644819
#
# macro
# Precision: 0.8790060534414499
# Recall: 0.8785414306153183
# F1 Score: 0.8787730716744417
#
# weighted
# Precision: 0.895119574732993
# Recall: 0.8951828250644819
# F1 Score: 0.8951506815858111
#
# start RF 50 FGSM
# Accuracy: 0.9134282447959075
#
# macro
# Precision: 0.9010463486044251
# Recall: 0.8838931198912778
# F1 Score: 0.8918552281284848
#
# weighted
# Precision: 0.9123885019032294
# Recall: 0.9134282447959075
# F1 Score: 0.9124827742191933
#
# start RF 50 PGD
# Accuracy: 0.8951828250644819
#
# macro
# Precision: 0.8790060534414499
# Recall: 0.8785414306153183
# F1 Score: 0.8787730716744417
#
# weighted
# Precision: 0.895119574732993
# Recall: 0.8951828250644819
# F1 Score: 0.8951506815858111
#
# start RF 50 DF
# Accuracy: 0.9084699816621044
#
# macro
# Precision: 0.7847002829992896
# Recall: 0.7831856377287276
# F1 Score: 0.7839399157256652
#
# weighted
# Precision: 0.9082275845464466
# Recall: 0.9084699816621044
# F1 Score: 0.9083479190055819
#
# start RF 50 AutoPGD
# Accuracy: 0.9424610185114064
#
# macro
# Precision: 0.9251675362333833
# Recall: 0.9409623206848676
# F1 Score: 0.9324744573071468
#
# weighted
# Precision: 0.9443778179088904
# Recall: 0.9424610185114064
# F1 Score: 0.9429854092159823
#
# start RF 50 ZOO
# Accuracy: 0.7782682071920031
#
# macro
# Precision: 0.7705125588830501
# Recall: 0.7238943002052319
# F1 Score: 0.7364303559749288
#
# weighted
# Precision: 0.7751959409687545
# Recall: 0.7782682071920031
# F1 Score: 0.7679348441348046
#
# start RF 50 CaFA
# Accuracy: 0.840963074168834
#
# macro
# Precision: 0.8393465891308558
# Recall: 0.804124249465203
# F1 Score: 0.8167693023719749
#
# weighted
# Precision: 0.840472158419865
# Recall: 0.840963074168834
# F1 Score: 0.8366316123574673
#
# start RF 50 SINIFGSM
# Accuracy: 0.9136759545923633
#
# macro
# Precision: 0.9143788253749949
# Recall: 0.9034374240355932
# F1 Score: 0.9081952786354548
#
# weighted
# Precision: 0.9138098633911577
# Recall: 0.9136759545923633
# F1 Score: 0.9130989048785019
#
# start RF 50 VNIFGSM
# Accuracy: 0.9243603906146436
#
# macro
# Precision: 0.934179426075147
# Recall: 0.903006309838212
# F1 Score: 0.9153551791380071
#
# weighted
# Precision: 0.9270094565066435
# Recall: 0.9243603906146436
# F1 Score: 0.9229562237118573
#
# start RF 20 baseline
# Accuracy: 0.7181208053691275
#
# macro
# Precision: 0.7353436539169802
# Recall: 0.6839709768934407
# F1 Score: 0.6851757944557133
#
# weighted
# Precision: 0.7297290526709814
# Recall: 0.7181208053691275
# F1 Score: 0.7013748973322261
#
# start RF 20 BIM
# Accuracy: 0.9090545139120572
#
# macro
# Precision: 0.9066578519105704
# Recall: 0.8900399815463291
# F1 Score: 0.8974136599039446
#
# weighted
# Precision: 0.9086936647197827
# Recall: 0.9090545139120572
# F1 Score: 0.9081068282633825
#
# start RF 20 FGSM
# Accuracy: 0.9177706330903765
#
# macro
# Precision: 0.9112421130261958
# Recall: 0.8885686213254937
# F1 Score: 0.8988018613692483
#
# weighted
# Precision: 0.9170154015301479
# Recall: 0.9177706330903765
# F1 Score: 0.9166061039088967
#
# start RF 20 PGD
# Accuracy: 0.9090545139120572
#
# macro
# Precision: 0.9066578519105704
# Recall: 0.8900399815463291
# F1 Score: 0.8974136599039446
#
# weighted
# Precision: 0.9086936647197827
# Recall: 0.9090545139120572
# F1 Score: 0.9081068282633825
#
# start RF 20 DF
# Accuracy: 0.881181008112781
#
# macro
# Precision: 0.7394677931090066
# Recall: 0.7427572793895953
# F1 Score: 0.741094004381402
#
# weighted
# Precision: 0.8820033086277808
# Recall: 0.881181008112781
# F1 Score: 0.8815862645060156
#
# start RF 20 AutoPGD
# Accuracy: 0.9457661076859174
#
# macro
# Precision: 0.9321497853460965
# Recall: 0.9421632079675248
# F1 Score: 0.9369110242135826
#
# weighted
# Precision: 0.9467557275265973
# Recall: 0.9457661076859174
# F1 Score: 0.946076613112893
#
# start RF 20 ZOO
# Accuracy: 0.7199616385806274
#
# macro
# Precision: 0.697796537646064
# Recall: 0.6419176033084335
# F1 Score: 0.6485038421740089
#
# weighted
# Precision: 0.7093633891626675
# Recall: 0.7199616385806274
# F1 Score: 0.6975102981113344
#
# start RF 20 CaFA
# Accuracy: 0.8473028693909431
#
# macro
# Precision: 0.8536495855838774
# Recall: 0.8409036501491618
# F1 Score: 0.8439428648361481
#
# weighted
# Precision: 0.8510282646805423
# Recall: 0.8473028693909431
# F1 Score: 0.8459070962683417
#
# start RF 20 SINIFGSM
# Accuracy: 0.9172930368514459
#
# macro
# Precision: 0.9232782375095219
# Recall: 0.9035347375840943
# F1 Score: 0.9113625276216482
#
# weighted
# Precision: 0.9189988035037822
# Recall: 0.9172930368514459
# F1 Score: 0.9163075107994353
#
# start RF 20 VNIFGSM
# Accuracy: 0.929378855130909
#
# macro
# Precision: 0.9376796483890009
# Recall: 0.9090792865249395
# F1 Score: 0.9207517634995745
#
# weighted
# Precision: 0.9313910858795859
# Recall: 0.929378855130909
# F1 Score: 0.9281889671516956
#
# start RF 1 baseline
# Accuracy: 0.6579497907949791
#
# macro
# Precision: 0.6859567249107592
# Recall: 0.6336209704578455
# F1 Score: 0.6200317965023847
#
# weighted
# Precision: 0.6809886332839834
# Recall: 0.6579497907949791
# F1 Score: 0.6314574172991599
#
# start RF 1 BIM
# Accuracy: 0.8459484560018574
#
# macro
# Precision: 0.8126643089326355
# Recall: 0.8185668593457492
# F1 Score: 0.8154978120398704
#
# weighted
# Precision: 0.8475609756260706
# Recall: 0.8459484560018574
# F1 Score: 0.8466686331051927
#
# start RF 1 FGSM
# Accuracy: 0.8856952023862834
#
# macro
# Precision: 0.8660078636375499
# Recall: 0.8326564040861133
# F1 Score: 0.8471089409234001
#
# weighted
# Precision: 0.8830991552903045
# Recall: 0.8856952023862834
# F1 Score: 0.882971562301759
#
# start RF 1 PGD
# Accuracy: 0.8459484560018574
#
# macro
# Precision: 0.8126643089326355
# Recall: 0.8185668593457492
# F1 Score: 0.8154978120398704
#
# weighted
# Precision: 0.8475609756260706
# Recall: 0.8459484560018574
# F1 Score: 0.8466686331051927
#
# start RF 1 DF
# Accuracy: 0.8215532176664072
#
# macro
# Precision: 0.6678081302389292
# Recall: 0.697966476146612
# F1 Score: 0.6801879065504643
#
# weighted
# Precision: 0.8383951149905613
# Recall: 0.8215532176664072
# F1 Score: 0.8288940274698146
#
# start RF 1 AutoPGD
# Accuracy: 0.9066878452383774
#
# macro
# Precision: 0.8757323451387342
# Recall: 0.9116310020705047
# F1 Score: 0.8902454043369956
#
# weighted
# Precision: 0.9158567278069786
# Recall: 0.9066878452383774
# F1 Score: 0.9088088224248233
#
# start RF 1 ZOO
# Accuracy: 0.7104655636783378
#
# macro
# Precision: 0.6595691472859793
# Recall: 0.6052754937186667
# F1 Score: 0.609096671371204
#
# weighted
# Precision: 0.6879214451233696
# Recall: 0.7104655636783378
# F1 Score: 0.6816288519642193
#
# start RF 1 CaFA
# Accuracy: 0.828167231762756
#
# macro
# Precision: 0.8247367663881352
# Recall: 0.7869355910753995
# F1 Score: 0.8000300857545699
#
# weighted
# Precision: 0.8270833582875419
# Recall: 0.828167231762756
# F1 Score: 0.8228882281489946
#
# start RF 1 SINIFGSM
# Accuracy: 0.880451016536376
#
# macro
# Precision: 0.8765920494090615
# Recall: 0.866065345294027
# F1 Score: 0.8707172789539966
#
# weighted
# Precision: 0.879833358965766
# Recall: 0.880451016536376
# F1 Score: 0.8796042725324953
#
# start RF 1 VNIFGSM
# Accuracy: 0.8911919054630574
#
# macro
# Precision: 0.8917142251542262
# Recall: 0.8520504555145005
# F1 Score: 0.8679458584401961
#
# weighted
# Precision: 0.8913074767518632
# Recall: 0.8911919054630574
# F1 Score: 0.888300216863723
#
# start DT 100 baseline
# Accuracy: 0.7816482582837723
#
# macro
# Precision: 0.7787511330508483
# Recall: 0.7514586557677253
# F1 Score: 0.7594792264217238
#
# weighted
# Precision: 0.7804824999933261
# Recall: 0.7816482582837723
# F1 Score: 0.7760646401841892
#
# start DT 100 BIM
# Accuracy: 0.890885876352676
#
# macro
# Precision: 0.8760353454536995
# Recall: 0.8663637516762182
# F1 Score: 0.870934502477799
#
# weighted
# Precision: 0.8898644395386714
# Recall: 0.890885876352676
# F1 Score: 0.8901752998448879
#
# start DT 100 FGSM
# Accuracy: 0.9048574188648079
#
# macro
# Precision: 0.9041522735858336
# Recall: 0.8948612645927206
# F1 Score: 0.8989625612507123
#
# weighted
# Precision: 0.9047364929543488
# Recall: 0.9048574188648079
# F1 Score: 0.9043045566272715
#
# start DT 100 PGD
# Accuracy: 0.890885876352676
#
# macro
# Precision: 0.8760353454536995
# Recall: 0.8663637516762182
# F1 Score: 0.870934502477799
#
# weighted
# Precision: 0.8898644395386714
# Recall: 0.890885876352676
# F1 Score: 0.8901752998448879
#
# start DT 100 DF
# Accuracy: 0.8947552105872991
#
# macro
# Precision: 0.7649223625048474
# Recall: 0.7798849903891576
# F1 Score: 0.7720733332914009
#
# weighted
# Precision: 0.8978500996972649
# Recall: 0.8947552105872991
# F1 Score: 0.8962002020636123
#
# start DT 100 AutoPGD
# Accuracy: 0.9293428212641273
#
# macro
# Precision: 0.9047202351750019
# Recall: 0.9265755155121448
# F1 Score: 0.9146035799998937
#
# weighted
# Precision: 0.9326518465803015
# Recall: 0.9293428212641273
# F1 Score: 0.93027086364342
#
# start DT 100 ZOO
# Accuracy: 0.759563586771224
#
# macro
# Precision: 0.7397840185847887
# Recall: 0.7163992968869415
# F1 Score: 0.7242656923847814
#
# weighted
# Precision: 0.7537058286332051
# Recall: 0.759563586771224
# F1 Score: 0.7534283324010247
#
# start DT 100 CaFA
# Accuracy: 0.8756983081961268
#
# macro
# Precision: 0.8821969009145463
# Recall: 0.8703676583747217
# F1 Score: 0.8733468875089159
#
# weighted
# Precision: 0.8795044411579439
# Recall: 0.8756983081961268
# F1 Score: 0.8747245546669183
#
# start DT 100 SINIFGSM
# Accuracy: 0.8763794625613861
#
# macro
# Precision: 0.845993744162078
# Recall: 0.8582864687825735
# F1 Score: 0.8517079148167068
#
# weighted
# Precision: 0.8791573336203129
# Recall: 0.8763794625613861
# F1 Score: 0.8774579066982209
#
# start DT 100 VNIFGSM
# Accuracy: 0.9138362977819899
#
# macro
# Precision: 0.9174933061497635
# Recall: 0.8887520663279798
# F1 Score: 0.9007326399120934
#
# weighted
# Precision: 0.9146021661817655
# Recall: 0.9138362977819899
# F1 Score: 0.9123037000200851
#
# start DT 50 baseline
# Accuracy: 0.768661971830986
#
# macro
# Precision: 0.7641743111738599
# Recall: 0.731248152539516
# F1 Score: 0.7400642720579262
#
# weighted
# Precision: 0.7667736183943747
# Recall: 0.768661971830986
# F1 Score: 0.7610419902566355
#
# start DT 50 BIM
# Accuracy: 0.6909784389999242
#
# macro
# Precision: 0.6677915193008591
# Recall: 0.7444434867862602
# F1 Score: 0.6543377269307431
#
# weighted
# Precision: 0.8189507480454611
# Recall: 0.6909784389999242
# F1 Score: 0.7178731915965428
#
# start DT 50 FGSM
# Accuracy: 0.8451148737585258
#
# macro
# Precision: 0.7987547604363756
# Recall: 0.8386504244117154
# F1 Score: 0.8135614353975695
#
# weighted
# Precision: 0.8618490062551687
# Recall: 0.8451148737585258
# F1 Score: 0.8499389796452267
#
# start DT 50 PGD
# Accuracy: 0.6909784389999242
#
# macro
# Precision: 0.6677915193008591
# Recall: 0.7444434867862602
# F1 Score: 0.6543377269307431
#
# weighted
# Precision: 0.8189507480454611
# Recall: 0.6909784389999242
# F1 Score: 0.7178731915965428
#
# start DT 50 DF
# Accuracy: 0.8666095240771706
#
# macro
# Precision: 0.7304828889377699
# Recall: 0.7387601730533488
# F1 Score: 0.7344908457761574
#
# weighted
# Precision: 0.8690554533669831
# Recall: 0.8666095240771706
# F1 Score: 0.8677859124521468
#
# start DT 50 AutoPGD
# Accuracy: 0.747257788229829
#
# macro
# Precision: 0.7089569592416691
# Recall: 0.8162428780696269
# F1 Score: 0.7074898833933748
#
# weighted
# Precision: 0.8675764444042857
# Recall: 0.747257788229829
# F1 Score: 0.7715560476015475
#
# start DT 50 ZOO
# Accuracy: 0.7258797777403603
#
# macro
# Precision: 0.7062201793636832
# Recall: 0.6815164637314267
# F1 Score: 0.688057372428936
#
# weighted
# Precision: 0.7185480313748647
# Recall: 0.7258797777403603
# F1 Score: 0.7172106190761365
#
# start DT 50 CaFA
# Accuracy: 0.8797856336968786
#
# macro
# Precision: 0.8875100437593261
# Recall: 0.8689890911552555
# F1 Score: 0.8748447927678413
#
# weighted
# Precision: 0.8833210555553636
# Recall: 0.8797856336968786
# F1 Score: 0.8783193890008486
#
# start DT 50 SINIFGSM
# Accuracy: 0.8494583720210461
#
# macro
# Precision: 0.801756898721797
# Recall: 0.8703838782528247
# F1 Score: 0.8212847617183432
#
# weighted
# Precision: 0.8845812190497847
# Recall: 0.8494583720210461
# F1 Score: 0.8570395356930718
#
# start DT 50 VNIFGSM
# Accuracy: 0.8753582962607489
#
# macro
# Precision: 0.8198894546631836
# Recall: 0.8590505095346479
# F1 Score: 0.8361363669315915
#
# weighted
# Precision: 0.8865190680536125
# Recall: 0.8753582962607489
# F1 Score: 0.8789434931623934
#
# start DT 20 baseline
# Accuracy: 0.7284330985915493
#
# macro
# Precision: 0.7252251370937337
# Recall: 0.7046611847999553
# F1 Score: 0.7088669452507683
#
# weighted
# Precision: 0.7268434573895667
# Recall: 0.7284330985915493
# F1 Score: 0.7219885591210714
#
# start DT 20 BIM
# Accuracy: 0.8974793596210929
#
# macro
# Precision: 0.8862735837791251
# Recall: 0.88340295840343
# F1 Score: 0.884808023439789
#
# weighted
# Precision: 0.8971462528715027
# Recall: 0.8974793596210929
# F1 Score: 0.8972881818628372
#
# start DT 20 FGSM
# Accuracy: 0.8790456262398435
#
# macro
# Precision: 0.8592777420262652
# Recall: 0.8523365099670909
# F1 Score: 0.8556679806173064
#
# weighted
# Precision: 0.8780726597537764
# Recall: 0.8790456262398435
# F1 Score: 0.8784557918769611
#
# start DT 20 PGD
# Accuracy: 0.8974793596210929
#
# macro
# Precision: 0.8862735837791251
# Recall: 0.88340295840343
# F1 Score: 0.884808023439789
#
# weighted
# Precision: 0.8971462528715027
# Recall: 0.8974793596210929
# F1 Score: 0.8972881818628372
#
# start DT 20 DF
# Accuracy: 0.8423855461997435
#
# macro
# Precision: 0.7051861828601826
# Recall: 0.7157396099613975
# F1 Score: 0.7101975480623036
#
# weighted
# Precision: 0.846548504125138
# Recall: 0.8423855461997435
# F1 Score: 0.8443610263353896
#
# start DT 20 AutoPGD
# Accuracy: 0.938156322951882
#
# macro
# Precision: 0.920730128133872
# Recall: 0.9392748515141693
# F1 Score: 0.9290681935755747
#
# weighted
# Precision: 0.9409135050530156
# Recall: 0.938156322951882
# F1 Score: 0.938822579611869
#
# start DT 20 ZOO
# Accuracy: 0.7014871886758646
#
# macro
# Precision: 0.6766743712482994
# Recall: 0.6554505387823739
# F1 Score: 0.6605082401532942
#
# weighted
# Precision: 0.6921732865329662
# Recall: 0.7014871886758646
# F1 Score: 0.6920191283674006
#
# start DT 20 CaFA
# Accuracy: 0.8710697985339542
#
# macro
# Precision: 0.8772608177221799
# Recall: 0.8628962609170301
# F1 Score: 0.8672158663485328
#
# weighted
# Precision: 0.8740971167334817
# Recall: 0.8710697985339542
# F1 Score: 0.8698226122126089
#
# start DT 20 SINIFGSM
# Accuracy: 0.9142891287893877
#
# macro
# Precision: 0.9071778889458155
# Recall: 0.9054414629630143
# F1 Score: 0.9062967263835131
#
# weighted
# Precision: 0.914128019706436
# Recall: 0.9142891287893877
# F1 Score: 0.9141975553106396
#
# start DT 20 VNIFGSM
# Accuracy: 0.9034461533200537
#
# macro
# Precision: 0.8889285452380438
# Recall: 0.8822342520808648
# F1 Score: 0.8854627893639092
#
# weighted
# Precision: 0.9027849959383433
# Recall: 0.9034461533200537
# F1 Score: 0.9030271144395463
#
# start DT 1 baseline
# Accuracy: 0.8010478617955253
#
# macro
# Precision: 0.7871849408440053
# Recall: 0.7974490395797758
# F1 Score: 0.7910194764445102
#
# weighted
# Precision: 0.8068837393165879
# Recall: 0.8010478617955253
# F1 Score: 0.8027916469664517
#
# start DT 1 BIM
# Accuracy: 0.8494116915938186
#
# macro
# Precision: 0.8498225480068642
# Recall: 0.8488881136713051
# F1 Score: 0.8491424215883354
#
# weighted
# Precision: 0.8496353018828602
# Recall: 0.8494116915938186
# F1 Score: 0.8493110206552646
#
# start DT 1 FGSM
# Accuracy: 0.8477382998850587
#
# macro
# Precision: 0.8429036911669714
# Recall: 0.8424461015542835
# F1 Score: 0.842671921205145
#
# weighted
# Precision: 0.8476422534466388
# Recall: 0.8477382998850587
# F1 Score: 0.8476874695355323
#
# start DT 1 PGD
# Accuracy: 0.8494116915938186
#
# macro
# Precision: 0.8498225480068642
# Recall: 0.8488881136713051
# F1 Score: 0.8491424215883354
#
# weighted
# Precision: 0.8496353018828602
# Recall: 0.8494116915938186
# F1 Score: 0.8493110206552646
#
# start DT 1 DF
# Accuracy: 0.7821871223405751
#
# macro
# Precision: 0.6616385378795056
# Recall: 0.6924390322149709
# F1 Score: 0.6731645183292316
#
# weighted
# Precision: 0.8050368300552672
# Recall: 0.7821871223405751
# F1 Score: 0.7916251375491482
#
# start DT 1 AutoPGD
# Accuracy: 0.9077309130765016
#
# macro
# Precision: 0.8981561688994322
# Recall: 0.9143688584782559
# F1 Score: 0.903924839464396
#
# weighted
# Precision: 0.9138206625085332
# Recall: 0.9077309130765016
# F1 Score: 0.9086492464593857
#
# start DT 1 ZOO
# Accuracy: 0.728916351985353
#
# macro
# Precision: 0.7238930341945418
# Recall: 0.71674117573381
# F1 Score: 0.7189707358283453
#
# weighted
# Precision: 0.7270992474930117
# Recall: 0.728916351985353
# F1 Score: 0.7267203308995903
#
# start DT 1 CaFA
# Accuracy: 0.8632009861018444
#
# macro
# Precision: 0.8696207861774478
# Recall: 0.8611214922821082
# F1 Score: 0.8620036493705323
#
# weighted
# Precision: 0.8683146905378426
# Recall: 0.8632009861018444
# F1 Score: 0.8624084791382517
#
# start DT 1 SINIFGSM
# Accuracy: 0.8247296291431324
#
# macro
# Precision: 0.8279083836522807
# Recall: 0.8275577023694121
# F1 Score: 0.8247262014212465
#
# weighted
# Precision: 0.8306525470204151
# Recall: 0.8247296291431324
# F1 Score: 0.8246829137057478
#
# start DT 1 VNIFGSM
# Accuracy: 0.842803509249713
#
# macro
# Precision: 0.8410073606899855
# Recall: 0.8416572251426988
# F1 Score: 0.8413118970893261
#
# weighted
# Precision: 0.8429932165331654
# Recall: 0.842803509249713
# F1 Score: 0.8428783292818353

# %%
epsilon = 0

Def = "Def1"
attack_names = [
    "baseline", "BIM", "FGSM", "PGD", "DF",
    "AutoPGD", "ZOO", "CaFA", "SINIFGSM", "VNIFGSM"
]

percentage = ["100", "50", "20", "1"]
model_name = ["XGB", "RF", "DT" ]

base_path = "/home/jovyan/Sample_Based_Extension/UNSW/UNSW_Dynamite_Selection_Data"
total_num_attack = ["2", "3"]
for num_attack in total_num_attack:
    for m_name in model_name:
        for p in percentage:
            for attack in attack_names:
                print(f"start {m_name} {p} {attack}")
                
                x_path = f"{base_path}/{m_name}_Exclude{num_attack}Attack/UNSW_Input{p}/x_test_adv_{attack}_{Def}.npy"
                y_path = f"{base_path}/{m_name}_Exclude{num_attack}Attack/UNSW_Input{p}/y_test_adv_{attack}_{Def}.npy"
    
                try:
                    x_test_adv = np.load(x_path)
                    y_test_adv = np.load(y_path)
                    m_per_name = f"{m_name}{p}_Exclude{num_attack}Attack"
                    calculate_performance_metrics(x_test_adv, y_test_adv, model, m_per_name, attack, epsilon)
                except FileNotFoundError:
                    print(x_path, "not found")
                    print_empty_file()
# Out:
# start XGB 100 baseline
# Accuracy: 0.8992805755395683
#
# macro
# Precision: 0.9457364341085271
# Recall: 0.7083333333333334
# F1 Score: 0.7654291224686596
#
# weighted
# Precision: 0.9102113657910881
# Recall: 0.8992805755395683
# F1 Score: 0.8814337151301139
#
# start XGB 100 BIM
# Accuracy: 0.7568667581459172
#
# macro
# Precision: 0.735071256439335
# Recall: 0.7865693076710769
# F1 Score: 0.7369616077522276
#
# weighted
# Precision: 0.8185635612205835
# Recall: 0.7568667581459172
# F1 Score: 0.7685308262367745
#
# start XGB 100 FGSM
# Accuracy: 0.8692349790212109
#
# macro
# Precision: 0.8319137267817365
# Recall: 0.7997750097626126
# F1 Score: 0.8137867366139506
#
# weighted
# Precision: 0.8650164736067877
# Recall: 0.8692349790212109
# F1 Score: 0.8659135443693537
#
# start XGB 100 PGD
# Accuracy: 0.7568667581459172
#
# macro
# Precision: 0.735071256439335
# Recall: 0.7865693076710769
# F1 Score: 0.7369616077522276
#
# weighted
# Precision: 0.8185635612205835
# Recall: 0.7568667581459172
# F1 Score: 0.7685308262367745
#
# start XGB 100 DF
# Accuracy: 0.907133153087715
#
# macro
# Precision: 0.8093027414439457
# Recall: 0.7584275387125485
# F1 Score: 0.7804388751058142
#
# weighted
# Precision: 0.9009203139153444
# Recall: 0.907133153087715
# F1 Score: 0.9029782861101773
#
# start XGB 100 AutoPGD
# Accuracy: 0.8061672360906755
#
# macro
# Precision: 0.778362396447887
# Recall: 0.8494504775543263
# F1 Score: 0.7861705273360415
#
# weighted
# Precision: 0.8695651819777672
# Recall: 0.8061672360906755
# F1 Score: 0.8168199170235723
#
# start XGB 100 ZOO
# Accuracy: 0.8841201716738197
#
# macro
# Precision: 0.9239515250544662
# Recall: 0.6905446756425948
# F1 Score: 0.7417487684729065
#
# weighted
# Precision: 0.8945283645170037
# Recall: 0.8841201716738197
# F1 Score: 0.8627233133892894
#
# start XGB 100 CaFA
# Accuracy: 0.5519584780254658
#
# macro
# Precision: 0.5547378524321582
# Recall: 0.5399781646001712
# F1 Score: 0.5127834183182742
#
# weighted
# Precision: 0.5544905445065323
# Recall: 0.5519584780254658
# F1 Score: 0.5191853473539109
#
# start XGB 100 SINIFGSM
# Accuracy: 0.8679391510373995
#
# macro
# Precision: 0.8676415997603781
# Recall: 0.875399732463759
# F1 Score: 0.8672115286975872
#
# weighted
# Precision: 0.8777599010391968
# Recall: 0.8679391510373995
# F1 Score: 0.8686252011765224
#
# start XGB 100 VNIFGSM
# Accuracy: 0.908777996070727
#
# macro
# Precision: 0.902691626001545
# Recall: 0.860578896300741
# F1 Score: 0.8784661131022318
#
# weighted
# Precision: 0.9078468293882445
# Recall: 0.908777996070727
# F1 Score: 0.90626718958849
#
# start XGB 50 baseline
# Accuracy: 0.8379888268156425
#
# macro
# Precision: 0.8852657004830917
# Recall: 0.6851575456053067
# F1 Score: 0.7206887274683884
#
# weighted
# Precision: 0.8558416322564976
# Recall: 0.8379888268156425
# F1 Score: 0.8106862174848162
#
# start XGB 50 BIM
# Accuracy: 0.8481328126533095
#
# macro
# Precision: 0.8279849469391377
# Recall: 0.8442694772516436
# F1 Score: 0.8345621422587983
#
# weighted
# Precision: 0.8544389988316754
# Recall: 0.8481328126533095
# F1 Score: 0.8499692000482503
#
# start XGB 50 FGSM
# Accuracy: 0.8769073277352775
#
# macro
# Precision: 0.8437958546117192
# Recall: 0.7796300459332242
# F1 Score: 0.8047892538837611
#
# weighted
# Precision: 0.871582215039712
# Recall: 0.8769073277352775
# F1 Score: 0.870601079249092
#
# start XGB 50 PGD
# Accuracy: 0.8481328126533095
#
# macro
# Precision: 0.8279849469391377
# Recall: 0.8442694772516436
# F1 Score: 0.8345621422587983
#
# weighted
# Precision: 0.8544389988316754
# Recall: 0.8481328126533095
# F1 Score: 0.8499692000482503
#
# start XGB 50 DF
# Accuracy: 0.903504508882769
#
# macro
# Precision: 0.797795362987592
# Recall: 0.7577184293138337
# F1 Score: 0.7755509538505407
#
# weighted
# Precision: 0.8979108482470626
# Recall: 0.903504508882769
# F1 Score: 0.9000271371028836
#
# start XGB 50 AutoPGD
# Accuracy: 0.8770096372202325
#
# macro
# Precision: 0.8559661629348194
# Recall: 0.8952877409246541
# F1 Score: 0.8672079853915948
#
# weighted
# Precision: 0.8973303381704434
# Recall: 0.8770096372202325
# F1 Score: 0.8802011760324849
#
# start XGB 50 ZOO
# Accuracy: 0.8402061855670103
#
# macro
# Precision: 0.869706888855825
# Recall: 0.6951740605755938
# F1 Score: 0.730827568715406
#
# weighted
# Precision: 0.850779446480258
# Recall: 0.8402061855670103
# F1 Score: 0.8163256789228595
#
# start XGB 50 CaFA
# Accuracy: 0.7817593396027298
#
# macro
# Precision: 0.7522876780945607
# Recall: 0.7976379864493697
# F1 Score: 0.7602169766151317
#
# weighted
# Precision: 0.8228498250410216
# Recall: 0.7817593396027298
# F1 Score: 0.7906082094630608
#
# start XGB 50 SINIFGSM
# Accuracy: 0.8825550568034991
#
# macro
# Precision: 0.8742898206436748
# Recall: 0.8839130619149125
# F1 Score: 0.8781075186037341
#
# weighted
# Precision: 0.8858786596210922
# Recall: 0.8825550568034991
# F1 Score: 0.8832995815617622
#
# start XGB 50 VNIFGSM
# Accuracy: 0.9164659638280469
#
# macro
# Precision: 0.9013352496599698
# Recall: 0.843826554997081
# F1 Score: 0.868133309486758
#
# weighted
# Precision: 0.9145784847047508
# Recall: 0.9164659638280469
# F1 Score: 0.913250800674046
#
# start XGB 20 baseline
# Accuracy: 0.9074074074074074
#
# macro
# Precision: 0.9532710280373832
# Recall: 0.5454545454545454
# F1 Score: 0.5588235294117647
#
# weighted
# Precision: 0.9160609207338178
# Recall: 0.9074074074074074
# F1 Score: 0.8710965867828612
#
# start XGB 20 BIM
# Accuracy: 0.8901066681559254
#
# macro
# Precision: 0.8778047695569237
# Recall: 0.8883208613224891
# F1 Score: 0.8823984789582162
#
# weighted
# Precision: 0.8927731701128898
# Recall: 0.8901066681559254
# F1 Score: 0.890860378317429
#
# start XGB 20 FGSM
# Accuracy: 0.8692233815701659
#
# macro
# Precision: 0.8191810270969387
# Recall: 0.8048361707035061
# F1 Score: 0.8116004510332473
#
# weighted
# Precision: 0.8666797066289261
# Recall: 0.8692233815701659
# F1 Score: 0.8677206908724262
#
# start XGB 20 PGD
# Accuracy: 0.8901066681559254
#
# macro
# Precision: 0.8778047695569237
# Recall: 0.8883208613224891
# F1 Score: 0.8823984789582162
#
# weighted
# Precision: 0.8927731701128898
# Recall: 0.8901066681559254
# F1 Score: 0.890860378317429
#
# start XGB 20 DF
# Accuracy: 0.8912912106358692
#
# macro
# Precision: 0.7657674264654841
# Recall: 0.7484462971850865
# F1 Score: 0.7566418900645961
#
# weighted
# Precision: 0.8879241155579325
# Recall: 0.8912912106358692
# F1 Score: 0.8894607188794119
#
# start XGB 20 AutoPGD
# Accuracy: 0.9276589595375723
#
# macro
# Precision: 0.9106061002059889
# Recall: 0.9341589816888112
# F1 Score: 0.9202995210623681
#
# weighted
# Precision: 0.9330626641913441
# Recall: 0.9276589595375723
# F1 Score: 0.9286655100918184
#
# start XGB 20 ZOO
# Accuracy: 0.8819095477386935
#
# macro
# Precision: 0.9395886889460154
# Recall: 0.5803571428571429
# F1 Score: 0.606313795643481
#
# weighted
# Precision: 0.8961775458268205
# Recall: 0.8819095477386935
# F1 Score: 0.8430116487943242
#
# start XGB 20 CaFA
# Accuracy: 0.7489175371217496
#
# macro
# Precision: 0.7616386775766906
# Recall: 0.7336174640607176
# F1 Score: 0.7357629220983689
#
# weighted
# Precision: 0.7577521429311497
# Recall: 0.7489175371217496
# F1 Score: 0.7419198184403064
#
# start XGB 20 SINIFGSM
# Accuracy: 0.9208490688891783
#
# macro
# Precision: 0.9222561903529936
# Recall: 0.9198520468393732
# F1 Score: 0.9205516960357143
#
# weighted
# Precision: 0.9216236152302603
# Recall: 0.9208490688891783
# F1 Score: 0.9207361456940782
#
# start XGB 20 VNIFGSM
# Accuracy: 0.9170174667001759
#
# macro
# Precision: 0.914752919711454
# Recall: 0.8884724158784459
# F1 Score: 0.900009089077093
#
# weighted
# Precision: 0.9166830965522116
# Recall: 0.9170174667001759
# F1 Score: 0.9156616935971896
#
# start XGB 1 baseline
# Accuracy: 0.8064516129032258
#
# macro
# Precision: 0.8421052631578947
# Recall: 0.8333333333333333
# F1 Score: 0.80625
#
# weighted
# Precision: 0.8675721561969439
# Recall: 0.8064516129032258
# F1 Score: 0.8052419354838709
#
# start XGB 1 BIM
# Accuracy: 0.885913464011936
#
# macro
# Precision: 0.8355511956923727
# Recall: 0.8599646548814726
# F1 Score: 0.8465738977677597
#
# weighted
# Precision: 0.8913099508145033
# Recall: 0.885913464011936
# F1 Score: 0.8879139672408937
#
# start XGB 1 FGSM
# Accuracy: 0.9024839314408142
#
# macro
# Precision: 0.7596576523795254
# Recall: 0.7493571639716157
# F1 Score: 0.7543523515389441
#
# weighted
# Precision: 0.9005939748971258
# Recall: 0.9024839314408142
# F1 Score: 0.9014973241599227
#
# start XGB 1 PGD
# Accuracy: 0.885913464011936
#
# macro
# Precision: 0.8355511956923727
# Recall: 0.8599646548814726
# F1 Score: 0.8465738977677597
#
# weighted
# Precision: 0.8913099508145033
# Recall: 0.885913464011936
# F1 Score: 0.8879139672408937
#
# start XGB 1 DF
# Accuracy: 0.8456601300049161
#
# macro
# Precision: 0.6728072095451156
# Recall: 0.6869844225654089
# F1 Score: 0.679371823284696
#
# weighted
# Precision: 0.8520972085540643
# Recall: 0.8456601300049161
# F1 Score: 0.8486998358543983
#
# start XGB 1 AutoPGD
# Accuracy: 0.8975814952564689
#
# macro
# Precision: 0.862138163325205
# Recall: 0.9092838129579733
# F1 Score: 0.8796132763701072
#
# weighted
# Precision: 0.9124372812474607
# Recall: 0.8975814952564689
# F1 Score: 0.9006946791562888
#
# start XGB 1 ZOO
# Accuracy: 0.8906666666666667
#
# macro
# Precision: 0.87958999316384
# Recall: 0.6129084967320262
# F1 Score: 0.6527529968263317
#
# weighted
# Precision: 0.888284449363586
# Recall: 0.8906666666666667
# F1 Score: 0.862000522169152
#
# start XGB 1 CaFA
# Accuracy: 0.7666354264292409
#
# macro
# Precision: 0.711437131658323
# Recall: 0.6482241164244487
# F1 Score: 0.6629466346917781
#
# weighted
# Precision: 0.7486627940485466
# Recall: 0.7666354264292409
# F1 Score: 0.7464722502016027
#
# start XGB 1 SINIFGSM
# Accuracy: 0.8737309609792832
#
# macro
# Precision: 0.8410032546843231
# Recall: 0.885726813653547
# F1 Score: 0.856191936144283
#
# weighted
# Precision: 0.892196638872676
# Recall: 0.8737309609792832
# F1 Score: 0.8775901813647919
#
# start XGB 1 VNIFGSM
# Accuracy: 0.9146066107254459
#
# macro
# Precision: 0.8185839492095862
# Recall: 0.8363514967440524
# F1 Score: 0.8270782807019599
#
# weighted
# Precision: 0.9171816565265127
# Recall: 0.9146066107254459
# F1 Score: 0.915764708719264
#
# start RF 100 baseline
# Accuracy: 0.985200845665962
#
# macro
# Precision: 0.9903047091412742
# Recall: 0.9705882352941176
# F1 Score: 0.9799533799533799
#
# weighted
# Precision: 0.9854878098774252
# Recall: 0.985200845665962
# F1 Score: 0.9850490594676641
#
# start RF 100 BIM
# Accuracy: 0.8240649419619149
#
# macro
# Precision: 0.8231502291802728
# Recall: 0.8237819303717322
# F1 Score: 0.8234128220243475
#
# weighted
# Precision: 0.8243424464866115
# Recall: 0.8240649419619149
# F1 Score: 0.8241508329149901
#
# start RF 100 FGSM
# Accuracy: 0.8039324471272276
#
# macro
# Precision: 0.7899445481134618
# Recall: 0.7508228838308759
# F1 Score: 0.7640810953995154
#
# weighted
# Precision: 0.7997286967927396
# Recall: 0.8039324471272276
# F1 Score: 0.7968852993460042
#
# start RF 100 PGD
# Accuracy: 0.8240649419619149
#
# macro
# Precision: 0.8231502291802728
# Recall: 0.8237819303717322
# F1 Score: 0.8234128220243475
#
# weighted
# Precision: 0.8243424464866115
# Recall: 0.8240649419619149
# F1 Score: 0.8241508329149901
#
# start RF 100 DF
# Accuracy: 0.9342056074766355
#
# macro
# Precision: 0.829257321148549
# Recall: 0.8283969927192691
# F1 Score: 0.8288263728064873
#
# weighted
# Precision: 0.9341199237485135
# Recall: 0.9342056074766355
# F1 Score: 0.9341625721235166
#
# start RF 100 AutoPGD
# Accuracy: 0.9111922441226534
#
# macro
# Precision: 0.9136360854900949
# Recall: 0.9120167328691307
# F1 Score: 0.9111459786137487
#
# weighted
# Precision: 0.9143821775035121
# Recall: 0.9111922441226534
# F1 Score: 0.9111053149826788
#
# start RF 100 ZOO
# Accuracy: 0.9949748743718593
#
# macro
# Precision: 0.9966887417218543
# Recall: 0.9897959183673469
# F1 Score: 0.9931842312566359
#
# weighted
# Precision: 0.9950081533495291
# Recall: 0.9949748743718593
# F1 Score: 0.9949573190472002
#
# start RF 100 CaFA
# Accuracy: 0.8180641369780334
#
# macro
# Precision: 0.7985631955366269
# Recall: 0.7368181740799133
# F1 Score: 0.7567373902000842
#
# weighted
# Precision: 0.8124138385015839
# Recall: 0.8180641369780334
# F1 Score: 0.8076743929807758
#
# start RF 100 SINIFGSM
# Accuracy: 0.8870826010544816
#
# macro
# Precision: 0.8528759639281174
# Recall: 0.8836576953069499
# F1 Score: 0.8656378646743845
#
# weighted
# Precision: 0.8955190088632748
# Recall: 0.8870826010544816
# F1 Score: 0.8894367622767718
#
# start RF 100 VNIFGSM
# Accuracy: 0.8683873771639665
#
# macro
# Precision: 0.8831299273190456
# Recall: 0.8616042581334511
# F1 Score: 0.865030220451282
#
# weighted
# Precision: 0.8789960023956229
# Recall: 0.8683873771639665
# F1 Score: 0.8665006468681513
#
# start RF 50 baseline
# Accuracy: 0.9142091152815014
#
# macro
# Precision: 0.9420256877022654
# Recall: 0.833314268283383
# F1 Score: 0.8715232928614485
#
# weighted
# Precision: 0.9210213370988313
# Recall: 0.9142091152815014
# F1 Score: 0.9082529540135871
#
# start RF 50 BIM
# Accuracy: 0.7734021949644933
#
# macro
# Precision: 0.7617688777710663
# Recall: 0.771300579243618
# F1 Score: 0.7648358065746431
#
# weighted
# Precision: 0.7805889939390227
# Recall: 0.7734021949644933
# F1 Score: 0.7754238031872844
#
# start RF 50 FGSM
# Accuracy: 0.8204441950314044
#
# macro
# Precision: 0.7991456415511564
# Recall: 0.7762398591489557
# F1 Score: 0.7856345037661976
#
# weighted
# Precision: 0.8164851868394293
# Recall: 0.8204441950314044
# F1 Score: 0.8168774601952855
#
# start RF 50 PGD
# Accuracy: 0.7734021949644933
#
# macro
# Precision: 0.7617688777710663
# Recall: 0.771300579243618
# F1 Score: 0.7648358065746431
#
# weighted
# Precision: 0.7805889939390227
# Recall: 0.7734021949644933
# F1 Score: 0.7754238031872844
#
# start RF 50 DF
# Accuracy: 0.9110404763820713
#
# macro
# Precision: 0.7928455850368081
# Recall: 0.7867334651871
# F1 Score: 0.7897411934767802
#
# weighted
# Precision: 0.9101298775920686
# Recall: 0.9110404763820713
# F1 Score: 0.9105714116502671
#
# start RF 50 AutoPGD
# Accuracy: 0.8635793060163185
#
# macro
# Precision: 0.8598313023011268
# Recall: 0.8745719281588828
# F1 Score: 0.861472257469283
#
# weighted
# Precision: 0.87723357185874
# Recall: 0.8635793060163185
# F1 Score: 0.8649395816322891
#
# start RF 50 ZOO
# Accuracy: 0.9305555555555556
#
# macro
# Precision: 0.9516469594594594
# Recall: 0.8602374636857395
# F1 Score: 0.8952501774927548
#
# weighted
# Precision: 0.9347374718468469
# Recall: 0.9305555555555556
# F1 Score: 0.9266702747161086
#
# start RF 50 CaFA
# Accuracy: 0.771617691032158
#
# macro
# Precision: 0.7571004855001584
# Recall: 0.6997488593402841
# F1 Score: 0.7138696998144971
#
# weighted
# Precision: 0.7659137216684158
# Recall: 0.771617691032158
# F1 Score: 0.7574991082399783
#
# start RF 50 SINIFGSM
# Accuracy: 0.8309112333071484
#
# macro
# Precision: 0.8243057645691321
# Recall: 0.8347084704762529
# F1 Score: 0.8271283293096356
#
# weighted
# Precision: 0.8380815321932696
# Recall: 0.8309112333071484
# F1 Score: 0.8322420923305018
#
# start RF 50 VNIFGSM
# Accuracy: 0.8432142680697594
#
# macro
# Precision: 0.8582599011458345
# Recall: 0.8354043366096653
# F1 Score: 0.8386716093591271
#
# weighted
# Precision: 0.8540578910042489
# Recall: 0.8432142680697594
# F1 Score: 0.8406550519817879
#
# start RF 20 baseline
# Accuracy: 0.8355555555555556
#
# macro
# Precision: 0.9123222748815165
# Recall: 0.6372549019607843
# F1 Score: 0.6673326673326674
#
# weighted
# Precision: 0.864391785150079
# Recall: 0.8355555555555556
# F1 Score: 0.7966540126540127
#
# start RF 20 BIM
# Accuracy: 0.8031745298276419
#
# macro
# Precision: 0.8048546414934747
# Recall: 0.8002875576242527
# F1 Score: 0.8013348721760927
#
# weighted
# Precision: 0.8041399328005828
# Recall: 0.8031745298276419
# F1 Score: 0.8024329247383379
#
# start RF 20 FGSM
# Accuracy: 0.809765659805756
#
# macro
# Precision: 0.766823927655278
# Recall: 0.7266359686491283
# F1 Score: 0.7416734079862036
#
# weighted
# Precision: 0.8010293654014574
# Recall: 0.809765659805756
# F1 Score: 0.8020547617994633
#
# start RF 20 PGD
# Accuracy: 0.8031745298276419
#
# macro
# Precision: 0.8048546414934747
# Recall: 0.8002875576242527
# F1 Score: 0.8013348721760927
#
# weighted
# Precision: 0.8041399328005828
# Recall: 0.8031745298276419
# F1 Score: 0.8024329247383379
#
# start RF 20 DF
# Accuracy: 0.8886693548387097
#
# macro
# Precision: 0.7527065474889723
# Recall: 0.7565205492780596
# F1 Score: 0.7545904783802246
#
# weighted
# Precision: 0.8895175413352551
# Recall: 0.8886693548387097
# F1 Score: 0.889086271316705
#
# start RF 20 AutoPGD
# Accuracy: 0.9123412262819508
#
# macro
# Precision: 0.9132426223033553
# Recall: 0.9133124214734871
# F1 Score: 0.9123410741845184
#
# weighted
# Precision: 0.9142213597607127
# Recall: 0.9123412262819508
# F1 Score: 0.9123449236981044
#
# start RF 20 ZOO
# Accuracy: 0.8482871125611745
#
# macro
# Precision: 0.9181338028169015
# Recall: 0.6630434782608696
# F1 Score: 0.7013187054995835
#
# weighted
# Precision: 0.8731274268777428
# Recall: 0.8482871125611745
# F1 Score: 0.8165009221966909
#
# start RF 20 CaFA
# Accuracy: 0.6388613124193389
#
# macro
# Precision: 0.5296657058656782
# Recall: 0.5201396989896875
# F1 Score: 0.51110360004805
#
# weighted
# Precision: 0.5932918227011176
# Recall: 0.6388613124193389
# F1 Score: 0.6051742640196461
#
# start RF 20 SINIFGSM
# Accuracy: 0.8786504836309523
#
# macro
# Precision: 0.841152881161064
# Recall: 0.8810813689016253
# F1 Score: 0.8564509938085145
#
# weighted
# Precision: 0.8919343642386731
# Recall: 0.8786504836309523
# F1 Score: 0.8819909732896827
#
# start RF 20 VNIFGSM
# Accuracy: 0.8305755054260132
#
# macro
# Precision: 0.8535225025966893
# Recall: 0.8245600460834359
# F1 Score: 0.8256547403358607
#
# weighted
# Precision: 0.8498504817496069
# Recall: 0.8305755054260132
# F1 Score: 0.8270123525499988
#
# start RF 1 baseline
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 1 BIM
# Accuracy: 0.8359151203313445
#
# macro
# Precision: 0.7374091043867669
# Recall: 0.7465061646659776
# F1 Score: 0.7417579410047241
#
# weighted
# Precision: 0.83919542634277
# Recall: 0.8359151203313445
# F1 Score: 0.8374571881138739
#
# start RF 1 FGSM
# Accuracy: 0.873028592664855
#
# macro
# Precision: 0.7434951555548726
# Recall: 0.6491053004251084
# F1 Score: 0.678608524089638
#
# weighted
# Precision: 0.8543325640168667
# Recall: 0.873028592664855
# F1 Score: 0.8579066124464275
#
# start RF 1 PGD
# Accuracy: 0.8359151203313445
#
# macro
# Precision: 0.7374091043867669
# Recall: 0.7465061646659776
# F1 Score: 0.7417579410047241
#
# weighted
# Precision: 0.83919542634277
# Recall: 0.8359151203313445
# F1 Score: 0.8374571881138739
#
# start RF 1 DF
# Accuracy: 0.8245024313767172
#
# macro
# Precision: 0.6508247328707907
# Recall: 0.6885350361360085
# F1 Score: 0.6653278195193091
#
# weighted
# Precision: 0.8470878729855351
# Recall: 0.8245024313767172
# F1 Score: 0.8342202795470244
#
# start RF 1 AutoPGD
# Accuracy: 0.8298135528416886
#
# macro
# Precision: 0.8015821113843822
# Recall: 0.8396842438604506
# F1 Score: 0.8125087970215621
#
# weighted
# Precision: 0.8528400521480857
# Recall: 0.8298135528416886
# F1 Score: 0.8348263977872138
#
# start RF 1 ZOO
# Accuracy: 0.8691695108077361
#
# macro
# Precision: 0.605246222359513
# Recall: 0.5385265340097058
# F1 Score: 0.5448200398960721
#
# weighted
# Precision: 0.8248564648460591
# Recall: 0.8691695108077361
# F1 Score: 0.8394447614519502
#
# start RF 1 CaFA
# Accuracy: 0.8353764932217798
#
# macro
# Precision: 0.8283936333954873
# Recall: 0.7722686968966466
# F1 Score: 0.7913086372050386
#
# weighted
# Precision: 0.8333154610064725
# Recall: 0.8353764932217798
# F1 Score: 0.8277471227415751
#
# start RF 1 SINIFGSM
# Accuracy: 0.8648641145934541
#
# macro
# Precision: 0.8586806592830138
# Recall: 0.8453255466521516
# F1 Score: 0.8511239897707339
#
# weighted
# Precision: 0.8638097347628589
# Recall: 0.8648641145934541
# F1 Score: 0.863583471848563
#
# start RF 1 VNIFGSM
# Accuracy: 0.8936725501188935
#
# macro
# Precision: 0.8594699351033642
# Recall: 0.7979958545468223
# F1 Score: 0.8231550755047178
#
# weighted
# Precision: 0.8891818609423929
# Recall: 0.8936725501188935
# F1 Score: 0.8887179332856968
#
# start DT 100 baseline
# Accuracy: 0.9613821138211383
#
# macro
# Precision: 0.9687981510015409
# Recall: 0.9333047102435754
# F1 Score: 0.9491909578602371
#
# weighted
# Precision: 0.9622511806782167
# Recall: 0.9613821138211383
# F1 Score: 0.9606233281804182
#
# start DT 100 BIM
# Accuracy: 0.8546474874399725
#
# macro
# Precision: 0.8385235510185562
# Recall: 0.8560698476341942
# F1 Score: 0.8450403320229527
#
# weighted
# Precision: 0.8622431561300459
# Recall: 0.8546474874399725
# F1 Score: 0.8564789704556441
#
# start DT 100 FGSM
# Accuracy: 0.862377500037065
#
# macro
# Precision: 0.8369334123510448
# Recall: 0.8633390403173905
# F1 Score: 0.8469595086212143
#
# weighted
# Precision: 0.8726353931643415
# Recall: 0.862377500037065
# F1 Score: 0.8649640295076038
#
# start DT 100 PGD
# Accuracy: 0.8546474874399725
#
# macro
# Precision: 0.8385235510185562
# Recall: 0.8560698476341942
# F1 Score: 0.8450403320229527
#
# weighted
# Precision: 0.8622431561300459
# Recall: 0.8546474874399725
# F1 Score: 0.8564789704556441
#
# start DT 100 DF
# Accuracy: 0.8946433774053469
#
# macro
# Precision: 0.7648964108185046
# Recall: 0.7820346024439898
# F1 Score: 0.7730326307475825
#
# weighted
# Precision: 0.8982133198811345
# Recall: 0.8946433774053469
# F1 Score: 0.8962937118305276
#
# start DT 100 AutoPGD
# Accuracy: 0.9122388973296752
#
# macro
# Precision: 0.8979194267621748
# Recall: 0.9230724850005931
# F1 Score: 0.9067321908596597
#
# weighted
# Precision: 0.9214436024783972
# Recall: 0.9122388973296752
# F1 Score: 0.9135782928260033
#
# start DT 100 ZOO
# Accuracy: 0.962253193960511
#
# macro
# Precision: 0.9500645873803162
# Recall: 0.9409109878050665
# F1 Score: 0.9453849475587174
#
# weighted
# Precision: 0.9619761801745974
# Recall: 0.962253193960511
# F1 Score: 0.9620593060708352
#
# start DT 100 CaFA
# Accuracy: 0.7121559216028508
#
# macro
# Precision: 0.7275985060932166
# Recall: 0.737603070128009
# F1 Score: 0.7110828607224571
#
# weighted
# Precision: 0.7601983803455004
# Recall: 0.7121559216028508
# F1 Score: 0.7151606201181777
#
# start DT 100 SINIFGSM
# Accuracy: 0.8666476999597775
#
# macro
# Precision: 0.8011241967830071
# Recall: 0.8434933804031616
# F1 Score: 0.8184765277685879
#
# weighted
# Precision: 0.8797202886305194
# Recall: 0.8666476999597775
# F1 Score: 0.8710171399359085
#
# start DT 100 VNIFGSM
# Accuracy: 0.923525833722683
#
# macro
# Precision: 0.923403694835585
# Recall: 0.9206384579394782
# F1 Score: 0.9219001891027828
#
# weighted
# Precision: 0.9235083585837904
# Recall: 0.923525833722683
# F1 Score: 0.9234005778345189
#
# start DT 50 baseline
# Accuracy: 0.8119001919385797
#
# macro
# Precision: 0.8159935616037459
# Recall: 0.7496531791907515
# F1 Score: 0.767825311942959
#
# weighted
# Precision: 0.8135201827601296
# Recall: 0.8119001919385797
# F1 Score: 0.8010270937898804
#
# start DT 50 BIM
# Accuracy: 0.8578581197597669
#
# macro
# Precision: 0.7668412380651304
# Recall: 0.8274999102967276
# F1 Score: 0.7898025894727436
#
# weighted
# Precision: 0.8794435883476703
# Recall: 0.8578581197597669
# F1 Score: 0.8650726176094018
#
# start DT 50 FGSM
# Accuracy: 0.8476114848031888
#
# macro
# Precision: 0.8351979296447112
# Recall: 0.8326085732987769
# F1 Score: 0.833863492888721
#
# weighted
# Precision: 0.8470892103862838
# Recall: 0.8476114848031888
# F1 Score: 0.84731606110684
#
# start DT 50 PGD
# Accuracy: 0.8578581197597669
#
# macro
# Precision: 0.7668412380651304
# Recall: 0.8274999102967276
# F1 Score: 0.7898025894727436
#
# weighted
# Precision: 0.8794435883476703
# Recall: 0.8578581197597669
# F1 Score: 0.8650726176094018
#
# start DT 50 DF
# Accuracy: 0.8701676383820589
#
# macro
# Precision: 0.7401880935184764
# Recall: 0.7477869647521256
# F1 Score: 0.7438820027751151
#
# weighted
# Precision: 0.8722652188013664
# Recall: 0.8701676383820589
# F1 Score: 0.8711784665984934
#
# start DT 50 AutoPGD
# Accuracy: 0.8978643903345341
#
# macro
# Precision: 0.8226408210461353
# Recall: 0.9140256144893265
# F1 Score: 0.8549139781398245
#
# weighted
# Precision: 0.9236202772573288
# Recall: 0.8978643903345341
# F1 Score: 0.9041425229411556
#
# start DT 50 ZOO
# Accuracy: 0.8034464189553042
#
# macro
# Precision: 0.7969576402400592
# Recall: 0.7311055927445476
# F1 Score: 0.7494626497696278
#
# weighted
# Precision: 0.8010723255106743
# Recall: 0.8034464189553042
# F1 Score: 0.7913595657617596
#
# start DT 50 CaFA
# Accuracy: 0.7600473767799941
#
# macro
# Precision: 0.7699699232834754
# Recall: 0.7716137151847465
# F1 Score: 0.7600089621650412
#
# weighted
# Precision: 0.7822700363720375
# Recall: 0.7600473767799941
# F1 Score: 0.760406430829968
#
# start DT 50 SINIFGSM
# Accuracy: 0.8081204346622703
#
# macro
# Precision: 0.7116336981722771
# Recall: 0.7838923255579048
# F1 Score: 0.7327136347625671
#
# weighted
# Precision: 0.8513691418523102
# Recall: 0.8081204346622703
# F1 Score: 0.8219262788325885
#
# start DT 50 VNIFGSM
# Accuracy: 0.8784448208899723
#
# macro
# Precision: 0.8264785944160823
# Recall: 0.8308282343751029
# F1 Score: 0.8286168942542864
#
# weighted
# Precision: 0.8792905182024867
# Recall: 0.8784448208899723
# F1 Score: 0.878846997713473
#
# start DT 20 baseline
# Accuracy: 0.7066666666666667
#
# macro
# Precision: 0.6615384615384615
# Recall: 0.5857843137254901
# F1 Score: 0.5816430020283976
#
# weighted
# Precision: 0.6836923076923076
# Recall: 0.7066666666666667
# F1 Score: 0.6639756592292089
#
# start DT 20 BIM
# Accuracy: 0.8476519102327831
#
# macro
# Precision: 0.8184838577606294
# Recall: 0.8492094875859507
# F1 Score: 0.8294753260308653
#
# weighted
# Precision: 0.8615140694416666
# Recall: 0.8476519102327831
# F1 Score: 0.851141837685139
#
# start DT 20 FGSM
# Accuracy: 0.8328687400054178
#
# macro
# Precision: 0.763238380320038
# Recall: 0.8054595292987083
# F1 Score: 0.7794365428543357
#
# weighted
# Precision: 0.8510741443083587
# Recall: 0.8328687400054178
# F1 Score: 0.8390462893680072
#
# start DT 20 PGD
# Accuracy: 0.8476519102327831
#
# macro
# Precision: 0.8184838577606294
# Recall: 0.8492094875859507
# F1 Score: 0.8294753260308653
#
# weighted
# Precision: 0.8615140694416666
# Recall: 0.8476519102327831
# F1 Score: 0.851141837685139
#
# start DT 20 DF
# Accuracy: 0.821786608129081
#
# macro
# Precision: 0.6720412739171602
# Recall: 0.7006324948661937
# F1 Score: 0.6839414880093464
#
# weighted
# Precision: 0.837383204248358
# Recall: 0.821786608129081
# F1 Score: 0.8286098438083717
#
# start DT 20 AutoPGD
# Accuracy: 0.9065383496814108
#
# macro
# Precision: 0.8705275475318328
# Recall: 0.9186294542282792
# F1 Score: 0.8887870660191821
#
# weighted
# Precision: 0.920224609814807
# Recall: 0.9065383496814108
# F1 Score: 0.9093729633718984
#
# start DT 20 ZOO
# Accuracy: 0.7457983193277311
#
# macro
# Precision: 0.6914629439011837
# Recall: 0.6407901677267362
# F1 Score: 0.6521287454625619
#
# weighted
# Precision: 0.7274022617281601
# Recall: 0.7457983193277311
# F1 Score: 0.7267104574469746
#
# start DT 20 CaFA
# Accuracy: 0.759454380959009
#
# macro
# Precision: 0.7742710765054062
# Recall: 0.7565865190549846
# F1 Score: 0.7546953281856532
#
# weighted
# Precision: 0.7728983663267615
# Recall: 0.759454380959009
# F1 Score: 0.7555023745088655
#
# start DT 20 SINIFGSM
# Accuracy: 0.8665899600265828
#
# macro
# Precision: 0.8421479761695897
# Recall: 0.8663971502626437
# F1 Score: 0.8516382804512901
#
# weighted
# Precision: 0.8753718132070025
# Recall: 0.8665899600265828
# F1 Score: 0.8688669319450324
#
# start DT 20 VNIFGSM
# Accuracy: 0.884751352377337
#
# macro
# Precision: 0.8671228352303902
# Recall: 0.8589351472355105
# F1 Score: 0.86283857549559
#
# weighted
# Precision: 0.8837360815004893
# Recall: 0.884751352377337
# F1 Score: 0.8841016368843603
#
# start DT 1 baseline
# Accuracy: 0.6615384615384615
#
# macro
# Precision: 0.6516129032258065
# Recall: 0.6499179780059542
# F1 Score: 0.6506016736912834
#
# weighted
# Precision: 0.6599503722084367
# Recall: 0.6615384615384615
# F1 Score: 0.6605874365082721
#
# start DT 1 BIM
# Accuracy: 0.6618419913275739
#
# macro
# Precision: 0.6365131446534787
# Recall: 0.6974748589528539
# F1 Score: 0.6211054300287432
#
# weighted
# Precision: 0.7867122961810706
# Recall: 0.6618419913275739
# F1 Score: 0.6908219083788882
#
# start DT 1 FGSM
# Accuracy: 0.8526594887933491
#
# macro
# Precision: 0.7882474446688503
# Recall: 0.8227722101285317
# F1 Score: 0.8026513070325496
#
# weighted
# Precision: 0.8643264455441777
# Recall: 0.8526594887933491
# F1 Score: 0.8568123747925354
#
# start DT 1 PGD
# Accuracy: 0.6618419913275739
#
# macro
# Precision: 0.6365131446534787
# Recall: 0.6974748589528539
# F1 Score: 0.6211054300287432
#
# weighted
# Precision: 0.7867122961810706
# Recall: 0.6618419913275739
# F1 Score: 0.6908219083788882
#
# start DT 1 DF
# Accuracy: 0.7576427752680197
#
# macro
# Precision: 0.6270020069930137
# Recall: 0.6360558756475776
# F1 Score: 0.6310156728095528
#
# weighted
# Precision: 0.7665364601902189
# Recall: 0.7576427752680197
# F1 Score: 0.7618111129332578
#
# start DT 1 AutoPGD
# Accuracy: 0.6721024567372175
#
# macro
# Precision: 0.6823033759625603
# Recall: 0.759718115977065
# F1 Score: 0.6492610926390614
#
# weighted
# Precision: 0.8354362590440312
# Recall: 0.6721024567372175
# F1 Score: 0.6982041539879561
#
# start DT 1 ZOO
# Accuracy: 0.6816999132697311
#
# macro
# Precision: 0.6450905176698856
# Recall: 0.6046074794304541
# F1 Score: 0.6054021037711217
#
# weighted
# Precision: 0.6635581653018552
# Recall: 0.6816999132697311
# F1 Score: 0.6565682876557908
#
# start DT 1 CaFA
# Accuracy: 0.8604315913417627
#
# macro
# Precision: 0.8675495809849054
# Recall: 0.8551634877315202
# F1 Score: 0.8578535662822774
#
# weighted
# Precision: 0.8649308068374283
# Recall: 0.8604315913417627
# F1 Score: 0.8592403238379721
#
# start DT 1 SINIFGSM
# Accuracy: 0.7918116938196496
#
# macro
# Precision: 0.7259110408472291
# Recall: 0.7600355998119381
# F1 Score: 0.7382541118351862
#
# weighted
# Precision: 0.8125293857245937
# Recall: 0.7918116938196496
# F1 Score: 0.7990867841255846
#
# start DT 1 VNIFGSM
# Accuracy: 0.8993509110183939
#
# macro
# Precision: 0.7784349091297982
# Recall: 0.8542099773061507
# F1 Score: 0.8085815137233996
#
# weighted
# Precision: 0.9164795802598887
# Recall: 0.8993509110183939
# F1 Score: 0.9053547530898255
#
# start XGB 100 baseline
# Accuracy: 0.8762376237623762
#
# macro
# Precision: 0.9331550802139037
# Recall: 0.6875
# F1 Score: 0.7369106538160979
#
# weighted
# Precision: 0.8927833959866575
# Recall: 0.8762376237623762
# F1 Score: 0.8525425608463425
#
# start XGB 100 BIM
# Accuracy: 0.7113515215790521
#
# macro
# Precision: 0.7271723491013797
# Recall: 0.7629412911447186
# F1 Score: 0.7047673338345579
#
# weighted
# Precision: 0.8043287226754023
# Recall: 0.7113515215790521
# F1 Score: 0.7213323465228784
#
# start XGB 100 FGSM
# Accuracy: 0.8592674724408728
#
# macro
# Precision: 0.8335805721460507
# Recall: 0.8567526378955401
# F1 Score: 0.8427588696304518
#
# weighted
# Precision: 0.8678210161869861
# Recall: 0.8592674724408728
# F1 Score: 0.8616237766938192
#
# start XGB 100 PGD
# Accuracy: 0.7113515215790521
#
# macro
# Precision: 0.7271723491013797
# Recall: 0.7629412911447186
# F1 Score: 0.7047673338345579
#
# weighted
# Precision: 0.8043287226754023
# Recall: 0.7113515215790521
# F1 Score: 0.7213323465228784
#
# start XGB 100 DF
# Accuracy: 0.3740758395108401
#
# macro
# Precision: 0.37891868980816135
# Recall: 0.35850368626746976
# F1 Score: 0.353746954599498
#
# weighted
# Precision: 0.45015245847445146
# Recall: 0.3740758395108401
# F1 Score: 0.3973704838590366
#
# start XGB 100 AutoPGD
# Accuracy: 0.7588366890380314
#
# macro
# Precision: 0.7689003882980647
# Recall: 0.8211978319287527
# F1 Score: 0.7508050869827624
#
# weighted
# Precision: 0.856320474888521
# Recall: 0.7588366890380314
# F1 Score: 0.7689580377955407
#
# start XGB 100 ZOO
# Accuracy: 0.8612903225806452
#
# macro
# Precision: 0.8989006674519042
# Recall: 0.6872120877096002
# F1 Score: 0.730402071029852
#
# weighted
# Precision: 0.8730435553529137
# Recall: 0.8612903225806452
# F1 Score: 0.8370517574786464
#
# start XGB 100 CaFA
# Accuracy: 0.8049781447304517
#
# macro
# Precision: 0.7785215067896961
# Recall: 0.718551547559539
# F1 Score: 0.7372707537605806
#
# weighted
# Precision: 0.7972139313919197
# Recall: 0.8049781447304517
# F1 Score: 0.7933346111003782
#
# start XGB 100 SINIFGSM
# Accuracy: 0.8188786121224301
#
# macro
# Precision: 0.7998157862376254
# Recall: 0.832464481398359
# F1 Score: 0.8071043860716005
#
# weighted
# Precision: 0.843580240800991
# Recall: 0.8188786121224301
# F1 Score: 0.8235078521247085
#
# start XGB 100 VNIFGSM
# Accuracy: 0.9019635213102549
#
# macro
# Precision: 0.8807250823365396
# Recall: 0.9005565733991612
# F1 Score: 0.8892830500559937
#
# weighted
# Precision: 0.9065785745982057
# Recall: 0.9019635213102549
# F1 Score: 0.9032062193483166
#
# start XGB 50 baseline
# Accuracy: 0.8483412322274881
#
# macro
# Precision: 0.9227053140096618
# Recall: 0.5555555555555556
# F1 Score: 0.5581151832460733
#
# weighted
# Precision: 0.8717860658928039
# Recall: 0.8483412322274881
# F1 Score: 0.7940299248157614
#
# start XGB 50 BIM
# Accuracy: 0.7123896036041817
#
# macro
# Precision: 0.7269740877228118
# Recall: 0.7645370073872961
# F1 Score: 0.70521434937862
#
# weighted
# Precision: 0.8062073671903957
# Recall: 0.7123896036041817
# F1 Score: 0.7228022694701298
#
# start XGB 50 FGSM
# Accuracy: 0.8563730232642248
#
# macro
# Precision: 0.8294286327039955
# Recall: 0.8562700933454497
# F1 Score: 0.8395818809693631
#
# weighted
# Precision: 0.8671666870819518
# Recall: 0.8563730232642248
# F1 Score: 0.8591749882366305
#
# start XGB 50 PGD
# Accuracy: 0.7123896036041817
#
# macro
# Precision: 0.7269740877228118
# Recall: 0.7645370073872961
# F1 Score: 0.70521434937862
#
# weighted
# Precision: 0.8062073671903957
# Recall: 0.7123896036041817
# F1 Score: 0.7228022694701298
#
# start XGB 50 DF
# Accuracy: 0.36096841276040365
#
# macro
# Precision: 0.36084902936372704
# Recall: 0.33871620225829696
# F1 Score: 0.3381842207011039
#
# weighted
# Precision: 0.4294969567200623
# Recall: 0.36096841276040365
# F1 Score: 0.38367349588818384
#
# start XGB 50 AutoPGD
# Accuracy: 0.7543054525085864
#
# macro
# Precision: 0.7647925658157251
# Recall: 0.8174816814965139
# F1 Score: 0.7460043016461361
#
# weighted
# Precision: 0.8539688521440841
# Recall: 0.7543054525085864
# F1 Score: 0.7648192358421059
#
# start XGB 50 ZOO
# Accuracy: 0.8480620155038759
#
# macro
# Precision: 0.6491090146750524
# Recall: 0.5160565129054105
# F1 Score: 0.4963507139214686
#
# weighted
# Precision: 0.7922155591308728
# Recall: 0.8480620155038759
# F1 Score: 0.7906397621842992
#
# start XGB 50 CaFA
# Accuracy: 0.8309680751635594
#
# macro
# Precision: 0.8257065702258106
# Recall: 0.7862146397826939
# F1 Score: 0.8001432478679924
#
# weighted
# Precision: 0.8293935746445623
# Recall: 0.8309680751635594
# F1 Score: 0.8255444113284633
#
# start XGB 50 SINIFGSM
# Accuracy: 0.8216075082915814
#
# macro
# Precision: 0.8021737753049629
# Recall: 0.8346458659473859
# F1 Score: 0.8097434201886464
#
# weighted
# Precision: 0.8453975562529692
# Recall: 0.8216075082915814
# F1 Score: 0.8261121112875036
#
# start XGB 50 VNIFGSM
# Accuracy: 0.8968965183261769
#
# macro
# Precision: 0.8736440210793963
# Recall: 0.8968562405553211
# F1 Score: 0.8833747986754845
#
# weighted
# Precision: 0.9029192648094777
# Recall: 0.8968965183261769
# F1 Score: 0.8984468970015183
#
# start XGB 20 baseline
# Accuracy: 0.7476635514018691
#
# macro
# Precision: 0.7277173913043478
# Recall: 0.6286855036855037
# F1 Score: 0.6374246987951807
#
# weighted
# Precision: 0.7383380739536773
# Recall: 0.7476635514018691
# F1 Score: 0.7140313590811845
#
# start XGB 20 BIM
# Accuracy: 0.718894724823019
#
# macro
# Precision: 0.7316980869756473
# Recall: 0.7718930296218655
# F1 Score: 0.7111614782512674
#
# weighted
# Precision: 0.8127492176865356
# Recall: 0.718894724823019
# F1 Score: 0.7295295038130558
#
# start XGB 20 FGSM
# Accuracy: 0.8581688095110012
#
# macro
# Precision: 0.8314785450589789
# Recall: 0.8558531325497079
# F1 Score: 0.8410486963078712
#
# weighted
# Precision: 0.867332401473883
# Recall: 0.8581688095110012
# F1 Score: 0.8606771464989912
#
# start XGB 20 PGD
# Accuracy: 0.718894724823019
#
# macro
# Precision: 0.7316980869756473
# Recall: 0.7718930296218655
# F1 Score: 0.7111614782512674
#
# weighted
# Precision: 0.8127492176865356
# Recall: 0.718894724823019
# F1 Score: 0.7295295038130558
#
# start XGB 20 DF
# Accuracy: 0.37156903968690363
#
# macro
# Precision: 0.3701997456183243
# Recall: 0.3476991079910431
# F1 Score: 0.3465276116204309
#
# weighted
# Precision: 0.4444439694498909
# Recall: 0.37156903968690363
# F1 Score: 0.39570351143465415
#
# start XGB 20 AutoPGD
# Accuracy: 0.7580646750968353
#
# macro
# Precision: 0.767575963084272
# Recall: 0.8206797656324962
# F1 Score: 0.7497324723558777
#
# weighted
# Precision: 0.855994925062933
# Recall: 0.7580646750968353
# F1 Score: 0.7684055539482499
#
# start XGB 20 ZOO
# Accuracy: 0.7405405405405405
#
# macro
# Precision: 0.706170800583132
# Recall: 0.6681662079345413
# F1 Score: 0.6780596568507491
#
# weighted
# Precision: 0.7286768739562575
# Recall: 0.7405405405405405
# F1 Score: 0.7275077181757988
#
# start XGB 20 CaFA
# Accuracy: 0.8133757675265963
#
# macro
# Precision: 0.696502992813792
# Recall: 0.6310159094162316
# F1 Score: 0.6498807305493043
#
# weighted
# Precision: 0.7896735222157302
# Recall: 0.8133757675265963
# F1 Score: 0.7949262411783155
#
# start XGB 20 SINIFGSM
# Accuracy: 0.8211841477001433
#
# macro
# Precision: 0.8017186070387432
# Recall: 0.8347537928163411
# F1 Score: 0.8092757061596834
#
# weighted
# Precision: 0.8456407612873524
# Recall: 0.8211841477001433
# F1 Score: 0.8257787327153323
#
# start XGB 20 VNIFGSM
# Accuracy: 0.9018446499654157
#
# macro
# Precision: 0.879163770664339
# Recall: 0.9003472828427825
# F1 Score: 0.8882823491579372
#
# weighted
# Precision: 0.9067846924880942
# Recall: 0.9018446499654157
# F1 Score: 0.9031765772760906
#
# start XGB 1 baseline
# Accuracy: 0.5287356321839081
#
# macro
# Precision: 0.5265111346765641
# Recall: 0.5265957446808511
# F1 Score: 0.5264834727200318
#
# weighted
# Precision: 0.5296254311868456
# Recall: 0.5287356321839081
# F1 Score: 0.529110992094554
#
# start XGB 1 BIM
# Accuracy: 0.7077349637423574
#
# macro
# Precision: 0.7209835346764804
# Recall: 0.7602850462941635
# F1 Score: 0.6995599950717336
#
# weighted
# Precision: 0.8036324086102333
# Recall: 0.7077349637423574
# F1 Score: 0.7190311479591892
#
# start XGB 1 FGSM
# Accuracy: 0.8526726361851431
#
# macro
# Precision: 0.8242348702329434
# Recall: 0.8528404911762838
# F1 Score: 0.8348628651690462
#
# weighted
# Precision: 0.8646625632809772
# Recall: 0.8526726361851431
# F1 Score: 0.8557734338735136
#
# start XGB 1 PGD
# Accuracy: 0.7077349637423574
#
# macro
# Precision: 0.7209835346764804
# Recall: 0.7602850462941635
# F1 Score: 0.6995599950717336
#
# weighted
# Precision: 0.8036324086102333
# Recall: 0.7077349637423574
# F1 Score: 0.7190311479591892
#
# start XGB 1 DF
# Accuracy: 0.3605986717571946
#
# macro
# Precision: 0.36165756257746684
# Recall: 0.3376742493031698
# F1 Score: 0.3367976277285526
#
# weighted
# Precision: 0.43525047458638455
# Recall: 0.3605986717571946
# F1 Score: 0.3850946367793737
#
# start XGB 1 AutoPGD
# Accuracy: 0.7456458160548256
#
# macro
# Precision: 0.75796395627918
# Recall: 0.8093997041040472
# F1 Score: 0.737375633911115
#
# weighted
# Precision: 0.8483314712595619
# Recall: 0.7456458160548256
# F1 Score: 0.7565264806949207
#
# start XGB 1 ZOO
# Accuracy: 0.7181719260065288
#
# macro
# Precision: 0.6968004879671732
# Recall: 0.6805055436883328
# F1 Score: 0.6855504693207565
#
# weighted
# Precision: 0.7114743243417736
# Recall: 0.7181719260065288
# F1 Score: 0.7121105066899158
#
# start XGB 1 CaFA
# Accuracy: 0.7249782419495213
#
# macro
# Precision: 0.6814062365987703
# Recall: 0.6269897635743887
# F1 Score: 0.6346898631661583
#
# weighted
# Precision: 0.7068509682606067
# Recall: 0.7249782419495213
# F1 Score: 0.7012639630082274
#
# start XGB 1 SINIFGSM
# Accuracy: 0.8098262792454204
#
# macro
# Precision: 0.7889954391801337
# Recall: 0.8278755280370337
# F1 Score: 0.7962682983295645
#
# weighted
# Precision: 0.8420387035960814
# Recall: 0.8098262792454204
# F1 Score: 0.8157381672834088
#
# start XGB 1 VNIFGSM
# Accuracy: 0.8931421255263324
#
# macro
# Precision: 0.8685263388169884
# Recall: 0.8930821875538035
# F1 Score: 0.8787196330963486
#
# weighted
# Precision: 0.8998055671804573
# Recall: 0.8931421255263324
# F1 Score: 0.8948614816565538
#
# start RF 100 baseline
# Accuracy: 0.9872611464968153
#
# macro
# Precision: 0.9916434540389972
# Recall: 0.9745762711864407
# F1 Score: 0.9827430385930631
#
# weighted
# Precision: 0.9874740521263949
# Recall: 0.9872611464968153
# F1 Score: 0.987148662482614
#
# start RF 100 BIM
# Accuracy: 0.7102975911497608
#
# macro
# Precision: 0.7283058704991163
# Recall: 0.7661673902863864
# F1 Score: 0.7036138548326867
#
# weighted
# Precision: 0.8099939758905953
# Recall: 0.7102975911497608
# F1 Score: 0.7207615699133417
#
# start RF 100 FGSM
# Accuracy: 0.8633297293301174
#
# macro
# Precision: 0.837296427494805
# Recall: 0.8641323110958741
# F1 Score: 0.8475271651009924
#
# weighted
# Precision: 0.8736125793022601
# Recall: 0.8633297293301174
# F1 Score: 0.865935933356768
#
# start RF 100 PGD
# Accuracy: 0.7102975911497608
#
# macro
# Precision: 0.7283058704991163
# Recall: 0.7661673902863864
# F1 Score: 0.7036138548326867
#
# weighted
# Precision: 0.8099939758905953
# Recall: 0.7102975911497608
# F1 Score: 0.7207615699133417
#
# start RF 100 DF
# Accuracy: 0.376105699249804
#
# macro
# Precision: 0.3768826471346892
# Recall: 0.35572555043377496
# F1 Score: 0.35288066323987444
#
# weighted
# Precision: 0.4500202917601766
# Recall: 0.376105699249804
# F1 Score: 0.39982947679808517
#
# start RF 100 AutoPGD
# Accuracy: 0.7565043067232052
#
# macro
# Precision: 0.7671423417675962
# Recall: 0.8199868213268263
# F1 Score: 0.7483547481211641
#
# weighted
# Precision: 0.8560562248282246
# Recall: 0.7565043067232052
# F1 Score: 0.7668689876701832
#
# start RF 100 ZOO
# Accuracy: 0.9957446808510638
#
# macro
# Precision: 0.9972067039106145
# Recall: 0.9912280701754386
# F1 Score: 0.9941746610148484
#
# weighted
# Precision: 0.9957684535837394
# Recall: 0.9957446808510638
# F1 Score: 0.9957318118360129
#
# start RF 100 CaFA
# Accuracy: 0.832510942804144
#
# macro
# Precision: 0.8265067426840755
# Recall: 0.782847360405905
# F1 Score: 0.7981507253859064
#
# weighted
# Precision: 0.8307351128136055
# Recall: 0.832510942804144
# F1 Score: 0.8265478364599556
#
# start RF 100 SINIFGSM
# Accuracy: 0.828561239524386
#
# macro
# Precision: 0.8075505801427936
# Recall: 0.85195678696412
# F1 Score: 0.8159119637221648
#
# weighted
# Precision: 0.8628707704518612
# Recall: 0.828561239524386
# F1 Score: 0.8342468924563955
#
# start RF 100 VNIFGSM
# Accuracy: 0.9016002055738548
#
# macro
# Precision: 0.8789595348915373
# Recall: 0.9018625235665482
# F1 Score: 0.8886276868784313
#
# weighted
# Precision: 0.907257671077686
# Recall: 0.9016002055738548
# F1 Score: 0.90304098484469
#
# start RF 50 baseline
# Accuracy: 0.9297752808988764
#
# macro
# Precision: 0.9577702702702703
# Recall: 0.8529411764705883
# F1 Score: 0.8917472480690871
#
# weighted
# Precision: 0.9357064227148496
# Recall: 0.9297752808988764
# F1 Score: 0.9252695898052993
#
# start RF 50 BIM
# Accuracy: 0.7077510058733756
#
# macro
# Precision: 0.7254951730171506
# Recall: 0.7625077289675953
# F1 Score: 0.7010551981111354
#
# weighted
# Precision: 0.8063195327281785
# Recall: 0.7077510058733756
# F1 Score: 0.7182138132993883
#
# start RF 50 FGSM
# Accuracy: 0.8613502136939313
#
# macro
# Precision: 0.8347635562175287
# Recall: 0.863266163909429
# F1 Score: 0.8453838789452734
#
# weighted
# Precision: 0.872759122105486
# Recall: 0.8613502136939313
# F1 Score: 0.8641707801180377
#
# start RF 50 PGD
# Accuracy: 0.7077510058733756
#
# macro
# Precision: 0.7254951730171506
# Recall: 0.7625077289675953
# F1 Score: 0.7010551981111354
#
# weighted
# Precision: 0.8063195327281785
# Recall: 0.7077510058733756
# F1 Score: 0.7182138132993883
#
# start RF 50 DF
# Accuracy: 0.373097623917097
#
# macro
# Precision: 0.374085000887003
# Recall: 0.351791947038915
# F1 Score: 0.34926394332822375
#
# weighted
# Precision: 0.4490552526074888
# Recall: 0.373097623917097
# F1 Score: 0.39756747408983373
#
# start RF 50 AutoPGD
# Accuracy: 0.7547028875828042
#
# macro
# Precision: 0.7656975024372776
# Recall: 0.8183933105796697
# F1 Score: 0.7465356732678144
#
# weighted
# Precision: 0.8549941822954955
# Recall: 0.7547028875828042
# F1 Score: 0.7651636653133428
#
# start RF 50 ZOO
# Accuracy: 0.9507575757575758
#
# macro
# Precision: 0.9703196347031964
# Recall: 0.8879310344827587
# F1 Score: 0.9215990862364363
#
# weighted
# Precision: 0.9536806420368064
# Recall: 0.9507575757575758
# F1 Score: 0.9484031635602167
#
# start RF 50 CaFA
# Accuracy: 0.8134519938387814
#
# macro
# Precision: 0.8228111048965594
# Recall: 0.8018915377705147
# F1 Score: 0.8062157789770223
#
# weighted
# Precision: 0.8190674604734483
# Recall: 0.8134519938387814
# F1 Score: 0.8103507588980275
#
# start RF 50 SINIFGSM
# Accuracy: 0.8242206100669449
#
# macro
# Precision: 0.8033925871713479
# Recall: 0.8472642630529121
# F1 Score: 0.8113980124981222
#
# weighted
# Precision: 0.859022504649578
# Recall: 0.8242206100669449
# F1 Score: 0.8300571613353133
#
# start RF 50 VNIFGSM
# Accuracy: 0.9002925572866362
#
# macro
# Precision: 0.8773748689444121
# Recall: 0.9007424020130959
# F1 Score: 0.8871883824379488
#
# weighted
# Precision: 0.9061932962905169
# Recall: 0.9002925572866362
# F1 Score: 0.901787147953418
#
# start RF 20 baseline
# Accuracy: 0.8488372093023255
#
# macro
# Precision: 0.888468930172966
# Recall: 0.7303951367781155
# F1 Score: 0.7668404588112617
#
# weighted
# Precision: 0.8635937011158619
# Recall: 0.8488372093023255
# F1 Score: 0.8300797827194024
#
# start RF 20 BIM
# Accuracy: 0.7070596007521124
#
# macro
# Precision: 0.7258494768860265
# Recall: 0.7634954895211594
# F1 Score: 0.7003822260994186
#
# weighted
# Precision: 0.8083080005731625
# Recall: 0.7070596007521124
# F1 Score: 0.7176782258458173
#
# start RF 20 FGSM
# Accuracy: 0.8570681756691689
#
# macro
# Precision: 0.8307092673507193
# Recall: 0.8575925329318095
# F1 Score: 0.8408153195846287
#
# weighted
# Precision: 0.8679553226403791
# Recall: 0.8570681756691689
# F1 Score: 0.8598501477489668
#
# start RF 20 PGD
# Accuracy: 0.7070596007521124
#
# macro
# Precision: 0.7258494768860265
# Recall: 0.7634954895211594
# F1 Score: 0.7003822260994186
#
# weighted
# Precision: 0.8083080005731625
# Recall: 0.7070596007521124
# F1 Score: 0.7176782258458173
#
# start RF 20 DF
# Accuracy: 0.37605637288261423
#
# macro
# Precision: 0.3770941241461524
# Recall: 0.355970449726701
# F1 Score: 0.3529986434474414
#
# weighted
# Precision: 0.45018180045088213
# Recall: 0.37605637288261423
# F1 Score: 0.39977831363631355
#
# start RF 20 AutoPGD
# Accuracy: 0.7522058751361803
#
# macro
# Precision: 0.7640804220779983
# Recall: 0.8166711313389657
# F1 Score: 0.7440783626958105
#
# weighted
# Precision: 0.8542007134664105
# Recall: 0.7522058751361803
# F1 Score: 0.7628002444944815
#
# start RF 20 ZOO
# Accuracy: 0.8734693877551021
#
# macro
# Precision: 0.9023809523809524
# Recall: 0.7606645513837476
# F1 Score: 0.8007659820046693
#
# weighted
# Precision: 0.8823906705539359
# Recall: 0.8734693877551021
# F1 Score: 0.8602059285979284
#
# start RF 20 CaFA
# Accuracy: 0.6337101021129022
#
# macro
# Precision: 0.5093848921922624
# Recall: 0.5063218017117584
# F1 Score: 0.4953815940457184
#
# weighted
# Precision: 0.5836608920057299
# Recall: 0.6337101021129022
# F1 Score: 0.5988501303466919
#
# start RF 20 SINIFGSM
# Accuracy: 0.8254802972935072
#
# macro
# Precision: 0.8047548746776287
# Recall: 0.8503913296444462
# F1 Score: 0.8127182399920356
#
# weighted
# Precision: 0.8620378921765802
# Recall: 0.8254802972935072
# F1 Score: 0.8314610619391659
#
# start RF 20 VNIFGSM
# Accuracy: 0.898208692657455
#
# macro
# Precision: 0.8744038447081185
# Recall: 0.8998954772655334
# F1 Score: 0.8848998927551914
#
# weighted
# Precision: 0.9050500013895489
# Recall: 0.898208692657455
# F1 Score: 0.8998808309330011
#
# start RF 1 baseline
# Accuracy: 0.4666666666666667
#
# macro
# Precision: 0.6363636363636364
# Recall: 0.6666666666666666
# F1 Score: 0.4642857142857143
#
# weighted
# Precision: 0.8545454545454546
# Recall: 0.4666666666666667
# F1 Score: 0.4857142857142857
#
# start RF 1 BIM
# Accuracy: 0.6965691647828836
#
# macro
# Precision: 0.7147174759997429
# Recall: 0.7491561301231384
# F1 Score: 0.6898888032834649
#
# weighted
# Precision: 0.7941784454018961
# Recall: 0.6965691647828836
# F1 Score: 0.7072042489487437
#
# start RF 1 FGSM
# Accuracy: 0.844445246875409
#
# macro
# Precision: 0.8165263641169427
# Recall: 0.8479485225202049
# F1 Score: 0.8273155061938063
#
# weighted
# Precision: 0.8596148915066518
# Recall: 0.844445246875409
# F1 Score: 0.8481047533723085
#
# start RF 1 PGD
# Accuracy: 0.6965691647828836
#
# macro
# Precision: 0.7147174759997429
# Recall: 0.7491561301231384
# F1 Score: 0.6898888032834649
#
# weighted
# Precision: 0.7941784454018961
# Recall: 0.6965691647828836
# F1 Score: 0.7072042489487437
#
# start RF 1 DF
# Accuracy: 0.37764599066558563
#
# macro
# Precision: 0.37855948351110646
# Recall: 0.3577879694052201
# F1 Score: 0.35466602574408473
#
# weighted
# Precision: 0.45137683879114027
# Recall: 0.37764599066558563
# F1 Score: 0.40120984726787706
#
# start RF 1 AutoPGD
# Accuracy: 0.7445507307113166
#
# macro
# Precision: 0.7576025653853027
# Recall: 0.8080086074049935
# F1 Score: 0.736542408028261
#
# weighted
# Precision: 0.8471627216724408
# Recall: 0.7445507307113166
# F1 Score: 0.7552913915628574
#
# start RF 1 ZOO
# Accuracy: 0.6867469879518072
#
# macro
# Precision: 0.7308823529411765
# Recall: 0.6401785714285715
# F1 Score: 0.6279310344827587
#
# weighted
# Precision: 0.7200566973777462
# Recall: 0.6867469879518072
# F1 Score: 0.6511009555463232
#
# start RF 1 CaFA
# Accuracy: 0.8101339904512552
#
# macro
# Precision: 0.6647625223784696
# Recall: 0.6130126070112809
# F1 Score: 0.6284202877082451
#
# weighted
# Precision: 0.7845554330190935
# Recall: 0.8101339904512552
# F1 Score: 0.7926053374535372
#
# start RF 1 SINIFGSM
# Accuracy: 0.8090366854797332
#
# macro
# Precision: 0.7889616536959903
# Recall: 0.8320229013339554
# F1 Score: 0.7956156423426286
#
# weighted
# Precision: 0.8468737774707742
# Recall: 0.8090366854797332
# F1 Score: 0.8155481839458268
#
# start RF 1 VNIFGSM
# Accuracy: 0.8838477328543675
#
# macro
# Precision: 0.8591595333850918
# Recall: 0.8842094875595801
# F1 Score: 0.8692969437224766
#
# weighted
# Precision: 0.8915007301013463
# Recall: 0.8838477328543675
# F1 Score: 0.8858003600364169
#
# start DT 100 baseline
# Accuracy: 0.9322709163346613
#
# macro
# Precision: 0.9276873243666474
# Recall: 0.8987101289871013
# F1 Score: 0.9117659222497932
#
# weighted
# Precision: 0.9317695859631598
# Recall: 0.9322709163346613
# F1 Score: 0.9310846770074376
#
# start DT 100 BIM
# Accuracy: 0.7118667488679606
#
# macro
# Precision: 0.6865953585076304
# Recall: 0.7740958191681341
# F1 Score: 0.6760753047852346
#
# weighted
# Precision: 0.8391963335194015
# Recall: 0.7118667488679606
# F1 Score: 0.7374879840699274
#
# start DT 100 FGSM
# Accuracy: 0.858257669229228
#
# macro
# Precision: 0.7711898889054927
# Recall: 0.8332104924991116
# F1 Score: 0.7944028361520451
#
# weighted
# Precision: 0.880493275035823
# Recall: 0.858257669229228
# F1 Score: 0.8654881141198341
#
# start DT 100 PGD
# Accuracy: 0.7118667488679606
#
# macro
# Precision: 0.6865953585076304
# Recall: 0.7740958191681341
# F1 Score: 0.6760753047852346
#
# weighted
# Precision: 0.8391963335194015
# Recall: 0.7118667488679606
# F1 Score: 0.7374879840699274
#
# start DT 100 DF
# Accuracy: 0.32889052610428315
#
# macro
# Precision: 0.36467554278221065
# Recall: 0.30730056773302605
# F1 Score: 0.2979006701446118
#
# weighted
# Precision: 0.5098088534733716
# Recall: 0.32889052610428315
# F1 Score: 0.3801636891309894
#
# start DT 100 AutoPGD
# Accuracy: 0.7533646638705005
#
# macro
# Precision: 0.7268540409428668
# Recall: 0.8338705131376094
# F1 Score: 0.7218810186442687
#
# weighted
# Precision: 0.8774938008078276
# Recall: 0.7533646638705005
# F1 Score: 0.7754252298595032
#
# start DT 100 ZOO
# Accuracy: 0.9573248407643312
#
# macro
# Precision: 0.9450021729682747
# Recall: 0.9412388903851333
# F1 Score: 0.943099787685775
#
# weighted
# Precision: 0.9571688576276725
# Recall: 0.9573248407643312
# F1 Score: 0.9572342353307098
#
# start DT 100 CaFA
# Accuracy: 0.6840397677683755
#
# macro
# Precision: 0.6787965168132912
# Recall: 0.7056961402768009
# F1 Score: 0.6713848139909153
#
# weighted
# Precision: 0.7426372717543042
# Recall: 0.6840397677683755
# F1 Score: 0.6947737820282284
#
# start DT 100 SINIFGSM
# Accuracy: 0.8436047170881052
#
# macro
# Precision: 0.7509773681973146
# Recall: 0.8573687184384624
# F1 Score: 0.780378939808092
#
# weighted
# Precision: 0.8935510802454774
# Recall: 0.8436047170881052
# F1 Score: 0.85703109203866
#
# start DT 100 VNIFGSM
# Accuracy: 0.9087374617005215
#
# macro
# Precision: 0.8318490134643042
# Recall: 0.8872920248177127
# F1 Score: 0.8552695314516222
#
# weighted
# Precision: 0.9195387840408163
# Recall: 0.9087374617005215
# F1 Score: 0.912246579454092
#
# start DT 50 baseline
# Accuracy: 0.7889344262295082
#
# macro
# Precision: 0.7547738227660363
# Recall: 0.7193229197837493
# F1 Score: 0.7319524954804579
#
# weighted
# Precision: 0.7806611550781987
# Recall: 0.7889344262295082
# F1 Score: 0.7810835824374169
#
# start DT 50 BIM
# Accuracy: 0.7056549874060574
#
# macro
# Precision: 0.6994521045135618
# Recall: 0.7673969789794108
# F1 Score: 0.6834566205773376
#
# weighted
# Precision: 0.8242110678986662
# Recall: 0.7056549874060574
# F1 Score: 0.7257505453059637
#
# start DT 50 FGSM
# Accuracy: 0.8622339695904951
#
# macro
# Precision: 0.7907376590791073
# Recall: 0.8481213916364372
# F1 Score: 0.8123519635389065
#
# weighted
# Precision: 0.8823546163178924
# Recall: 0.8622339695904951
# F1 Score: 0.8683871062155005
#
# start DT 50 PGD
# Accuracy: 0.7056549874060574
#
# macro
# Precision: 0.6994521045135618
# Recall: 0.7673969789794108
# F1 Score: 0.6834566205773376
#
# weighted
# Precision: 0.8242110678986662
# Recall: 0.7056549874060574
# F1 Score: 0.7257505453059637
#
# start DT 50 DF
# Accuracy: 0.3714239271781534
#
# macro
# Precision: 0.40600033807896024
# Recall: 0.3886525933716998
# F1 Score: 0.3613893283097155
#
# weighted
# Precision: 0.4898939663774344
# Recall: 0.3714239271781534
# F1 Score: 0.39552908525524183
#
# start DT 50 AutoPGD
# Accuracy: 0.7471390329140701
#
# macro
# Precision: 0.7327544901672236
# Recall: 0.8226018310876347
# F1 Score: 0.7232930320614179
#
# weighted
# Precision: 0.8661370598235449
# Recall: 0.7471390329140701
# F1 Score: 0.7663424064184876
#
# start DT 50 ZOO
# Accuracy: 0.8114175753688262
#
# macro
# Precision: 0.775175227247837
# Recall: 0.7429623004121693
# F1 Score: 0.755608236076986
#
# weighted
# Precision: 0.8045478228695865
# Recall: 0.8114175753688262
# F1 Score: 0.8055744499127677
#
# start DT 50 CaFA
# Accuracy: 0.8390716261912081
#
# macro
# Precision: 0.8010241694141591
# Recall: 0.8427745775016059
# F1 Score: 0.8148845313436317
#
# weighted
# Precision: 0.8598205059828821
# Recall: 0.8390716261912081
# F1 Score: 0.8442537355052284
#
# start DT 50 SINIFGSM
# Accuracy: 0.8299755538194007
#
# macro
# Precision: 0.7905037875865393
# Recall: 0.8512082135272847
# F1 Score: 0.8056025272509141
#
# weighted
# Precision: 0.867978188920464
# Recall: 0.8299755538194007
# F1 Score: 0.8378957726197455
#
# start DT 50 VNIFGSM
# Accuracy: 0.9013500325309044
#
# macro
# Precision: 0.856364694952267
# Recall: 0.8887334258975541
# F1 Score: 0.8705331599186362
#
# weighted
# Precision: 0.9080625782009455
# Recall: 0.9013500325309044
# F1 Score: 0.9034895936982671
#
# start DT 20 baseline
# Accuracy: 0.6603119584055459
#
# macro
# Precision: 0.6133273836085081
# Recall: 0.6015298099730817
# F1 Score: 0.6043520850825637
#
# weighted
# Precision: 0.6469408541154799
# Recall: 0.6603119584055459
# F1 Score: 0.6510282927851434
#
# start DT 20 BIM
# Accuracy: 0.6887602930687934
#
# macro
# Precision: 0.6594040468136204
# Recall: 0.750943642361455
# F1 Score: 0.6437128039419402
#
# weighted
# Precision: 0.8351986139604521
# Recall: 0.6887602930687934
# F1 Score: 0.7209155575726442
#
# start DT 20 FGSM
# Accuracy: 0.857348508704845
#
# macro
# Precision: 0.734410035518702
# Recall: 0.816378114371208
# F1 Score: 0.7629627965419925
#
# weighted
# Precision: 0.8882150669876487
# Recall: 0.857348508704845
# F1 Score: 0.8678758093877268
#
# start DT 20 PGD
# Accuracy: 0.6887602930687934
#
# macro
# Precision: 0.6594040468136204
# Recall: 0.750943642361455
# F1 Score: 0.6437128039419402
#
# weighted
# Precision: 0.8351986139604521
# Recall: 0.6887602930687934
# F1 Score: 0.7209155575726442
#
# start DT 20 DF
# Accuracy: 0.3046684762618667
#
# macro
# Precision: 0.31970631146686973
# Recall: 0.27902022208768695
# F1 Score: 0.281325044959489
#
# weighted
# Precision: 0.4082091006632226
# Recall: 0.3046684762618667
# F1 Score: 0.3375684281627818
#
# start DT 20 AutoPGD
# Accuracy: 0.7337465187417249
#
# macro
# Precision: 0.6980766257643588
# Recall: 0.8178797859204116
# F1 Score: 0.6906649865268117
#
# weighted
# Precision: 0.8760079820155572
# Recall: 0.7337465187417249
# F1 Score: 0.762439430581459
#
# start DT 20 ZOO
# Accuracy: 0.6827548806941431
#
# macro
# Precision: 0.6310249212652335
# Recall: 0.6238267396201083
# F1 Score: 0.6266187072770828
#
# weighted
# Precision: 0.6751160006748481
# Recall: 0.6827548806941431
# F1 Score: 0.678279689246909
#
# start DT 20 CaFA
# Accuracy: 0.7427662121521796
#
# macro
# Precision: 0.7539763446541741
# Recall: 0.7575430458470176
# F1 Score: 0.7425927804628629
#
# weighted
# Precision: 0.7706803072522396
# Recall: 0.7427662121521796
# F1 Score: 0.7436474168098215
#
# start DT 20 SINIFGSM
# Accuracy: 0.8281333727021204
#
# macro
# Precision: 0.7635577553030266
# Recall: 0.851389314850747
# F1 Score: 0.7854066577632537
#
# weighted
# Precision: 0.8787575902107744
# Recall: 0.8281333727021204
# F1 Score: 0.8401650849450334
#
# start DT 20 VNIFGSM
# Accuracy: 0.8988527454875017
#
# macro
# Precision: 0.8226165017007252
# Recall: 0.8740440564768936
# F1 Score: 0.8443045857718581
#
# weighted
# Precision: 0.9100246388026567
# Recall: 0.8988527454875017
# F1 Score: 0.9025767121618947
#
# start DT 1 baseline
# Accuracy: 0.6705370101596516
#
# macro
# Precision: 0.5079595791805094
# Recall: 0.5067350715674561
# F1 Score: 0.5055498123717663
#
# weighted
# Precision: 0.6456411622602936
# Recall: 0.6705370101596516
# F1 Score: 0.6568571671269877
#
# start DT 1 BIM
# Accuracy: 0.7071598503012062
#
# macro
# Precision: 0.6900386170005847
# Recall: 0.762089380047474
# F1 Score: 0.6786411077899337
#
# weighted
# Precision: 0.8223388446784329
# Recall: 0.7071598503012062
# F1 Score: 0.7291430384044515
#
# start DT 1 FGSM
# Accuracy: 0.8610631655395528
#
# macro
# Precision: 0.7962842150608431
# Recall: 0.8576295647804182
# F1 Score: 0.8182746776816253
#
# weighted
# Precision: 0.8841480656540401
# Recall: 0.8610631655395528
# F1 Score: 0.8675342729963983
#
# start DT 1 PGD
# Accuracy: 0.7071598503012062
#
# macro
# Precision: 0.6900386170005847
# Recall: 0.762089380047474
# F1 Score: 0.6786411077899337
#
# weighted
# Precision: 0.8223388446784329
# Recall: 0.7071598503012062
# F1 Score: 0.7291430384044515
#
# start DT 1 DF
# Accuracy: 0.33116465509646725
#
# macro
# Precision: 0.3773716775688111
# Recall: 0.32838636254090225
# F1 Score: 0.30680036664214966
#
# weighted
# Precision: 0.519445770502568
# Recall: 0.33116465509646725
# F1 Score: 0.3790156573663377
#
# start DT 1 AutoPGD
# Accuracy: 0.7459942832987781
#
# macro
# Precision: 0.7319829655299566
# Recall: 0.8186661470120526
# F1 Score: 0.7226644013744759
#
# weighted
# Precision: 0.8623044984503275
# Recall: 0.7459942832987781
# F1 Score: 0.764794601958867
#
# start DT 1 ZOO
# Accuracy: 0.7208425023577492
#
# macro
# Precision: 0.6207590703583306
# Recall: 0.6167442243435486
# F1 Score: 0.6185970798330901
#
# weighted
# Precision: 0.7163283534960543
# Recall: 0.7208425023577492
# F1 Score: 0.7184834701440656
#
# start DT 1 CaFA
# Accuracy: 0.5637485240608208
#
# macro
# Precision: 0.5911431461990801
# Recall: 0.5810690978728816
# F1 Score: 0.5569114129191817
#
# weighted
# Precision: 0.5987882015765916
# Recall: 0.5637485240608208
# F1 Score: 0.5516181227996313
#
# start DT 1 SINIFGSM
# Accuracy: 0.8186876392812965
#
# macro
# Precision: 0.7794009464499869
# Recall: 0.835659155157624
# F1 Score: 0.7932857147867033
#
# weighted
# Precision: 0.8559535736971012
# Recall: 0.8186876392812965
# F1 Score: 0.8268595316198379
#
# start DT 1 VNIFGSM
# Accuracy: 0.9036766912914339
#
# macro
# Precision: 0.8776590247375426
# Recall: 0.902226095656393
# F1 Score: 0.8881874976682682
#
# weighted
# Precision: 0.9093172367053588
# Recall: 0.9036766912914339
# F1 Score: 0.9051914926658707

# %%
epsilon = 0

Def = "Def1"
attack_names = [
    "baseline", "BIM", "FGSM", "PGD", "DF",
    "AutoPGD", "ZOO", "CaFA", "SINIFGSM", "VNIFGSM"
]

base_path = "/home/jovyan/Sample_Based_Extension/UNSW/UNSW_Dynamite_Selection_Data"

rec_list = ["Euclidean", "cosine", "manhattan"]
for rec in rec_list:
    for attack in attack_names:
        print(f"start {attack}")
        
        x_path = f"{base_path}/Recommendation_{rec}/x_test_adv_{attack}_{Def}.npy"
        y_path = f"{base_path}/Recommendation_{rec}/y_test_adv_{attack}_{Def}.npy"
    
        try:
            x_test_adv = np.load(x_path)
            y_test_adv = np.load(y_path)
            m_per_name = f"Recommendation_{rec}"
            calculate_performance_metrics(x_test_adv, y_test_adv, model, m_per_name, attack, epsilon)
            except FileNotFoundError:
            print(x_path, "not found")
            print_empty_file()
# Out:
# start baseline
# Accuracy: 0.9768107745059917
#
# macro
# Precision: 0.9595073343292229
# Recall: 0.9363704305507241
# F1 Score: 0.9475150716969581
#
# weighted
# Precision: 0.9764606697728941
# Recall: 0.9768107745059917
# F1 Score: 0.9765113720074465
#
# start BIM
# Accuracy: 0.7263643805712207
#
# macro
# Precision: 0.7040913940520609
# Recall: 0.791017408490514
# F1 Score: 0.695406373095555
#
# weighted
# Precision: 0.8463404393565661
# Recall: 0.7263643805712207
# F1 Score: 0.7489402002569302
#
# start FGSM
# Accuracy: 0.8816982589859174
#
# macro
# Precision: 0.8369564048413338
# Recall: 0.8871862212393059
# F1 Score: 0.8556754533647116
#
# weighted
# Precision: 0.8983404398828025
# Recall: 0.8816982589859174
# F1 Score: 0.8857790374077908
#
# start PGD
# Accuracy: 0.7263643805712207
#
# macro
# Precision: 0.7040913940520609
# Recall: 0.791017408490514
# F1 Score: 0.695406373095555
#
# weighted
# Precision: 0.8463404393565661
# Recall: 0.7263643805712207
# F1 Score: 0.7489402002569302
#
# start DF
# Accuracy: 0.8880507922726286
#
# macro
# Precision: 0.7486103053474205
# Recall: 0.7593993907361188
# F1 Score: 0.7538193933028066
#
# weighted
# Precision: 0.8905424625735833
# Recall: 0.8880507922726286
# F1 Score: 0.8892394664284885
#
# start AutoPGD
# Accuracy: 0.7700459871051233
#
# macro
# Precision: 0.7398163914910103
# Recall: 0.8350397874256811
# F1 Score: 0.741119011841298
#
# weighted
# Precision: 0.8712217718714799
# Recall: 0.7700459871051233
# F1 Score: 0.7881528937645619
#
# start ZOO
# Accuracy: 0.9767470405324314
#
# macro
# Precision: 0.86933405693069
# Recall: 0.8107869668157361
# F1 Score: 0.8372820066718956
#
# weighted
# Precision: 0.9752168336284079
# Recall: 0.9767470405324314
# F1 Score: 0.9757465032625688
#
# start CaFA
# Accuracy: 0.9698028764977521
#
# macro
# Precision: 0.9688440325421503
# Recall: 0.9668504520612723
# F1 Score: 0.9678283217493819
#
# weighted
# Precision: 0.9697721354798973
# Recall: 0.9698028764977521
# F1 Score: 0.9697707082247662
#
# start SINIFGSM
# Accuracy: 0.8320832237408963
#
# macro
# Precision: 0.7776266100388861
# Recall: 0.8563096853785399
# F1 Score: 0.7974587511905176
#
# weighted
# Precision: 0.8777763143809401
# Recall: 0.8320832237408963
# F1 Score: 0.8423163059501061
#
# start VNIFGSM
# Accuracy: 0.9049167641266211
#
# macro
# Precision: 0.8662077671339964
# Recall: 0.9000998184971813
# F1 Score: 0.8807154324659948
#
# weighted
# Precision: 0.9122675420672407
# Recall: 0.9049167641266211
# F1 Score: 0.9070153979850912
#
# start baseline
# Accuracy: 0.9735587665723223
#
# macro
# Precision: 0.9549486461251167
# Recall: 0.9329026631398968
# F1 Score: 0.9435239285068292
#
# weighted
# Precision: 0.9731564059160583
# Recall: 0.9735587665723223
# F1 Score: 0.973230533738801
#
# start BIM
# Accuracy: 0.745018754155394
#
# macro
# Precision: 0.7435916184533864
# Recall: 0.8004190921368108
# F1 Score: 0.7319520230235926
#
# weighted
# Precision: 0.8374892040691545
# Recall: 0.745018754155394
# F1 Score: 0.757694233191224
#
# start FGSM
# Accuracy: 0.8866746059899661
#
# macro
# Precision: 0.853470393299002
# Recall: 0.892710141898089
# F1 Score: 0.8683595658766672
#
# weighted
# Precision: 0.8995128863454299
# Recall: 0.8866746059899661
# F1 Score: 0.8896417150641942
#
# start PGD
# Accuracy: 0.745018754155394
#
# macro
# Precision: 0.7435916184533864
# Recall: 0.8004190921368108
# F1 Score: 0.7319520230235926
#
# weighted
# Precision: 0.8374892040691545
# Recall: 0.745018754155394
# F1 Score: 0.757694233191224
#
# start DF
# Accuracy: 0.9339860253493663
#
# macro
# Precision: 0.8446039667112137
# Recall: 0.8247233326193952
# F1 Score: 0.8342466329630263
#
# weighted
# Precision: 0.9322462210687247
# Recall: 0.9339860253493663
# F1 Score: 0.9330057813428461
#
# start AutoPGD
# Accuracy: 0.7826167316429471
#
# macro
# Precision: 0.7723554532597126
# Recall: 0.8384494644056102
# F1 Score: 0.7685362735045456
#
# weighted
# Precision: 0.8650226627548766
# Recall: 0.7826167316429471
# F1 Score: 0.7938897357188287
#
# start ZOO
# Accuracy: 0.9738453705724053
#
# macro
# Precision: 0.8557674519532568
# Recall: 0.8058605392693686
# F1 Score: 0.8287193550213037
#
# weighted
# Precision: 0.9722514511887631
# Recall: 0.9738453705724053
# F1 Score: 0.9728591952743288
#
# start CaFA
# Accuracy: 0.9707979007625683
#
# macro
# Precision: 0.9696993029573393
# Recall: 0.9684965985909164
# F1 Score: 0.9690903709687246
#
# weighted
# Precision: 0.9707740769036003
# Recall: 0.9707979007625683
# F1 Score: 0.9707791833254964
#
# start SINIFGSM
# Accuracy: 0.8493824867675736
#
# macro
# Precision: 0.8183621846231559
# Recall: 0.8729224850955346
# F1 Score: 0.8322480545399644
#
# weighted
# Precision: 0.8816672203274599
# Recall: 0.8493824867675736
# F1 Score: 0.8552470889177983
#
# start VNIFGSM
# Accuracy: 0.9148493507795659
#
# macro
# Precision: 0.888926839175072
# Recall: 0.912278090395392
# F1 Score: 0.8992228211427893
#
# weighted
# Precision: 0.9193157415782568
# Recall: 0.9148493507795659
# F1 Score: 0.9160887831293849
#
# start baseline
# Accuracy: 0.9738757230826647
#
# macro
# Precision: 0.9552096319758852
# Recall: 0.9344641932451001
# F1 Score: 0.9444809536149016
#
# weighted
# Precision: 0.9734929066550725
# Recall: 0.9738757230826647
# F1 Score: 0.9735711765661499
#
# start BIM
# Accuracy: 0.7293785003534338
#
# macro
# Precision: 0.7146019430245092
# Recall: 0.7980755293793971
# F1 Score: 0.7035967997122365
#
# weighted
# Precision: 0.8491927662554613
# Recall: 0.7293785003534338
# F1 Score: 0.7500591571638583
#
# start FGSM
# Accuracy: 0.8819559055683123
#
# macro
# Precision: 0.8327780838980413
# Recall: 0.8877099108634723
# F1 Score: 0.8531068952070922
#
# weighted
# Precision: 0.9000067789802214
# Recall: 0.8819559055683123
# F1 Score: 0.8864294509385998
#
# start PGD
# Accuracy: 0.7293785003534338
#
# macro
# Precision: 0.7146019430245092
# Recall: 0.7980755293793971
# F1 Score: 0.7035967997122365
#
# weighted
# Precision: 0.8491927662554613
# Recall: 0.7293785003534338
# F1 Score: 0.7500591571638583
#
# start DF
# Accuracy: 0.8658656791965261
#
# macro
# Precision: 0.7126891406250138
# Recall: 0.7392681808187342
# F1 Score: 0.7246027202433372
#
# weighted
# Precision: 0.8746574756248291
# Recall: 0.8658656791965261
# F1 Score: 0.8698065815627993
#
# start AutoPGD
# Accuracy: 0.7692617133133892
#
# macro
# Precision: 0.7449699609728675
# Recall: 0.836119016576973
# F1 Score: 0.7438864031908514
#
# weighted
# Precision: 0.8711820576044521
# Recall: 0.7692617133133892
# F1 Score: 0.7864457279538444
#
# start ZOO
# Accuracy: 0.9729898766581336
#
# macro
# Precision: 0.8530598983208341
# Recall: 0.8009104418403497
# F1 Score: 0.8246672282343228
#
# weighted
# Precision: 0.9712613665926073
# Recall: 0.9729898766581336
# F1 Score: 0.9719132561848748
#
# start CaFA
# Accuracy: 0.9681316495972954
#
# macro
# Precision: 0.9673165385856393
# Recall: 0.9653010263442319
# F1 Score: 0.9662871118159275
#
# weighted
# Precision: 0.9681017731538998
# Recall: 0.9681316495972954
# F1 Score: 0.9680972143919824
#
# start SINIFGSM
# Accuracy: 0.837035436668152
#
# macro
# Precision: 0.7878305790930672
# Recall: 0.865368954097592
# F1 Score: 0.8069054941041602
#
# weighted
# Precision: 0.8823165128214353
# Recall: 0.837035436668152
# F1 Score: 0.8465302429209267
#
# start VNIFGSM
# Accuracy: 0.9159927686405926
#
# macro
# Precision: 0.8773777502452974
# Recall: 0.9171883377934289
# F1 Score: 0.8941342626892665
#
# weighted
# Precision: 0.9241987813094341
# Recall: 0.9159927686405926
# F1 Score: 0.9180922474659065

# %%
# torch.save(model.state_dict(), "./Adversarial_Training_pgd.pt")

# %%
# import time

# epsilon_values = [0.01, 0.1, 0.2, 0.3]

# start_time = time.time()

# # Iterate over epsilon values
# for epsilon in epsilon_values:
#     filename = f'/home/jovyan/UNSW/transfer_attack/x_test_adv_BIM_eps_{epsilon}.npy'
#     x_test_adv = np.load(filename)

#     calculate_performance_metrics(x_test_adv, y_test, model, 'DNN', 'BIM', epsilon)

# end_time = time.time()
# result = end_time - start_time
# print(f"Execution Time: {result:.6f} seconds")
