# %%
import numpy as np
import pandas as pd

from sklearn.metrics import accuracy_score, precision_recall_fscore_support, roc_auc_score, confusion_matrix
from sklearn.preprocessing import label_binarize

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset

import time

# %%
head = {
            "model" : '',
            "attack_model": '',
            'epsilon': '',
            'Accuracy': '',
            'Macro Precision': '',
            'Weighted Precision': '',
            'Macro Recall': '',
            'Weighted Recall': '',
            'Macro F1': '',
            'Weighted F1': '',

        }
head = pd.DataFrame([head])
head.to_csv("./AT_interpolated.csv", mode='a', index=False)

# %%
def calculate_performance_metrics(X_test, y_test, model, model_name, attack_name, eps):
    model.eval()
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.to(device)
    
    all_preds = []
    all_labels = []
    probabilities = []

    num_classes = len(np.unique(y_test))
    
    X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
    y_test_tensor = torch.tensor(y_test, dtype=torch.long)
    test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
    test_loader = DataLoader(dataset=test_dataset)

    with torch.no_grad():
        
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            preds = torch.argmax(outputs, dim=1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            probabilities.extend(torch.nn.functional.softmax(outputs, dim=1).cpu().numpy())
        
        all_preds = np.array(all_preds)
        all_labels = np.array(all_labels)
        probabilities = np.array(probabilities)
        
        accuracy = accuracy_score(all_labels, all_preds)

        precision_macro, recall_macro, f1_macro, _ = precision_recall_fscore_support(all_labels, all_preds, average='macro')
        precision_weighted, recall_weighted, f1_weighted, _ = precision_recall_fscore_support(all_labels, all_preds, average='weighted')
    

        print(f"Accuracy: {accuracy}")
        
        print("\nmacro")
        print(f"Precision: {precision_macro}\nRecall: {recall_macro}\nF1 Score: {f1_macro}")
    
        print("\nweighted")
        print(f"Precision: {precision_weighted}\nRecall: {recall_weighted}\nF1 Score: {f1_weighted}")
        print()
        

        new_row = {
            "model" : model_name,
            "attack_model" : attack_name,
            'epsilon': eps,
            'Accuracy': accuracy,
            'Macro Precision': precision_macro,
            'Weighted Precision': precision_weighted,
            'Macro Recall': recall_macro,
            'Weighted Recall': recall_weighted,
            'Macro F1': f1_macro,
            'Weighted F1': f1_weighted,
        }
        new_row_df = pd.DataFrame([new_row])
        new_row_df.to_csv("./AT_interpolated.csv", mode='a', index=False, header=False)

# %%
# def calculate_performance_metrics(X_test, y_test, model, model_name, attack_name, eps):
#     model.eval()
#     device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#     model.to(device)
    
#     all_preds = []
#     all_labels = []
#     probabilities = []

#     num_classes = len(np.unique(y_test))
    
#     X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
#     y_test_tensor = torch.tensor(y_test, dtype=torch.long)
#     test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
#     test_loader = DataLoader(dataset=test_dataset)

#     with torch.no_grad():
        
#         for inputs, labels in test_loader:
#             inputs, labels = inputs.to(device), labels.to(device)
#             outputs = model(inputs)
#             preds = torch.argmax(outputs, dim=1)
#             all_preds.extend(preds.cpu().numpy())
#             all_labels.extend(labels.cpu().numpy())
#             probabilities.extend(torch.nn.functional.softmax(outputs, dim=1).cpu().numpy())
        
#         all_preds = np.array(all_preds)
#         all_labels = np.array(all_labels)
#         probabilities = np.array(probabilities)

#         np.save(f"/home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Defense_Label/WUSTL_Def2/y_pred_{attack_name}{eps}_Def2.npy", all_preds)

# %%
x_test = np.load('/home/jovyan/Sample_Based_Extension/WUSTL/x_test.npy')
x_train = np.load('/home/jovyan/Sample_Based_Extension/WUSTL/x_train.npy')
x_val = np.load('/home/jovyan/Sample_Based_Extension/WUSTL/x_val.npy')
y_test = np.load('/home/jovyan/Sample_Based_Extension/WUSTL/y_test.npy')
y_train = np.load('/home/jovyan/Sample_Based_Extension/WUSTL/y_train.npy')
y_val = np.load('/home/jovyan/Sample_Based_Extension/WUSTL/y_val.npy')

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
input_shape = x_train.shape[1]
output_shape = len(np.unique(y_train))

# %%
x_train_tensor = torch.tensor(x_train, dtype=torch.float32).to(device)
y_train_tensor = torch.tensor(y_train, dtype=torch.long).to(device)

x_val_tensor = torch.tensor(x_val, dtype=torch.float32).to(device)
y_val_tensor = torch.tensor(y_val, dtype=torch.long).to(device)

train_dataset = TensorDataset(x_train_tensor, y_train_tensor)
train_loader = DataLoader(train_dataset, batch_size=100, shuffle=True)

val_dataset = TensorDataset(x_val_tensor, y_val_tensor)
val_loader = DataLoader(val_dataset, batch_size=100, shuffle=True)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

class DNNModel(nn.Module):
    def __init__(self, input_size, output_size):
        super(DNNModel, self).__init__()
        self.fc1 = nn.Linear(input_size, 50)
        self.fc2 = nn.Linear(50, 30)
        self.fc3 = nn.Linear(30, 20)
        self.fc4 = nn.Linear(20, output_size)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = self.fc4(x)
        return x

# %%
# Adversarial training function with interpolation
def interpolated_adversarial_training(model, train_loader, optimizer, epoch, device, eps=0.3, alpha=2/255, iters=40):
    model.train()
    loss_fn = nn.CrossEntropyLoss()

    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        
        # Create adversarial examples
        data_adv = data.clone().detach().requires_grad_(True).to(device)
        outputs = model(data_adv)
        loss = loss_fn(outputs, target)
        loss.backward()
        data_adv = data_adv + alpha * data_adv.grad.sign()
        eta = torch.clamp(data_adv - data, min=-eps, max=eps)
        data_adv = torch.clamp(data + eta, min=0, max=1).detach_()

        # Interpolation
        lam = np.random.beta(1.0, 1.0)
        data_mixed = lam * data + (1 - lam) * data_adv
        target_mixed = lam * target + (1 - lam) * target

        optimizer.zero_grad()
        output = model(data_mixed)
        target_mixed = target_mixed.long()
        
        loss = loss_fn(output, target_mixed)
        loss.backward()
        optimizer.step()

        if batch_idx % 1000 == 0:
            print(f'Train Epoch: {epoch} [{batch_idx * len(data)}/{len(train_loader.dataset)}'
                  f' ({100. * batch_idx / len(train_loader):.0f}%)]\tLoss: {loss.item():.6f}')

# Model initialization
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
input_size = input_shape  # Replace with your input shape
output_size = output_shape  # Replace with your output shape
model = DNNModel(input_size=input_size, output_size=output_size).to(device)

# Compile model
optimizer = optim.Adam(model.parameters(), lr=0.001)
loss_function = nn.CrossEntropyLoss()

# Early stopping variables
min_delta = 0.001
patience = 5
patience_counter = 0
best_loss = float('inf')

# %%
# # Training loop with early stopping and validation evaluation
# for epoch in range(10):
#     interpolated_adversarial_training(model, train_loader, optimizer, epoch, device, eps=0.3, alpha=2/255, iters=40)

#     # Validation
#     model.eval()
#     val_train_loss = 0.0
#     correct_predictions = 0
#     with torch.no_grad():
#         for inputs, labels in val_loader:
#             inputs, labels = inputs.to(device), labels.to(device)
#             outputs = model(inputs)
#             loss = loss_function(outputs, labels)
#             val_train_loss += loss.item()
#             _, predicted = torch.max(outputs.data, 1)
#             correct_predictions += (predicted == labels).sum().item()

#     avg_val_loss = val_train_loss / len(val_loader)
#     val_accuracy = correct_predictions / len(val_dataset)

#     print(f"Epoch {epoch+1}, Validation Loss: {avg_val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}")

#     # Early stopping check using min_delta
#     if best_loss - avg_val_loss > min_delta:
#         best_loss = avg_val_loss
#         patience_counter = 0
#     else:
#         patience_counter += 1

#     if patience_counter >= patience:
#         print("Early stopping triggered")
#         break

# %%
model.load_state_dict(torch.load("/home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Defense/Adversarial_Training/Adversarial_Training_interpolated.pt"))
# Out:
# /tmp/ipykernel_13162/1923152346.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("/home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Defense/Adversarial_Training/Adversarial_Training_interpolated.pt"))
# <All keys matched successfully>

# %%
# calculate_performance_metrics(x_test, y_test, model, 'DNN', 'baseline', '0')

# %%
def print_empty_file():
    new_row = {
        "model" : "0",
        "attack_model" : "0",
        'epsilon': "0",
        'Accuracy': "0",
        'Macro Precision': "0",
        'Weighted Precision': "0",
        'Macro Recall': "0",
        'Weighted Recall': "0",
        'Macro F1': "0",
        'Weighted F1': "0",
    }
    new_row_df = pd.DataFrame([new_row])
    new_row_df.to_csv("./AT_interpolated.csv", mode='a', index=False, header=False)

# %%
epsilon = 0

Def = "Def2"
attack_names = [
    "baseline", "BIM", "FGSM", "PGD", "DF",
    "AutoPGD", "ZOO", "CaFA", "SINIFGSM", "VNIFGSM"
]

percentage = ["100", "50", "20", "10", "1"]
model_name = ["XGB", "RF" ]

base_path = "/home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data"

for m_name in model_name:
    for p in percentage:
        for attack in attack_names:
            print(f"start {m_name} {p} {attack}")
            
            x_path = f"{base_path}/{m_name}/WUSTL_Input{p}/x_test_adv_{attack}_{Def}.npy"
            y_path = f"{base_path}/{m_name}/WUSTL_Input{p}/y_test_adv_{attack}_{Def}.npy"

            try:
                x_test_adv = np.load(x_path)
                y_test_adv = np.load(y_path)
                print(x_test_adv.shape, y_test_adv.shape)

                m_per_name = f"{m_name}{p}"
                calculate_performance_metrics(x_test_adv, y_test_adv, model, m_per_name, attack, epsilon)
            except FileNotFoundError:
                print(x_path, "not found")
                print_empty_file()
# Out:
# start XGB 100 baseline
# (11, 42) (11,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input100/x_test_adv_BIM_Def2.npy not found
# start XGB 100 FGSM
# (1, 42) (1,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 100 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input100/x_test_adv_PGD_Def2.npy not found
# start XGB 100 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input100/x_test_adv_DF_Def2.npy not found
# start XGB 100 AutoPGD
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (3, 42) (3,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 ZOO
# (31, 42) (31,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 CaFA
# (3, 42) (3,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 100 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input100/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 100 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input100/x_test_adv_VNIFGSM_Def2.npy not found
# start XGB 50 baseline
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (8, 42) (8,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input50/x_test_adv_BIM_Def2.npy not found
# start XGB 50 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input50/x_test_adv_FGSM_Def2.npy not found
# start XGB 50 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input50/x_test_adv_PGD_Def2.npy not found
# start XGB 50 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input50/x_test_adv_DF_Def2.npy not found
# start XGB 50 AutoPGD
# (3, 42) (3,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 ZOO
# (22, 42) (22,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 CaFA
# (3, 42) (3,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 50 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input50/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 50 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input50/x_test_adv_VNIFGSM_Def2.npy not found
# start XGB 20 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input20/x_test_adv_baseline_Def2.npy not found
# start XGB 20 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input20/x_test_adv_BIM_Def2.npy not found
# start XGB 20 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input20/x_test_adv_FGSM_Def2.npy not found
# start XGB 20 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input20/x_test_adv_PGD_Def2.npy not found
# start XGB 20 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input20/x_test_adv_DF_Def2.npy not found
# start XGB 20 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input20/x_test_adv_AutoPGD_Def2.npy not found
# start XGB 20 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input20/x_test_adv_ZOO_Def2.npy not found
# start XGB 20 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input20/x_test_adv_CaFA_Def2.npy not found
# start XGB 20 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input20/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 20 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input20/x_test_adv_VNIFGSM_Def2.npy not found
# start XGB 10 baseline
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input10/x_test_adv_baseline_Def2.npy not found
# start XGB 10 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input10/x_test_adv_BIM_Def2.npy not found
# start XGB 10 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input10/x_test_adv_FGSM_Def2.npy not found
# start XGB 10 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input10/x_test_adv_PGD_Def2.npy not found
# start XGB 10 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input10/x_test_adv_DF_Def2.npy not found
# start XGB 10 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input10/x_test_adv_AutoPGD_Def2.npy not found
# start XGB 10 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input10/x_test_adv_ZOO_Def2.npy not found
# start XGB 10 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input10/x_test_adv_CaFA_Def2.npy not found
# start XGB 10 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input10/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 10 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input10/x_test_adv_VNIFGSM_Def2.npy not found
# start XGB 1 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input1/x_test_adv_baseline_Def2.npy not found
# start XGB 1 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input1/x_test_adv_BIM_Def2.npy not found
# start XGB 1 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input1/x_test_adv_FGSM_Def2.npy not found
# start XGB 1 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input1/x_test_adv_PGD_Def2.npy not found
# start XGB 1 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input1/x_test_adv_DF_Def2.npy not found
# start XGB 1 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input1/x_test_adv_AutoPGD_Def2.npy not found
# start XGB 1 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input1/x_test_adv_ZOO_Def2.npy not found
# start XGB 1 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input1/x_test_adv_CaFA_Def2.npy not found
# start XGB 1 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input1/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 1 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB/WUSTL_Input1/x_test_adv_VNIFGSM_Def2.npy not found
# start RF 100 baseline
# (9, 42) (9,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input100/x_test_adv_BIM_Def2.npy not found
# start RF 100 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input100/x_test_adv_FGSM_Def2.npy not found
# start RF 100 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input100/x_test_adv_PGD_Def2.npy not found
# start RF 100 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input100/x_test_adv_DF_Def2.npy not found
# start RF 100 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input100/x_test_adv_AutoPGD_Def2.npy not found
# start RF 100 ZOO
# (27, 42) (27,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input100/x_test_adv_CaFA_Def2.npy not found
# start RF 100 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input100/x_test_adv_SINIFGSM_Def2.npy not found
# start RF 100 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input100/x_test_adv_VNIFGSM_Def2.npy not found
# start RF 50 baseline
# (3, 42) (3,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input50/x_test_adv_BIM_Def2.npy not found
# start RF 50 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input50/x_test_adv_FGSM_Def2.npy not found
# start RF 50 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input50/x_test_adv_PGD_Def2.npy not found
# start RF 50 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input50/x_test_adv_DF_Def2.npy not found
# start RF 50 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input50/x_test_adv_AutoPGD_Def2.npy not found
# start RF 50 ZOO
# (9, 42) (9,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input50/x_test_adv_CaFA_Def2.npy not found
# start RF 50 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input50/x_test_adv_SINIFGSM_Def2.npy not found
# start RF 50 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input50/x_test_adv_VNIFGSM_Def2.npy not found
# start RF 20 baseline
# (1, 42) (1,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input20/x_test_adv_BIM_Def2.npy not found
# start RF 20 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input20/x_test_adv_FGSM_Def2.npy not found
# start RF 20 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input20/x_test_adv_PGD_Def2.npy not found
# start RF 20 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input20/x_test_adv_DF_Def2.npy not found
# start RF 20 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input20/x_test_adv_AutoPGD_Def2.npy not found
# start RF 20 ZOO
# (3, 42) (3,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input20/x_test_adv_CaFA_Def2.npy not found
# start RF 20 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input20/x_test_adv_SINIFGSM_Def2.npy not found
# start RF 20 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input20/x_test_adv_VNIFGSM_Def2.npy not found
# start RF 10 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input10/x_test_adv_baseline_Def2.npy not found
# start RF 10 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input10/x_test_adv_BIM_Def2.npy not found
# start RF 10 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input10/x_test_adv_FGSM_Def2.npy not found
# start RF 10 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input10/x_test_adv_PGD_Def2.npy not found
# start RF 10 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input10/x_test_adv_DF_Def2.npy not found
# start RF 10 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input10/x_test_adv_AutoPGD_Def2.npy not found
# start RF 10 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input10/x_test_adv_ZOO_Def2.npy not found
# start RF 10 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input10/x_test_adv_CaFA_Def2.npy not found
# start RF 10 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input10/x_test_adv_SINIFGSM_Def2.npy not found
# start RF 10 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input10/x_test_adv_VNIFGSM_Def2.npy not found
# start RF 1 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input1/x_test_adv_baseline_Def2.npy not found
# start RF 1 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input1/x_test_adv_BIM_Def2.npy not found
# start RF 1 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input1/x_test_adv_FGSM_Def2.npy not found
# start RF 1 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input1/x_test_adv_PGD_Def2.npy not found
# start RF 1 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input1/x_test_adv_DF_Def2.npy not found
# start RF 1 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input1/x_test_adv_AutoPGD_Def2.npy not found
# start RF 1 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input1/x_test_adv_ZOO_Def2.npy not found
# start RF 1 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input1/x_test_adv_CaFA_Def2.npy not found
# start RF 1 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input1/x_test_adv_SINIFGSM_Def2.npy not found
# start RF 1 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF/WUSTL_Input1/x_test_adv_VNIFGSM_Def2.npy not found

# %%
epsilon = 0

Def = "Def2"
attack_names = [
    "baseline", "BIM", "FGSM", "PGD", "DF",
    "AutoPGD", "ZOO", "CaFA", "SINIFGSM", "VNIFGSM"
]

percentage = ["100", "50", "20", "10", "1"]
model_name = ["XGB", "RF" ]

base_path = "/home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data"

for m_name in model_name:
    for p in percentage:
        for attack in attack_names:
            print(f"start {m_name} {p} {attack}")
            
            x_path = f"{base_path}/{m_name}_ExcludeCaFA/WUSTL_Input{p}/x_test_adv_{attack}_{Def}.npy"
            y_path = f"{base_path}/{m_name}_ExcludeCaFA/WUSTL_Input{p}/y_test_adv_{attack}_{Def}.npy"

            try:
                x_test_adv = np.load(x_path)
                y_test_adv = np.load(y_path)
                print(x_test_adv.shape, y_test_adv.shape)

                m_per_name = f"{m_name}{p}_ExcludeCaFA"
                calculate_performance_metrics(x_test_adv, y_test_adv, model, m_per_name, attack, epsilon)
            except FileNotFoundError:
                print(x_path, "not found")
                print_empty_file()
# Out:
# start XGB 100 baseline
# (11, 42) (11,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input100/x_test_adv_BIM_Def2.npy not found
# start XGB 100 FGSM
# (7, 42) (7,)
# Accuracy: 0.42857142857142855
#
# macro
# Precision: 0.21428571428571427
# Recall: 0.5
# F1 Score: 0.3
#
# weighted
# Precision: 0.18367346938775508
# Recall: 0.42857142857142855
# F1 Score: 0.2571428571428571
#
# start XGB 100 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input100/x_test_adv_PGD_Def2.npy not found
# start XGB 100 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input100/x_test_adv_DF_Def2.npy not found
# start XGB 100 AutoPGD
# (6, 42) (6,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 ZOO
# (36, 42) (36,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 CaFA
# (22835, 42) (22835,)
# Accuracy: 0.023166192248740967
#
# macro
# Precision: 0.10987679817198541
# Recall: 0.3678272805757755
# F1 Score: 0.018952674918273054
#
# weighted
# Precision: 0.5023449324853589
# Recall: 0.023166192248740967
# F1 Score: 0.03291540951018157
#
# start XGB 100 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input100/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 100 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input100/x_test_adv_VNIFGSM_Def2.npy not found
# start XGB 50 baseline
# (12, 42) (12,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input50/x_test_adv_BIM_Def2.npy not found
# start XGB 50 FGSM
# (4, 42) (4,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 50 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input50/x_test_adv_PGD_Def2.npy not found
# start XGB 50 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input50/x_test_adv_DF_Def2.npy not found
# start XGB 50 AutoPGD
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (27, 42) (27,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 ZOO
# (37, 42) (37,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 CaFA
# (29213, 42) (29213,)
# Accuracy: 0.03214322390716462
#
# macro
# Precision: 0.13194627318767843
# Recall: 0.4549384192231229
# F1 Score: 0.020945088844399485
#
# weighted
# Precision: 0.6148223492562359
# Recall: 0.03214322390716462
# F1 Score: 0.05243080617473505
#
# start XGB 50 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input50/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 50 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input50/x_test_adv_VNIFGSM_Def2.npy not found
# start XGB 20 baseline
# (1, 42) (1,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input20/x_test_adv_BIM_Def2.npy not found
# start XGB 20 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input20/x_test_adv_FGSM_Def2.npy not found
# start XGB 20 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input20/x_test_adv_PGD_Def2.npy not found
# start XGB 20 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input20/x_test_adv_DF_Def2.npy not found
# start XGB 20 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input20/x_test_adv_AutoPGD_Def2.npy not found
# start XGB 20 ZOO
# (4, 42) (4,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 CaFA
# (16400, 42) (16400,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.01176829268292683
#
# macro
# Precision: 0.051622757625469716
# Recall: 0.3595301323796306
# F1 Score: 0.010685000889641716
#
# weighted
# Precision: 0.2298848252896917
# Recall: 0.01176829268292683
# F1 Score: 0.015377905105982696
#
# start XGB 20 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input20/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 20 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input20/x_test_adv_VNIFGSM_Def2.npy not found
# start XGB 10 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input10/x_test_adv_baseline_Def2.npy not found
# start XGB 10 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input10/x_test_adv_BIM_Def2.npy not found
# start XGB 10 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input10/x_test_adv_FGSM_Def2.npy not found
# start XGB 10 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input10/x_test_adv_PGD_Def2.npy not found
# start XGB 10 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input10/x_test_adv_DF_Def2.npy not found
# start XGB 10 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input10/x_test_adv_AutoPGD_Def2.npy not found
# start XGB 10 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input10/x_test_adv_ZOO_Def2.npy not found
# start XGB 10 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input10/x_test_adv_CaFA_Def2.npy not found
# start XGB 10 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input10/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 10 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input10/x_test_adv_VNIFGSM_Def2.npy not found
# start XGB 1 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input1/x_test_adv_baseline_Def2.npy not found
# start XGB 1 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input1/x_test_adv_BIM_Def2.npy not found
# start XGB 1 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input1/x_test_adv_FGSM_Def2.npy not found
# start XGB 1 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input1/x_test_adv_PGD_Def2.npy not found
# start XGB 1 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input1/x_test_adv_DF_Def2.npy not found
# start XGB 1 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input1/x_test_adv_AutoPGD_Def2.npy not found
# start XGB 1 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input1/x_test_adv_ZOO_Def2.npy not found
# start XGB 1 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input1/x_test_adv_CaFA_Def2.npy not found
# start XGB 1 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input1/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 1 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ExcludeCaFA/WUSTL_Input1/x_test_adv_VNIFGSM_Def2.npy not found
# start RF 100 baseline
# (10, 42) (10,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input100/x_test_adv_BIM_Def2.npy not found
# start RF 100 FGSM
# (2, 42) (2,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input100/x_test_adv_PGD_Def2.npy not found
# start RF 100 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input100/x_test_adv_DF_Def2.npy not found
# start RF 100 AutoPGD
# (3, 42) (3,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 ZOO
# (33, 42) (33,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 CaFA
# (67, 42) (67,)
# Accuracy: 0.014925373134328358
#
# macro
# Precision: 0.010526315789473684
# Recall: 0.2
# F1 Score: 0.02
#
# weighted
# Precision: 0.0007855459544383346
# Recall: 0.014925373134328358
# F1 Score: 0.0014925373134328358
#
# start RF 100 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input100/x_test_adv_SINIFGSM_Def2.npy not found
# start RF 100 VNIFGSM
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (2, 42) (2,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 baseline
# (5, 42) (5,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input50/x_test_adv_BIM_Def2.npy not found
# start RF 50 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input50/x_test_adv_FGSM_Def2.npy not found
# start RF 50 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input50/x_test_adv_PGD_Def2.npy not found
# start RF 50 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input50/x_test_adv_DF_Def2.npy not found
# start RF 50 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input50/x_test_adv_AutoPGD_Def2.npy not found
# start RF 50 ZOO
# (15, 42) (15,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input50/x_test_adv_CaFA_Def2.npy not found
# start RF 50 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input50/x_test_adv_SINIFGSM_Def2.npy not found
# start RF 50 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input50/x_test_adv_VNIFGSM_Def2.npy not found
# start RF 20 baseline
# (1, 42) (1,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input20/x_test_adv_BIM_Def2.npy not found
# start RF 20 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input20/x_test_adv_FGSM_Def2.npy not found
# start RF 20 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input20/x_test_adv_PGD_Def2.npy not found
# start RF 20 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input20/x_test_adv_DF_Def2.npy not found
# start RF 20 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input20/x_test_adv_AutoPGD_Def2.npy not found
# start RF 20 ZOO
# (3, 42) (3,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input20/x_test_adv_CaFA_Def2.npy not found
# start RF 20 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input20/x_test_adv_SINIFGSM_Def2.npy not found
# start RF 20 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input20/x_test_adv_VNIFGSM_Def2.npy not found
# start RF 10 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input10/x_test_adv_baseline_Def2.npy not found
# start RF 10 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input10/x_test_adv_BIM_Def2.npy not found
# start RF 10 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input10/x_test_adv_FGSM_Def2.npy not found
# start RF 10 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input10/x_test_adv_PGD_Def2.npy not found
# start RF 10 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input10/x_test_adv_DF_Def2.npy not found
# start RF 10 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input10/x_test_adv_AutoPGD_Def2.npy not found
# start RF 10 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input10/x_test_adv_ZOO_Def2.npy not found
# start RF 10 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input10/x_test_adv_CaFA_Def2.npy not found
# start RF 10 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input10/x_test_adv_SINIFGSM_Def2.npy not found
# start RF 10 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input10/x_test_adv_VNIFGSM_Def2.npy not found
# start RF 1 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input1/x_test_adv_baseline_Def2.npy not found
# start RF 1 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input1/x_test_adv_BIM_Def2.npy not found
# start RF 1 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input1/x_test_adv_FGSM_Def2.npy not found
# start RF 1 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input1/x_test_adv_PGD_Def2.npy not found
# start RF 1 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input1/x_test_adv_DF_Def2.npy not found
# start RF 1 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input1/x_test_adv_AutoPGD_Def2.npy not found
# start RF 1 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input1/x_test_adv_ZOO_Def2.npy not found
# start RF 1 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input1/x_test_adv_CaFA_Def2.npy not found
# start RF 1 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input1/x_test_adv_SINIFGSM_Def2.npy not found
# start RF 1 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ExcludeCaFA/WUSTL_Input1/x_test_adv_VNIFGSM_Def2.npy not found

# %%
epsilon = 0

Def = "Def2"
attack_names = [
    "baseline", "BIM", "FGSM", "PGD", "DF",
    "AutoPGD", "ZOO", "CaFA", "SINIFGSM", "VNIFGSM"
]

percentage = ["100", "50", "20", "10", "1"]
model_name = ["XGB", "RF" ]

base_path = "/home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data"

total_num_attack = ["2", "3"]
for num_attack in total_num_attack:
    for m_name in model_name:
        for p in percentage:
            for attack in attack_names:
                print(f"start {m_name} {p} {attack}")
                
                x_path = f"{base_path}/{m_name}_Exclude{num_attack}Attack/WUSTL_Input{p}/x_test_adv_{attack}_{Def}.npy"
                y_path = f"{base_path}/{m_name}_Exclude{num_attack}Attack/WUSTL_Input{p}/y_test_adv_{attack}_{Def}.npy"
    
                try:
                    x_test_adv = np.load(x_path)
                    y_test_adv = np.load(y_path)
                    print(x_test_adv.shape, y_test_adv.shape)
    
                    m_per_name = f"{m_name}{p}_Exclude{num_attack}Attack"
                    calculate_performance_metrics(x_test_adv, y_test_adv, model, m_per_name, attack, epsilon)
                except FileNotFoundError:
                    print(x_path, "not found")
                    print_empty_file()
# Out:
# start XGB 100 baseline
# (5, 42) (5,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input100/x_test_adv_BIM_Def2.npy not found
# start XGB 100 FGSM
# (4, 42) (4,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 100 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input100/x_test_adv_PGD_Def2.npy not found
# start XGB 100 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input100/x_test_adv_DF_Def2.npy not found
# start XGB 100 AutoPGD
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (3, 42) (3,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 ZOO
# (15, 42) (15,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 CaFA
# (11224, 42) (11224,)
# Accuracy: 0.11662508909479687
#
# macro
# Precision: 0.17629846865285043
# Recall: 0.33974192247593127
# F1 Score: 0.05227261151740008
#
# weighted
# Precision: 0.8238162015865321
# Recall: 0.11662508909479687
# F1 Score: 0.1968757036818455
#
# start XGB 100 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input100/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 100 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input100/x_test_adv_VNIFGSM_Def2.npy not found
# start XGB 50 baseline
# (7, 42) (7,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 BIM
# (34, 42) (34,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 FGSM
# (46, 42) (46,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 PGD
# (34, 42) (34,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input50/x_test_adv_DF_Def2.npy not found
# start XGB 50 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input50/x_test_adv_AutoPGD_Def2.npy not found
# start XGB 50 ZOO
# (25, 42) (25,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 CaFA
# (13274, 42) (13274,)
# Accuracy: 0.0688564110290794
#
# macro
# Precision: 0.187849225791719
# Recall: 0.2595829535095716
# F1 Score: 0.028368803863568763
#
# weighted
# Precision: 0.9243386892914595
# Recall: 0.0688564110290794
# F1 Score: 0.12705268035721085
#
# start XGB 50 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input50/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 50 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input50/x_test_adv_VNIFGSM_Def2.npy not found
# start XGB 20 baseline
# (9, 42) (9,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input20/x_test_adv_BIM_Def2.npy not found
# start XGB 20 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input20/x_test_adv_FGSM_Def2.npy not found
# start XGB 20 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input20/x_test_adv_PGD_Def2.npy not found
# start XGB 20 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input20/x_test_adv_DF_Def2.npy not found
# start XGB 20 AutoPGD
# (1, 42) (1,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 ZOO
# (28, 42) (28,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 CaFA
# (6038, 42) (6038,)
# Accuracy: 0.1187479297780722
#
# macro
# Precision: 0.16799071011261196
# Recall: 0.3707153220899574
# F1 Score: 0.052422151506697504
#
# weighted
# Precision: 0.7815161513872202
# Recall: 0.1187479297780722
# F1 Score: 0.19860513211629047
#
# start XGB 20 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input20/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 20 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input20/x_test_adv_VNIFGSM_Def2.npy not found
# start XGB 10 baseline
# (3, 42) (3,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 10 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input10/x_test_adv_BIM_Def2.npy not found
# start XGB 10 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input10/x_test_adv_FGSM_Def2.npy not found
# start XGB 10 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input10/x_test_adv_PGD_Def2.npy not found
# start XGB 10 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input10/x_test_adv_DF_Def2.npy not found
# start XGB 10 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input10/x_test_adv_AutoPGD_Def2.npy not found
# start XGB 10 ZOO
# (9, 42) (9,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 10 CaFA
# (102, 42) (102,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.029411764705882353
#
# macro
# Precision: 0.08259803921568627
# Recall: 0.4020408163265306
# F1 Score: 0.034345883567948626
#
# weighted
# Precision: 0.32104238754325254
# Recall: 0.029411764705882353
# F1 Score: 0.020514916637722196
#
# start XGB 10 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input10/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 10 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input10/x_test_adv_VNIFGSM_Def2.npy not found
# start XGB 1 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input1/x_test_adv_baseline_Def2.npy not found
# start XGB 1 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input1/x_test_adv_BIM_Def2.npy not found
# start XGB 1 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input1/x_test_adv_FGSM_Def2.npy not found
# start XGB 1 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input1/x_test_adv_PGD_Def2.npy not found
# start XGB 1 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input1/x_test_adv_DF_Def2.npy not found
# start XGB 1 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input1/x_test_adv_AutoPGD_Def2.npy not found
# start XGB 1 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input1/x_test_adv_ZOO_Def2.npy not found
# start XGB 1 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input1/x_test_adv_CaFA_Def2.npy not found
# start XGB 1 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input1/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 1 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude2Attack/WUSTL_Input1/x_test_adv_VNIFGSM_Def2.npy not found
# start RF 100 baseline
# (10, 42) (10,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 BIM
# (1084, 42) (1084,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 FGSM
# (686, 42) (686,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 PGD
# (1084, 42) (1084,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input100/x_test_adv_DF_Def2.npy not found
# start RF 100 AutoPGD
# (217, 42) (217,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 ZOO
# (32, 42) (32,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input100/x_test_adv_CaFA_Def2.npy not found
# start RF 100 SINIFGSM
# (18967, 42) (18967,)
# Accuracy: 0.9999472768492645
#
# macro
# Precision: 0.9951690821256038
# Recall: 0.8333333333333334
# F1 Score: 0.8864557988645579
#
# weighted
# Precision: 0.9999480409528984
# Recall: 0.9999472768492645
# F1 Score: 0.9999386820777334
#
# start RF 100 VNIFGSM
# (31360, 42) (31360,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 baseline
# (5, 42) (5,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 BIM
# (217690, 42) (217690,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.999986218935183
#
# macro
# Precision: 0.75
# Recall: 0.7492652207942
# F1 Score: 0.74963232772646
#
# weighted
# Precision: 1.0
# Recall: 0.999986218935183
# F1 Score: 0.9999931040370615
#
# start RF 50 FGSM
# (216228, 42) (216228,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.9999953752520487
#
# macro
# Precision: 0.75
# Recall: 0.74951171875
# F1 Score: 0.7497556207233627
#
# weighted
# Precision: 1.0
# Recall: 0.9999953752520487
# F1 Score: 0.9999976853656393
#
# start RF 50 PGD
# (217690, 42) (217690,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.999986218935183
#
# macro
# Precision: 0.75
# Recall: 0.7492652207942
# F1 Score: 0.74963232772646
#
# weighted
# Precision: 1.0
# Recall: 0.999986218935183
# F1 Score: 0.9999931040370615
#
# start RF 50 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input50/x_test_adv_DF_Def2.npy not found
# start RF 50 AutoPGD
# (223, 42) (223,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.9910313901345291
#
# macro
# Precision: 0.75
# Recall: 0.7282608695652174
# F1 Score: 0.7386363636363636
#
# weighted
# Precision: 1.0
# Recall: 0.9910313901345291
# F1 Score: 0.9953118630248674
#
# start RF 50 ZOO
# (18, 42) (18,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input50/x_test_adv_CaFA_Def2.npy not found
# start RF 50 SINIFGSM
# (217253, 42) (217253,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.9999769853580848
#
# macro
# Precision: 0.7485763097949886
# Recall: 0.75
# F1 Score: 0.7492861222158766
#
# weighted
# Precision: 0.9999541017790506
# Recall: 0.9999769853580848
# F1 Score: 0.9999655108964104
#
# start RF 50 VNIFGSM
# (193099, 42) (193099,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.9999948213092766
#
# macro
# Precision: 0.75
# Recall: 0.749743062692703
# F1 Score: 0.7498714652956298
#
# weighted
# Precision: 1.0
# Recall: 0.9999948213092766
# F1 Score: 0.9999974093233552
#
# start RF 20 baseline
# (2, 42) (2,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 BIM
# (32, 42) (32,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 FGSM
# (43, 42) (43,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 PGD
# (32, 42) (32,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input20/x_test_adv_DF_Def2.npy not found
# start RF 20 AutoPGD
# (8, 42) (8,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 ZOO
# (6, 42) (6,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input20/x_test_adv_CaFA_Def2.npy not found
# start RF 20 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input20/x_test_adv_SINIFGSM_Def2.npy not found
# start RF 20 VNIFGSM
# (3, 42) (3,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 10 baseline
# (1, 42) (1,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 10 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input10/x_test_adv_BIM_Def2.npy not found
# start RF 10 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input10/x_test_adv_FGSM_Def2.npy not found
# start RF 10 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input10/x_test_adv_PGD_Def2.npy not found
# start RF 10 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input10/x_test_adv_DF_Def2.npy not found
# start RF 10 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input10/x_test_adv_AutoPGD_Def2.npy not found
# start RF 10 ZOO
# (3, 42) (3,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 10 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input10/x_test_adv_CaFA_Def2.npy not found
# start RF 10 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input10/x_test_adv_SINIFGSM_Def2.npy not found
# start RF 10 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input10/x_test_adv_VNIFGSM_Def2.npy not found
# start RF 1 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input1/x_test_adv_baseline_Def2.npy not found
# start RF 1 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input1/x_test_adv_BIM_Def2.npy not found
# start RF 1 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input1/x_test_adv_FGSM_Def2.npy not found
# start RF 1 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input1/x_test_adv_PGD_Def2.npy not found
# start RF 1 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input1/x_test_adv_DF_Def2.npy not found
# start RF 1 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input1/x_test_adv_AutoPGD_Def2.npy not found
# start RF 1 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input1/x_test_adv_ZOO_Def2.npy not found
# start RF 1 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input1/x_test_adv_CaFA_Def2.npy not found
# start RF 1 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input1/x_test_adv_SINIFGSM_Def2.npy not found
# start RF 1 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude2Attack/WUSTL_Input1/x_test_adv_VNIFGSM_Def2.npy not found
# start XGB 100 baseline
# (9, 42) (9,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 BIM
# (2, 42) (2,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 FGSM
# (44, 42) (44,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 PGD
# (2, 42) (2,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 DF
# (9, 42) (9,)
# Accuracy: 0.6666666666666666
#
# macro
# Precision: 0.3333333333333333
# Recall: 0.3333333333333333
# F1 Score: 0.3333333333333333
#
# weighted
# Precision: 0.6666666666666666
# Recall: 0.6666666666666666
# F1 Score: 0.6666666666666666
#
# start XGB 100 AutoPGD
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (7, 42) (7,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 ZOO
# (34, 42) (34,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 CaFA
# (94107, 42) (94107,)
# Accuracy: 0.02803192111107569
#
# macro
# Precision: 0.13447441996617066
# Recall: 0.2217271418548555
# F1 Score: 0.014419624004808753
#
# weighted
# Precision: 0.6516883164385199
# Recall: 0.02803192111107569
# F1 Score: 0.05345029764422595
#
# start XGB 100 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input100/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 100 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input100/x_test_adv_VNIFGSM_Def2.npy not found
# start XGB 50 baseline
# (13, 42) (13,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 BIM
# (12, 42) (12,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 FGSM
# (66, 42) (66,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 PGD
# (12, 42) (12,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 DF
# (61, 42) (61,)
# Accuracy: 0.11475409836065574
#
# macro
# Precision: 0.10606060606060606
# Recall: 0.050724637681159424
# F1 Score: 0.06862745098039215
#
# weighted
# Precision: 0.2399403874813711
# Recall: 0.11475409836065574
# F1 Score: 0.1552555448408872
#
# start XGB 50 AutoPGD
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (13, 42) (13,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 ZOO
# (43, 42) (43,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 CaFA
# (130464, 42) (130464,)
# Accuracy: 0.06834069168506254
#
# macro
# Precision: 0.16241996010996482
# Recall: 0.16200721161435075
# F1 Score: 0.029631654160613384
#
# weighted
# Precision: 0.7842355591869371
# Recall: 0.06834069168506254
# F1 Score: 0.12531278099541002
#
# start XGB 50 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input50/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 50 VNIFGSM
# (4, 42) (4,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 baseline
# (7, 42) (7,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 BIM
# (3, 42) (3,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 FGSM
# (10, 42) (10,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 PGD
# (3, 42) (3,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 DF
# (9, 42) (9,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 20 AutoPGD
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (76, 42) (76,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 ZOO
# (21, 42) (21,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 CaFA
# (99770, 42) (99770,)
# Accuracy: 0.045584845143830814
#
# macro
# Precision: 0.16026736509473824
# Recall: 0.20428197121051092
# F1 Score: 0.03623454192656829
#
# weighted
# Precision: 0.7197261392884405
# Recall: 0.045584845143830814
# F1 Score: 0.08496630053909994
#
# start XGB 20 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input20/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 20 VNIFGSM
# (2, 42) (2,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 10 baseline
# (1, 42) (1,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 10 BIM
# (10, 42) (10,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 10 FGSM
# (4, 42) (4,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 10 PGD
# (10, 42) (10,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 10 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input10/x_test_adv_DF_Def2.npy not found
# start XGB 10 AutoPGD
# (46, 42) (46,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 10 ZOO
# (3, 42) (3,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 10 CaFA
# (32399, 42) (32399,)
# Accuracy: 0.08660761134602919
#
# macro
# Precision: 0.2080041900452536
# Recall: 0.23164013242613413
# F1 Score: 0.0629089745970377
#
# weighted
# Precision: 0.8948962606067868
# Recall: 0.08660761134602919
# F1 Score: 0.15732182753673704
#
# start XGB 10 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input10/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 10 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input10/x_test_adv_VNIFGSM_Def2.npy not found
# start XGB 1 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input1/x_test_adv_baseline_Def2.npy not found
# start XGB 1 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input1/x_test_adv_BIM_Def2.npy not found
# start XGB 1 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input1/x_test_adv_FGSM_Def2.npy not found
# start XGB 1 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input1/x_test_adv_PGD_Def2.npy not found
# start XGB 1 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input1/x_test_adv_DF_Def2.npy not found
# start XGB 1 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input1/x_test_adv_AutoPGD_Def2.npy not found
# start XGB 1 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input1/x_test_adv_ZOO_Def2.npy not found
# start XGB 1 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input1/x_test_adv_CaFA_Def2.npy not found
# start XGB 1 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input1/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 1 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Exclude3Attack/WUSTL_Input1/x_test_adv_VNIFGSM_Def2.npy not found
# start RF 100 baseline
# (10, 42) (10,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 BIM
# (233721, 42) (233721,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.9999871641829361
#
# macro
# Precision: 0.75
# Recall: 0.7497306246794958
# F1 Score: 0.7498652566198519
#
# weighted
# Precision: 1.0
# Recall: 0.9999871641829361
# F1 Score: 0.9999935807836877
#
# start RF 100 FGSM
# (231031, 42) (231031,)
# Accuracy: 0.9999956715765417
#
# macro
# Precision: 0.875
# Recall: 0.9999786105407256
# F1 Score: 0.9166559714795008
#
# weighted
# Precision: 0.9999978357882708
# Recall: 0.9999956715765417
# F1 Score: 0.9999963928878648
#
# start RF 100 PGD
# (233721, 42) (233721,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.9999871641829361
#
# macro
# Precision: 0.75
# Recall: 0.7497306246794958
# F1 Score: 0.7498652566198519
#
# weighted
# Precision: 1.0
# Recall: 0.9999871641829361
# F1 Score: 0.9999935807836877
#
# start RF 100 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input100/x_test_adv_DF_Def2.npy not found
# start RF 100 AutoPGD
# (9974, 42) (9974,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.9997994786444756
#
# macro
# Precision: 0.8
# Recall: 0.7981566820276498
# F1 Score: 0.799074074074074
#
# weighted
# Precision: 1.0
# Recall: 0.9997994786444756
# F1 Score: 0.9998992751524334
#
# start RF 100 ZOO
# (36, 42) (36,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 CaFA
# (20, 42) (20,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start RF 100 SINIFGSM
# (219449, 42) (219449,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 VNIFGSM
# (227910, 42) (227910,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 baseline
# (4, 42) (4,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 BIM
# (3867, 42) (3867,)
# Accuracy: 0.9994828032066201
#
# macro
# Precision: 0.9285714285714286
# Recall: 0.999630027117884
# F1 Score: 0.9581482693626497
#
# weighted
# Precision: 0.9996305737190143
# Recall: 0.9994828032066201
# F1 Score: 0.9995258072249095
#
# start RF 50 FGSM
# (138603, 42) (138603,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 PGD
# (3867, 42) (3867,)
# Accuracy: 0.9994828032066201
#
# macro
# Precision: 0.9285714285714286
# Recall: 0.999630027117884
# F1 Score: 0.9581482693626497
#
# weighted
# Precision: 0.9996305737190143
# Recall: 0.9994828032066201
# F1 Score: 0.9995258072249095
#
# start RF 50 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input50/x_test_adv_DF_Def2.npy not found
# start RF 50 AutoPGD
# (1233, 42) (1233,)
# Accuracy: 0.9991889699918897
#
# macro
# Precision: 0.9166666666666666
# Recall: 0.9983552631578947
# F1 Score: 0.9491749174917492
#
# weighted
# Precision: 0.9994593133279264
# Recall: 0.9991889699918897
# F1 Score: 0.9992687346593541
#
# start RF 50 ZOO
# (15, 42) (15,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input50/x_test_adv_CaFA_Def2.npy not found
# start RF 50 SINIFGSM
# (11475, 42) (11475,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 VNIFGSM
# (144475, 42) (144475,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 baseline
# (4, 42) (4,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input20/x_test_adv_BIM_Def2.npy not found
# start RF 20 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input20/x_test_adv_FGSM_Def2.npy not found
# start RF 20 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input20/x_test_adv_PGD_Def2.npy not found
# start RF 20 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input20/x_test_adv_DF_Def2.npy not found
# start RF 20 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input20/x_test_adv_AutoPGD_Def2.npy not found
# start RF 20 ZOO
# (12, 42) (12,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input20/x_test_adv_CaFA_Def2.npy not found
# start RF 20 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input20/x_test_adv_SINIFGSM_Def2.npy not found
# start RF 20 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input20/x_test_adv_VNIFGSM_Def2.npy not found
# start RF 10 baseline
# (1, 42) (1,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 10 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input10/x_test_adv_BIM_Def2.npy not found
# start RF 10 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input10/x_test_adv_FGSM_Def2.npy not found
# start RF 10 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input10/x_test_adv_PGD_Def2.npy not found
# start RF 10 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input10/x_test_adv_DF_Def2.npy not found
# start RF 10 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input10/x_test_adv_AutoPGD_Def2.npy not found
# start RF 10 ZOO
# (3, 42) (3,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 10 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input10/x_test_adv_CaFA_Def2.npy not found
# start RF 10 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input10/x_test_adv_SINIFGSM_Def2.npy not found
# start RF 10 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input10/x_test_adv_VNIFGSM_Def2.npy not found
# start RF 1 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input1/x_test_adv_baseline_Def2.npy not found
# start RF 1 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input1/x_test_adv_BIM_Def2.npy not found
# start RF 1 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input1/x_test_adv_FGSM_Def2.npy not found
# start RF 1 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input1/x_test_adv_PGD_Def2.npy not found
# start RF 1 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input1/x_test_adv_DF_Def2.npy not found
# start RF 1 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input1/x_test_adv_AutoPGD_Def2.npy not found
# start RF 1 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input1/x_test_adv_ZOO_Def2.npy not found
# start RF 1 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input1/x_test_adv_CaFA_Def2.npy not found
# start RF 1 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input1/x_test_adv_SINIFGSM_Def2.npy not found
# start RF 1 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Exclude3Attack/WUSTL_Input1/x_test_adv_VNIFGSM_Def2.npy not found

# %%
epsilon = 0

Def = "Def2"
attack_names = [
    "baseline", "BIM", "FGSM", "PGD", "DF",
    "AutoPGD", "ZOO", "CaFA", "SINIFGSM", "VNIFGSM"
]

base_path = "/home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data"

rec_list = ["Euclidean", "cosine", "manhattan"]
for rec in rec_list:
    for attack in attack_names:
        print(f"start {attack}")
        
        x_path = f"{base_path}/Recommendation_{rec}/x_test_adv_{attack}_{Def}.npy"
        y_path = f"{base_path}/Recommendation_{rec}/y_test_adv_{attack}_{Def}.npy"
    
        try:
            x_test_adv = np.load(x_path)
            y_test_adv = np.load(y_path)
            m_per_name = f"Recommendation_{rec}"
            calculate_performance_metrics(x_test_adv, y_test_adv, model, m_per_name, attack, epsilon)
        except FileNotFoundError:
            print(x_path, "not found")
            print_empty_file()
# Out:
# start baseline
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start BIM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start FGSM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start PGD
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/Recommendation_Euclidean/x_test_adv_DF_Def2.npy not found
# start AutoPGD
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start ZOO
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start CaFA
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.7142857142857143
#
# macro
# Precision: 0.6666666666666666
# Recall: 0.625
# F1 Score: 0.6166666666666667
#
# weighted
# Precision: 0.9047619047619048
# Recall: 0.7142857142857143
# F1 Score: 0.7523809523809524
#
# start SINIFGSM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start VNIFGSM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start baseline
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start BIM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start FGSM
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.8666666666666667
#
# macro
# Precision: 0.627906976744186
# Recall: 0.38095238095238093
# F1 Score: 0.39609053497942387
#
# weighted
# Precision: 0.9018087855297158
# Recall: 0.8666666666666667
# F1 Score: 0.8312071330589847
#
# start PGD
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/Recommendation_cosine/x_test_adv_DF_Def2.npy not found
# start AutoPGD
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start ZOO
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start CaFA
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.3333333333333333
#
# macro
# Precision: 0.35
# Recall: 0.41666666666666663
# F1 Score: 0.375
#
# weighted
# Precision: 0.24444444444444446
# Recall: 0.3333333333333333
# F1 Score: 0.2777777777777778
#
# start SINIFGSM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start VNIFGSM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start baseline
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start BIM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start FGSM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start PGD
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/Recommendation_manhattan/x_test_adv_DF_Def2.npy not found
# start AutoPGD
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start ZOO
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start CaFA
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.4
#
# macro
# Precision: 0.4583333333333333
# Recall: 0.4464285714285714
# F1 Score: 0.3611111111111111
#
# weighted
# Precision: 0.8333333333333334
# Recall: 0.4
# F1 Score: 0.4611111111111111
#
# start SINIFGSM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start VNIFGSM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0

# %%
epsilon = 0

Def = "Def2"
attack_names = [
    "baseline", "BIM", "FGSM", "PGD", "DF",
    "AutoPGD", "ZOO", "CaFA", "SINIFGSM", "VNIFGSM"
]

percentage = ["100", "50", "20", "10", "1"]
model_name = ["XGB", "RF" ]

base_path = "/home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data"

for m_name in model_name:
    for p in percentage:
        for attack in attack_names:
            print(f"start {m_name} {p} {attack}")
            
            x_path = f"{base_path}/{m_name}_Cluster/WUSTL_Input{p}/x_test_adv_{attack}_{Def}.npy"
            y_path = f"{base_path}/{m_name}_Cluster/WUSTL_Input{p}/y_test_adv_{attack}_{Def}.npy"

            try:
                x_test_adv = np.load(x_path)
                y_test_adv = np.load(y_path)
                print(x_test_adv.shape, y_test_adv.shape)

                m_per_name = f"{m_name}{p}_Cluster"
                calculate_performance_metrics(x_test_adv, y_test_adv, model, m_per_name, attack, epsilon)
            except FileNotFoundError:
                print(x_path, "not found")
                print_empty_file()
# Out:
# start XGB 100 baseline
# (11, 42) (11,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input100/x_test_adv_BIM_Def2.npy not found
# start XGB 100 FGSM
# (1, 42) (1,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 100 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input100/x_test_adv_PGD_Def2.npy not found
# start XGB 100 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input100/x_test_adv_DF_Def2.npy not found
# start XGB 100 AutoPGD
# (3, 42) (3,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 ZOO
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (31, 42) (31,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 CaFA
# (3, 42) (3,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 100 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input100/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 100 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input100/x_test_adv_VNIFGSM_Def2.npy not found
# start XGB 50 baseline
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (17, 42) (17,)
# Accuracy: 0.7058823529411765
#
# macro
# Precision: 0.35294117647058826
# Recall: 0.5
# F1 Score: 0.41379310344827586
#
# weighted
# Precision: 0.49826989619377166
# Recall: 0.7058823529411765
# F1 Score: 0.5841784989858012
#
# start XGB 50 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input50/x_test_adv_BIM_Def2.npy not found
# start XGB 50 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input50/x_test_adv_FGSM_Def2.npy not found
# start XGB 50 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input50/x_test_adv_PGD_Def2.npy not found
# start XGB 50 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input50/x_test_adv_DF_Def2.npy not found
# start XGB 50 AutoPGD
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (15, 42) (15,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 50 ZOO
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (42, 42) (42,)
# Accuracy: 0.6428571428571429
#
# macro
# Precision: 0.32142857142857145
# Recall: 0.5
# F1 Score: 0.391304347826087
#
# weighted
# Precision: 0.413265306122449
# Recall: 0.6428571428571429
# F1 Score: 0.5031055900621118
#
# start XGB 50 CaFA
# (3, 42) (3,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.3333333333333333
#
# macro
# Precision: 0.5
# Recall: 0.16666666666666666
# F1 Score: 0.25
#
# weighted
# Precision: 1.0
# Recall: 0.3333333333333333
# F1 Score: 0.5
#
# start XGB 50 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input50/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 50 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input50/x_test_adv_VNIFGSM_Def2.npy not found
# start XGB 20 baseline
# (343, 42) (343,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input20/x_test_adv_BIM_Def2.npy not found
# start XGB 20 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input20/x_test_adv_FGSM_Def2.npy not found
# start XGB 20 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input20/x_test_adv_PGD_Def2.npy not found
# start XGB 20 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input20/x_test_adv_DF_Def2.npy not found
# start XGB 20 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input20/x_test_adv_AutoPGD_Def2.npy not found
# start XGB 20 ZOO
# (1026, 42) (1026,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 CaFA
# (668, 42) (668,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.5224550898203593
#
# macro
# Precision: 0.24102209944751382
# Recall: 0.13569206842923795
# F1 Score: 0.1736318407960199
#
# weighted
# Precision: 0.928007245178152
# Recall: 0.5224550898203593
# F1 Score: 0.6685345726457532
#
# start XGB 20 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input20/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 20 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input20/x_test_adv_VNIFGSM_Def2.npy not found
# start XGB 10 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input10/x_test_adv_baseline_Def2.npy not found
# start XGB 10 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input10/x_test_adv_BIM_Def2.npy not found
# start XGB 10 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input10/x_test_adv_FGSM_Def2.npy not found
# start XGB 10 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input10/x_test_adv_PGD_Def2.npy not found
# start XGB 10 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input10/x_test_adv_DF_Def2.npy not found
# start XGB 10 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input10/x_test_adv_AutoPGD_Def2.npy not found
# start XGB 10 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input10/x_test_adv_ZOO_Def2.npy not found
# start XGB 10 CaFA
# (182, 42) (182,)
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.2032967032967033
#
# macro
# Precision: 0.5
# Recall: 0.10164835164835165
# F1 Score: 0.1689497716894977
#
# weighted
# Precision: 1.0
# Recall: 0.2032967032967033
# F1 Score: 0.3378995433789954
#
# start XGB 10 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input10/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 10 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input10/x_test_adv_VNIFGSM_Def2.npy not found
# start XGB 1 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input1/x_test_adv_baseline_Def2.npy not found
# start XGB 1 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input1/x_test_adv_BIM_Def2.npy not found
# start XGB 1 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input1/x_test_adv_FGSM_Def2.npy not found
# start XGB 1 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input1/x_test_adv_PGD_Def2.npy not found
# start XGB 1 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input1/x_test_adv_DF_Def2.npy not found
# start XGB 1 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input1/x_test_adv_AutoPGD_Def2.npy not found
# start XGB 1 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input1/x_test_adv_ZOO_Def2.npy not found
# start XGB 1 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input1/x_test_adv_CaFA_Def2.npy not found
# start XGB 1 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input1/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 1 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_Cluster/WUSTL_Input1/x_test_adv_VNIFGSM_Def2.npy not found
# start RF 100 baseline
# (9, 42) (9,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input100/x_test_adv_BIM_Def2.npy not found
# start RF 100 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input100/x_test_adv_FGSM_Def2.npy not found
# start RF 100 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input100/x_test_adv_PGD_Def2.npy not found
# start RF 100 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input100/x_test_adv_DF_Def2.npy not found
# start RF 100 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input100/x_test_adv_AutoPGD_Def2.npy not found
# start RF 100 ZOO
# (27, 42) (27,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input100/x_test_adv_CaFA_Def2.npy not found
# start RF 100 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input100/x_test_adv_SINIFGSM_Def2.npy not found
# start RF 100 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input100/x_test_adv_VNIFGSM_Def2.npy not found
# start RF 50 baseline
# (11, 42) (11,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input50/x_test_adv_BIM_Def2.npy not found
# start RF 50 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input50/x_test_adv_FGSM_Def2.npy not found
# start RF 50 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input50/x_test_adv_PGD_Def2.npy not found
# start RF 50 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input50/x_test_adv_DF_Def2.npy not found
# start RF 50 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input50/x_test_adv_AutoPGD_Def2.npy not found
# start RF 50 ZOO
# (30, 42) (30,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input50/x_test_adv_CaFA_Def2.npy not found
# start RF 50 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input50/x_test_adv_SINIFGSM_Def2.npy not found
# start RF 50 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input50/x_test_adv_VNIFGSM_Def2.npy not found
# start RF 20 baseline
# (78, 42) (78,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input20/x_test_adv_BIM_Def2.npy not found
# start RF 20 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input20/x_test_adv_FGSM_Def2.npy not found
# start RF 20 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input20/x_test_adv_PGD_Def2.npy not found
# start RF 20 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input20/x_test_adv_DF_Def2.npy not found
# start RF 20 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input20/x_test_adv_AutoPGD_Def2.npy not found
# start RF 20 ZOO
# (231, 42) (231,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input20/x_test_adv_CaFA_Def2.npy not found
# start RF 20 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input20/x_test_adv_SINIFGSM_Def2.npy not found
# start RF 20 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input20/x_test_adv_VNIFGSM_Def2.npy not found
# start RF 10 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input10/x_test_adv_baseline_Def2.npy not found
# start RF 10 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input10/x_test_adv_BIM_Def2.npy not found
# start RF 10 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input10/x_test_adv_FGSM_Def2.npy not found
# start RF 10 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input10/x_test_adv_PGD_Def2.npy not found
# start RF 10 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input10/x_test_adv_DF_Def2.npy not found
# start RF 10 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input10/x_test_adv_AutoPGD_Def2.npy not found
# start RF 10 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input10/x_test_adv_ZOO_Def2.npy not found
# start RF 10 CaFA
# (48, 42) (48,)
# Accuracy: 0.5625
#
# macro
# Precision: 0.5
# Recall: 0.28125
# F1 Score: 0.36
#
# weighted
# Precision: 1.0
# Recall: 0.5625
# F1 Score: 0.7200000000000001
#
# start RF 10 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input10/x_test_adv_SINIFGSM_Def2.npy not found
# start RF 10 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input10/x_test_adv_VNIFGSM_Def2.npy not found
# start RF 1 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input1/x_test_adv_baseline_Def2.npy not found
# start RF 1 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input1/x_test_adv_BIM_Def2.npy not found
# start RF 1 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input1/x_test_adv_FGSM_Def2.npy not found
# start RF 1 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input1/x_test_adv_PGD_Def2.npy not found
# start RF 1 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input1/x_test_adv_DF_Def2.npy not found
# start RF 1 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input1/x_test_adv_AutoPGD_Def2.npy not found
# start RF 1 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input1/x_test_adv_ZOO_Def2.npy not found
# start RF 1 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input1/x_test_adv_CaFA_Def2.npy not found
# start RF 1 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input1/x_test_adv_SINIFGSM_Def2.npy not found
# start RF 1 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_Cluster/WUSTL_Input1/x_test_adv_VNIFGSM_Def2.npy not found
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
epsilon = 0

Def = "Def2"
attack_names = [
    "baseline", "BIM", "FGSM", "PGD", "DF",
    "AutoPGD", "ZOO", "CaFA", "SINIFGSM", "VNIFGSM"
]

percentage = ["100", "50", "20", "10", "1"]
model_name = ["XGB", "RF" ]

base_path = "/home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data"

for m_name in model_name:
    for p in percentage:
        for attack in attack_names:
            print(f"start {m_name} {p} {attack}")
            
            x_path = f"{base_path}/{m_name}_ActiveLearning/WUSTL_Input{p}/x_test_adv_{attack}_{Def}.npy"
            y_path = f"{base_path}/{m_name}_ActiveLearning/WUSTL_Input{p}/y_test_adv_{attack}_{Def}.npy"

            try:
                x_test_adv = np.load(x_path)
                y_test_adv = np.load(y_path)
                print(x_test_adv.shape, y_test_adv.shape)

                m_per_name = f"{m_name}{p}_ActiveLearning"
                calculate_performance_metrics(x_test_adv, y_test_adv, model, m_per_name, attack, epsilon)
            except FileNotFoundError:
                print(x_path, "not found")
                print_empty_file()
# Out:
# start XGB 100 baseline
# (11, 42) (11,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input100/x_test_adv_BIM_Def2.npy not found
# start XGB 100 FGSM
# (1, 42) (1,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 100 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input100/x_test_adv_PGD_Def2.npy not found
# start XGB 100 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input100/x_test_adv_DF_Def2.npy not found
# start XGB 100 AutoPGD
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (3, 42) (3,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 ZOO
# (31, 42) (31,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 CaFA
# (3, 42) (3,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 100 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input100/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 100 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input100/x_test_adv_VNIFGSM_Def2.npy not found
# start XGB 50 baseline
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (3, 42) (3,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input50/x_test_adv_BIM_Def2.npy not found
# start XGB 50 FGSM
# (1, 42) (1,)
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 50 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input50/x_test_adv_PGD_Def2.npy not found
# start XGB 50 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input50/x_test_adv_DF_Def2.npy not found
# start XGB 50 AutoPGD
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (3, 42) (3,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 ZOO
# (7, 42) (7,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input50/x_test_adv_CaFA_Def2.npy not found
# start XGB 50 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input50/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 50 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input50/x_test_adv_VNIFGSM_Def2.npy not found
# start XGB 20 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input20/x_test_adv_baseline_Def2.npy not found
# start XGB 20 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input20/x_test_adv_BIM_Def2.npy not found
# start XGB 20 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input20/x_test_adv_FGSM_Def2.npy not found
# start XGB 20 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input20/x_test_adv_PGD_Def2.npy not found
# start XGB 20 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input20/x_test_adv_DF_Def2.npy not found
# start XGB 20 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input20/x_test_adv_AutoPGD_Def2.npy not found
# start XGB 20 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input20/x_test_adv_ZOO_Def2.npy not found
# start XGB 20 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input20/x_test_adv_CaFA_Def2.npy not found
# start XGB 20 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input20/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 20 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input20/x_test_adv_VNIFGSM_Def2.npy not found
# start XGB 10 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input10/x_test_adv_baseline_Def2.npy not found
# start XGB 10 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input10/x_test_adv_BIM_Def2.npy not found
# start XGB 10 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input10/x_test_adv_FGSM_Def2.npy not found
# start XGB 10 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input10/x_test_adv_PGD_Def2.npy not found
# start XGB 10 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input10/x_test_adv_DF_Def2.npy not found
# start XGB 10 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input10/x_test_adv_AutoPGD_Def2.npy not found
# start XGB 10 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input10/x_test_adv_ZOO_Def2.npy not found
# start XGB 10 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input10/x_test_adv_CaFA_Def2.npy not found
# start XGB 10 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input10/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 10 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input10/x_test_adv_VNIFGSM_Def2.npy not found
# start XGB 1 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input1/x_test_adv_baseline_Def2.npy not found
# start XGB 1 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input1/x_test_adv_BIM_Def2.npy not found
# start XGB 1 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input1/x_test_adv_FGSM_Def2.npy not found
# start XGB 1 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input1/x_test_adv_PGD_Def2.npy not found
# start XGB 1 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input1/x_test_adv_DF_Def2.npy not found
# start XGB 1 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input1/x_test_adv_AutoPGD_Def2.npy not found
# start XGB 1 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input1/x_test_adv_ZOO_Def2.npy not found
# start XGB 1 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input1/x_test_adv_CaFA_Def2.npy not found
# start XGB 1 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input1/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 1 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning/WUSTL_Input1/x_test_adv_VNIFGSM_Def2.npy not found
# start RF 100 baseline
# (9, 42) (9,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input100/x_test_adv_BIM_Def2.npy not found
# start RF 100 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input100/x_test_adv_FGSM_Def2.npy not found
# start RF 100 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input100/x_test_adv_PGD_Def2.npy not found
# start RF 100 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input100/x_test_adv_DF_Def2.npy not found
# start RF 100 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input100/x_test_adv_AutoPGD_Def2.npy not found
# start RF 100 ZOO
# (27, 42) (27,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input100/x_test_adv_CaFA_Def2.npy not found
# start RF 100 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input100/x_test_adv_SINIFGSM_Def2.npy not found
# start RF 100 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input100/x_test_adv_VNIFGSM_Def2.npy not found
# start RF 50 baseline
# (2, 42) (2,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input50/x_test_adv_BIM_Def2.npy not found
# start RF 50 FGSM
# (2, 42) (2,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input50/x_test_adv_PGD_Def2.npy not found
# start RF 50 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input50/x_test_adv_DF_Def2.npy not found
# start RF 50 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input50/x_test_adv_AutoPGD_Def2.npy not found
# start RF 50 ZOO
# (6, 42) (6,)
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input50/x_test_adv_CaFA_Def2.npy not found
# start RF 50 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input50/x_test_adv_SINIFGSM_Def2.npy not found
# start RF 50 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input50/x_test_adv_VNIFGSM_Def2.npy not found
# start RF 20 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input20/x_test_adv_baseline_Def2.npy not found
# start RF 20 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input20/x_test_adv_BIM_Def2.npy not found
# start RF 20 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input20/x_test_adv_FGSM_Def2.npy not found
# start RF 20 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input20/x_test_adv_PGD_Def2.npy not found
# start RF 20 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input20/x_test_adv_DF_Def2.npy not found
# start RF 20 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input20/x_test_adv_AutoPGD_Def2.npy not found
# start RF 20 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input20/x_test_adv_ZOO_Def2.npy not found
# start RF 20 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input20/x_test_adv_CaFA_Def2.npy not found
# start RF 20 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input20/x_test_adv_SINIFGSM_Def2.npy not found
# start RF 20 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input20/x_test_adv_VNIFGSM_Def2.npy not found
# start RF 10 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input10/x_test_adv_baseline_Def2.npy not found
# start RF 10 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input10/x_test_adv_BIM_Def2.npy not found
# start RF 10 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input10/x_test_adv_FGSM_Def2.npy not found
# start RF 10 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input10/x_test_adv_PGD_Def2.npy not found
# start RF 10 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input10/x_test_adv_DF_Def2.npy not found
# start RF 10 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input10/x_test_adv_AutoPGD_Def2.npy not found
# start RF 10 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input10/x_test_adv_ZOO_Def2.npy not found
# start RF 10 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input10/x_test_adv_CaFA_Def2.npy not found
# start RF 10 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input10/x_test_adv_SINIFGSM_Def2.npy not found
# start RF 10 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input10/x_test_adv_VNIFGSM_Def2.npy not found
# start RF 1 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input1/x_test_adv_baseline_Def2.npy not found
# start RF 1 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input1/x_test_adv_BIM_Def2.npy not found
# start RF 1 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input1/x_test_adv_FGSM_Def2.npy not found
# start RF 1 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input1/x_test_adv_PGD_Def2.npy not found
# start RF 1 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input1/x_test_adv_DF_Def2.npy not found
# start RF 1 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input1/x_test_adv_AutoPGD_Def2.npy not found
# start RF 1 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input1/x_test_adv_ZOO_Def2.npy not found
# start RF 1 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input1/x_test_adv_CaFA_Def2.npy not found
# start RF 1 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input1/x_test_adv_SINIFGSM_Def2.npy not found
# start RF 1 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning/WUSTL_Input1/x_test_adv_VNIFGSM_Def2.npy not found

# %%
epsilon = 0

Def = "Def2"
attack_names = [
    "baseline", "BIM", "FGSM", "PGD", "DF",
    "AutoPGD", "ZOO", "CaFA", "SINIFGSM", "VNIFGSM"
]

percentage = ["100", "50", "20", "10", "1"]
model_name = ["XGB", "RF" ]
active_learning_name = ["DensityWeighted", "BatchMode"]

base_path = "/home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data"

for ac_name in active_learning_name:
    for m_name in model_name:
        for p in percentage:
            for attack in attack_names:
                print(f"start {m_name} {p} {attack}")
                
                x_path = f"{base_path}/{m_name}_ActiveLearning_{ac_name}/WUSTL_Input{p}/x_test_adv_{attack}_{Def}.npy"
                y_path = f"{base_path}/{m_name}_ActiveLearning_{ac_name}/WUSTL_Input{p}/y_test_adv_{attack}_{Def}.npy"
    
                try:
                    x_test_adv = np.load(x_path)
                    y_test_adv = np.load(y_path)
                    m_per_name = f"{m_name}{p}_ActiveLearning_{ac_name}"
                    calculate_performance_metrics(x_test_adv, y_test_adv, model, m_per_name, attack, epsilon)
                except FileNotFoundError:
                    print(x_path, "not found")
                    print_empty_file()
# Out:
# start XGB 100 baseline
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input100/x_test_adv_BIM_Def2.npy not found
# start XGB 100 FGSM
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 100 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input100/x_test_adv_PGD_Def2.npy not found
# start XGB 100 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input100/x_test_adv_DF_Def2.npy not found
# start XGB 100 AutoPGD
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 ZOO
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 CaFA
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 100 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input100/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 100 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input100/x_test_adv_VNIFGSM_Def2.npy not found
# start XGB 50 baseline
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input50/x_test_adv_BIM_Def2.npy not found
# start XGB 50 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input50/x_test_adv_FGSM_Def2.npy not found
# start XGB 50 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input50/x_test_adv_PGD_Def2.npy not found
# start XGB 50 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input50/x_test_adv_DF_Def2.npy not found
# start XGB 50 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input50/x_test_adv_AutoPGD_Def2.npy not found
# start XGB 50 ZOO
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input50/x_test_adv_CaFA_Def2.npy not found
# start XGB 50 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input50/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 50 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input50/x_test_adv_VNIFGSM_Def2.npy not found
# start XGB 20 baseline
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input20/x_test_adv_BIM_Def2.npy not found
# start XGB 20 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input20/x_test_adv_FGSM_Def2.npy not found
# start XGB 20 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input20/x_test_adv_PGD_Def2.npy not found
# start XGB 20 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input20/x_test_adv_DF_Def2.npy not found
# start XGB 20 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input20/x_test_adv_AutoPGD_Def2.npy not found
# start XGB 20 ZOO
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input20/x_test_adv_CaFA_Def2.npy not found
# start XGB 20 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input20/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 20 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input20/x_test_adv_VNIFGSM_Def2.npy not found
# start XGB 10 baseline
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input10/x_test_adv_baseline_Def2.npy not found
# start XGB 10 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input10/x_test_adv_BIM_Def2.npy not found
# start XGB 10 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input10/x_test_adv_FGSM_Def2.npy not found
# start XGB 10 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input10/x_test_adv_PGD_Def2.npy not found
# start XGB 10 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input10/x_test_adv_DF_Def2.npy not found
# start XGB 10 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input10/x_test_adv_AutoPGD_Def2.npy not found
# start XGB 10 ZOO
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input10/x_test_adv_ZOO_Def2.npy not found
# start XGB 10 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input10/x_test_adv_CaFA_Def2.npy not found
# start XGB 10 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input10/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 10 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input10/x_test_adv_VNIFGSM_Def2.npy not found
# start XGB 1 baseline
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 1 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input1/x_test_adv_BIM_Def2.npy not found
# start XGB 1 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input1/x_test_adv_FGSM_Def2.npy not found
# start XGB 1 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input1/x_test_adv_PGD_Def2.npy not found
# start XGB 1 DF
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 1 AutoPGD
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 1 ZOO
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 1 CaFA
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.018867924528301886
#
# macro
# Precision: 0.042222222222222223
# Recall: 0.32
# F1 Score: 0.06955329153605015
#
# weighted
# Precision: 0.0023680198208500098
# Recall: 0.018867924528301886
# F1 Score: 0.0037955802330395696
#
# start XGB 1 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input1/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 1 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_DensityWeighted/WUSTL_Input1/x_test_adv_VNIFGSM_Def2.npy not found
# start RF 100 baseline
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input100/x_test_adv_BIM_Def2.npy not found
# start RF 100 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input100/x_test_adv_FGSM_Def2.npy not found
# start RF 100 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input100/x_test_adv_PGD_Def2.npy not found
# start RF 100 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input100/x_test_adv_DF_Def2.npy not found
# start RF 100 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input100/x_test_adv_AutoPGD_Def2.npy not found
# start RF 100 ZOO
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input100/x_test_adv_CaFA_Def2.npy not found
# start RF 100 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input100/x_test_adv_SINIFGSM_Def2.npy not found
# start RF 100 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input100/x_test_adv_VNIFGSM_Def2.npy not found
# start RF 50 baseline
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input50/x_test_adv_BIM_Def2.npy not found
# start RF 50 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input50/x_test_adv_FGSM_Def2.npy not found
# start RF 50 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input50/x_test_adv_PGD_Def2.npy not found
# start RF 50 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input50/x_test_adv_DF_Def2.npy not found
# start RF 50 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input50/x_test_adv_AutoPGD_Def2.npy not found
# start RF 50 ZOO
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input50/x_test_adv_CaFA_Def2.npy not found
# start RF 50 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input50/x_test_adv_SINIFGSM_Def2.npy not found
# start RF 50 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input50/x_test_adv_VNIFGSM_Def2.npy not found
# start RF 20 baseline
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input20/x_test_adv_BIM_Def2.npy not found
# start RF 20 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input20/x_test_adv_FGSM_Def2.npy not found
# start RF 20 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input20/x_test_adv_PGD_Def2.npy not found
# start RF 20 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input20/x_test_adv_DF_Def2.npy not found
# start RF 20 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input20/x_test_adv_AutoPGD_Def2.npy not found
# start RF 20 ZOO
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input20/x_test_adv_CaFA_Def2.npy not found
# start RF 20 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input20/x_test_adv_SINIFGSM_Def2.npy not found
# start RF 20 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input20/x_test_adv_VNIFGSM_Def2.npy not found
# start RF 10 baseline
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 10 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input10/x_test_adv_BIM_Def2.npy not found
# start RF 10 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input10/x_test_adv_FGSM_Def2.npy not found
# start RF 10 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input10/x_test_adv_PGD_Def2.npy not found
# start RF 10 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input10/x_test_adv_DF_Def2.npy not found
# start RF 10 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input10/x_test_adv_AutoPGD_Def2.npy not found
# start RF 10 ZOO
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 10 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input10/x_test_adv_CaFA_Def2.npy not found
# start RF 10 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input10/x_test_adv_SINIFGSM_Def2.npy not found
# start RF 10 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input10/x_test_adv_VNIFGSM_Def2.npy not found
# start RF 1 baseline
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 1 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input1/x_test_adv_BIM_Def2.npy not found
# start RF 1 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input1/x_test_adv_FGSM_Def2.npy not found
# start RF 1 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input1/x_test_adv_PGD_Def2.npy not found
# start RF 1 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input1/x_test_adv_DF_Def2.npy not found
# start RF 1 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input1/x_test_adv_AutoPGD_Def2.npy not found
# start RF 1 ZOO
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 1 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input1/x_test_adv_CaFA_Def2.npy not found
# start RF 1 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input1/x_test_adv_SINIFGSM_Def2.npy not found
# start RF 1 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_DensityWeighted/WUSTL_Input1/x_test_adv_VNIFGSM_Def2.npy not found
# start XGB 100 baseline
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input100/x_test_adv_BIM_Def2.npy not found
# start XGB 100 FGSM
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 100 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input100/x_test_adv_PGD_Def2.npy not found
# start XGB 100 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input100/x_test_adv_DF_Def2.npy not found
# start XGB 100 AutoPGD
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 ZOO
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 100 CaFA
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 100 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input100/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 100 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input100/x_test_adv_VNIFGSM_Def2.npy not found
# start XGB 50 baseline
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input50/x_test_adv_BIM_Def2.npy not found
# start XGB 50 FGSM
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 50 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input50/x_test_adv_PGD_Def2.npy not found
# start XGB 50 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input50/x_test_adv_DF_Def2.npy not found
# start XGB 50 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input50/x_test_adv_AutoPGD_Def2.npy not found
# start XGB 50 ZOO
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 50 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input50/x_test_adv_CaFA_Def2.npy not found
# start XGB 50 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input50/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 50 VNIFGSM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 baseline
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input20/x_test_adv_BIM_Def2.npy not found
# start XGB 20 FGSM
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 20 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input20/x_test_adv_PGD_Def2.npy not found
# start XGB 20 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input20/x_test_adv_DF_Def2.npy not found
# start XGB 20 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input20/x_test_adv_AutoPGD_Def2.npy not found
# start XGB 20 ZOO
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 20 CaFA
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 20 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input20/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 20 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input20/x_test_adv_VNIFGSM_Def2.npy not found
# start XGB 10 baseline
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 10 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input10/x_test_adv_BIM_Def2.npy not found
# start XGB 10 FGSM
# Accuracy: 0.0
#
# macro
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# weighted
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# start XGB 10 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input10/x_test_adv_PGD_Def2.npy not found
# start XGB 10 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input10/x_test_adv_DF_Def2.npy not found
# start XGB 10 AutoPGD
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 10 ZOO
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 10 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input10/x_test_adv_CaFA_Def2.npy not found
# start XGB 10 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input10/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 10 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input10/x_test_adv_VNIFGSM_Def2.npy not found
# start XGB 1 baseline
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 1 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input1/x_test_adv_BIM_Def2.npy not found
# start XGB 1 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input1/x_test_adv_FGSM_Def2.npy not found
# start XGB 1 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input1/x_test_adv_PGD_Def2.npy not found
# start XGB 1 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input1/x_test_adv_DF_Def2.npy not found
# start XGB 1 AutoPGD
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 1 ZOO
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start XGB 1 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input1/x_test_adv_CaFA_Def2.npy not found
# start XGB 1 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/XGB_ActiveLearning_BatchMode/WUSTL_Input1/x_test_adv_SINIFGSM_Def2.npy not found
# start XGB 1 VNIFGSM
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 baseline
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input100/x_test_adv_BIM_Def2.npy not found
# start RF 100 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input100/x_test_adv_FGSM_Def2.npy not found
# start RF 100 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input100/x_test_adv_PGD_Def2.npy not found
# start RF 100 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input100/x_test_adv_DF_Def2.npy not found
# start RF 100 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input100/x_test_adv_AutoPGD_Def2.npy not found
# start RF 100 ZOO
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 100 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input100/x_test_adv_CaFA_Def2.npy not found
# start RF 100 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input100/x_test_adv_SINIFGSM_Def2.npy not found
# start RF 100 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input100/x_test_adv_VNIFGSM_Def2.npy not found
# start RF 50 baseline
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input50/x_test_adv_BIM_Def2.npy not found
# start RF 50 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input50/x_test_adv_FGSM_Def2.npy not found
# start RF 50 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input50/x_test_adv_PGD_Def2.npy not found
# start RF 50 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input50/x_test_adv_DF_Def2.npy not found
# start RF 50 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input50/x_test_adv_AutoPGD_Def2.npy not found
# start RF 50 ZOO
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 50 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input50/x_test_adv_CaFA_Def2.npy not found
# start RF 50 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input50/x_test_adv_SINIFGSM_Def2.npy not found
# start RF 50 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input50/x_test_adv_VNIFGSM_Def2.npy not found
# start RF 20 baseline
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input20/x_test_adv_BIM_Def2.npy not found
# start RF 20 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input20/x_test_adv_FGSM_Def2.npy not found
# start RF 20 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input20/x_test_adv_PGD_Def2.npy not found
# start RF 20 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input20/x_test_adv_DF_Def2.npy not found
# start RF 20 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input20/x_test_adv_AutoPGD_Def2.npy not found
# start RF 20 ZOO
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 20 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input20/x_test_adv_CaFA_Def2.npy not found
# start RF 20 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input20/x_test_adv_SINIFGSM_Def2.npy not found
# start RF 20 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input20/x_test_adv_VNIFGSM_Def2.npy not found
# start RF 10 baseline
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 10 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input10/x_test_adv_BIM_Def2.npy not found
# start RF 10 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input10/x_test_adv_FGSM_Def2.npy not found
# start RF 10 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input10/x_test_adv_PGD_Def2.npy not found
# start RF 10 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input10/x_test_adv_DF_Def2.npy not found
# start RF 10 AutoPGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input10/x_test_adv_AutoPGD_Def2.npy not found
# start RF 10 ZOO
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 10 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input10/x_test_adv_CaFA_Def2.npy not found
# start RF 10 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input10/x_test_adv_SINIFGSM_Def2.npy not found
# start RF 10 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input10/x_test_adv_VNIFGSM_Def2.npy not found
# start RF 1 baseline
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 1 BIM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input1/x_test_adv_BIM_Def2.npy not found
# start RF 1 FGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input1/x_test_adv_FGSM_Def2.npy not found
# start RF 1 PGD
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input1/x_test_adv_PGD_Def2.npy not found
# start RF 1 DF
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input1/x_test_adv_DF_Def2.npy not found
# start RF 1 AutoPGD
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 1 ZOO
# Accuracy: 1.0
#
# macro
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# weighted
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# start RF 1 CaFA
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input1/x_test_adv_CaFA_Def2.npy not found
# start RF 1 SINIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input1/x_test_adv_SINIFGSM_Def2.npy not found
# start RF 1 VNIFGSM
# /home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data/RF_ActiveLearning_BatchMode/WUSTL_Input1/x_test_adv_VNIFGSM_Def2.npy not found

# %%
epsilon = 0

Def = "Def2"
attack_names = [
    "baseline", "BIM", "FGSM", "PGD", "DF",
    "AutoPGD", "ZOO", "CaFA", "SINIFGSM", "VNIFGSM"
]

percentage = ["100", "50", "20", "10", "1"]
model_name = ["XGB", "RF"]

base_path = "/home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Dynamite_Selection_Data"
total_num_attack = ["EOAL", "EOAL_ExcludeCaFA", "EOAL_Exclude2Attack", "EOAL_Exclude3Attack"]
for num_attack in total_num_attack:
    for m_name in model_name:
        for p in percentage:
            for attack in attack_names:
                print(f"start {m_name} {p} {attack}")
                
                x_path = f"{base_path}/{m_name}_ActiveLearning_{num_attack}/WUSTL_Input{p}/x_test_adv_{attack}_{Def}.npy"
                y_path = f"{base_path}/{m_name}_ActiveLearning_{num_attack}/WUSTL_Input{p}/y_test_adv_{attack}_{Def}.npy"
    
                try:
                    x_test_adv = np.load(x_path)
                    y_test_adv = np.load(y_path)
                    m_per_name = f"{m_name}{p}_ActiveLearning_{num_attack}"
                    calculate_performance_metrics(x_test_adv, y_test_adv, model, m_per_name, attack, epsilon)
                except FileNotFoundError:
                    print(x_path, "not found")
                    print_empty_file()

# %%
# torch.save(model.state_dict(), "/home/jovyan/Sample_Based_Extension/WUSTL/WUSTL_Defense/Adversarial_Training/Adversarial_Training_interpolated.pt")

# %%
# import time

# epsilon_values = [0.01, 0.1, 0.2, 0.3]

# start_time = time.time()

# for epsilon in epsilon_values:
#     filename = f'/home/jovyan/Sample_Based_Extension/WUSTL/transfer_attack/x_test_adv_BIM_eps_{epsilon}.npy'
#     x_test_adv = np.load(filename)

#     calculate_performance_metrics(x_test_adv, y_test, model, 'DNN', 'BIM', epsilon)

# end_time = time.time()
# result = end_time - start_time
# print(f"Execution Time: {result:.6f} seconds")
